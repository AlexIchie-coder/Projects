# %%
import numpy as np
import pandas as pd

red_wine = pd.read_csv('winequality-red.csv', sep=';')

# %%
#import numpy as np
#import pandas as pd

white_wine = pd.read_csv('winequality-white.csv', sep=';')

# %%
pd.concat([red_wine.describe(), white_wine.describe()], axis=1, keys=["Red Wines Stats", "White Wines Stats"])
# Out:
#       Red Wines Stats                                               \
#         fixed acidity volatile acidity  citric acid residual sugar
# count     1599.000000      1599.000000  1599.000000    1599.000000
# mean         8.319637         0.527821     0.270976       2.538806
# std          1.741096         0.179060     0.194801       1.409928
# min          4.600000         0.120000     0.000000       0.900000
# 25%          7.100000         0.390000     0.090000       1.900000
# 50%          7.900000         0.520000     0.260000       2.200000
# 75%          9.200000         0.640000     0.420000       2.600000
# max         15.900000         1.580000     1.000000      15.500000
#
#                                                                           \
#          chlorides free sulfur dioxide total sulfur dioxide      density
# count  1599.000000         1599.000000          1599.000000  1599.000000
# mean      0.087467           15.874922            46.467792     0.996747
# ...

# %%
# we are creating a new column called "quality_label", we define a range and associate that range with a label
red_wine['quality_label'] = red_wine['quality'].apply(lambda value: 'low'
if value <= 5 else 'medium'
if value <= 7 else 'high')

#here we are transforming these labels into a categorical data type (specific to pandas) instead of a simple string
red_wine['quality_label'] = pd.Categorical(red_wine['quality_label'],
categories=['low', 'medium', 'high'])

red_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
print(red_wine)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
# we are creating a new column called "quality_label", we define a range and associate that range with a label
white_wine['quality_label'] = white_wine['quality'].apply(lambda value: 'low'
if value <= 5 else 'medium'
if value <= 7 else 'high')

#here we are transforming these labels into a categorical data type (specific to pandas) instead of a simple string
white_wine['quality_label'] = pd.Categorical(white_wine['quality_label'],
categories=['low', 'medium', 'high'])

white_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
print(white_wine)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
import matplotlib.pyplot as plt

import seaborn as sns

# %%
fig, pie_lst = plt.subplots(1)
fig.tight_layout()

labels = 'Red Wine', 'White Wine'
quality_count = [1599, 4898]

pie_lst.pie(quality_count, labels=labels, autopct='%1.0f%%')
pie_lst.set_title('Wine Quality')
# Out:
# Text(0.5, 1.0, 'Wine Quality')

# %%
fig, ax = plt.subplots(1,2, sharey=True)
#fig.tight_layout()
fig.suptitle('Distribution of Quality Score')


sns.histplot(red_wine['quality_label'],  ax=ax[0], color='red', shrink=0.7)
ax[0].set_title( 'Red Wine')
ax[1].set_title( 'White Wine')
sns.histplot(white_wine['quality_label'],  ax=ax[1], color='grey' , shrink=0.7)

# plt.xlabel('Quality Score')
# plt.ylabel('Frequency')
# plt.title('Distribution of Quality Scores') 
#äplt.xlabel('Quality Score')
# plt.ylabel('Frequency')
# plt.title('Distribution of Quality Scores
# Out:
# <Axes: title={'center': 'White Wine'}, xlabel='quality_label', ylabel='Count'>

# %%
fig, ax = plt.subplots(1,2)
fig.set_figwidth(12)
#fig.tight_layout()
fig.suptitle('White Wine Quality - Ahcohol Content/PH')

#ax[0].set_title( 'Red Wine')
sns.boxplot(white_wine,  ax=ax[0], x='quality_label', y="pH", hue='quality_label')
#ax[1].set_title( 'White Wine')
sns.boxplot(white_wine, ax=ax[1],x='quality_label' ,y='alcohol', hue='quality_label')
# Out:
# <Axes: xlabel='quality_label', ylabel='alcohol'>

# %%
fig, ax = plt.subplots(1,2)
fig.set_figwidth(12)
#fig.tight_layout()
fig.suptitle('Red Wine Quality - Ahcohol Content/PH')

#ax[0].set_title( 'Red Wine')
sns.boxplot(red_wine,  ax=ax[0], x='quality_label', y="pH", hue='quality_label')
#ax[1].set_title( 'Red Wine')
sns.boxplot(red_wine, ax=ax[1],x='quality_label' ,y='alcohol', hue='quality_label')
# Out:
# <Axes: xlabel='quality_label', ylabel='alcohol'>

# %%
numeric_colums =red_wine.select_dtypes(include=['float64', 'int64'])
corr_matrix = numeric_colums.corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', square=True, fmt='.1f')
plt.title('Correlation Matrix')
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
numeric_colums =white_wine.select_dtypes(include=['float64', 'int64'])
corr_matrix = numeric_colums.corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', square=True, fmt='.1f')
plt.title('Correlation Matrix')
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %% [markdown]
# Density and residual sugar are two crucial parameters in wine production and quality assessment.
#
# Residual Sugar:
# Measured in units of grams per liter (g/L) or grams per 100 milliliters (g/100mL)
# Refers to the amount of unfermented sugars remaining in the wine after fermentation
# Influenced by factors like grape variety, ripeness, fermentation conditions, and yeast strain
# Higher residual sugar levels typically indicate a sweeter wine, while lower levels indicate a drier wine
# Residual sugar can also affect the wine’s overall balance, with high levels potentially masking acidity and tannins
#
#
# Density:
#
# -Influenced by factors like grape variety, ripeness, fermentation conditions, and aging
#
# -Higher density typically indicates a wine with more solids and potentially more tannins and acidity
#
# -Lower density may indicate a wine with more water and potentially less tannins and acidity

# %% [markdown]
# Red Wine (Residual Sugar)
#
# -Residual sugar levels in red wine are not always directly correlated with perceived sweetness, as other factors like acidity, tannins, and fruit flavors influence the overall taste experience.
#
# -Dry red wines can still have some residual sugar, while sweet red wines may have very little.
#
# Red Wine (Density)
#
# -It’s worth noting that the density of wine can range from 980 to 1020 kg/m³, with red wines typically having a higher density due to their higher alcohol and tannin content.

# %%
# Create a figure with two subplots
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(8, 6))

sns.kdeplot(red_wine["residual sugar"], fill=True, ax=ax1)
ax1.set_xlabel("Residual Sugar")
ax1.set_ylabel("Density")
ax1.set_title("Red Wine - Density of Residual Sugar")

# Bottom subplot: Residual plot
sns.residplot(x="density", y="residual sugar", data=red_wine, ax=ax2)
ax2.set_xlabel("density")
ax2.set_ylabel("Residual")
ax2.set_title("Residual Plot")

plt.tight_layout()
plt.show()

# %% [markdown]
# White Wine (Residual Sugar)
#
# -Residual sugar levels in white wine vary significantly across styles and regions.(In Portugal)
#
# -Dry white wines typically have RS levels below 2 g/L, while off-dry and sweet wines have higher levels.
#
#
# White Wine (Density)
#
# -Density has a moderate impact on white wine quality. Higher density wines tend to have a richer mouthfeel and more full-bodied character, while lower density wines may appear lighter and more crisp.

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(8, 6))

sns.kdeplot(white_wine["residual sugar"], fill=True, ax=ax1)
ax1.set_xlabel("Residual Sugar")
ax1.set_ylabel("Density")
ax1.set_title("White Wine - Density of Residual Sugar")

# Bottom subplot: Residual plot
sns.residplot( x="density", y="residual sugar", data=white_wine, ax=ax2)
ax2.set_xlabel("density")
ax2.set_ylabel("Residual")
ax2.set_title("Residual Plot")

plt.tight_layout()
plt.show()

# %% [markdown]
# Free Sulfur Dioxide and pH in Red Wine:
#
# Free sulfur dioxide (FSO2) is a crucial component in wine making, particularly in red wine production, as it serves as a preservative to prevent oxidation and microbial spoilage. The pH of red wine typically ranges from 3.0 to 4.0, and the free SO2 concentration is dependent on this pH level. At lower pH levels, the molecular form of SO2 is more prevalent, which is more effective in protecting the wine.

# %% [markdown]
# Optimal Free Sulfur Dioxide Concentration:
# The optimal concentration of FSO2 in white wine can vary based on the wine’s pH. Generally, for white wines with a pH between 3.00 and 3.20, a free SO2 concentration of 0 to 20 mg/L is recommended. However, this can vary depending on factors such as the wine’s intended aging period and its susceptibility to oxidation and microbial spoilage.

# %% [markdown]
# Relationship between fixed acidity and density in Red Wines

# %% [markdown]
# Relationship between Alcohol and Quality in White Wines

# %%
fig, ax = plt.subplots(1,2,)
fig.set_figwidth(12)
#fig.tight_layout()
fig.suptitle('Red Wine Quality - Fixed Acidity Content/Density')

#ax[0].set_title( 'Red Wine')
sns.boxplot(red_wine,  ax=ax[0], x='density', hue='quality_label')
#ax[1].set_title( 'Red Wine')
sns.boxplot(red_wine, ax=ax[1],x='quality_label' ,y='fixed acidity', hue='quality_label')
# Out:
# <Axes: xlabel='quality_label', ylabel='fixed acidity'>

# %%
ig, ax = plt.subplots(1,2,)
#fig.set_figheight(100)
#fig.set_figwidth(100)
fig.tight_layout()
fig.suptitle('white Wine Quality - Fixed Acidity Content/Density')

#ax[0].set_title( 'Red Wine')
sns.boxplot(white_wine,  ax=ax[0], x='density', hue='quality_label')
#ax[1].set_title( 'Red Wine')
sns.boxplot(white_wine, ax=ax[1],x='quality_label', y='fixed acidity', hue='quality_label' )
# Out:
# <Axes: xlabel='quality_label', ylabel='fixed acidity'>

# %% [markdown]
# -The density of Portuguese red wines is generally around 0.981-0.986 g/cm³.
#
# -The alcohol content of Portuguese red wines typically ranges from 12% to 15% vol/vol.
#
# -Density decreases with increasing alcohol content.
# Varietal and regional differences may influence the density and alcohol profiles of Portuguese red wines.

# %%
sns.histplot(x=red_wine['density'], y=red_wine['alcohol'])
plt.title('Density vs. Alcohol Content')
plt.xlabel('Density (g/mL)')
plt.ylabel('Alcohol Content (%)')
plt.show()

# %% [markdown]
# -Portuguese white wines, particularly Vinho Verde, tend to have lower alcohol levels (9-11% abv) due to cooler climate, valley-grown grapes, and traditional production methods.
#
# -Indigenous grape varieties like Loureiro, Fernão Pires, and Arinto contribute to lower sugar concentrations and lower alcohol levels.
#
# -Regional differences and vineyard elevation can impact alcohol levels, with the Minho region producing wines with lower alcohol and the Douro region producing wines with a broader range of alcohol levels.

# %%
sns.histplot(x=white_wine['density'], y=white_wine['alcohol'])
plt.title('Density vs. Alcohol Content')
plt.xlabel('Density (g/mL)')
plt.ylabel('Alcohol Content (%)')
plt.show()

# %% [markdown]
# Red wines typically have higher acidity than white wines, with an average pH range of 3.5-4.0.
# Acidity in red wine helps balance the tannins and bitterness, making the wine more refreshing and food-friendly.
# High acidity can also enhance the fruit flavors and aromas in red wine.
# Some red grape varieties, such as Pinot Noir and Sangiovese, tend to have higher acidity than others, like Cabernet Sauvignon and Syrah/Shiraz.
#
#
#
# Residual sugar in red wine is generally lower than in white wine, with an average range of 0-10 grams per liter (g/L).
# Red wines with residual sugar levels above 10 g/L are considered sweet or off-dry, while those below 1 g/L are considered dry.
# Some red wine styles, such as Port and Vin Doux Naturel, intentionally have higher residual sugar levels to balance the sweetness and acidity.
# In general, residual sugar in red wine is more noticeable when the acidity is lower, as the sweetness can become more apparent.
#
#
#
#
# In red wine, residual sugar levels have an opposite effect on quality perception. As residual sugar increases, quality perception decreases.

# %%
#fig, ax = plt.subplots(1,2,)
#fig.set_figwidth(12)
#fig.tight_layout()
fig.suptitle('Red Wine Quality - Fixed Acidity Content/Density')

#ax[0].set_title( 'Red Wine')
sns.histplot(red_wine,   x='quality_label', hue='')
#ax[1].set_title( 'Red Wine')
#sns.boxplot(red_wine, ax=ax[1],x='quality_label' ,y='fixed acidity', hue='quality_label')
# Out:
# <Axes: xlabel='quality_label', ylabel='Count'>
