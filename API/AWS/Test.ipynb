# %%
import requests
from datetime import datetime
import bs4
import pandas as pd

def get_news_data(currency):
    url = f"https://u.today/search/node?keys={currency}"
    response = requests.get(url, timeout=10)
    soup = bs4.BeautifulSoup(response.text, 'html.parser')
    
    news_data = []
    for card in soup.select('div.news__item'):
        data = []
        date_element = card.select_one('div.news__item-head div.humble')
        if date_element:
            datestr = date_element.get_text().split(" - ")[0]
            try:
                data.append(datetime.strptime(datestr, "%b %d, %Y").date())
            except ValueError:
                continue  # Skip invalid dates
        
        title_element = card.select_one('div.news__item-title')
        if title_element:
            data.append(title_element.get_text())
        
        if len(data) == 2:
            news_data.append(tuple(data))
    
    df = pd.DataFrame(news_data, columns=['date', 'title'])
    df['currency'] = currency
    return df

get_news_data('BTC')
# Out:
#           date                                              title currency
# 0   2025-04-09  Michael Saylor Breaks Silence With One-Word Tw...      BTC
# 1   2025-04-09  Stellar (XLM) On Verge of Death Cross, Shiba I...      BTC
# 2   2025-04-08          ETH/BTC Somehow Keeps Plunging Even Lower      BTC
# 3   2025-04-08         Bitcoin (BTC) Price Prediction for April 8      BTC
# 4   2025-04-08  ‘Bitcoin Is Digital Gold’: Michael Saylor As B...      BTC
# 5   2025-04-07  Bitcoin (BTC) Confirms First Major "Death Cros...      BTC
# 6   2025-04-07                       ETH/BTC Collapses Below 0.02      BTC
# 7   2025-04-07  Is Bitcoin (BTC) Headed for $72,000? Dogecoin ...      BTC
# 8   2025-04-06  '$1 Million BTC' Advocate Mow Predicts China's...      BTC
# 9   2025-04-06  Bitcoin (BTC) Storm Approaching: Volatility Ge...      BTC
# 10  2025-04-06         Bitcoin (BTC) Price Prediction for April 6      BTC
# 11  2025-04-05  Bitcoin (BTC) in 'Make or Break' Mode as Black...      BTC
# 12  2025-04-05  Bitcoin (BTC) Is Better Buy Right Now: Billion...      BTC
# 13  2025-04-04            'Max Pain' Bitcoin (BTC) Price Revealed      BTC
# 14  2025-04-04         Bitcoin (BTC) Price Prediction for April 4      BTC
# 15  2025-04-04  Bitcoin Could Decouple From Crashing Stocks, ‘...      BTC
# 16  2025-04-04    Bitcoin (BTC) Pleasantly Surprises Peter Schiff      BTC
# 17  2025-04-04  Breaking: Bitcoin (BTC) Rapidly Adds $2,000, S...      BTC
# 18  2025-04-04  Bitcoin (BTC): Is $100,000 Ready? XRP Holds Ti...      BTC
# 19  2025-04-03  JPMorgan Issues Dire Bitcoin Warning as BTC Pr...      BTC
# 20  2025-04-03      Decade-Old 1,057 BTC Awaken: What's Going On?      BTC
# 21  2025-04-03   'There Are No Tariffs on Bitcoin': Saylor Stu...      BTC
# 22  2025-04-02  Mysterious $90 Million BTC Leaves Biggest Cryp...      BTC
# 23  2025-04-02  Strategy’s Saylor Flaunts 15,586 BTC Gain as B...      BTC
# 24  2025-04-02  $94 Million Bitcoin (BTC) Mystery Stuns Major ...      BTC
# 25  2025-04-02         Bitcoin (BTC) Price Prediction for April 2      BTC
# 26  2025-04-02  Michael Saylor Stuns With Bullish Call: ‘More ...      BTC
# 27  2025-04-02  Bitcoin (BTC) Controlled by Bears, But There's...      BTC
# 28  2025-04-02  Bitcoin (BTC) Price Sees Very Rare Golden and ...      BTC
# 29  2025-04-01  Bitcoin (BTC) Records Major Volume Reversal, X...      BTC
# 30  2025-03-31  Bitcoin (BTC) Outperforms Gold Amid Macro Unce...      BTC
# 31  2025-03-31  Michael Saylor's Strategy Loses $3 Billion in ...      BTC
# 32  2025-03-31  Bitcoin (BTC) 'Death Cross' Appears on Rare In...      BTC
# 33  2025-03-31  XRP Rapidly Diving Below $2, Bitcoin (BTC) on ...      BTC
# 34  2025-03-30        Bitcoin (BTC) Price Prediction for March 30      BTC
# 35  2025-03-30  Bitcoin (BTC) Finds Bottom? Key Indicator Hint...      BTC
# 36  2025-03-29  Bitcoin (BTC) Price to $72,000: Top Trader on ...      BTC
# 37  2025-03-29  Bitcoin (BTC) Bleeds, but Price History Says A...      BTC
# 38  2025-03-29  Bitcoin Shows Bear Trap, '$1 Million BTC' Sams...      BTC
# 39  2025-03-28  Fed's Key Inflation Measure Released; BTC, XRP...      BTC
# 40  2025-03-28  Bitcoin (BTC) Loses Crucial 200-Day Moving Ave...      BTC
# 41  2025-03-28          Schiff: Bitcoin (BTC) to Collapse to $10K      BTC
# 42  2025-03-28        Bitcoin (BTC) Price Prediction for March 28      BTC
# 43  2025-03-28  Bitcoin (BTC) Major Core Update: Key Changes R...      BTC
# 44  2025-03-28  Bitcoin (BTC) Faces Brutal Drop, Confirms Lege...      BTC
# 45  2025-03-28  Shiba Inu (SHIB): Bulls in Control Now? Bitcoi...      BTC
# 46  2025-03-27  XRP vs. Bitcoin (BTC): 3 Big Scenarios From Bo...      BTC
# 47  2025-03-27  Anti-Bitcoin Vanguard Will Be Inadvertently 'B...      BTC
# 48  2025-03-26  Bitcoin Whales With 10K BTC Holdings Increase ...      BTC
# 49  2025-03-26  Bitcoin up 700% Since Michael Saylor's Strateg...      BTC
# 50  2025-04-09  Backpack Exchange, Seamless Hub for Trading, L...      BTC
# 51  2025-04-01              Top Crypto Exchanges 2025: Full Guide      BTC
# 52  2025-02-02  Ripple v. SEC: How Will New Developments Affec...      BTC
# 53  2025-01-18          Stellar Lumen (XLM) Price Prediction 2025      BTC
# 54  2025-01-16  What is DeSci: Guide on Decentralized Science ...      BTC
