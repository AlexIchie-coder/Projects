# %%
import requests
import json
import pandas as pd

# %%
from api_key import my_api_key

# %%
from dotenv import load_dotenv
import os

load_dotenv()
api_key = os.getenv("API_KEY")

# %% [markdown]
# # Bitcoin

# %%
import requests

url = 'https://www.alphavantage.co/query?function=DIGITAL_CURRENCY_WEEKLY&symbol=BTC&market=EUR&apikey=api_key'
response_btc = requests.get(url)
response_btc
# Out:
# <Response [200]>

# %%
import json

status_code = response_btc.status_code
Bitcoin = response_btc.json()

print(json.dumps(Bitcoin, indent=2))
# Out:
# {
#   "Meta Data": {
#     "1. Information": "Weekly Prices and Volumes for Digital Currency",
#     "2. Digital Currency Code": "BTC",
#     "3. Digital Currency Name": "Bitcoin",
#     "4. Market Code": "EUR",
#     "5. Market Name": "Euro",
#     "6. Last Refreshed": "2025-03-31 00:00:00",
#     "7. Time Zone": "UTC"
#   },
#   "Time Series (Digital Currency Weekly)": {
#     "2025-03-31": {
#       "1. open": "76102.60000000",
#       "2. high": "76178.93000000",
#       "3. low": "75510.34000000",
#       "4. close": "75543.67000000",
#       "5. volume": "2.65307413"
#     },
#     "2025-03-30": {
#       "1. open": "79441.34000000",
#       "2. high": "82091.43000000",
#       "3. low": "75432.48000000",
#       "4. close": "76135.85000000",
#       "5. volume": "2003.05822813"
#     },
#     "2025-03-23": {
#       "1. open": "75935.10000000",
#       "2. high": "80150.77000000",
#       "3. low": "74226.31000000",
#       "4. close": "79452.90000000",
#       "5. volume": "2004.67925658"
#     },
#     "2025-03-16": {
#       "1. open": "74334.78000000",
#       "2. high": "78476.10000000",
#       "3. low": "70570.00000000",
#       "4. close": "75928.62000000",
#       "5. volume": "3317.85059693"
#     },
#     "2025-03-09": {
#       "1. open": "90634.87000000",
#       "2. high": "90798.09000000",
#       "3. low": "73680.00000000",
#       "4. close": "74310.03000000",
#       "5. volume": "4567.15724730"
#     },
#     "2025-03-02": {
#       "1. open": "91900.51000000",
#       "2. high": "92078.26000000",
#       "3. low": "75141.16000000",
#       "4. close": "90642.23000000",
#       "5. volume": "5817.43954029"
#     },
#     "2025-02-23": {
#       "1. open": "91620.25000000",
#       "2. high": "94977.61000000",
#       "3. low": "89368.01000000",
#       "4. close": "91874.60000000",
#       "5. volume": "1663.37913607"
#     },
#     "2025-02-16": {
#       "1. open": "93636.05000000",
#       "2. high": "95586.34000000",
#       "3. low": "91150.00000000",
#       "4. close": "91634.19000000",
#       "5. volume": "1897.10832421"
#     },
#     "2025-02-09": {
#       "1. open": "95431.64000000",
#       "2. high": "99421.84000000",
#       "3. low": "89248.90000000",
#       "4. close": "93607.15000000",
#       "5. volume": "3166.38457836"
#     },
#     "2025-02-02": {
#       "1. open": "98050.00000000",
#       "2. high": "102000.00000000",
#       "3. low": "93414.78000000",
#       "4. close": "95427.29000000",
#       "5. volume": "2910.03861451"
#     },
#     "2025-01-26": {
#       "1. open": "98539.45000000",
#       "2. high": "105951.19000000",
#       "3. low": "96436.00000000",
#       "4. close": "98088.57000000",
#       "5. volume": "3658.55695193"
#     },
#     "2025-01-19": {
#   '2. high': '78476.10000000',
#   '3. low': '70570.00000000',
#   '4. close': '75928.62000000',
#   '5. volume': '3317.85059693'},
#  '2025-03-09': {'1. open': '90634.87000000',
#   '2. high': '90798.09000000',
#   '3. low': '73680.00000000',
#   '4. close': '74310.03000000',
#   '5. volume': '4567.15724730'},
#  '2025-03-02': {'1. open': '91900.51000000',
#   '2. high': '92078.26000000',
#   '3. low': '75141.16000000',
#   '4. close': '90642.23000000',
#   '5. volume': '5817.43954029'},
#  '2025-02-23': {'1. open': '91620.25000000',
#   '2. high': '94977.61000000',
#   '3. low': '89368.01000000',
#   '4. close': '91874.60000000',
#   '5. volume': '1663.37913607'},
#  '2025-02-16': {'1. open': '93636.05000000',
#   '2. high': '95586.34000000',
#   '3. low': '91150.00000000',
#   '4. close': '91634.19000000',
#   '5. volume': '1897.10832421'},
#  '2025-02-09': {'1. open': '95431.64000000',
#   '2. high': '99421.84000000',
#   '3. low': '89248.90000000',
#   '4. close': '93607.15000000',
#   '5. volume': '3166.38457836'},
#  '2025-02-02': {'1. open': '98050.00000000',
#   '2. high': '102000.00000000',
#   '3. low': '93414.78000000',
#   '4. close': '95427.29000000',
#   '5. volume': '2910.03861451'},
#  '2025-01-26': {'1. open': '98539.45000000',
#   '2. high': '105951.19000000',
#   '3. low': '96436.00000000',
#   '4. close': '98088.57000000',
#   '5. volume': '3658.55695193'},
#  '2025-01-19': {'1. open': '92284.22000000',
#   '2. high': '103599.98000000',
#   '3. low': '87437.71000000',
#   '4. close': '98574.14000000',
#   '5. volume': '3343.99758658'},
#  '2025-01-12': {'1. open': '95456.12000000',
#   '2. high': '98960.78000000',
#   '3. low': '88606.32000000',
#   '4. close': '92337.55000000',
#   '5. volume': '2445.36645429'},
#  '2025-01-05': {'1. open': '89692.71000000',
#   '2. high': '96143.44000000',
#   '3. low': '87834.22000000',
#   '4. close': '95451.75000000',
#   '5. volume': '2005.55539841'},
#  '2024-12-29': {'1. open': '91182.16000000',
#   '2. high': '96129.98000000',
#   '3. low': '88832.59000000',
#   '4. close': '89702.09000000',
#   '5. volume': '2344.01826091'},
#  '2024-12-22': {'1. open': '99120.98000000',
#   '2. high': '103000.00000000',
#   '3. low': '88421.18000000',
#   '4. close': '91204.69000000',
#   '5. volume': '4072.70477282'},
#  '2024-12-15': {'1. open': '95662.16000000',
#   '2. high': '99800.00000000',
#   '3. low': '89217.53000000',
#   '4. close': '99111.37000000',
#   '5. volume': '2699.63992449'},
#  '2024-12-08': {'1. open': '92096.25000000',
#   '2. high': '98456.03000000',
#   '3. low': '86600.00000000',
#   '4. close': '95685.97000000',
#   '5. volume': '3394.00176391'},
#  '2024-12-01': {'1. open': '93388.13000000',
#   '2. high': '94400.00000000',
#   '3. low': '86543.90000000',
#   '4. close': '92099.58000000',
#   '5. volume': '3804.20978625'},
#  '2024-11-24': {'1. open': '85046.28000000',
#   '2. high': '95501.25000000',
#   '3. low': '84594.12000000',
#   '4. close': '93391.61000000',
#   '5. volume': '5630.82466588'},
#  '2024-11-17': {'1. open': '74780.73000000',
#   '2. high': '88000.00000000',
#   '3. low': '74639.10000000',
#   '4. close': '85016.99000000',
#   '5. volume': '6663.35849385'},
#  '2024-11-10': {'1. open': '63408.26000000',
#   '2. high': '75699.99000000',
#   '3. low': '61410.68000000',
#   '4. close': '74757.19000000',
#   '5. volume': '3545.72577803'},
#  '2024-11-03': {'1. open': '62928.68000000',
#   '2. high': '68000.00000000',
#   '3. low': '62351.09000000',
#   '4. close': '63426.11000000',
#   '5. volume': '2261.17772077'},
#  '2024-10-27': {'1. open': '63445.78000000',
#   '2. high': '63900.00000000',
#   '3. low': '60465.00000000',
#   '4. close': '62928.34000000',
#   '5. volume': '1786.10966199'},
#  '2024-10-20': {'1. open': '57516.93000000',
#   '2. high': '63779.18000000',
#   '3. low': '57148.57000000',
#   '4. close': '63433.63000000',
#   '5. volume': '2063.91962502'},
#  '2024-10-13': {'1. open': '57256.48000000',
#   '2. high': '58723.00000000',
#   '3. low': '53904.09000000',
#   '4. close': '57519.27000000',
#   '5. volume': '1245.49032033'},
#  '2024-10-06': {'1. open': '58752.02000000',
#   '2. high': '58757.86000000',
#   '3. low': '54237.15000000',
#   '4. close': '57248.79000000',
#   '5. volume': '1637.16110423'},
#  '2024-09-29': {'1. open': '56988.75000000',
#   '2. high': '59528.74000000',
#   '3. low': '56080.15000000',
#   '4. close': '58742.25000000',
#   '5. volume': '1390.31440855'},
#  '2024-09-22': {'1. open': '53320.98000000',
#   '2. high': '57414.44000000',
#   '3. low': '51650.17000000',
#   '4. close': '57001.09000000',
#   '5. volume': '1655.13071181'},
#  '2024-09-15': {'1. open': '49526.79000000',
#   '2. high': '54781.85000000',
#   '3. low': '49315.32000000',
#   '4. close': '53343.95000000',
#   '5. volume': '1707.00085554'},
#  '2024-09-08': {'1. open': '51911.95000000',
#   '2. high': '54065.45000000',
#   '3. low': '47428.66000000',
#   '4. close': '49505.02000000',
#   '5. volume': '2198.29055177'},
#  '2024-09-01': {'1. open': '57406.50000000',
#   '2. high': '57632.29000000',
#   '3. low': '51802.75000000',
#   '4. close': '51931.36000000',
#   '5. volume': '1877.16287658'},
#  '2024-08-25': {'1. open': '53049.34000000',
#   '2. high': '58113.94000000',
#   '3. low': '52408.27000000',
#   '4. close': '57402.19000000',
#   '5. volume': '2010.86924833'},
#  '2024-08-18': {'1. open': '53822.14000000',
#   '2. high': '56141.89000000',
#   '3. low': '51195.03000000',
#   '4. close': '53046.89000000',
#   '5. volume': '1836.96086527'},
#  '2024-08-11': {'1. open': '53330.01000000',
#   '2. high': '57499.00000000',
#   '3. low': '45021.36000000',
#   '4. close': '53835.66000000',
#   '5. volume': '5859.41666575'},
#  '2024-08-04': {'1. open': '62866.50000000',
#   '2. high': '64749.00000000',
#   '3. low': '52521.27000000',
#   '4. close': '53309.69000000',
#   '5. volume': '3522.97605496'},
#  '2024-07-28': {'1. open': '62526.97000000',
#   '2. high': '63876.72000000',
#   '3. low': '58512.00000000',
#   '4. close': '62854.02000000',
#   '5. volume': '1840.76222947'},
#  '2024-07-21': {'1. open': '55876.94000000',
#   '2. high': '62721.17000000',
#   '3. low': '55750.00000000',
#   '4. close': '62529.01000000',
#   '5. volume': '2216.33637267'},
#  '2024-07-14': {'1. open': '51589.15000000',
#   '2. high': '56400.63000000',
#   '3. low': '50144.21000000',
#   '4. close': '55876.86000000',
#   '5. volume': '5468.18414888'},
#  '2024-07-07': {'1. open': '58416.69000000',
#   '2. high': '59467.74000000',
#   '3. low': '49437.20000000',
#   '4. close': '51589.15000000',
#   '5. volume': '3660.07676506'},
#  '2024-06-30': {'1. open': '59127.81000000',
#   '2. high': '59261.30000000',
#   '3. low': '54419.19000000',
#   '4. close': '58407.41000000',
#   '5. volume': '2451.79270208'},
#  '2024-06-23': {'1. open': '62279.16000000',
#   '2. high': '62696.68000000',
#   '3. low': '59085.16000000',
#   '4. close': '59107.12000000',
#   '5. volume': '1526.55665651'},
#  '2024-06-16': {'1. open': '64664.14000000',
#   '2. high': '65298.24000000',
#   '3. low': '60801.06000000',
#   '4. close': '62262.17000000',
#   '5. volume': '1826.63665226'},
#  '2024-06-09': {'1. open': '62428.48000000',
#   '2. high': '66132.47000000',
#   '3. low': '62283.90000000',
#   '4. close': '64648.18000000',
#   '5. volume': '1890.77051357'},
#  '2024-06-02': {'1. open': '63145.80000000',
#   '2. high': '64989.91000000',
#   '3. low': '61440.00000000',
#   '4. close': '62452.47000000',
#   '5. volume': '1558.52996222'},
#  '2024-05-26': {'1. open': '60930.51000000',
#   '2. high': '65933.02000000',
#   '3. low': '60750.00000000',
#   '4. close': '63138.93000000',
#   '5. volume': '2469.25527144'},
#  '2024-05-19': {'1. open': '57085.97000000',
#   '2. high': '62261.43000000',
#   '3. low': '56418.03000000',
#   '4. close': '60927.75000000',
#   '5. volume': '2144.93191604'},
#  '2024-05-12': {'1. open': '59515.05000000',
#   '2. high': '60834.00000000',
#   '3. low': '55876.05000000',
#   '4. close': '57075.98000000',
#   '5. volume': '2126.96316157'},
#  '2024-05-05': {'1. open': '58965.50000000',
#   '2. high': '60365.57000000',
#   '3. low': '52943.49000000',
#   '4. close': '59506.98000000',
#   '5. volume': '4178.03884138'},
#  '2024-04-28': {'1. open': '60985.08000000',
#   '2. high': '63134.63000000',
#   '3. low': '58411.49000000',
#   '4. close': '58947.56000000',
#   '5. volume': '2398.39662537'}}

# %%
for x, obj in Bitcoin.items():
    print(x)
    
    for y in obj:
        print(y + ':', obj[y])
# Out:
# Meta Data
# 1. Information: Weekly Prices and Volumes for Digital Currency
# 2. Digital Currency Code: BTC
# 3. Digital Currency Name: Bitcoin
# 4. Market Code: EUR
# 5. Market Name: Euro
# 6. Last Refreshed: 2025-03-31 00:00:00
# 7. Time Zone: UTC
# Time Series (Digital Currency Weekly)
# 2025-03-31: {'1. open': '76102.60000000', '2. high': '76178.93000000', '3. low': '75510.34000000', '4. close': '75543.67000000', '5. volume': '2.65307413'}
# 2025-03-30: {'1. open': '79441.34000000', '2. high': '82091.43000000', '3. low': '75432.48000000', '4. close': '76135.85000000', '5. volume': '2003.05822813'}
# 2024-06-23: {'1. open': '62279.16000000', '2. high': '62696.68000000', '3. low': '59085.16000000', '4. close': '59107.12000000', '5. volume': '1526.55665651'}
# 2024-06-16: {'1. open': '64664.14000000', '2. high': '65298.24000000', '3. low': '60801.06000000', '4. close': '62262.17000000', '5. volume': '1826.63665226'}
# 2024-06-09: {'1. open': '62428.48000000', '2. high': '66132.47000000', '3. low': '62283.90000000', '4. close': '64648.18000000', '5. volume': '1890.77051357'}
# 2024-06-02: {'1. open': '63145.80000000', '2. high': '64989.91000000', '3. low': '61440.00000000', '4. close': '62452.47000000', '5. volume': '1558.52996222'}
# 2024-05-26: {'1. open': '60930.51000000', '2. high': '65933.02000000', '3. low': '60750.00000000', '4. close': '63138.93000000', '5. volume': '2469.25527144'}
# 2024-05-19: {'1. open': '57085.97000000', '2. high': '62261.43000000', '3. low': '56418.03000000', '4. close': '60927.75000000', '5. volume': '2144.93191604'}
# 2024-05-12: {'1. open': '59515.05000000', '2. high': '60834.00000000', '3. low': '55876.05000000', '4. close': '57075.98000000', '5. volume': '2126.96316157'}
# 2024-05-05: {'1. open': '58965.50000000', '2. high': '60365.57000000', '3. low': '52943.49000000', '4. close': '59506.98000000', '5. volume': '4178.03884138'}
# 2024-04-28: {'1. open': '60985.08000000', '2. high': '63134.63000000', '3. low': '58411.49000000', '4. close': '58947.56000000', '5. volume': '2398.39662537'}

# %%
import json
import pandas as pd

# Assuming response_btc is your API response
status_code = response_btc.status_code
data = response_btc.json()

# Print the raw data to understand its structure (debugging)
print(json.dumps(data, indent=2))

# Initialize lists to store data
dates = []
opens = []
highs = []
lows = []
closes = []
volumes = []

# Extract metadata
meta_data = data.get("Meta Data", {})
digital_currency_name = meta_data.get("Digital Currency Name", "Bitcoin")

# Extract time series data
time_series_key = "Time Series (Digital Currency Weekly)"
time_series = data.get(time_series_key, {})

for date_str, values in time_series.items():
    dates.append(date_str)
    opens.append(float(values.get("1. open", 0)))
    highs.append(float(values.get("2. high", 0)))
    lows.append(float(values.get("3. low", 0)))
    closes.append(float(values.get("4. close", 0)))
    volumes.append(float(values.get("5. volume", 0)))

# Create DataFrame
BitcoinDF = pd.DataFrame({
    "date": dates,
    "open": opens,
    "high": highs,
    "low": lows,
    "close": closes,
    "volume": volumes,
    "currency_name": digital_currency_name
})

# Convert date column to datetime and sort
BitcoinDF['date'] = pd.to_datetime(BitcoinDF['date'])
BitcoinDF = BitcoinDF.sort_values('date', ascending=False)

# Display the DataFrame
print(BitcoinDF.head())

# Optional: Save to CSV
BitcoinDF.to_csv('Bitcoin_Weekly_Prices.csv', index=False)
# Out:
# {
#   "Meta Data": {
#     "1. Information": "Weekly Prices and Volumes for Digital Currency",
#     "2. Digital Currency Code": "BTC",
#     "3. Digital Currency Name": "Bitcoin",
#     "4. Market Code": "EUR",
#     "5. Market Name": "Euro",
#     "6. Last Refreshed": "2025-03-31 00:00:00",
#     "7. Time Zone": "UTC"
#   },
#   "Time Series (Digital Currency Weekly)": {
#       "4. close": "3440.31000000",
#       "5. volume": "19138.04014213"
#     },
#     "2024-06-02": {
#       "1. open": "3526.77000000",
#       "2. high": "3658.41000000",
#       "3. low": "3424.17000000",
#       "4. close": "3484.69000000",
#       "5. volume": "20890.42698352"
#     },
#     "2024-05-26": {
#       "1. open": "2823.87000000",
#       "2. high": "3636.98000000",
#       "3. low": "2802.80000000",
#       "4. close": "3526.15000000",
#       "5. volume": "41926.94799782"
#     },
#     "2024-05-19": {
#       "1. open": "2721.16000000",
#       "2. high": "2896.11000000",
#       "3. low": "2644.76000000",
#       "4. close": "2823.47000000",
#       "5. volume": "24141.81977669"
#     },
#     "2024-05-12": {
#       "1. open": "2915.58000000",
#       "2. high": "2990.50000000",
#       "3. low": "2673.14000000",
#       "4. close": "2719.32000000",
#       "5. volume": "19954.11023420"
#     },
#     "2024-05-05": {
#       "1. open": "3047.27000000",
#       "2. high": "3068.73000000",
#       "3. low": "2636.70000000",
#       "4. close": "2915.95000000",
#       "5. volume": "32549.15746624"
#     },
#     "2024-04-28": {
#       "1. open": "2955.71000000",
#       "2. high": "3140.31000000",
#       "3. low": "2865.00000000",
#       "4. close": "3047.19000000",
#       "5. volume": "22462.60494444"
#     }
#   }
# }

# %%
import json
import pandas as pd

# Assuming response_btc is your API response
status_code = response_eth.status_code
Ethereum = response_eth.json()

# Print the raw data to understand its structure (debugging)
print(json.dumps(Ethereum, indent=2))

# Initialize lists to store data
dates = []
opens = []
highs = []
lows = []
closes = []
volumes = []

# Extract metadata
meta_data = data.get("Meta Data", {})
digital_currency_name = meta_data.get("Digital Currency Name", "Ethereum")

# Extract time series data
time_series_key = "Time Series (Digital Currency Weekly)"
time_series = data.get(time_series_key, {})

for date_str, values in time_series.items():
    dates.append(date_str)
    opens.append(float(values.get("1. open", 0)))
    highs.append(float(values.get("2. high", 0)))
    lows.append(float(values.get("3. low", 0)))
    closes.append(float(values.get("4. close", 0)))
    volumes.append(float(values.get("5. volume", 0)))

# Create DataFrame
Ethereum = pd.DataFrame({
    "date": dates,
    "open": opens,
    "high": highs,
    "low": lows,
    "close": closes,
    "volume": volumes,
    "currency_name": digital_currency_name
})

# Convert date column to datetime and sort
Ethereum['date'] = pd.to_datetime(Ethereum['date'])
Ethereum = Ethereum.sort_values('date', ascending=False)

# Display the DataFrame
print(Ethereum.head())

# Optional: Save to CSV
Ethereum.to_csv('Ethereum_Weekly_Prices.csv', index=False)
# Out:
# {
#   "Meta Data": {
#     "1. Information": "Weekly Prices and Volumes for Digital Currency",
#     "2. Digital Currency Code": "ETH",
#     "3. Digital Currency Name": "Ethereum",
#     "4. Market Code": "EUR",
#     "5. Market Name": "Euro",
#     "6. Last Refreshed": "2025-03-31 00:00:00",
#     "7. Time Zone": "UTC"
#   },
#   "Time Series (Digital Currency Weekly)": {
#     "2025-03-31": {
#       "1. open": "1670.57000000",
#       "2. high": "1674.29000000",
#       "3. low": "1641.05000000",
#       "4. close": "1646.74000000",
#       "5. volume": "581.69363887"
#     },
#     "2025-03-30": {
# 29 2024-09-15  49526.79   54781.85  49315.32  53343.95  1707.000856
# 30 2024-09-08  51911.95   54065.45  47428.66  49505.02  2198.290552
# 31 2024-09-01  57406.50   57632.29  51802.75  51931.36  1877.162877
# 32 2024-08-25  53049.34   58113.94  52408.27  57402.19  2010.869248
# 33 2024-08-18  53822.14   56141.89  51195.03  53046.89  1836.960865
# 34 2024-08-11  53330.01   57499.00  45021.36  53835.66  5859.416666
# 35 2024-08-04  62866.50   64749.00  52521.27  53309.69  3522.976055
# 36 2024-07-28  62526.97   63876.72  58512.00  62854.02  1840.762229
# 37 2024-07-21  55876.94   62721.17  55750.00  62529.01  2216.336373
# 38 2024-07-14  51589.15   56400.63  50144.21  55876.86  5468.184149
# 39 2024-07-07  58416.69   59467.74  49437.20  51589.15  3660.076765
# 40 2024-06-30  59127.81   59261.30  54419.19  58407.41  2451.792702
# 41 2024-06-23  62279.16   62696.68  59085.16  59107.12  1526.556657
# 42 2024-06-16  64664.14   65298.24  60801.06  62262.17  1826.636652
# 43 2024-06-09  62428.48   66132.47  62283.90  64648.18  1890.770514
# 44 2024-06-02  63145.80   64989.91  61440.00  62452.47  1558.529962
# 45 2024-05-26  60930.51   65933.02  60750.00  63138.93  2469.255271
# 46 2024-05-19  57085.97   62261.43  56418.03  60927.75  2144.931916
# 47 2024-05-12  59515.05   60834.00  55876.05  57075.98  2126.963162
# 48 2024-05-05  58965.50   60365.57  52943.49  59506.98  4178.038841
# 49 2024-04-28  60985.08   63134.63  58411.49  58947.56  2398.396625
#
#    currency_name
# 0       Ethereum
# 1       Ethereum
# 2       Ethereum
# 3       Ethereum
# 4       Ethereum
# 5       Ethereum
# 6       Ethereum
# 7       Ethereum
# 8       Ethereum
# 9       Ethereum
# 10      Ethereum
# 11      Ethereum
# 12      Ethereum
# 13      Ethereum
# 14      Ethereum
# 15      Ethereum
# 16      Ethereum
# 17      Ethereum
# 18      Ethereum
# 19      Ethereum
# 20      Ethereum
# 21      Ethereum
# 22      Ethereum
# 23      Ethereum
# 24      Ethereum
# 25      Ethereum
# 26      Ethereum
# 27      Ethereum
# 28      Ethereum
# 29      Ethereum
# 30      Ethereum
# 31      Ethereum
# 32      Ethereum
# 33      Ethereum
# 34      Ethereum
# 35      Ethereum
# 36      Ethereum
# 37      Ethereum
# 38      Ethereum
# 39      Ethereum
# 40      Ethereum
# 41      Ethereum
# 42      Ethereum
# 43      Ethereum
# 44      Ethereum
# 45      Ethereum
# 46      Ethereum
# 47      Ethereum
# 48      Ethereum
# 49      Ethereum

# %% [markdown]
# # Solana

# %%
import requests

url = 'https://www.alphavantage.co/query?function=DIGITAL_CURRENCY_WEEKLY&symbol=SOL&market=EUR&apikey=api_key'
response_sol = requests.get(url)
response_sol
# Out:
# <Response [200]>

# %%
import json

status_code = response_sol.status_code
Solana = response_sol.json()

print(json.dumps(Solana, indent=2))
# Out:
# {
#   "Meta Data": {
#     "1. Information": "Weekly Prices and Volumes for Digital Currency",
#     "2. Digital Currency Code": "SOL",
#     "3. Digital Currency Name": "Solana",
#       "2. high": "138.65000000",
#       "3. low": "111.27000000",
#       "4. close": "135.49000000",
#       "5. volume": "365208.75200000"
#     },
#     "2024-04-28": {
#       "1. open": "139.77000000",
#       "2. high": "149.56000000",
#       "3. low": "124.47000000",
#       "4. close": "128.87000000",
#       "5. volume": "317097.18100000"
#     }
#   }
# }

# %%
import json
import pandas as pd

# Assuming response_btc is your API response
status_code = response_sol.status_code
Solana = response_eth.json()

# Print the raw data to understand its structure (debugging)
print(json.dumps(Solana, indent=2))

# Initialize lists to store data
dates = []
opens = []
highs = []
lows = []
closes = []
volumes = []

# Extract metadata
meta_data = data.get("Meta Data", {})
digital_currency_name = meta_data.get("Digital Currency Name", "Solana")

# Extract time series data
time_series_key = "Time Series (Digital Currency Weekly)"
time_series = data.get(time_series_key, {})

for date_str, values in time_series.items():
    dates.append(date_str)
    opens.append(float(values.get("1. open", 0)))
    highs.append(float(values.get("2. high", 0)))
    lows.append(float(values.get("3. low", 0)))
    closes.append(float(values.get("4. close", 0)))
    volumes.append(float(values.get("5. volume", 0)))

# Create DataFrame
Solana = pd.DataFrame({
    "date": dates,
    "open": opens,
    "high": highs,
    "low": lows,
    "close": closes,
    "volume": volumes,
    "currency_name": digital_currency_name
})

# Convert date column to datetime and sort
Solana['date'] = pd.to_datetime(Solana['date'])
Solana = Solana.sort_values('date', ascending=False)

# Display the DataFrame
print(Solana.head())

# Optional: Save to CSV
Solana.to_csv('Solana_Weekly_Data.csv', index=False)
# Out:
# {
#   "Meta Data": {
#     "1. Information": "Weekly Prices and Volumes for Digital Currency",
#     "2. Digital Currency Code": "ETH",
#     "3. Digital Currency Name": "Ethereum",
#     "4. Market Code": "EUR",
#     "5. Market Name": "Euro",
#     "6. Last Refreshed": "2025-03-31 00:00:00",
#     "7. Time Zone": "UTC"
#   },
#   "Time Series (Digital Currency Weekly)": {
#     "2025-03-31": {
#       "1. open": "1670.57000000",
#       "2. high": "1674.29000000",
#       "3. low": "1641.05000000",
#       "4. close": "1646.74000000",
#       "5. volume": "581.69363887"
#     },
#     "2025-03-30": {
#       "1. open": "1849.23000000",
#       "2. high": "1945.20000000",
#       "3. low": "1635.00000000",
#       "4. close": "1669.86000000",
#       "5. volume": "64432.13343915"
#     },
#     "2025-03-23": {
#       "1. open": "1735.03000000",
#       "2. high": "1898.07000000",
#       "3. low": "1710.92000000",
#       "4. close": "1849.98000000",
#       "5. volume": "49409.12563792"
#     },
#     "2025-03-16": {
#       "1. open": "1860.63000000",
#       "2. high": "1985.93000000",
#       "3. low": "1616.86000000",
#       "4. close": "1735.26000000",
#       "5. volume": "95653.82797713"
#     },
#     "2025-03-09": {
#       "1. open": "2421.48000000",
#       "2. high": "2426.40000000",
#       "3. low": "1832.78000000",
#       "4. close": "1859.68000000",
#       "5. volume": "92640.20045031"
#     },
#     "2025-03-02": {
#       "1. open": "2691.28000000",
#       "2. high": "2708.39000000",
#       "3. low": "1994.22000000",
#       "4. close": "2421.03000000",
#       "5. volume": "109277.77896004"
#     },
# 42 2024-06-16  64664.14   65298.24  60801.06  62262.17  1826.636652
# 43 2024-06-09  62428.48   66132.47  62283.90  64648.18  1890.770514
# 44 2024-06-02  63145.80   64989.91  61440.00  62452.47  1558.529962
# 45 2024-05-26  60930.51   65933.02  60750.00  63138.93  2469.255271
# 46 2024-05-19  57085.97   62261.43  56418.03  60927.75  2144.931916
# 47 2024-05-12  59515.05   60834.00  55876.05  57075.98  2126.963162
# 48 2024-05-05  58965.50   60365.57  52943.49  59506.98  4178.038841
# 49 2024-04-28  60985.08   63134.63  58411.49  58947.56  2398.396625
#
#    currency_name
# 0         Solana
# 1         Solana
# 2         Solana
# 3         Solana
# 4         Solana
# 5         Solana
# 6         Solana
# 7         Solana
# 8         Solana
# 9         Solana
# 10        Solana
# 11        Solana
# 12        Solana
# 13        Solana
# 14        Solana
# 15        Solana
# 16        Solana
# 17        Solana
# 18        Solana
# 19        Solana
# 20        Solana
# 21        Solana
# 22        Solana
# 23        Solana
# 24        Solana
# 25        Solana
# 26        Solana
# 27        Solana
# 28        Solana
# 29        Solana
# 30        Solana
# 31        Solana
# 32        Solana
# 33        Solana
# 34        Solana
# 35        Solana
# 36        Solana
# 37        Solana
# 38        Solana
# 39        Solana
# 40        Solana
# 41        Solana
# 42        Solana
# 43        Solana
# 44        Solana
# 45        Solana
# 46        Solana
# 47        Solana
# 48        Solana
# 49        Solana

# %% [markdown]
# # Merge Both DataSet

# %%
import pandas as pd

# Load datasets
bitcoin = pd.read_csv('Bitcoin_Weekly_Prices.csv')
ethereum = pd.read_csv('Ethereum_Weekly_Prices.csv')
Solana = pd.read_csv('Solana_Weekly_Data.csv')

# Add currency identifier
#bitcoin['currency'] = 'Bitcoin'
#ethereum['currency'] = 'Ethereum'

# Combine vertically
crypto = pd.concat([bitcoin, ethereum, Solana], ignore_index=True)

# Convert date to datetime and sort
crypto['date'] = pd.to_datetime(crypto['date'])
crypto = crypto.sort_values(['date'])

# Reset index
crypto = crypto.reset_index(drop=True)

# Save to CSV
crypto.to_csv('Combined_Crypto_Data.csv', index=False)

# Display result
print(crypto.head(10))
# Out:
#         date      open      high       low     close       volume  \
# 0 2024-04-28  60985.08  63134.63  58411.49  58947.56  2398.396625
# 1 2024-04-28  60985.08  63134.63  58411.49  58947.56  2398.396625
# 2 2024-04-28  60985.08  63134.63  58411.49  58947.56  2398.396625
# 3 2024-05-05  58965.50  60365.57  52943.49  59506.98  4178.038841
# 4 2024-05-05  58965.50  60365.57  52943.49  59506.98  4178.038841
# 5 2024-05-05  58965.50  60365.57  52943.49  59506.98  4178.038841
# 6 2024-05-12  59515.05  60834.00  55876.05  57075.98  2126.963162
# 7 2024-05-12  59515.05  60834.00  55876.05  57075.98  2126.963162
# 8 2024-05-12  59515.05  60834.00  55876.05  57075.98  2126.963162
# 9 2024-05-19  57085.97  62261.43  56418.03  60927.75  2144.931916
#
#   currency_name
# 0        Solana
# 1       Bitcoin
# 2      Ethereum
# 3       Bitcoin
# 4      Ethereum
# 5        Solana
# 6      Ethereum
# 7       Bitcoin
# 40 2024-07-28  62526.97  63876.72  58512.00  62854.02  1840.762229
# 41 2024-07-28  62526.97  63876.72  58512.00  62854.02  1840.762229
# 42 2024-08-04  62866.50  64749.00  52521.27  53309.69  3522.976055
# 43 2024-08-04  62866.50  64749.00  52521.27  53309.69  3522.976055
# 44 2024-08-04  62866.50  64749.00  52521.27  53309.69  3522.976055
# 45 2024-08-11  53330.01  57499.00  45021.36  53835.66  5859.416666
# 46 2024-08-11  53330.01  57499.00  45021.36  53835.66  5859.416666
# 47 2024-08-11  53330.01  57499.00  45021.36  53835.66  5859.416666
# 48 2024-08-18  53822.14  56141.89  51195.03  53046.89  1836.960865
# 49 2024-08-18  53822.14  56141.89  51195.03  53046.89  1836.960865
#
#    currency_name
# 0         Solana
# 1        Bitcoin
# 2       Ethereum
# 3        Bitcoin
# 4       Ethereum
# 5         Solana
# 6       Ethereum
# 7        Bitcoin
# 8         Solana
# 9        Bitcoin
# 10        Solana
# 11      Ethereum
# 12       Bitcoin
# 13        Solana
# 14      Ethereum
# 15       Bitcoin
# 16        Solana
# 17      Ethereum
# 18        Solana
# 19      Ethereum
# 20       Bitcoin
# 21        Solana
# 22      Ethereum
# 23       Bitcoin
# 24      Ethereum
# 25       Bitcoin
# 26        Solana
# 27      Ethereum
# 28       Bitcoin
# 29        Solana
# 30       Bitcoin
# 31        Solana
# 32      Ethereum
# 33      Ethereum
# 34        Solana
# 35       Bitcoin
# 36      Ethereum
# 37       Bitcoin
# 38        Solana
# 39       Bitcoin
# 40        Solana
# 41      Ethereum
# 42        Solana
# 43       Bitcoin
# 44      Ethereum
# 45      Ethereum
# 46       Bitcoin
# 47        Solana
# 48      Ethereum
# 49       Bitcoin

# %% [markdown]
# # Web Scraping

# %% [markdown]
# ## Beatiful Soup

# %%
import requests

url = 'import requests'

url = 'https://u.today/search/node?keys=Bitcoin'
response_f = requests.get(url)
response_f
# Out:
# <Response [200]>

# %%
import requests
import bs4

response = requests.get("https://u.today/search/node?keys=Bitcoin")
# soup = bs4.BeautifulSoup(response.text, 'lxml') # with lxml package
document = bs4.BeautifulSoup(response.text, 'html.parser') 
document
# Out:
#  <!DOCTYPE html>
#
# <html class="theme-light" dir="ltr" lang="en" prefix="og: ogp.me/ns#">
# <head>
# <script async="" crossorigin="anonymous" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js?client=ca-pub-9245916885225528"></script>
# <link href="https://www.google-analytics.com" rel="preconnect"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=5" name="viewport"/>
# <script src="/core/assets/vendor/jquery/jquery.min.js"></script>
# <meta charset="utf-8">
# <link href="https://u.today/search/node" rel="canonical">
# <meta content="article" property="og:type"/>
# <meta content="https://u.today/search/node" property="og:url"/>
# <meta content="Search" property="og:title"/>
# <meta content="Search" property="og:description"/>
# <meta content="https://u.today/img/logo-utoday.png" property="og:image"/>
# <meta content="https://u.today/img/logo-utoday.png" property="og:image:url"/>
# <meta content="https://u.today/img/logo-utoday.png" property="og:image:secure_url"/>
# <meta content="2560796210663191" property="fb:app_id"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="@Utoday_en" name="twitter:site"/>
# <meta content="https://u.today/img/logo-utoday.png" name="twitter:image"/>
# <meta content="Drupal 10 (https://www.drupal.org)" name="Generator"/>
# <meta content="width" name="MobileOptimized"/>
# <meta content="true" name="HandheldFriendly"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <script type="application/ld+json">{
#     "@context": "https://schema.org",
#     "@graph": [
#         {
#             "@type": "Organization",
#             "name": "U.Today",
#             "url": "https://u.today/search/node",
#             "image": {
#                 "@type": "ImageObject",
#                 "url": "https://U.today/img/logo-utoday.png"
#             }
#         }
#     ]
# }</script>
# <!-- end: separate google analytics code -->
# <!-- Google Tag Manager -->
# <!-- End Google Tag Manager -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-2PE2QV2V0X"></script>
# <script>
#         window.dataLayer = window.dataLayer || [];
#         function gtag(){dataLayer.push(arguments);}
#         gtag('js', new Date());
#
#         gtag('config', 'G-2PE2QV2V0X');
#     </script>
# <link color="#263238" href="/img/favicon/safari-pinned-tab.svg" rel="mask-icon"/>
# <link href="/img/favicon/apple-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
# <link href="/img/favicon/apple-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
# <link href="/img/favicon/apple-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
# <link href="/img/favicon/apple-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
# <link href="/img/favicon/apple-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
# <link href="/img/favicon/apple-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
# <link href="/img/favicon/apple-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
# <link href="/img/favicon/apple-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
# <link href="/img/favicon/apple-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/img/favicon/android-icon-192x192.png" rel="icon" sizes="192x192" type="image/png"/>
# <link href="/img/favicon/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/img/favicon/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
# <link href="/img/favicon/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/site.webmanifest" rel="manifest"/>
# <link color="#263238" href="/img/favicon/safari-pinned-tab.svg" rel="mask-icon"/>
# <link href="/img/favicon/favicon.ico" rel="shortcut icon"/>
# <meta content="#263238" name="msapplication-TileColor"/>
# <meta content="/img/favicon/browserconfig.xml" name="msapplication-config"/>
# <meta content="#263238" name="theme-color"/>
# <meta content="2E6EDC1D9A57E69FC6232E905A08CBFA" name="msvalidate.01">
# <link href="/manifest.json" rel="manifest">
# <meta content="266789420636465" property="fb:pages">
# <link href="/modules/contrib/paragraphs/css/paragraphs.unpublished.css?stzpi2" media="all" rel="stylesheet">
# <link href="/themes/cryptod/libs/air-datepicker/air-datepicker.css?stzpi2" media="all" rel="stylesheet">
# <link href="/themes/cryptod/styles/slick-theme.css?stzpi2" media="all" rel="stylesheet">
# <link href="/themes/cryptod/styles/common.css?stzpi2" media="all" rel="stylesheet">
# <link href="/themes/cryptod/styles/app.css?stzpi2" media="all" rel="stylesheet">
# <link href="/themes/cryptod/styles/push.css?stzpi2" media="all" rel="stylesheet">
# <style>.ccc-widget.ccc-list .header-div a img {
#                             width: 26px;
#                             height: 26px;
#                         }
#                     </style>
# <title>Search | U.Today</title>
# <script src="https://cdn.onesignal.com/sdks/OneSignalSDK.js"></script>
# <script>
#                         function copyToClipboard(e) {
#                             let input = document.body.appendChild(document.createElement("input"));
#                             input.value = window.location.href;
#                             input.select();
#                             document.execCommand('copy');
#                             input.parentNode.removeChild(input);
#
#                             let tooltip = document.createElement('div');
#                             tooltip.className = 'copy-tooltip';
#                             tooltip.innerHTML = 'Copied!';
#
#                             if (!e.querySelector('.copy-tooltip')) {
#                                 e.append(tooltip);
#
#                                 setTimeout(() => {
#                                     e.querySelector('.copy-tooltip').remove();
#                                 }, 2000);
#                             }
#                         }
#                     </script>
# <style>
#                         @media (max-width: 849px) {
#                             body #onesignal-slidedown-container.slide-up {
#                                 bottom: 60px
#                             }
#                         }
#                     </style>
# <script async="" defer="" src="https://www.google.com/recaptcha/api.js"></script>
# <style>
#                         .captcha-container {
#                             display: none; /* CAPTCHA скрыта по умолчанию */
#                         }
#                     </style>
# </link></link></link></link></link></link></meta></link></meta></link></meta></head>
# <body class="not_logged_in">
# <!-- Google Tag Manager (noscript) -->
# <!-- End Google Tag Manager (noscript) -->
# <div class="something--upper">
# <div class="something">
# <div class="something__title">Advertisement</div>
# <div class="something__nav">
# <div class="something__label">AD</div>
# <button aria-label="Close ad" class="btn btn--light something__close"></button>
# </div>
# <div class="something__content">
# <div class="something__content--long">
# <div>
# <!-- Wideheader Fixed Desktop 1150x60 [async] -->
# <script type="text/javascript">
#
# if (!window.AdButler){(function(){var s = document.createElement("script"); s.async = true; s.type = "text/javascript"; s.src = 'https://servedbyadbutler.com/app.js'; var n = document.getElementsByTagName("script")[0]; n.parentNode.insertBefore(s, n);}());}
#
# </script>
# <script type="text/javascript">
# var AdButler = AdButler || {};
# AdButler.ads = AdButler.ads || [];
# var abkw = window.abkw || '';
# var plc602403 = window.plc602403 || 0;
# document.write('<'+'div id="placement_602403_'+plc602403+'"></'+'div>');
# AdButler.ads.push({handler: function(opt){ AdButler.register(183269, 602403, [1150,60], 'placement_602403_'+opt.place, opt); }, opt: { place: plc602403++, keywords: abkw, domain: 'servedbyadbutler.com', click: 'CLICK_MACRO_PLACEHOLDER' }});
#
# </script>
# </div>
# </div>
# <div class="something__content--square">
# <div>
# <!-- Wideheader Fixed Mobile 336x60 [async] -->
# <script type="text/javascript">
# if (document.documentElement.clientWidth < 768) {
# if (!window.AdButler){(function(){var s = document.createElement("script"); s.async = true; s.type = "text/javascript"; s.src = 'https://servedbyadbutler.com/app.js'; var n = document.getElementsByTagName("script")[0]; n.parentNode.insertBefore(s, n);}());}
# }
# </script>
# <script type="text/javascript">
# if (document.documentElement.clientWidth < 768) {
# var AdButler = AdButler || {};
# AdButler.ads = AdButler.ads || [];
# var abkw = window.abkw || '';
# var plc551690 = window.plc551690 || 0;
# document.write('<'+'div id="placement_551690_'+plc551690+'"></'+'div>');
# AdButler.ads.push({handler: function(opt){ AdButler.register(183269, 551690, [336,60], 'placement_551690_'+opt.place, opt); }, opt: { place: plc551690++, keywords: abkw, domain: 'servedbyadbutler.com', click: 'CLICK_MACRO_PLACEHOLDER' }});
# }
# </script>
# </div>
# </div>
# </div>
# </div>
# </div>
# <header class="header">
# <div class="header__container"><a class="header__logo" href="https://u.today/" title="U.Today logo"></a>
# <div class="header__search" style="display: block">
# <form action="/search/node" class="header__search-form" method="get">
# <button class="header__search-submit btn btn--light btn--search" style="display: none;" type="submit"></button>
# <input class="header__search-input" id="search_text" name="keys" type="text"/>
# <button class="header__search-close btn btn--light btn--cross"></button>
# </form>
# </div>
# </div>
# </header>
# <div class="mobile-menu-cover"></div>
# <div class="page-container container">
# <div class="main-aside-container">
# <main class="main-block">
# <div class="search-result">
# <h1 class="page-bg-title">Search results for “Bitcoin”</h1>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 31, 2025 - 12:47</div>
# </div>
# <a class="news__item-body" href="https://u.today/litecoin-ltc-decouples-from-bitcoin-in-key-metric-details">
# <div class="news__item-title">Litecoin (LTC) Decouples From Bitcoin in Key Metric: Details</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/godfrey-benjamin"><img alt="Godfrey Benjamin" class="humble__img" height="24" src="https://u.today/sites/default/files/2022-12/29302.jpg" width="24"/>Godfrey Benjamin
#             </a></div>
# </div>
# <div class="something something--content">
# <div class="something__content-long">
# <ins class="adsbygoogle" data-ad-client="ca-pub-4834169448759613" data-ad-slot="1698558466" style="display:inline-block;width:728px;height:90px"></ins>
# </div>
# <div class="something__content-square">
# <ins class="adsbygoogle" data-ad-client="ca-pub-4834169448759613" data-ad-slot="4003311693" style="display:inline-block;width:336px;height:280px"></ins>
# </div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 31, 2025 - 12:02</div>
# </div>
# <a class="news__item-body" href="https://u.today/breaking-strategy-buys-nearly-2-billion-worth-of-bitcoin">
# <div class="news__item-title">Breaking: Strategy Buys Nearly $2 Billion Worth of Bitcoin</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/alex-dovbnya"><img alt="Alex Dovbnya" class="humble__img" height="24" src="https://u.today/sites/default/files/2019-11/alex-m-ava.jpg" width="24"/>Alex Dovbnya
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 31, 2025 - 10:27</div>
# </div>
# <a class="news__item-body" href="https://u.today/bitcoin-btc-death-cross-appears-on-rare-indicator-what-happens-next">
# <div class="news__item-title">Bitcoin (BTC) 'Death Cross' Appears on Rare Indicator: What Happens Next?</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/tomiwabold-olajide"><img alt="Tomiwabold Olajide" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-11/8944.jpg" width="24"/>Tomiwabold Olajide
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 31, 2025 - 9:05</div>
# </div>
# <a class="news__item-body" href="https://u.today/spot-bitcoin-etf-inflows-down-73-in-seven-days-details">
# <div class="news__item-title">Spot Bitcoin ETF Inflows Down 73% in Seven Days: Details</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/godfrey-benjamin"><img alt="Godfrey Benjamin" class="humble__img" height="24" src="https://u.today/sites/default/files/2022-12/29302.jpg" width="24"/>Godfrey Benjamin
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 31, 2025 - 7:16</div>
# </div>
# <a class="news__item-body" href="https://u.today/metaplanet-issues-more-debt-to-buy-bitcoin">
# <div class="news__item-title">Metaplanet Issues More Debt to Buy Bitcoin</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/alex-dovbnya"><img alt="Alex Dovbnya" class="humble__img" height="24" src="https://u.today/sites/default/files/2019-11/alex-m-ava.jpg" width="24"/>Alex Dovbnya
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 31, 2025 - 0:01</div>
# </div>
# <a class="news__item-body" href="https://u.today/xrp-rapidly-diving-below-2-bitcoin-btc-on-verge-of-losing-80000-shiba-inu-shib-loses-all-breakout">
# <div class="news__item-title">XRP Rapidly Diving Below $2, Bitcoin (BTC) on Verge of Losing $80,000, Shiba Inu (SHIB) Loses All Breakout Gains</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/arman-shirinyan"><img alt="Arman Shirinyan" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8993.jpg" width="24"/>Arman Shirinyan
#             </a></div>
# </div>
# <div class="something something--content">
# <div class="something__content-long">
# <ins class="adsbygoogle" data-ad-client="ca-pub-4834169448759613" data-ad-slot="1698558466" style="display:inline-block;width:728px;height:90px"></ins>
# </div>
# <div class="something__content-square">
# <ins class="adsbygoogle" data-ad-client="ca-pub-4834169448759613" data-ad-slot="4003311693" style="display:inline-block;width:336px;height:280px"></ins>
# </div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 30, 2025 - 17:54</div>
# </div>
# <a class="news__item-body" href="https://u.today/bitcoin-magnate-to-fly-into-space-tomorrow">
# <div class="news__item-title">Bitcoin Magnate to Fly into Space Tomorrow</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/alex-dovbnya"><img alt="Alex Dovbnya" class="humble__img" height="24" src="https://u.today/sites/default/files/2019-11/alex-m-ava.jpg" width="24"/>Alex Dovbnya
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 30, 2025 - 13:54</div>
# </div>
# <a class="news__item-body" href="https://u.today/bitcoin-btc-price-prediction-for-march-30">
# <div class="news__item-title">Bitcoin (BTC) Price Prediction for March 30</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/denys-serhiichuk"><img alt="Denys Serhiichuk" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8942.jpg" width="24"/>Denys Serhiichuk
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 30, 2025 - 13:36</div>
# </div>
# <a class="news__item-body" href="https://u.today/bitcoin-btc-finds-bottom-key-indicator-hints-at-reversal">
# <div class="news__item-title">Bitcoin (BTC) Finds Bottom? Key Indicator Hints at Reversal</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/gamza-khanzadaev"><img alt="Gamza Khanzadaev" class="humble__img" height="24" src="https://u.today/sites/default/files/2022-05/14694.jpg" width="24"/>Gamza Khanzadaev
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 30, 2025 - 13:21</div>
# </div>
# <a class="news__item-body" href="https://u.today/michael-saylor-teases-another-bitcoin-mega-buy-with-new-cryptic-post">
# <div class="news__item-title">Michael Saylor Teases Another Bitcoin Mega-Buy With New Cryptic Post</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/gamza-khanzadaev"><img alt="Gamza Khanzadaev" class="humble__img" height="24" src="https://u.today/sites/default/files/2022-05/14694.jpg" width="24"/>Gamza Khanzadaev
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 30, 2025 - 13:00</div>
# </div>
# <a class="news__item-body" href="https://u.today/bitcoin-etfs-skyrocket-by-200-million-but-worrying-catch-emerges">
# <div class="news__item-title">Bitcoin ETFs Skyrocket by $200 Million, but Worrying Catch Emerges</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/gamza-khanzadaev"><img alt="Gamza Khanzadaev" class="humble__img" height="24" src="https://u.today/sites/default/files/2022-05/14694.jpg" width="24"/>Gamza Khanzadaev
#             </a></div>
# </div>
# <div class="something something--content">
# <div class="something__content-long">
# <ins class="adsbygoogle" data-ad-client="ca-pub-4834169448759613" data-ad-slot="1698558466" style="display:inline-block;width:728px;height:90px"></ins>
# </div>
# <div class="something__content-square">
# <ins class="adsbygoogle" data-ad-client="ca-pub-4834169448759613" data-ad-slot="4003311693" style="display:inline-block;width:336px;height:280px"></ins>
# </div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 30, 2025 - 12:30</div>
# </div>
# <a class="news__item-body" href="https://u.today/mysterious-333000000-bitcoin-transfer-stuns-major-us-exchange">
# <div class="news__item-title">Mysterious $333,000,000 Bitcoin Transfer Stuns Major US Exchange</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/gamza-khanzadaev"><img alt="Gamza Khanzadaev" class="humble__img" height="24" src="https://u.today/sites/default/files/2022-05/14694.jpg" width="24"/>Gamza Khanzadaev
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 30, 2025 - 10:40</div>
# </div>
# <a class="news__item-body" href="https://u.today/has-20000000th-bitcoin-been-mined">
# <div class="news__item-title">Has 20,000,000th Bitcoin Been Mined?</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/alex-dovbnya"><img alt="Alex Dovbnya" class="humble__img" height="24" src="https://u.today/sites/default/files/2019-11/alex-m-ava.jpg" width="24"/>Alex Dovbnya
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 30, 2025 - 8:01</div>
# </div>
# <a class="news__item-body" href="https://u.today/legendary-trader-brandt-warns-this-bitcoin-pattern-could-be-a-trap">
# <div class="news__item-title">Legendary Trader Brandt Warns This Bitcoin Pattern Could Be a Trap</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/alex-dovbnya"><img alt="Alex Dovbnya" class="humble__img" height="24" src="https://u.today/sites/default/files/2019-11/alex-m-ava.jpg" width="24"/>Alex Dovbnya
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 29, 2025 - 20:00</div>
# </div>
# <a class="news__item-body" href="https://u.today/15-years-since-huge-bitcoin-bug-satoshi-had-to-fix-asap">
# <div class="news__item-title">15 Years Since Huge Bitcoin Bug Satoshi Had to Fix ASAP</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/yuri-molchan"><img alt="Yuri Molchan" class="humble__img" height="24" src="https://u.today/sites/default/files/2019-11/yuri-ava.jpg" width="24"/>Yuri Molchan
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 29, 2025 - 16:30</div>
# </div>
# <a class="news__item-body" href="https://u.today/bitcoin-btc-price-to-72000-top-trader-on-dead-cat-bounce">
# <div class="news__item-title">Bitcoin (BTC) Price to $72,000: Top Trader on 'Dead Cat Bounce'</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/vladislav-sopov"><img alt="Vladislav Sopov" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-07/8893.jpg" width="24"/>Vladislav Sopov
#             </a></div>
# </div>
# <div class="something something--content">
# <div class="something__content-long">
# <ins class="adsbygoogle" data-ad-client="ca-pub-4834169448759613" data-ad-slot="1698558466" style="display:inline-block;width:728px;height:90px"></ins>
# </div>
# <div class="something__content-square">
# <ins class="adsbygoogle" data-ad-client="ca-pub-4834169448759613" data-ad-slot="4003311693" style="display:inline-block;width:336px;height:280px"></ins>
# </div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 29, 2025 - 13:30</div>
# </div>
# <a class="news__item-body" href="https://u.today/bitcoin-btc-bleeds-but-price-history-says-april-could-be-fire">
# <div class="news__item-title">Bitcoin (BTC) Bleeds, but Price History Says April Could Be Fire</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/gamza-khanzadaev"><img alt="Gamza Khanzadaev" class="humble__img" height="24" src="https://u.today/sites/default/files/2022-05/14694.jpg" width="24"/>Gamza Khanzadaev
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 29, 2025 - 8:19</div>
# </div>
# <a class="news__item-body" href="https://u.today/bitcoin-shows-bear-trap-1-million-btc-samson-mow-claims">
# <div class="news__item-title">Bitcoin Shows Bear Trap, '$1 Million BTC' Samson Mow Claims</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/yuri-molchan"><img alt="Yuri Molchan" class="humble__img" height="24" src="https://u.today/sites/default/files/2019-11/yuri-ava.jpg" width="24"/>Yuri Molchan
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 28, 2025 - 19:38</div>
# </div>
# <a class="news__item-body" href="https://u.today/fidelity-says-its-possible-for-bitcoin-to-overtake-gold">
# <div class="news__item-title">Fidelity Says It's 'Possible' for Bitcoin to Overtake Gold</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/alex-dovbnya"><img alt="Alex Dovbnya" class="humble__img" height="24" src="https://u.today/sites/default/files/2019-11/alex-m-ava.jpg" width="24"/>Alex Dovbnya
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 28, 2025 - 15:51</div>
# </div>
# <a class="news__item-body" href="https://u.today/15-billion-blackrock-celebrates-new-crypto-milestone-and-its-not-bitcoin">
# <div class="news__item-title">$1.5 Billion: BlackRock Celebrates New Crypto Milestone, And It's Not Bitcoin</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/gamza-khanzadaev"><img alt="Gamza Khanzadaev" class="humble__img" height="24" src="https://u.today/sites/default/files/2022-05/14694.jpg" width="24"/>Gamza Khanzadaev
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 28, 2025 - 15:07</div>
# </div>
# <a class="news__item-body" href="https://u.today/bitcoin-btc-loses-crucial-200-day-moving-average-amid-inflation-report">
# <div class="news__item-title">Bitcoin (BTC) Loses Crucial 200-Day Moving Average Amid Inflation Report</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/gamza-khanzadaev"><img alt="Gamza Khanzadaev" class="humble__img" height="24" src="https://u.today/sites/default/files/2022-05/14694.jpg" width="24"/>Gamza Khanzadaev
#             </a></div>
# </div>
# <div class="something something--content">
# <div class="something__content-long">
# <ins class="adsbygoogle" data-ad-client="ca-pub-4834169448759613" data-ad-slot="1698558466" style="display:inline-block;width:728px;height:90px"></ins>
# </div>
# <div class="something__content-square">
# <ins class="adsbygoogle" data-ad-client="ca-pub-4834169448759613" data-ad-slot="4003311693" style="display:inline-block;width:336px;height:280px"></ins>
# </div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 28, 2025 - 14:54</div>
# </div>
# <a class="news__item-body" href="https://u.today/ethereum-crashes-74-against-bitcoin-is-reversal-imminent">
# <div class="news__item-title">Ethereum Crashes 74% Against Bitcoin; Is Reversal Imminent?</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/tomiwabold-olajide"><img alt="Tomiwabold Olajide" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-11/8944.jpg" width="24"/>Tomiwabold Olajide
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 28, 2025 - 14:37</div>
# </div>
# <a class="news__item-body" href="https://u.today/schiff-bitcoin-btc-to-collapse-to-10k">
# <div class="news__item-title">Schiff: Bitcoin (BTC) to Collapse to $10K</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/alex-dovbnya"><img alt="Alex Dovbnya" class="humble__img" height="24" src="https://u.today/sites/default/files/2019-11/alex-m-ava.jpg" width="24"/>Alex Dovbnya
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 28, 2025 - 14:36</div>
# </div>
# <a class="news__item-body" href="https://u.today/bitcoin-btc-price-prediction-for-march-28-0">
# <div class="news__item-title">Bitcoin (BTC) Price Prediction for March 28</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/denys-serhiichuk"><img alt="Denys Serhiichuk" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8942.jpg" width="24"/>Denys Serhiichuk
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 28, 2025 - 13:18</div>
# </div>
# <a class="news__item-body" href="https://u.today/breaking-tether-mints-1-billion-usdt-tokens-as-bitcoin-plunges-below-85k">
# <div class="news__item-title">Breaking: Tether Mints 1 Billion USDT Tokens as Bitcoin Plunges Below $85K</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/alex-dovbnya"><img alt="Alex Dovbnya" class="humble__img" height="24" src="https://u.today/sites/default/files/2019-11/alex-m-ava.jpg" width="24"/>Alex Dovbnya
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 28, 2025 - 12:14</div>
# </div>
# <a class="news__item-body" href="https://u.today/bitcoin-btc-major-core-update-key-changes-revealed">
# <div class="news__item-title">Bitcoin (BTC) Major Core Update: Key Changes Revealed</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/tomiwabold-olajide"><img alt="Tomiwabold Olajide" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-11/8944.jpg" width="24"/>Tomiwabold Olajide
#             </a></div>
# </div>
# <div class="something something--content">
# <div class="something__content-long">
# <ins class="adsbygoogle" data-ad-client="ca-pub-4834169448759613" data-ad-slot="1698558466" style="display:inline-block;width:728px;height:90px"></ins>
# </div>
# <div class="something__content-square">
# <ins class="adsbygoogle" data-ad-client="ca-pub-4834169448759613" data-ad-slot="4003311693" style="display:inline-block;width:336px;height:280px"></ins>
# </div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 28, 2025 - 11:32</div>
# </div>
# <a class="news__item-body" href="https://u.today/bitcoin-btc-faces-brutal-drop-confirms-legendary-trader-peter-brandt">
# <div class="news__item-title">Bitcoin (BTC) Faces Brutal Drop, Confirms Legendary Trader Peter Brandt</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/gamza-khanzadaev"><img alt="Gamza Khanzadaev" class="humble__img" height="24" src="https://u.today/sites/default/files/2022-05/14694.jpg" width="24"/>Gamza Khanzadaev
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 28, 2025 - 9:46</div>
# </div>
# <a class="news__item-body" href="https://u.today/rich-dad-poor-dad-author-predicts-new-ath-for-second-best-asset-to-bitcoin">
# <div class="news__item-title">'Rich Dad Poor Dad' Author Predicts New ATH for Second Best Asset to Bitcoin</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/yuri-molchan"><img alt="Yuri Molchan" class="humble__img" height="24" src="https://u.today/sites/default/files/2019-11/yuri-ava.jpg" width="24"/>Yuri Molchan
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 28, 2025 - 0:01</div>
# </div>
# <a class="news__item-body" href="https://u.today/shiba-inu-shib-bulls-in-control-now-bitcoin-btc-in-great-spot-ethereum-eth-major-bearish-signal-but">
# <div class="news__item-title">Shiba Inu (SHIB): Bulls in Control Now? Bitcoin (BTC) in Great Spot, Ethereum (ETH): Major Bearish Signal, But There's Silver Lining </div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/arman-shirinyan"><img alt="Arman Shirinyan" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8993.jpg" width="24"/>Arman Shirinyan
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 27, 2025 - 20:46</div>
# </div>
# <a class="news__item-body" href="https://u.today/buying-bitcoin-not-viable-long-term-business-model-says-peter-schiff">
# <div class="news__item-title">Buying Bitcoin 'Not Viable Long-Term Business Model', Says Peter Schiff</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/caroline-amosun"><img alt="Caroline Amosun" class="humble__img" height="24" src="https://u.today/sites/default/files/2025-03/56827.jpg" width="24"/>Caroline Amosun
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 27, 2025 - 20:04</div>
# </div>
# <a class="news__item-body" href="https://u.today/us-government-moving-millions-of-dollars-worth-of-bitcoin">
# <div class="news__item-title">US Government Moving Millions of Dollars Worth of Bitcoin</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/alex-dovbnya"><img alt="Alex Dovbnya" class="humble__img" height="24" src="https://u.today/sites/default/files/2019-11/alex-m-ava.jpg" width="24"/>Alex Dovbnya
#             </a></div>
# </div>
# <div class="something something--content">
# <div class="something__content-long">
# <ins class="adsbygoogle" data-ad-client="ca-pub-4834169448759613" data-ad-slot="1698558466" style="display:inline-block;width:728px;height:90px"></ins>
# </div>
# <div class="something__content-square">
# <ins class="adsbygoogle" data-ad-client="ca-pub-4834169448759613" data-ad-slot="4003311693" style="display:inline-block;width:336px;height:280px"></ins>
# </div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 27, 2025 - 18:29</div>
# </div>
# <a class="news__item-body" href="https://u.today/gamestop-shares-getting-annihilated-following-bitcoin-pivot">
# <div class="news__item-title">GameStop Shares Getting Annihilated Following Bitcoin Pivot</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/alex-dovbnya"><img alt="Alex Dovbnya" class="humble__img" height="24" src="https://u.today/sites/default/files/2019-11/alex-m-ava.jpg" width="24"/>Alex Dovbnya
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 27, 2025 - 15:13</div>
# </div>
# <a class="news__item-body" href="https://u.today/peter-schiff-reacts-to-bitcoins-drop-as-gold-sets-fresh-record-high">
# <div class="news__item-title">Peter Schiff Reacts to Bitcoin's Drop as Gold Sets Fresh Record High</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/tomiwabold-olajide"><img alt="Tomiwabold Olajide" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-11/8944.jpg" width="24"/>Tomiwabold Olajide
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 27, 2025 - 15:01</div>
# </div>
# <a class="news__item-body" href="https://u.today/xrp-vs-bitcoin-btc-3-big-scenarios-from-bollinger-bands">
# <div class="news__item-title">XRP vs. Bitcoin (BTC): 3 Big Scenarios From Bollinger Bands</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/gamza-khanzadaev"><img alt="Gamza Khanzadaev" class="humble__img" height="24" src="https://u.today/sites/default/files/2022-05/14694.jpg" width="24"/>Gamza Khanzadaev
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 27, 2025 - 13:53</div>
# </div>
# <a class="news__item-body" href="https://u.today/billionaire-cliff-asness-im-not-a-bitcoin-fan">
# <div class="news__item-title">Billionaire Cliff Asness: "I'm Not a Bitcoin Fan'</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/alex-dovbnya"><img alt="Alex Dovbnya" class="humble__img" height="24" src="https://u.today/sites/default/files/2019-11/alex-m-ava.jpg" width="24"/>Alex Dovbnya
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 27, 2025 - 13:47</div>
# </div>
# <a class="news__item-body" href="https://u.today/strategys-saylor-joins-gihbli-trend-with-bullish-bitcoin-post">
# <div class="news__item-title">Strategy's Saylor Joins Gihbli Trend With Bullish Bitcoin Post</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/godfrey-benjamin"><img alt="Godfrey Benjamin" class="humble__img" height="24" src="https://u.today/sites/default/files/2022-12/29302.jpg" width="24"/>Godfrey Benjamin
#             </a></div>
# </div>
# <div class="something something--content">
# <div class="something__content-long">
# <ins class="adsbygoogle" data-ad-client="ca-pub-4834169448759613" data-ad-slot="1698558466" style="display:inline-block;width:728px;height:90px"></ins>
# </div>
# <div class="something__content-square">
# <ins class="adsbygoogle" data-ad-client="ca-pub-4834169448759613" data-ad-slot="4003311693" style="display:inline-block;width:336px;height:280px"></ins>
# </div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 26, 2025 - 20:16</div>
# </div>
# <a class="news__item-body" href="https://u.today/breaking-gamestop-raising-13-billion-to-buy-bitcoin">
# <div class="news__item-title">Breaking: GameStop Raising $1.3 Billion to Buy Bitcoin</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/alex-dovbnya"><img alt="Alex Dovbnya" class="humble__img" height="24" src="https://u.today/sites/default/files/2019-11/alex-m-ava.jpg" width="24"/>Alex Dovbnya
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 26, 2025 - 19:45</div>
# </div>
# <a class="news__item-body" href="https://u.today/bitcoin-whales-with-10k-btc-holdings-increase-supply-squeeze-incoming">
# <div class="news__item-title">Bitcoin Whales With 10K BTC Holdings Increase — Supply Squeeze Incoming?</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/andy-sawa"><img alt="Andy Sawa" class="humble__img" height="24" src="https://u.today/sites/default/files/2025-03/56809.jpg" width="24"/>Andy Sawa
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 26, 2025 - 15:45</div>
# </div>
# <a class="news__item-body" href="https://u.today/bitcoin-not-in-overheated-zone-yet-cryptoquant">
# <div class="news__item-title">Bitcoin Not in 'Overheated Zone' Yet: CryptoQuant</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/godfrey-benjamin"><img alt="Godfrey Benjamin" class="humble__img" height="24" src="https://u.today/sites/default/files/2022-12/29302.jpg" width="24"/>Godfrey Benjamin
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 26, 2025 - 15:30</div>
# </div>
# <a class="news__item-body" href="https://u.today/we-are-all-satoshi-usdt-founder-reacts-to-news-about-bitcoin-creator">
# <div class="news__item-title">'We Are All Satoshi': USDT Founder Reacts to News About Bitcoin Creator</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/gamza-khanzadaev"><img alt="Gamza Khanzadaev" class="humble__img" height="24" src="https://u.today/sites/default/files/2022-05/14694.jpg" width="24"/>Gamza Khanzadaev
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 26, 2025 - 14:46</div>
# </div>
# <a class="news__item-body" href="https://u.today/bitcoin-up-700-since-michael-saylors-strategys-first-btc-buy">
# <div class="news__item-title">Bitcoin up 700% Since Michael Saylor's Strategy's First BTC Buy</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/tomiwabold-olajide"><img alt="Tomiwabold Olajide" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-11/8944.jpg" width="24"/>Tomiwabold Olajide
#             </a></div>
# </div>
# <div class="something something--content">
# <div class="something__content-long">
# <ins class="adsbygoogle" data-ad-client="ca-pub-4834169448759613" data-ad-slot="1698558466" style="display:inline-block;width:728px;height:90px"></ins>
# </div>
# <div class="something__content-square">
# <ins class="adsbygoogle" data-ad-client="ca-pub-4834169448759613" data-ad-slot="4003311693" style="display:inline-block;width:336px;height:280px"></ins>
# </div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 26, 2025 - 14:17</div>
# </div>
# <a class="news__item-body" href="https://u.today/strategys-saylor-challenges-gamestop-to-go-big-on-bitcoin">
# <div class="news__item-title">Strategy's Saylor Challenges GameStop to Go Big on Bitcoin </div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/alex-dovbnya"><img alt="Alex Dovbnya" class="humble__img" height="24" src="https://u.today/sites/default/files/2019-11/alex-m-ava.jpg" width="24"/>Alex Dovbnya
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 26, 2025 - 11:55</div>
# </div>
# <a class="news__item-body" href="https://u.today/bitcoin-btc-invalidates-death-cross-whats-next">
# <div class="news__item-title">Bitcoin (BTC) Invalidates Death Cross: What's Next?</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/gamza-khanzadaev"><img alt="Gamza Khanzadaev" class="humble__img" height="24" src="https://u.today/sites/default/files/2022-05/14694.jpg" width="24"/>Gamza Khanzadaev
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 26, 2025 - 10:56</div>
# </div>
# <a class="news__item-body" href="https://u.today/mysterious-262759132-bitcoin-transfer-stuns-major-us-exchange">
# <div class="news__item-title">Mysterious $262,759,132 Bitcoin Transfer Stuns Major US Exchange</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/gamza-khanzadaev"><img alt="Gamza Khanzadaev" class="humble__img" height="24" src="https://u.today/sites/default/files/2022-05/14694.jpg" width="24"/>Gamza Khanzadaev
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 26, 2025 - 7:19</div>
# </div>
# <a class="news__item-body" href="https://u.today/legendary-angel-investor-mocks-gamestops-bitcoin-pivot">
# <div class="news__item-title">Legendary Angel Investor Mocks GameStop's Bitcoin Pivot</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/alex-dovbnya"><img alt="Alex Dovbnya" class="humble__img" height="24" src="https://u.today/sites/default/files/2019-11/alex-m-ava.jpg" width="24"/>Alex Dovbnya
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 26, 2025 - 0:01</div>
# </div>
# <a class="news__item-body" href="https://u.today/bitcoin-btc-mini-death-cross-originates-key-xrp-breakthrough-turns-to-be-fakeout-dogecoin-doge-only">
# <div class="news__item-title">Bitcoin (BTC) Mini-Death Cross Originates, Key XRP Breakthrough Turns to be Fakeout? Dogecoin (DOGE) Only Top Asset Didn't Do It</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/arman-shirinyan"><img alt="Arman Shirinyan" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8993.jpg" width="24"/>Arman Shirinyan
#             </a></div>
# </div>
# <div class="something something--content">
# <div class="something__content-long">
# <ins class="adsbygoogle" data-ad-client="ca-pub-4834169448759613" data-ad-slot="1698558466" style="display:inline-block;width:728px;height:90px"></ins>
# </div>
# <div class="something__content-square">
# <ins class="adsbygoogle" data-ad-client="ca-pub-4834169448759613" data-ad-slot="4003311693" style="display:inline-block;width:336px;height:280px"></ins>
# </div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 25, 2025 - 20:05</div>
# </div>
# <a class="news__item-body" href="https://u.today/breaking-gamestop-to-adopt-bitcoin-as-reserve-asset">
# <div class="news__item-title">Breaking: GameStop Adopts Bitcoin as Reserve Asset</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/alex-dovbnya"><img alt="Alex Dovbnya" class="humble__img" height="24" src="https://u.today/sites/default/files/2019-11/alex-m-ava.jpg" width="24"/>Alex Dovbnya
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 25, 2025 - 20:00</div>
# </div>
# <a class="news__item-body" href="https://u.today/fidelitys-timmer-says-bitcoins-wallet-count-shows-little-growth">
# <div class="news__item-title">Fidelity's Timmer Says Bitcoin's Wallet Count Shows Little Growth </div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/alex-dovbnya"><img alt="Alex Dovbnya" class="humble__img" height="24" src="https://u.today/sites/default/files/2019-11/alex-m-ava.jpg" width="24"/>Alex Dovbnya
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 25, 2025 - 15:49</div>
# </div>
# <a class="news__item-body" href="https://u.today/bitcoin-btc-breakout-bollinger-bands-hint-at-big-upside">
# <div class="news__item-title">Bitcoin (BTC) Breakout? Bollinger Bands Hint at Big Upside</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/gamza-khanzadaev"><img alt="Gamza Khanzadaev" class="humble__img" height="24" src="https://u.today/sites/default/files/2022-05/14694.jpg" width="24"/>Gamza Khanzadaev
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 25, 2025 - 15:38</div>
# </div>
# <a class="news__item-body" href="https://u.today/xrp-hits-bullish-reversal-bitcoin-faces-great-reset-risk-mike-mcglone-warns-second-biggest-shib">
# <div class="news__item-title">XRP Hits Bullish Reversal, Bitcoin Faces 'Great Reset' Risk, Mike McGlone Warns; Second Biggest SHIB Wallet Sees Mysterious Transfers: Crypto News Digest by U.Today</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/valeria-blokhina"><img alt="Valeria Blokhina" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-10/9844.jpg" width="24"/>Valeria Blokhina
#             </a></div>
# </div>
# <script>
#             document.getElementById("search_text").focus();
#         </script>
# </div>
# <div class="something something--content">
# <div class="something__content-long">
# <div>
# <!-- TAGS Title Banner Desktop 336x280 -->
# <ins class="adsbygoogle" data-ad-client="ca-pub-9245916885225528" data-ad-slot="6672099997" style="display:inline-block;width:336px;height:280px"></ins>
# </div>
# </div>
# <div class="something__content-square">
# <div>
# <!-- Tags Title Mobile 336x280 -->
# <ins class="adsbygoogle" data-ad-client="ca-pub-9245916885225528" data-ad-slot="2099638702" style="display:inline-block;width:336px;height:280px"></ins>
# </div>
# </div>
# </div>
# <div class="pag-nav">
# <ul class="pag-nav__list">
# <li class="pag-nav__item">
# <a aria-current="Current page" class="btn--light pag-nav__btn pag-nav__btn-active" href="https://u.today/search/node?keys=Bitcoin&amp;_wrapper_format=html&amp;page=0" title="Current page">
# <span class="visually-hidden">
#               Current page
#             </span>1</a>
# </li>
# <li class="pag-nav__item">
# <a class="btn--light pag-nav__btn" href="https://u.today/search/node?keys=Bitcoin&amp;_wrapper_format=html&amp;page=1" title="Go to page 2">
# <span class="visually-hidden">
#               Page
#             </span>2</a>
# </li>
# <li class="pag-nav__item">
# <a class="btn--light pag-nav__btn" href="https://u.today/search/node?keys=Bitcoin&amp;_wrapper_format=html&amp;page=2" title="Go to page 3">
# <span class="visually-hidden">
#               Page
#             </span>3</a>
# </li>
# <li class="pag-nav__item">
# <a class="btn--light pag-nav__btn" href="https://u.today/search/node?keys=Bitcoin&amp;_wrapper_format=html&amp;page=3" title="Go to page 4">
# <span class="visually-hidden">
#               Page
#             </span>4</a>
# </li>
# <li class="pag-nav__item">
# <a class="btn--light pag-nav__btn" href="https://u.today/search/node?keys=Bitcoin&amp;_wrapper_format=html&amp;page=4" title="Go to page 5">
# <span class="visually-hidden">
#               Page
#             </span>5</a>
# </li>
# <li class="pag-nav__item">
# <a class="btn--light pag-nav__btn" href="https://u.today/search/node?keys=Bitcoin&amp;_wrapper_format=html&amp;page=5" title="Go to page 6">
# <span class="visually-hidden">
#               Page
# ...
#                         });
#                     }
#                     jQuery.each(this, function (i, val) {
#                         var input = jQuery(val);
#                         if (input.attr('name') != 'file') data.append(input.attr('name'), input.val());
#                     });
#
#
#                     jQuery.ajax({
#                         url: jQuery(this).attr('action'),
#                         type: 'POST',
#                         dataType: 'json',
#                         cache: false,
#                         processData: false,
#                         contentType: false,
#                         data: data,
#                         success: function (data) {
#                             jQuery('.sevent').html('<h2>Thanks for submit. We will contact you soon.</h2>');
#                             return false;
#                         },
#                         error: function (xhr, err) {
#
#                             alert('Error');
#                         }
#                     });
#                     return false;
#                 });
#
#                 //submit event end
#             </script>
# <script type="text/javascript">
#                 const initBanners = function () {
#                     let elements =
#                         document.getElementsByClassName('imageBannersContainer');
#                     for (let i = 0; i < elements.length; i++) {
#                         let bannerElements = elements[i].getElementsByClassName("imageBanner");
#                         let bannerIndex = Math.random() * bannerElements.length;
#                         let firstDigitStr = String(bannerIndex)[0];
#                         bannerElements[firstDigitStr].style.display = 'block';
#                     }
#                 };
#
#                 jQuery(document).ready(function () {
#
#                     (function ($) {
#                         if (jQuery(window).width() > '850') {
#                             jQuery('.press-releases__slider, .upcoming__slider').slick({
#                                 infinite: false,
#                                 slidesToShow: 3,
#                                 slidesToScroll: 1,
#                                 arrows: true,
#                                 dots: false
#                             });
#                         }
#                     })(jQuery);
#
#
#                     initBanners();
#
#                     var OneSignal = window.OneSignal || [];
#                     OneSignal.push(function () {
#                         OneSignal.init({
#                             appId: "8fd8204c-a529-4b35-98be-27f71d473d9a",
#                         });
#                     });
#
#                     let menus = document.querySelectorAll('.main_page a');
#                     menus.forEach(el => el.addEventListener('click', event => {
#                         gtag('event', 'header_menu_click', {
#                             'header_menu_click': 'click',
#                         });
#                     }));
#
#                     menus = document.querySelectorAll('.article a[target="_blank"]');
#                     menus.forEach(el => el.addEventListener('click', event => {
#                         gtag('event', 'article_link_click', {
#                             'article_link_click': 'click',
#                         });
#                     }));
#                     menus = document.querySelectorAll('.article__related a');
#                     menus.forEach(el => el.addEventListener('click', event => {
#                         gtag('event', 'card_click', {
#                             'card_click': 'click',
#                         });
#                     }));
#                     menus = document.querySelectorAll('.views-infinite-scroll-content-wrapper .category-item a');
#                     menus.forEach(el => el.addEventListener('click', event => {
#                         gtag('event', 'related_click', {
#                             'related_click': 'click',
#                         });
#                     }));
#                     menus = document.querySelectorAll('.article__listen-audio');
#                     menus.forEach(el => el.addEventListener('click', event => {
#                         gtag('event', 'tts_click', {
#                             'tts_click': 'click',
#                         });
#                     }));
#                     menus = document.querySelectorAll('.header__nav-link');
#                     menus.forEach(el => el.addEventListener('click', event => {
#                         gtag('event', 'header_menu_click', {
#                             'header_menu': 'click',
#                         });
#                     }));
#                     menus = document.querySelectorAll('.footer__nav-child-link');
#                     menus.forEach(el => el.addEventListener('click', event => {
#                         gtag('event', 'footer_menu_click', {
#                             'footer_menu': 'click',
#                         });
#                     }));
#                     menus = document.querySelectorAll('.card__subscribe-item');
#                     menus.forEach(el => el.addEventListener('click', event => {
#                         gtag('event', 'subscribe', {
#                             'subscribe': 'click',
#                         });
#                     }));
#
#
#
#
#
#                                         [].forEach.call(document.querySelectorAll('.adsbygoogle'), function () {
#                         try {
#                             (adsbygoogle = window.adsbygoogle || []).push({});
#                         } catch (e) {
#                             return null;
#                         }
#                     });
#                     jQuery('.ad-feedback__form, .press-releases_form, .event_form, .airdrop_form').submit(function (e) {
#                         e.preventDefault();
#                         //data = 'subject=' + e.target.querySelector('input[name=subject]').value + '&name=' + e.target.querySelector('input[name=submit-name]').value + '&mail=' + e.target.querySelector('input[name=submit-email]').value + '&desc=' + e.target.querySelector('textarea[name=submit-massage]').value;
#                         let fd = new FormData();
#                         let other_data = jQuery(e.target).serializeArray();
#                         jQuery.each(other_data, function (key, input) {
#                             fd.append(input.name, input.value);
#                         });
#                         if(e.target.querySelector('input[name=submit-file]') != null) {
#                             fd.append('file', jQuery(e.target.querySelector('input[name=submit-file]'))[0].files[0]);
#                         }
#                         jQuery.ajax({
#                             url: '/umail',
#                             type: 'post',
#                             contentType: false,
#                             processData: false,
#                             data: fd,
#                             success: function () {
#
#                             }
#                         });
#                     });
#                     jQuery('.subscribe-page__form, .footer__subscribe-form,.aside-sub,.subscribe-form,.sub-slot__form').submit(function (e) {
#                         e.preventDefault();
#                         const form = e.target;
#                         const inputs = form.elements;
#                         let data = '';
#                         for (const input of inputs) {
#                             data = data + input.name + '=' + input.value + '&';
#                         }
#
#                         jQuery.ajax({
#                             url: '/getresponse.php',
#                             type: 'post',
#                             data: data,
#                             success: function () {
#                                 e.target.querySelector('.subscribe-result').innerHTML = '<div class="success">Subscribed</div>';
#                                 jQuery('.card__subscribe-em .input__status').text('Subscribed');
#                                 e.target.querySelector('.success').style.display = 'block';
#                             }
#                         });
#                     });
#                     jQuery('.modal__form').submit(function (e) {
#
#                         const form = e.target;
#                         const inputs = form.elements;
#                         let data = '';
#                         for (const input of inputs) {
#                             data = data + input.name + '=' + input.value + '&';
#                         }
#
#                         jQuery.ajax({
#                             url: '/getresponse.php',
#                             type: 'post',
#                             data: data,
#                             success: function () {
#                                 // e.target.querySelector('.subscribe-result').innerHTML = '<div class="success">Subscribed</div>';
#                                 // jQuery('.card__subscribe-em .input__status').text('Subscribed');
#                                 // e.target.querySelector('.success').style.display = 'block';
#                             }
#                         });
#                     });
#
#
#
#
#
#
#
#                 });
#
#                 function addLink() {
#                     let body = document.getElementsByTagName('body')[0],
#                         selection = window.getSelection(),
#                         copyright = "<p><br>Read more on U.Today <a href='" + document.location.href + "'>" + document.location.href + "</a></p>",
#                         copyrightText = selection + copyright,
#                         newdiv = document.createElement('div');
#
#                     newdiv.style.position = 'absolute';
#                     body.appendChild(newdiv);
#                     newdiv.innerHTML = copyrightText;
#                     selection.selectAllChildren(newdiv);
#
#                     window.onclick = function () {
#                         body.removeChild(newdiv);
#                     };
#                 }
#             </script>
# <script type="text/javascript">
#
#
#                 document.addEventListener("scroll", (event) => {
#
#                     [].forEach.call(document.querySelectorAll('.adsbygoogle'), function () {
#                         try {
#                             (adsbygoogle = window.adsbygoogle || []).push({});
#                         } catch (e) {
#                             //return null;
#                         }
#
#                     });
#                 });
#                 document.addEventListener('DOMContentLoaded', function () {
#                     document.querySelectorAll('audio').forEach(function (audio) {
#                         let loaded = false;
#
#                         audio.addEventListener('loadedmetadata', function () {
#                             loaded = true;
#                             checkLoad();
#                         });
#
#                         audio.addEventListener('canplaythrough', function () {
#                             loaded = true;
#                             checkLoad();
#                         });
#
#                         function checkLoad() {
#                             if (loaded) {
#                                 const article = audio.closest('.article__listen');
#                                 const duration = Math.floor(audio.duration);
#                                 const minutes = Math.floor(duration / 60);
#                                 const seconds = Math.floor(duration % 60);
#                                 minutesDisplay.textContent = `${minutes}:${(seconds < 10 ? '0' : '')}${seconds}`;
#
#                                 console.log(duration);
#                             }
#                         }
#                     });
#
#                     let currentAudio = null;
#
#                     document.body.addEventListener('click', function (e) {
#                         const article = e.target.closest('.article__listen');
#
#                         if (!article) return;
#
#                         const audio = article.querySelector('audio');
#                         const playPauseButton = article.querySelector('.article__listen-btn');
#
#                         if (audio && playPauseButton) {
#                             if (audio !== currentAudio) {
#                                 if (currentAudio) {
#                                     currentAudio.pause();
#                                     const currentPlayPauseButton = currentAudio.parentElement.querySelector('.article__listen-btn');
#                                     if (currentPlayPauseButton) {
#                                         currentPlayPauseButton.classList.remove('is-play');
#                                     }
#                                 }
#
#                                 currentAudio = audio;
#
#                                 audio.addEventListener('timeupdate', updateTimer);
#                             }
#
#                             if (audio.paused) {
#                                 audio.play();
#                                 playPauseButton.classList.add('is-play');
#                             } else {
#                                 audio.pause();
#                                 playPauseButton.classList.remove('is-play');
#                             }
#
#                             function updateTimer() {
#                                 if (!audio.duration) {
#                                     audio.removeEventListener('timeupdate', updateTimer);
#                                     audio.addEventListener('timeupdate', updateTimer);
#                                     return;
#                                 }
#
#                                 const currentTime = audio.duration - audio.currentTime;
#                                 const minutes = Math.floor(currentTime / 60);
#                                 const seconds = Math.floor(currentTime % 60);
#
#                                 minutesDisplay.textContent = `${minutes}:${(seconds < 10 ? '0' : '')}${seconds}`;
#                             }
#                         }
#                     });
#                 });
#             </script>
# <script>
#
#                 var emailInput = document.getElementsByClassName('input__elem');
#                 var submitButton = document.getElementsByClassName('submit-button');
#                 for (let i = 0; i < emailInput.length; i++) {
#                     emailInput[i].addEventListener('input', () => {
#                         let form = emailInput[i].closest('form');
#                         let captchaContainer = form.querySelector('.captcha-container');
#                         if (emailInput[i].validity.valid) {
#                             console.log('OK', captchaContainer);
#                             captchaContainer.style.display = 'block';
#                         } else {
#                             captchaContainer.style.display = 'none';
#                         }
#                     });
#                 }
#
#
#                 let isCaptchaCompleted = false;
#
#
#                 function captchaSuccess() {
#                     //console.log('captchaSuccess', submitButton.length);
#                     submitButton = document.getElementsByClassName('submit-button');
#                     isCaptchaCompleted = true;
#                     for (let i = 0; i < submitButton.length; i++) {
#                         submitButton[i].disabled = false;
#                     }
#                 }
#
#
#                 function captchaExpired() {
#                     isCaptchaCompleted = false;
#                     submitButton = document.getElementsByClassName('submit-button');
#                     for (let i = 0; i < submitButton.length; i++) {
#                         submitButton[i].disabled = true;
#                     }
#                 }
#
#
#                 function validateCaptcha() {
#                     if (!isCaptchaCompleted) {
#                         return false;
#                     }
#                     return true;
#                 }
#
#             </script>
# </body>
# </html>

# %%
# book_cards = soup.select("ol.row li article.product_pod")

# %%
# Option 1: Using CSS selectors (similar to your book_cards example)
Bitcoin_date = document.select("body.not_logged_in div.main-aside-container main.main-block div.search-result div.news__item div.news__item-head div.humble")
Bitcoin_date
# Out:
# [<div class="humble">Mar 31, 2025 - 12:47</div>,
#  <div class="humble">Mar 31, 2025 - 12:02</div>,
#  <div class="humble">Mar 31, 2025 - 10:27</div>,
#  <div class="humble">Mar 31, 2025 - 9:05</div>,
#  <div class="humble">Mar 31, 2025 - 7:16</div>,
#  <div class="humble">Mar 31, 2025 - 0:01</div>,
#  <div class="humble">Mar 30, 2025 - 17:54</div>,
#  <div class="humble">Mar 30, 2025 - 13:54</div>,
#  <div class="humble">Mar 30, 2025 - 13:36</div>,
#  <div class="humble">Mar 30, 2025 - 13:21</div>,
#  <div class="humble">Mar 30, 2025 - 13:00</div>,
#  <div class="humble">Mar 30, 2025 - 12:30</div>,
#  <div class="humble">Mar 30, 2025 - 10:40</div>,
#  <div class="humble">Mar 30, 2025 - 8:01</div>,
#  <div class="humble">Mar 29, 2025 - 20:00</div>,
#  <div class="humble">Mar 29, 2025 - 16:30</div>,
#  <div class="humble">Mar 29, 2025 - 13:30</div>,
#  <div class="humble">Mar 29, 2025 - 8:19</div>,
#  <div class="humble">Mar 28, 2025 - 19:38</div>,
#  <div class="humble">Mar 28, 2025 - 15:51</div>,
#  <div class="humble">Mar 28, 2025 - 15:07</div>,
#  <div class="humble">Mar 28, 2025 - 14:54</div>,
#  <div class="humble">Mar 28, 2025 - 14:37</div>,
#  <div class="humble">Mar 28, 2025 - 14:36</div>,
#  <div class="humble">Mar 28, 2025 - 13:18</div>,
#  <div class="humble">Mar 28, 2025 - 12:14</div>,
#  <div class="humble">Mar 28, 2025 - 11:32</div>,
#  <div class="humble">Mar 28, 2025 - 9:46</div>,
#  <div class="humble">Mar 28, 2025 - 0:01</div>,
#  <div class="humble">Mar 27, 2025 - 20:46</div>,
#  <div class="humble">Mar 27, 2025 - 20:04</div>,
#  <div class="humble">Mar 27, 2025 - 18:29</div>,
#  <div class="humble">Mar 27, 2025 - 15:13</div>,
#  <div class="humble">Mar 27, 2025 - 15:01</div>,
#  <div class="humble">Mar 27, 2025 - 13:53</div>,
#  <div class="humble">Mar 27, 2025 - 13:47</div>,
#  <div class="humble">Mar 26, 2025 - 20:16</div>,
#  <div class="humble">Mar 26, 2025 - 19:45</div>,
#  <div class="humble">Mar 26, 2025 - 15:45</div>,
#  <div class="humble">Mar 26, 2025 - 15:30</div>,
#  <div class="humble">Mar 26, 2025 - 14:46</div>,
#  <div class="humble">Mar 26, 2025 - 14:17</div>,
#  <div class="humble">Mar 26, 2025 - 11:55</div>,
#  <div class="humble">Mar 26, 2025 - 10:56</div>,
#  <div class="humble">Mar 26, 2025 - 7:19</div>,
#  <div class="humble">Mar 26, 2025 - 0:01</div>,
#  <div class="humble">Mar 25, 2025 - 20:05</div>,
#  <div class="humble">Mar 25, 2025 - 20:00</div>,
#  <div class="humble">Mar 25, 2025 - 15:49</div>,
#  <div class="humble">Mar 25, 2025 - 15:38</div>]

# %%
Bitcoin_dt = []
for Bitcoin in Bitcoin_date:
    
  Bitcoin_dt.append(Bitcoin.get_text())
  #print(Bitcoin.get_text())
Bitcoin_dt
# Out:
# ['Mar 31, 2025 - 12:47',
#  'Mar 31, 2025 - 12:02',
#  'Mar 31, 2025 - 10:27',
#  'Mar 31, 2025 - 9:05',
#  'Mar 31, 2025 - 7:16',
#  'Mar 31, 2025 - 0:01',
#  'Mar 30, 2025 - 17:54',
#  'Mar 30, 2025 - 13:54',
#  'Mar 30, 2025 - 13:36',
#  'Mar 30, 2025 - 13:21',
#  'Mar 30, 2025 - 13:00',
#  'Mar 30, 2025 - 12:30',
#  'Mar 30, 2025 - 10:40',
#  'Mar 30, 2025 - 8:01',
#  'Mar 29, 2025 - 20:00',
#  'Mar 29, 2025 - 16:30',
#  'Mar 29, 2025 - 13:30',
#  'Mar 29, 2025 - 8:19',
#  'Mar 28, 2025 - 19:38',
#  'Mar 28, 2025 - 15:51',
#  'Mar 28, 2025 - 15:07',
#  'Mar 28, 2025 - 14:54',
#  'Mar 28, 2025 - 14:37',
#  'Mar 28, 2025 - 14:36',
#  'Mar 28, 2025 - 13:18',
#  'Mar 28, 2025 - 12:14',
#  'Mar 28, 2025 - 11:32',
#  'Mar 28, 2025 - 9:46',
#  'Mar 28, 2025 - 0:01',
#  'Mar 27, 2025 - 20:46',
#  'Mar 27, 2025 - 20:04',
#  'Mar 27, 2025 - 18:29',
#  'Mar 27, 2025 - 15:13',
#  'Mar 27, 2025 - 15:01',
#  'Mar 27, 2025 - 13:53',
#  'Mar 27, 2025 - 13:47',
#  'Mar 26, 2025 - 20:16',
#  'Mar 26, 2025 - 19:45',
#  'Mar 26, 2025 - 15:45',
#  'Mar 26, 2025 - 15:30',
#  'Mar 26, 2025 - 14:46',
#  'Mar 26, 2025 - 14:17',
#  'Mar 26, 2025 - 11:55',
#  'Mar 26, 2025 - 10:56',
#  'Mar 26, 2025 - 7:19',
#  'Mar 26, 2025 - 0:01',
#  'Mar 25, 2025 - 20:05',
#  'Mar 25, 2025 - 20:00',
#  'Mar 25, 2025 - 15:49',
#  'Mar 25, 2025 - 15:38']

# %%
News_cards = document.select('div.news__item')
News_cards
# Out:
# [<div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 31, 2025 - 12:47</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/litecoin-ltc-decouples-from-bitcoin-in-key-metric-details">
#  <div class="news__item-title">Litecoin (LTC) Decouples From Bitcoin in Key Metric: Details</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/godfrey-benjamin"><img alt="Godfrey Benjamin" class="humble__img" height="24" src="https://u.today/sites/default/files/2022-12/29302.jpg" width="24"/>Godfrey Benjamin
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 31, 2025 - 12:02</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/breaking-strategy-buys-nearly-2-billion-worth-of-bitcoin">
#  <div class="news__item-title">Breaking: Strategy Buys Nearly $2 Billion Worth of Bitcoin</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/alex-dovbnya"><img alt="Alex Dovbnya" class="humble__img" height="24" src="https://u.today/sites/default/files/2019-11/alex-m-ava.jpg" width="24"/>Alex Dovbnya
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 31, 2025 - 10:27</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/bitcoin-btc-death-cross-appears-on-rare-indicator-what-happens-next">
#  <div class="news__item-title">Bitcoin (BTC) 'Death Cross' Appears on Rare Indicator: What Happens Next?</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/tomiwabold-olajide"><img alt="Tomiwabold Olajide" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-11/8944.jpg" width="24"/>Tomiwabold Olajide
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 31, 2025 - 9:05</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/spot-bitcoin-etf-inflows-down-73-in-seven-days-details">
#  <div class="news__item-title">Spot Bitcoin ETF Inflows Down 73% in Seven Days: Details</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/godfrey-benjamin"><img alt="Godfrey Benjamin" class="humble__img" height="24" src="https://u.today/sites/default/files/2022-12/29302.jpg" width="24"/>Godfrey Benjamin
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 31, 2025 - 7:16</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/metaplanet-issues-more-debt-to-buy-bitcoin">
#  <div class="news__item-title">Metaplanet Issues More Debt to Buy Bitcoin</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/alex-dovbnya"><img alt="Alex Dovbnya" class="humble__img" height="24" src="https://u.today/sites/default/files/2019-11/alex-m-ava.jpg" width="24"/>Alex Dovbnya
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 31, 2025 - 0:01</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/xrp-rapidly-diving-below-2-bitcoin-btc-on-verge-of-losing-80000-shiba-inu-shib-loses-all-breakout">
#  <div class="news__item-title">XRP Rapidly Diving Below $2, Bitcoin (BTC) on Verge of Losing $80,000, Shiba Inu (SHIB) Loses All Breakout Gains</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/arman-shirinyan"><img alt="Arman Shirinyan" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8993.jpg" width="24"/>Arman Shirinyan
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 30, 2025 - 17:54</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/bitcoin-magnate-to-fly-into-space-tomorrow">
#  <div class="news__item-title">Bitcoin Magnate to Fly into Space Tomorrow</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/alex-dovbnya"><img alt="Alex Dovbnya" class="humble__img" height="24" src="https://u.today/sites/default/files/2019-11/alex-m-ava.jpg" width="24"/>Alex Dovbnya
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 30, 2025 - 13:54</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/bitcoin-btc-price-prediction-for-march-30">
#  <div class="news__item-title">Bitcoin (BTC) Price Prediction for March 30</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/denys-serhiichuk"><img alt="Denys Serhiichuk" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8942.jpg" width="24"/>Denys Serhiichuk
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 30, 2025 - 13:36</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/bitcoin-btc-finds-bottom-key-indicator-hints-at-reversal">
#  <div class="news__item-title">Bitcoin (BTC) Finds Bottom? Key Indicator Hints at Reversal</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/gamza-khanzadaev"><img alt="Gamza Khanzadaev" class="humble__img" height="24" src="https://u.today/sites/default/files/2022-05/14694.jpg" width="24"/>Gamza Khanzadaev
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 30, 2025 - 13:21</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/michael-saylor-teases-another-bitcoin-mega-buy-with-new-cryptic-post">
#  <div class="news__item-title">Michael Saylor Teases Another Bitcoin Mega-Buy With New Cryptic Post</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/gamza-khanzadaev"><img alt="Gamza Khanzadaev" class="humble__img" height="24" src="https://u.today/sites/default/files/2022-05/14694.jpg" width="24"/>Gamza Khanzadaev
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 30, 2025 - 13:00</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/bitcoin-etfs-skyrocket-by-200-million-but-worrying-catch-emerges">
#  <div class="news__item-title">Bitcoin ETFs Skyrocket by $200 Million, but Worrying Catch Emerges</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/gamza-khanzadaev"><img alt="Gamza Khanzadaev" class="humble__img" height="24" src="https://u.today/sites/default/files/2022-05/14694.jpg" width="24"/>Gamza Khanzadaev
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 30, 2025 - 12:30</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/mysterious-333000000-bitcoin-transfer-stuns-major-us-exchange">
#  <div class="news__item-title">Mysterious $333,000,000 Bitcoin Transfer Stuns Major US Exchange</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/gamza-khanzadaev"><img alt="Gamza Khanzadaev" class="humble__img" height="24" src="https://u.today/sites/default/files/2022-05/14694.jpg" width="24"/>Gamza Khanzadaev
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 30, 2025 - 10:40</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/has-20000000th-bitcoin-been-mined">
#  <div class="news__item-title">Has 20,000,000th Bitcoin Been Mined?</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/alex-dovbnya"><img alt="Alex Dovbnya" class="humble__img" height="24" src="https://u.today/sites/default/files/2019-11/alex-m-ava.jpg" width="24"/>Alex Dovbnya
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 30, 2025 - 8:01</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/legendary-trader-brandt-warns-this-bitcoin-pattern-could-be-a-trap">
#  <div class="news__item-title">Legendary Trader Brandt Warns This Bitcoin Pattern Could Be a Trap</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/alex-dovbnya"><img alt="Alex Dovbnya" class="humble__img" height="24" src="https://u.today/sites/default/files/2019-11/alex-m-ava.jpg" width="24"/>Alex Dovbnya
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 29, 2025 - 20:00</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/15-years-since-huge-bitcoin-bug-satoshi-had-to-fix-asap">
#  <div class="news__item-title">15 Years Since Huge Bitcoin Bug Satoshi Had to Fix ASAP</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/yuri-molchan"><img alt="Yuri Molchan" class="humble__img" height="24" src="https://u.today/sites/default/files/2019-11/yuri-ava.jpg" width="24"/>Yuri Molchan
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 29, 2025 - 16:30</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/bitcoin-btc-price-to-72000-top-trader-on-dead-cat-bounce">
#  <div class="news__item-title">Bitcoin (BTC) Price to $72,000: Top Trader on 'Dead Cat Bounce'</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/vladislav-sopov"><img alt="Vladislav Sopov" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-07/8893.jpg" width="24"/>Vladislav Sopov
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 29, 2025 - 13:30</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/bitcoin-btc-bleeds-but-price-history-says-april-could-be-fire">
#  <div class="news__item-title">Bitcoin (BTC) Bleeds, but Price History Says April Could Be Fire</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/gamza-khanzadaev"><img alt="Gamza Khanzadaev" class="humble__img" height="24" src="https://u.today/sites/default/files/2022-05/14694.jpg" width="24"/>Gamza Khanzadaev
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 29, 2025 - 8:19</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/bitcoin-shows-bear-trap-1-million-btc-samson-mow-claims">
#  <div class="news__item-title">Bitcoin Shows Bear Trap, '$1 Million BTC' Samson Mow Claims</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/yuri-molchan"><img alt="Yuri Molchan" class="humble__img" height="24" src="https://u.today/sites/default/files/2019-11/yuri-ava.jpg" width="24"/>Yuri Molchan
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 28, 2025 - 19:38</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/fidelity-says-its-possible-for-bitcoin-to-overtake-gold">
#  <div class="news__item-title">Fidelity Says It's 'Possible' for Bitcoin to Overtake Gold</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/alex-dovbnya"><img alt="Alex Dovbnya" class="humble__img" height="24" src="https://u.today/sites/default/files/2019-11/alex-m-ava.jpg" width="24"/>Alex Dovbnya
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 28, 2025 - 15:51</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/15-billion-blackrock-celebrates-new-crypto-milestone-and-its-not-bitcoin">
#  <div class="news__item-title">$1.5 Billion: BlackRock Celebrates New Crypto Milestone, And It's Not Bitcoin</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/gamza-khanzadaev"><img alt="Gamza Khanzadaev" class="humble__img" height="24" src="https://u.today/sites/default/files/2022-05/14694.jpg" width="24"/>Gamza Khanzadaev
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 28, 2025 - 15:07</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/bitcoin-btc-loses-crucial-200-day-moving-average-amid-inflation-report">
#  <div class="news__item-title">Bitcoin (BTC) Loses Crucial 200-Day Moving Average Amid Inflation Report</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/gamza-khanzadaev"><img alt="Gamza Khanzadaev" class="humble__img" height="24" src="https://u.today/sites/default/files/2022-05/14694.jpg" width="24"/>Gamza Khanzadaev
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 28, 2025 - 14:54</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/ethereum-crashes-74-against-bitcoin-is-reversal-imminent">
#  <div class="news__item-title">Ethereum Crashes 74% Against Bitcoin; Is Reversal Imminent?</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/tomiwabold-olajide"><img alt="Tomiwabold Olajide" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-11/8944.jpg" width="24"/>Tomiwabold Olajide
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 28, 2025 - 14:37</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/schiff-bitcoin-btc-to-collapse-to-10k">
#  <div class="news__item-title">Schiff: Bitcoin (BTC) to Collapse to $10K</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/alex-dovbnya"><img alt="Alex Dovbnya" class="humble__img" height="24" src="https://u.today/sites/default/files/2019-11/alex-m-ava.jpg" width="24"/>Alex Dovbnya
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 28, 2025 - 14:36</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/bitcoin-btc-price-prediction-for-march-28-0">
#  <div class="news__item-title">Bitcoin (BTC) Price Prediction for March 28</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/denys-serhiichuk"><img alt="Denys Serhiichuk" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8942.jpg" width="24"/>Denys Serhiichuk
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 28, 2025 - 13:18</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/breaking-tether-mints-1-billion-usdt-tokens-as-bitcoin-plunges-below-85k">
#  <div class="news__item-title">Breaking: Tether Mints 1 Billion USDT Tokens as Bitcoin Plunges Below $85K</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/alex-dovbnya"><img alt="Alex Dovbnya" class="humble__img" height="24" src="https://u.today/sites/default/files/2019-11/alex-m-ava.jpg" width="24"/>Alex Dovbnya
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 28, 2025 - 12:14</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/bitcoin-btc-major-core-update-key-changes-revealed">
#  <div class="news__item-title">Bitcoin (BTC) Major Core Update: Key Changes Revealed</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/tomiwabold-olajide"><img alt="Tomiwabold Olajide" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-11/8944.jpg" width="24"/>Tomiwabold Olajide
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 28, 2025 - 11:32</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/bitcoin-btc-faces-brutal-drop-confirms-legendary-trader-peter-brandt">
#  <div class="news__item-title">Bitcoin (BTC) Faces Brutal Drop, Confirms Legendary Trader Peter Brandt</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/gamza-khanzadaev"><img alt="Gamza Khanzadaev" class="humble__img" height="24" src="https://u.today/sites/default/files/2022-05/14694.jpg" width="24"/>Gamza Khanzadaev
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 28, 2025 - 9:46</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/rich-dad-poor-dad-author-predicts-new-ath-for-second-best-asset-to-bitcoin">
#  <div class="news__item-title">'Rich Dad Poor Dad' Author Predicts New ATH for Second Best Asset to Bitcoin</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/yuri-molchan"><img alt="Yuri Molchan" class="humble__img" height="24" src="https://u.today/sites/default/files/2019-11/yuri-ava.jpg" width="24"/>Yuri Molchan
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 28, 2025 - 0:01</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/shiba-inu-shib-bulls-in-control-now-bitcoin-btc-in-great-spot-ethereum-eth-major-bearish-signal-but">
#  <div class="news__item-title">Shiba Inu (SHIB): Bulls in Control Now? Bitcoin (BTC) in Great Spot, Ethereum (ETH): Major Bearish Signal, But There's Silver Lining </div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/arman-shirinyan"><img alt="Arman Shirinyan" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8993.jpg" width="24"/>Arman Shirinyan
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 27, 2025 - 20:46</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/buying-bitcoin-not-viable-long-term-business-model-says-peter-schiff">
#  <div class="news__item-title">Buying Bitcoin 'Not Viable Long-Term Business Model', Says Peter Schiff</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/caroline-amosun"><img alt="Caroline Amosun" class="humble__img" height="24" src="https://u.today/sites/default/files/2025-03/56827.jpg" width="24"/>Caroline Amosun
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 27, 2025 - 20:04</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/us-government-moving-millions-of-dollars-worth-of-bitcoin">
#  <div class="news__item-title">US Government Moving Millions of Dollars Worth of Bitcoin</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/alex-dovbnya"><img alt="Alex Dovbnya" class="humble__img" height="24" src="https://u.today/sites/default/files/2019-11/alex-m-ava.jpg" width="24"/>Alex Dovbnya
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 27, 2025 - 18:29</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/gamestop-shares-getting-annihilated-following-bitcoin-pivot">
#  <div class="news__item-title">GameStop Shares Getting Annihilated Following Bitcoin Pivot</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/alex-dovbnya"><img alt="Alex Dovbnya" class="humble__img" height="24" src="https://u.today/sites/default/files/2019-11/alex-m-ava.jpg" width="24"/>Alex Dovbnya
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 27, 2025 - 15:13</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/peter-schiff-reacts-to-bitcoins-drop-as-gold-sets-fresh-record-high">
#  <div class="news__item-title">Peter Schiff Reacts to Bitcoin's Drop as Gold Sets Fresh Record High</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/tomiwabold-olajide"><img alt="Tomiwabold Olajide" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-11/8944.jpg" width="24"/>Tomiwabold Olajide
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 27, 2025 - 15:01</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/xrp-vs-bitcoin-btc-3-big-scenarios-from-bollinger-bands">
#  <div class="news__item-title">XRP vs. Bitcoin (BTC): 3 Big Scenarios From Bollinger Bands</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/gamza-khanzadaev"><img alt="Gamza Khanzadaev" class="humble__img" height="24" src="https://u.today/sites/default/files/2022-05/14694.jpg" width="24"/>Gamza Khanzadaev
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 27, 2025 - 13:53</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/billionaire-cliff-asness-im-not-a-bitcoin-fan">
#  <div class="news__item-title">Billionaire Cliff Asness: "I'm Not a Bitcoin Fan'</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/alex-dovbnya"><img alt="Alex Dovbnya" class="humble__img" height="24" src="https://u.today/sites/default/files/2019-11/alex-m-ava.jpg" width="24"/>Alex Dovbnya
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 27, 2025 - 13:47</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/strategys-saylor-joins-gihbli-trend-with-bullish-bitcoin-post">
#  <div class="news__item-title">Strategy's Saylor Joins Gihbli Trend With Bullish Bitcoin Post</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/godfrey-benjamin"><img alt="Godfrey Benjamin" class="humble__img" height="24" src="https://u.today/sites/default/files/2022-12/29302.jpg" width="24"/>Godfrey Benjamin
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 26, 2025 - 20:16</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/breaking-gamestop-raising-13-billion-to-buy-bitcoin">
#  <div class="news__item-title">Breaking: GameStop Raising $1.3 Billion to Buy Bitcoin</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/alex-dovbnya"><img alt="Alex Dovbnya" class="humble__img" height="24" src="https://u.today/sites/default/files/2019-11/alex-m-ava.jpg" width="24"/>Alex Dovbnya
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 26, 2025 - 19:45</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/bitcoin-whales-with-10k-btc-holdings-increase-supply-squeeze-incoming">
#  <div class="news__item-title">Bitcoin Whales With 10K BTC Holdings Increase — Supply Squeeze Incoming?</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/andy-sawa"><img alt="Andy Sawa" class="humble__img" height="24" src="https://u.today/sites/default/files/2025-03/56809.jpg" width="24"/>Andy Sawa
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 26, 2025 - 15:45</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/bitcoin-not-in-overheated-zone-yet-cryptoquant">
#  <div class="news__item-title">Bitcoin Not in 'Overheated Zone' Yet: CryptoQuant</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/godfrey-benjamin"><img alt="Godfrey Benjamin" class="humble__img" height="24" src="https://u.today/sites/default/files/2022-12/29302.jpg" width="24"/>Godfrey Benjamin
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 26, 2025 - 15:30</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/we-are-all-satoshi-usdt-founder-reacts-to-news-about-bitcoin-creator">
#  <div class="news__item-title">'We Are All Satoshi': USDT Founder Reacts to News About Bitcoin Creator</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/gamza-khanzadaev"><img alt="Gamza Khanzadaev" class="humble__img" height="24" src="https://u.today/sites/default/files/2022-05/14694.jpg" width="24"/>Gamza Khanzadaev
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 26, 2025 - 14:46</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/bitcoin-up-700-since-michael-saylors-strategys-first-btc-buy">
#  <div class="news__item-title">Bitcoin up 700% Since Michael Saylor's Strategy's First BTC Buy</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/tomiwabold-olajide"><img alt="Tomiwabold Olajide" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-11/8944.jpg" width="24"/>Tomiwabold Olajide
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 26, 2025 - 14:17</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/strategys-saylor-challenges-gamestop-to-go-big-on-bitcoin">
#  <div class="news__item-title">Strategy's Saylor Challenges GameStop to Go Big on Bitcoin </div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/alex-dovbnya"><img alt="Alex Dovbnya" class="humble__img" height="24" src="https://u.today/sites/default/files/2019-11/alex-m-ava.jpg" width="24"/>Alex Dovbnya
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 26, 2025 - 11:55</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/bitcoin-btc-invalidates-death-cross-whats-next">
#  <div class="news__item-title">Bitcoin (BTC) Invalidates Death Cross: What's Next?</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/gamza-khanzadaev"><img alt="Gamza Khanzadaev" class="humble__img" height="24" src="https://u.today/sites/default/files/2022-05/14694.jpg" width="24"/>Gamza Khanzadaev
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 26, 2025 - 10:56</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/mysterious-262759132-bitcoin-transfer-stuns-major-us-exchange">
#  <div class="news__item-title">Mysterious $262,759,132 Bitcoin Transfer Stuns Major US Exchange</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/gamza-khanzadaev"><img alt="Gamza Khanzadaev" class="humble__img" height="24" src="https://u.today/sites/default/files/2022-05/14694.jpg" width="24"/>Gamza Khanzadaev
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 26, 2025 - 7:19</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/legendary-angel-investor-mocks-gamestops-bitcoin-pivot">
#  <div class="news__item-title">Legendary Angel Investor Mocks GameStop's Bitcoin Pivot</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/alex-dovbnya"><img alt="Alex Dovbnya" class="humble__img" height="24" src="https://u.today/sites/default/files/2019-11/alex-m-ava.jpg" width="24"/>Alex Dovbnya
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 26, 2025 - 0:01</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/bitcoin-btc-mini-death-cross-originates-key-xrp-breakthrough-turns-to-be-fakeout-dogecoin-doge-only">
#  <div class="news__item-title">Bitcoin (BTC) Mini-Death Cross Originates, Key XRP Breakthrough Turns to be Fakeout? Dogecoin (DOGE) Only Top Asset Didn't Do It</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/arman-shirinyan"><img alt="Arman Shirinyan" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8993.jpg" width="24"/>Arman Shirinyan
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 25, 2025 - 20:05</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/breaking-gamestop-to-adopt-bitcoin-as-reserve-asset">
#  <div class="news__item-title">Breaking: GameStop Adopts Bitcoin as Reserve Asset</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/alex-dovbnya"><img alt="Alex Dovbnya" class="humble__img" height="24" src="https://u.today/sites/default/files/2019-11/alex-m-ava.jpg" width="24"/>Alex Dovbnya
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 25, 2025 - 20:00</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/fidelitys-timmer-says-bitcoins-wallet-count-shows-little-growth">
#  <div class="news__item-title">Fidelity's Timmer Says Bitcoin's Wallet Count Shows Little Growth </div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/alex-dovbnya"><img alt="Alex Dovbnya" class="humble__img" height="24" src="https://u.today/sites/default/files/2019-11/alex-m-ava.jpg" width="24"/>Alex Dovbnya
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 25, 2025 - 15:49</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/bitcoin-btc-breakout-bollinger-bands-hint-at-big-upside">
#  <div class="news__item-title">Bitcoin (BTC) Breakout? Bollinger Bands Hint at Big Upside</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/gamza-khanzadaev"><img alt="Gamza Khanzadaev" class="humble__img" height="24" src="https://u.today/sites/default/files/2022-05/14694.jpg" width="24"/>Gamza Khanzadaev
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 25, 2025 - 15:38</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/xrp-hits-bullish-reversal-bitcoin-faces-great-reset-risk-mike-mcglone-warns-second-biggest-shib">
#  <div class="news__item-title">XRP Hits Bullish Reversal, Bitcoin Faces 'Great Reset' Risk, Mike McGlone Warns; Second Biggest SHIB Wallet Sees Mysterious Transfers: Crypto News Digest by U.Today</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/valeria-blokhina"><img alt="Valeria Blokhina" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-10/9844.jpg" width="24"/>Valeria Blokhina
#              </a></div>
#  </div>,
#  <div class="news__item"><a class="news__item-body" href="https://u.today/press-releases/arciums-encrypted-ecosystem-established-to-accelerate-private-computation">
#  <div class="news__item-title">Arcium’s ‘Encrypted Ecosystem’ Established To Accelerate Private Computation</div>
#  </a></div>,
#  <div class="news__item"><a class="news__item-body" href="https://u.today/press-releases/blofin-becomes-title-sponsor-of-token2049-dubai-and-hosts-the-inaugural-whales-rave">
#  <div class="news__item-title">BloFin Becomes Title Sponsor of TOKEN2049 Dubai and Hosts the Inaugural Whale’s Rave: Arcadia Afterparty</div>
#  </a></div>,
#  <div class="news__item"><a class="news__item-body" href="https://u.today/press-releases/aster-emerges-astherus-rebrands-to-lead-decentralized-perpetual-trading">
#  <div class="news__item-title">Aster Emerges: Astherus Rebrands to Lead Decentralized Perpetual Trading</div>
#  </a></div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/companies" hreflang="en">Companies</a>
#  <div class="humble">Mar 14, 2025 - 16:04</div>
#  </div><a class="news__item-body" href="https://u.today/nebula-stride-announces-major-developments-as-nst-presale-gains-traction">
#  <div class="news__item-title">Nebula Stride Announces Major Developments as NST Presale Gains Traction</div></a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/vladislav-sopov">
#  <img alt="article image" class="humble__img" height="140" src="https://u.today/sites/default/files/2021-07/8893.jpg" width="224">
#              Vladislav Sopov</img></a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/opinions" hreflang="en">Opinions</a>
#  <div class="humble">Feb 2, 2025 - 18:00</div>
#  </div><a class="news__item-body" href="https://u.today/opinions/ripple-vs-sec-how-will-new-developments-affect-xrp-price">
#  <div class="news__item-title">Ripple v. SEC: How Will New Developments Affect XRP Price?</div></a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/dan-burgin">
#  <img alt="article image" class="humble__img" height="140" src="https://u.today/sites/default/files/2024-02/45425.jpg" width="224">
#              Dan Burgin</img></a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/opinions" hreflang="en">Opinions</a>
#  <div class="humble">Jan 18, 2025 - 18:00</div>
#  </div><a class="news__item-body" href="https://u.today/opinions/stellar-lumen-xlm-price-prediction-2025">
#  <div class="news__item-title">Stellar Lumen (XLM) Price Prediction 2025</div></a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/dan-burgin">
#  <img alt="article image" class="humble__img" height="140" src="https://u.today/sites/default/files/2024-02/45425.jpg" width="224">
#              Dan Burgin</img></a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/guides" hreflang="en">Guides</a>
#  <div class="humble">Jan 16, 2025 - 1:30</div>
#  </div><a class="news__item-body" href="https://u.today/guides/what-is-desci-guide-on-decentralized-science-in-crypto">
#  <div class="news__item-title">What is DeSci: Guide on Decentralized Science in Crypto</div></a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/vladislav-sopov">
#  <img alt="article image" class="humble__img" height="140" src="https://u.today/sites/default/files/2021-07/8893.jpg" width="224">
#              Vladislav Sopov</img></a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/latest-cryptocurrency-news" hreflang="en">News</a>
#  <div class="humble">Jan 15, 2025 - 10:56</div>
#  </div><a class="news__item-body" href="https://u.today/top-10-crypto-media-outlets-enter-2025-latest-similarweb-data-update">
#  <div class="news__item-title">Top 10 Crypto Media Outlets Enter 2025: Latest Similarweb Data Update</div></a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/vladislav-sopov">
#  <img alt="article image" class="humble__img" height="140" src="https://u.today/sites/default/files/2021-07/8893.jpg" width="224">
#              Vladislav Sopov</img></a></div>
#  </div>]

# %%
from datetime import datetime

Bitcoin_data = []
for card in News_cards:
    data = []
    date_bt = card.select_one('div.news__item-head div.humble')
    if date_bt != None:
        datestr = date_bt.get_text()
        data.append(datetime.strptime(datestr.split(" - ")[0], "%b %d, %Y").date())
    title_bt = card.select_one('div.news__item-title')
    if title_bt != None:
        data.append(title_bt.get_text())
    if len(data) == 2:
     Bitcoin_data.append(tuple(data))
    
Bitcoin_data
# Out:
# [(datetime.date(2025, 3, 31),
#   'Litecoin (LTC) Decouples From Bitcoin in Key Metric: Details'),
#  (datetime.date(2025, 3, 31),
#   'Breaking: Strategy Buys Nearly $2 Billion Worth of Bitcoin'),
#  (datetime.date(2025, 3, 31),
#   "Bitcoin (BTC) 'Death Cross' Appears on Rare Indicator: What Happens Next?"),
#  (datetime.date(2025, 3, 31),
#   'Spot Bitcoin ETF Inflows Down 73% in Seven Days: Details'),
#  (datetime.date(2025, 3, 31), 'Metaplanet Issues More Debt to Buy Bitcoin'),
#  (datetime.date(2025, 3, 31),
#   'XRP Rapidly Diving Below $2, Bitcoin (BTC) on Verge of Losing $80,000, Shiba Inu (SHIB) Loses All Breakout Gains'),
#  (datetime.date(2025, 3, 30), 'Bitcoin Magnate to Fly into Space Tomorrow'),
#  (datetime.date(2025, 3, 30), 'Bitcoin (BTC) Price Prediction for March 30'),
#  (datetime.date(2025, 3, 30),
#   'Bitcoin (BTC) Finds Bottom? Key Indicator Hints at Reversal'),
#  (datetime.date(2025, 3, 30),
#   'Michael Saylor Teases Another Bitcoin Mega-Buy With New Cryptic Post'),
#  (datetime.date(2025, 3, 30),
#   'Bitcoin ETFs Skyrocket by $200 Million, but Worrying Catch Emerges'),
#  (datetime.date(2025, 3, 30),
#   'Mysterious $333,000,000 Bitcoin Transfer Stuns Major US Exchange'),
#  (datetime.date(2025, 3, 30), 'Has 20,000,000th Bitcoin Been Mined?'),
#  (datetime.date(2025, 3, 30),
#   'Legendary Trader Brandt Warns This Bitcoin Pattern Could Be a Trap'),
#  (datetime.date(2025, 3, 29),
#   '15 Years Since Huge Bitcoin Bug Satoshi Had to Fix ASAP'),
#  (datetime.date(2025, 3, 29),
#   "Bitcoin (BTC) Price to $72,000: Top Trader on 'Dead Cat Bounce'"),
#  (datetime.date(2025, 3, 29),
#   'Bitcoin (BTC) Bleeds, but Price History Says April Could Be Fire'),
#  (datetime.date(2025, 3, 29),
#   "Bitcoin Shows Bear Trap, '$1 Million BTC' Samson Mow Claims"),
#  (datetime.date(2025, 3, 28),
#   "Fidelity Says It's 'Possible' for Bitcoin to Overtake Gold"),
#  (datetime.date(2025, 3, 28),
#   "$1.5 Billion: BlackRock Celebrates New Crypto Milestone, And It's Not Bitcoin"),
#  (datetime.date(2025, 3, 28),
#   'Bitcoin (BTC) Loses Crucial 200-Day Moving Average Amid Inflation Report'),
#  (datetime.date(2025, 3, 28),
#   'Ethereum Crashes 74% Against Bitcoin; Is Reversal Imminent?'),
#  (datetime.date(2025, 3, 28), 'Schiff: Bitcoin (BTC) to Collapse to $10K'),
#  (datetime.date(2025, 3, 28), 'Bitcoin (BTC) Price Prediction for March 28'),
#  (datetime.date(2025, 3, 28),
#   'Breaking: Tether Mints 1 Billion USDT Tokens as Bitcoin Plunges Below $85K'),
#  (datetime.date(2025, 3, 28),
#   'Bitcoin (BTC) Major Core Update: Key Changes Revealed'),
#  (datetime.date(2025, 3, 28),
#   'Bitcoin (BTC) Faces Brutal Drop, Confirms Legendary Trader Peter Brandt'),
#  (datetime.date(2025, 3, 28),
#   "'Rich Dad Poor Dad' Author Predicts New ATH for Second Best Asset to Bitcoin"),
#  (datetime.date(2025, 3, 28),
#   "Shiba Inu (SHIB): Bulls in Control Now? Bitcoin (BTC) in Great Spot, Ethereum (ETH): Major Bearish Signal, But There's Silver Lining "),
#  (datetime.date(2025, 3, 27),
#   "Buying Bitcoin 'Not Viable Long-Term Business Model', Says Peter Schiff"),
#  (datetime.date(2025, 3, 27),
#   'US Government Moving Millions of Dollars Worth of Bitcoin'),
#  (datetime.date(2025, 3, 27),
#   'GameStop Shares Getting Annihilated Following Bitcoin Pivot'),
#  (datetime.date(2025, 3, 27),
#   "Peter Schiff Reacts to Bitcoin's Drop as Gold Sets Fresh Record High"),
#  (datetime.date(2025, 3, 27),
#   'XRP vs. Bitcoin (BTC): 3 Big Scenarios From Bollinger Bands'),
#  (datetime.date(2025, 3, 27),
#   'Billionaire Cliff Asness: "I\'m Not a Bitcoin Fan\''),
#  (datetime.date(2025, 3, 27),
#   "Strategy's Saylor Joins Gihbli Trend With Bullish Bitcoin Post"),
#  (datetime.date(2025, 3, 26),
#   'Breaking: GameStop Raising $1.3 Billion to Buy Bitcoin'),
#  (datetime.date(2025, 3, 26),
#   'Bitcoin Whales With 10K BTC Holdings Increase — Supply Squeeze Incoming?'),
#  (datetime.date(2025, 3, 26),
#   "Bitcoin Not in 'Overheated Zone' Yet: CryptoQuant"),
#  (datetime.date(2025, 3, 26),
#   "'We Are All Satoshi': USDT Founder Reacts to News About Bitcoin Creator"),
#  (datetime.date(2025, 3, 26),
#   "Bitcoin up 700% Since Michael Saylor's Strategy's First BTC Buy"),
#  (datetime.date(2025, 3, 26),
#   "Strategy's Saylor Challenges GameStop to Go Big on Bitcoin "),
#  (datetime.date(2025, 3, 26),
#   "Bitcoin (BTC) Invalidates Death Cross: What's Next?"),
#  (datetime.date(2025, 3, 26),
#   'Mysterious $262,759,132 Bitcoin Transfer Stuns Major US Exchange'),
#  (datetime.date(2025, 3, 26),
#   "Legendary Angel Investor Mocks GameStop's Bitcoin Pivot"),
#  (datetime.date(2025, 3, 26),
#   "Bitcoin (BTC) Mini-Death Cross Originates, Key XRP Breakthrough Turns to be Fakeout? Dogecoin (DOGE) Only Top Asset Didn't Do It"),
#  (datetime.date(2025, 3, 25),
#   'Breaking: GameStop Adopts Bitcoin as Reserve Asset'),
#  (datetime.date(2025, 3, 25),
#   "Fidelity's Timmer Says Bitcoin's Wallet Count Shows Little Growth "),
#  (datetime.date(2025, 3, 25),
#   'Bitcoin (BTC) Breakout? Bollinger Bands Hint at Big Upside'),
#  (datetime.date(2025, 3, 25),
#   "XRP Hits Bullish Reversal, Bitcoin Faces 'Great Reset' Risk, Mike McGlone Warns; Second Biggest SHIB Wallet Sees Mysterious Transfers: Crypto News Digest by U.Today"),
#  (datetime.date(2025, 3, 14),
#   'Nebula Stride Announces Major Developments as NST Presale Gains Traction'),
#  (datetime.date(2025, 2, 2),
#   'Ripple v. SEC: How Will New Developments Affect XRP Price?'),
#  (datetime.date(2025, 1, 18), 'Stellar Lumen (XLM) Price Prediction 2025'),
#  (datetime.date(2025, 1, 16),
#   'What is DeSci: Guide on Decentralized Science in Crypto'),
#  (datetime.date(2025, 1, 15),
#   'Top 10 Crypto Media Outlets Enter 2025: Latest Similarweb Data Update')]

# %%
Bitcoin_Dataf = pd.DataFrame(Bitcoin_data, columns = ['date', 'title'])
Bitcoin_Dataf
# Out:
#           date                                              title
# 0   2025-03-31  Litecoin (LTC) Decouples From Bitcoin in Key M...
# 1   2025-03-31  Breaking: Strategy Buys Nearly $2 Billion Wort...
# 2   2025-03-31  Bitcoin (BTC) 'Death Cross' Appears on Rare In...
# 3   2025-03-31  Spot Bitcoin ETF Inflows Down 73% in Seven Day...
# 4   2025-03-31         Metaplanet Issues More Debt to Buy Bitcoin
# 5   2025-03-31  XRP Rapidly Diving Below $2, Bitcoin (BTC) on ...
# 6   2025-03-30         Bitcoin Magnate to Fly into Space Tomorrow
# 7   2025-03-30        Bitcoin (BTC) Price Prediction for March 30
# 8   2025-03-30  Bitcoin (BTC) Finds Bottom? Key Indicator Hint...
# 9   2025-03-30  Michael Saylor Teases Another Bitcoin Mega-Buy...
# 10  2025-03-30  Bitcoin ETFs Skyrocket by $200 Million, but Wo...
# 11  2025-03-30  Mysterious $333,000,000 Bitcoin Transfer Stuns...
# 12  2025-03-30               Has 20,000,000th Bitcoin Been Mined?
# 13  2025-03-30  Legendary Trader Brandt Warns This Bitcoin Pat...
# 14  2025-03-29  15 Years Since Huge Bitcoin Bug Satoshi Had to...
# 15  2025-03-29  Bitcoin (BTC) Price to $72,000: Top Trader on ...
# 16  2025-03-29  Bitcoin (BTC) Bleeds, but Price History Says A...
# 17  2025-03-29  Bitcoin Shows Bear Trap, '$1 Million BTC' Sams...
# 18  2025-03-28  Fidelity Says It's 'Possible' for Bitcoin to O...
# 19  2025-03-28  $1.5 Billion: BlackRock Celebrates New Crypto ...
# 20  2025-03-28  Bitcoin (BTC) Loses Crucial 200-Day Moving Ave...
# 21  2025-03-28  Ethereum Crashes 74% Against Bitcoin; Is Rever...
# 22  2025-03-28          Schiff: Bitcoin (BTC) to Collapse to $10K
# 23  2025-03-28        Bitcoin (BTC) Price Prediction for March 28
# 24  2025-03-28  Breaking: Tether Mints 1 Billion USDT Tokens a...
# 25  2025-03-28  Bitcoin (BTC) Major Core Update: Key Changes R...
# 26  2025-03-28  Bitcoin (BTC) Faces Brutal Drop, Confirms Lege...
# 27  2025-03-28  'Rich Dad Poor Dad' Author Predicts New ATH fo...
# 28  2025-03-28  Shiba Inu (SHIB): Bulls in Control Now? Bitcoi...
# 29  2025-03-27  Buying Bitcoin 'Not Viable Long-Term Business ...
# 30  2025-03-27  US Government Moving Millions of Dollars Worth...
# 31  2025-03-27  GameStop Shares Getting Annihilated Following ...
# 32  2025-03-27  Peter Schiff Reacts to Bitcoin's Drop as Gold ...
# 33  2025-03-27  XRP vs. Bitcoin (BTC): 3 Big Scenarios From Bo...
# 49  2025-03-25  XRP Hits Bullish Reversal, Bitcoin Faces 'Grea...  Bitcoin
# 50  2025-03-14  Nebula Stride Announces Major Developments as ...  Bitcoin
# 51  2025-02-02  Ripple v. SEC: How Will New Developments Affec...  Bitcoin
# 52  2025-01-18          Stellar Lumen (XLM) Price Prediction 2025  Bitcoin
# 53  2025-01-16  What is DeSci: Guide on Decentralized Science ...  Bitcoin
# 54  2025-01-15  Top 10 Crypto Media Outlets Enter 2025: Latest...  Bitcoin

# %%
# Optional: Save to CSV
Bitcoin_Dataf.to_csv('Bitcoin_Daily_News.csv', index=False)

# %% [markdown]
# # Ethereum scrapping

# %%
import requests

url = 'import requests'

url = 'https://u.today/search/node?keys=Ethereum'
response_e = requests.get(url)
response_e
# Out:
# <Response [200]>

# %%
import requests
import bs4

response = requests.get("https://u.today/search/node?keys=Ethereum")
# soup = bs4.BeautifulSoup(response.text, 'lxml') # with lxml package
doc = bs4.BeautifulSoup(response.text, 'html.parser') 
doc
# Out:
#  <!DOCTYPE html>
#
# <html class="theme-light" dir="ltr" lang="en" prefix="og: ogp.me/ns#">
# <head>
# <script async="" crossorigin="anonymous" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js?client=ca-pub-9245916885225528"></script>
# <link href="https://www.google-analytics.com" rel="preconnect"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=5" name="viewport"/>
# <script src="/core/assets/vendor/jquery/jquery.min.js"></script>
# <meta charset="utf-8">
# <link href="https://u.today/search/node" rel="canonical">
# <meta content="article" property="og:type"/>
# <meta content="https://u.today/search/node" property="og:url"/>
# <meta content="Search" property="og:title"/>
# <meta content="Search" property="og:description"/>
# <meta content="https://u.today/img/logo-utoday.png" property="og:image"/>
# <meta content="https://u.today/img/logo-utoday.png" property="og:image:url"/>
# <meta content="https://u.today/img/logo-utoday.png" property="og:image:secure_url"/>
# <meta content="2560796210663191" property="fb:app_id"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="@Utoday_en" name="twitter:site"/>
# <meta content="https://u.today/img/logo-utoday.png" name="twitter:image"/>
# <meta content="Drupal 10 (https://www.drupal.org)" name="Generator"/>
# <meta content="width" name="MobileOptimized"/>
# <meta content="true" name="HandheldFriendly"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <script type="application/ld+json">{
#     "@context": "https://schema.org",
#     "@graph": [
#         {
#             "@type": "Organization",
#             "name": "U.Today",
#             "url": "https://u.today/search/node",
#             "image": {
#                 "@type": "ImageObject",
#                 "url": "https://U.today/img/logo-utoday.png"
#             }
#         }
#     ]
# }</script>
# <!-- end: separate google analytics code -->
# <!-- Google Tag Manager -->
# <!-- End Google Tag Manager -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-2PE2QV2V0X"></script>
# <script>
#         window.dataLayer = window.dataLayer || [];
#         function gtag(){dataLayer.push(arguments);}
#         gtag('js', new Date());
#
#         gtag('config', 'G-2PE2QV2V0X');
#     </script>
# <link color="#263238" href="/img/favicon/safari-pinned-tab.svg" rel="mask-icon"/>
# <link href="/img/favicon/apple-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
# <link href="/img/favicon/apple-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
# <link href="/img/favicon/apple-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
# <link href="/img/favicon/apple-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
# <link href="/img/favicon/apple-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
# <link href="/img/favicon/apple-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
# <link href="/img/favicon/apple-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
# <link href="/img/favicon/apple-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
# <link href="/img/favicon/apple-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/img/favicon/android-icon-192x192.png" rel="icon" sizes="192x192" type="image/png"/>
# <link href="/img/favicon/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/img/favicon/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
# <link href="/img/favicon/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/site.webmanifest" rel="manifest"/>
# <link color="#263238" href="/img/favicon/safari-pinned-tab.svg" rel="mask-icon"/>
# <link href="/img/favicon/favicon.ico" rel="shortcut icon"/>
# <meta content="#263238" name="msapplication-TileColor"/>
# <meta content="/img/favicon/browserconfig.xml" name="msapplication-config"/>
# <meta content="#263238" name="theme-color"/>
# <meta content="2E6EDC1D9A57E69FC6232E905A08CBFA" name="msvalidate.01">
# <link href="/manifest.json" rel="manifest">
# <meta content="266789420636465" property="fb:pages">
# <link href="/modules/contrib/paragraphs/css/paragraphs.unpublished.css?stzpi2" media="all" rel="stylesheet">
# <link href="/themes/cryptod/libs/air-datepicker/air-datepicker.css?stzpi2" media="all" rel="stylesheet">
# <link href="/themes/cryptod/styles/slick-theme.css?stzpi2" media="all" rel="stylesheet">
# <link href="/themes/cryptod/styles/common.css?stzpi2" media="all" rel="stylesheet">
# <link href="/themes/cryptod/styles/app.css?stzpi2" media="all" rel="stylesheet">
# <link href="/themes/cryptod/styles/push.css?stzpi2" media="all" rel="stylesheet">
# <style>.ccc-widget.ccc-list .header-div a img {
#                             width: 26px;
#                             height: 26px;
#                         }
#                     </style>
# <title>Search | U.Today</title>
# <script src="https://cdn.onesignal.com/sdks/OneSignalSDK.js"></script>
# <script>
#                         function copyToClipboard(e) {
#                             let input = document.body.appendChild(document.createElement("input"));
#                             input.value = window.location.href;
#                             input.select();
#                             document.execCommand('copy');
#                             input.parentNode.removeChild(input);
#
#                             let tooltip = document.createElement('div');
#                             tooltip.className = 'copy-tooltip';
#                             tooltip.innerHTML = 'Copied!';
#
#                             if (!e.querySelector('.copy-tooltip')) {
#                                 e.append(tooltip);
#
#                                 setTimeout(() => {
#                                     e.querySelector('.copy-tooltip').remove();
#                                 }, 2000);
#                             }
#                         }
#                     </script>
# <style>
#                         @media (max-width: 849px) {
#                             body #onesignal-slidedown-container.slide-up {
#                                 bottom: 60px
#                             }
#                         }
#                     </style>
# <script async="" defer="" src="https://www.google.com/recaptcha/api.js"></script>
# <style>
#                         .captcha-container {
#                             display: none; /* CAPTCHA скрыта по умолчанию */
#                         }
#                     </style>
# </link></link></link></link></link></link></meta></link></meta></link></meta></head>
# <body class="not_logged_in">
# <!-- Google Tag Manager (noscript) -->
# <!-- End Google Tag Manager (noscript) -->
# <div class="something--upper">
# <div class="something">
# <div class="something__title">Advertisement</div>
# <div class="something__nav">
# <div class="something__label">AD</div>
# <button aria-label="Close ad" class="btn btn--light something__close"></button>
# </div>
# <div class="something__content">
# <div class="something__content--long">
# <div>
# <!-- Wideheader Fixed Desktop 1150x60 [async] -->
# <script type="text/javascript">
#
# if (!window.AdButler){(function(){var s = document.createElement("script"); s.async = true; s.type = "text/javascript"; s.src = 'https://servedbyadbutler.com/app.js'; var n = document.getElementsByTagName("script")[0]; n.parentNode.insertBefore(s, n);}());}
#
# </script>
# <script type="text/javascript">
# var AdButler = AdButler || {};
# AdButler.ads = AdButler.ads || [];
# var abkw = window.abkw || '';
# var plc602403 = window.plc602403 || 0;
# document.write('<'+'div id="placement_602403_'+plc602403+'"></'+'div>');
# AdButler.ads.push({handler: function(opt){ AdButler.register(183269, 602403, [1150,60], 'placement_602403_'+opt.place, opt); }, opt: { place: plc602403++, keywords: abkw, domain: 'servedbyadbutler.com', click: 'CLICK_MACRO_PLACEHOLDER' }});
#
# </script>
# </div>
# </div>
# <div class="something__content--square">
# <div>
# <!-- Wideheader Fixed Mobile 336x60 [async] -->
# <script type="text/javascript">
# if (document.documentElement.clientWidth < 768) {
# if (!window.AdButler){(function(){var s = document.createElement("script"); s.async = true; s.type = "text/javascript"; s.src = 'https://servedbyadbutler.com/app.js'; var n = document.getElementsByTagName("script")[0]; n.parentNode.insertBefore(s, n);}());}
# }
# </script>
# <script type="text/javascript">
# if (document.documentElement.clientWidth < 768) {
# var AdButler = AdButler || {};
# AdButler.ads = AdButler.ads || [];
# var abkw = window.abkw || '';
# var plc551690 = window.plc551690 || 0;
# document.write('<'+'div id="placement_551690_'+plc551690+'"></'+'div>');
# AdButler.ads.push({handler: function(opt){ AdButler.register(183269, 551690, [336,60], 'placement_551690_'+opt.place, opt); }, opt: { place: plc551690++, keywords: abkw, domain: 'servedbyadbutler.com', click: 'CLICK_MACRO_PLACEHOLDER' }});
# }
# </script>
# </div>
# </div>
# </div>
# </div>
# </div>
# <header class="header">
# <div class="header__container"><a class="header__logo" href="https://u.today/" title="U.Today logo"></a>
# <div class="header__search" style="display: block">
# <form action="/search/node" class="header__search-form" method="get">
# <button class="header__search-submit btn btn--light btn--search" style="display: none;" type="submit"></button>
# <input class="header__search-input" id="search_text" name="keys" type="text"/>
# <button class="header__search-close btn btn--light btn--cross"></button>
# </form>
# </div>
# </div>
# </header>
# <div class="mobile-menu-cover"></div>
# <div class="page-container container">
# <div class="main-aside-container">
# <main class="main-block">
# <div class="search-result">
# <h1 class="page-bg-title">Search results for “Ethereum”</h1>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 30, 2025 - 14:43</div>
# </div>
# <a class="news__item-body" href="https://u.today/ethereum-eth-price-prediction-for-march-30">
# <div class="news__item-title">Ethereum (ETH) Price Prediction for March 30</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/denys-serhiichuk"><img alt="Denys Serhiichuk" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8942.jpg" width="24"/>Denys Serhiichuk
#             </a></div>
# </div>
# <div class="something something--content">
# <div class="something__content-long">
# <ins class="adsbygoogle" data-ad-client="ca-pub-4834169448759613" data-ad-slot="1698558466" style="display:inline-block;width:728px;height:90px"></ins>
# </div>
# <div class="something__content-square">
# <ins class="adsbygoogle" data-ad-client="ca-pub-4834169448759613" data-ad-slot="4003311693" style="display:inline-block;width:336px;height:280px"></ins>
# </div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 30, 2025 - 12:00</div>
# </div>
# <a class="news__item-body" href="https://u.today/pre-mine-ethereum-address-suddenly-activated">
# <div class="news__item-title">Pre-Mine Ethereum Address Suddenly Activated</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/alex-dovbnya"><img alt="Alex Dovbnya" class="humble__img" height="24" src="https://u.today/sites/default/files/2019-11/alex-m-ava.jpg" width="24"/>Alex Dovbnya
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 30, 2025 - 11:00</div>
# </div>
# <a class="news__item-body" href="https://u.today/ethereum-eth-awaiting-crucial-crossover-details">
# <div class="news__item-title">Ethereum (ETH) Awaiting Crucial Crossover: Details</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/tomiwabold-olajide"><img alt="Tomiwabold Olajide" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-11/8944.jpg" width="24"/>Tomiwabold Olajide
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 29, 2025 - 14:54</div>
# </div>
# <a class="news__item-body" href="https://u.today/ethereum-eth-price-prediction-for-march-29">
# <div class="news__item-title">Ethereum (ETH) Price Prediction for March 29</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/denys-serhiichuk"><img alt="Denys Serhiichuk" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8942.jpg" width="24"/>Denys Serhiichuk
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 29, 2025 - 14:36</div>
# </div>
# <a class="news__item-body" href="https://u.today/ethereum-eth-founder-vitalik-buterin-bets-on-open-source-funding-not-public-goods">
# <div class="news__item-title">Ethereum (ETH) Founder Vitalik Buterin Bets on Open Source Funding, Not Public Goods</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/vladislav-sopov"><img alt="Vladislav Sopov" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-07/8893.jpg" width="24"/>Vladislav Sopov
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 29, 2025 - 11:16</div>
# </div>
# <a class="news__item-body" href="https://u.today/ethereum-eth-whales-close-to-liquidation-238-million-to-be-erased">
# <div class="news__item-title">Ethereum (ETH) Whales Close to Liquidation, $238 Million to Be Erased</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/vladislav-sopov"><img alt="Vladislav Sopov" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-07/8893.jpg" width="24"/>Vladislav Sopov
#             </a></div>
# </div>
# <div class="something something--content">
# <div class="something__content-long">
# <ins class="adsbygoogle" data-ad-client="ca-pub-4834169448759613" data-ad-slot="1698558466" style="display:inline-block;width:728px;height:90px"></ins>
# </div>
# <div class="something__content-square">
# <ins class="adsbygoogle" data-ad-client="ca-pub-4834169448759613" data-ad-slot="4003311693" style="display:inline-block;width:336px;height:280px"></ins>
# </div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 28, 2025 - 15:00</div>
# </div>
# <a class="news__item-body" href="https://u.today/is-1000-next-bloombergs-mcglone-queries-latest-ethereum-sell-off">
# <div class="news__item-title">'Is $1,000 Next?': Bloomberg's McGlone Queries Latest Ethereum Sell-Off</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/godfrey-benjamin"><img alt="Godfrey Benjamin" class="humble__img" height="24" src="https://u.today/sites/default/files/2022-12/29302.jpg" width="24"/>Godfrey Benjamin
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 28, 2025 - 14:54</div>
# </div>
# <a class="news__item-body" href="https://u.today/ethereum-crashes-74-against-bitcoin-is-reversal-imminent">
# <div class="news__item-title">Ethereum Crashes 74% Against Bitcoin; Is Reversal Imminent?</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/tomiwabold-olajide"><img alt="Tomiwabold Olajide" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-11/8944.jpg" width="24"/>Tomiwabold Olajide
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 28, 2025 - 0:01</div>
# </div>
# <a class="news__item-body" href="https://u.today/shiba-inu-shib-bulls-in-control-now-bitcoin-btc-in-great-spot-ethereum-eth-major-bearish-signal-but">
# <div class="news__item-title">Shiba Inu (SHIB): Bulls in Control Now? Bitcoin (BTC) in Great Spot, Ethereum (ETH): Major Bearish Signal, But There's Silver Lining </div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/arman-shirinyan"><img alt="Arman Shirinyan" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8993.jpg" width="24"/>Arman Shirinyan
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 27, 2025 - 17:11</div>
# </div>
# <a class="news__item-body" href="https://u.today/blockdag-bdag-pre-sale-hits-beta-testnet-launch-as-ethereum-eth-shiba-inu-shib-struggling-with">
# <div class="news__item-title">BlockDAG (BDAG) Pre-Sale Hits Beta Testnet Launch as Ethereum (ETH), Shiba Inu (SHIB) Struggling with Pressure</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/guest-author"><img alt="Guest Author" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-11/10896.jpg" width="24"/>Guest Author
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 27, 2025 - 12:52</div>
# </div>
# <a class="news__item-body" href="https://u.today/1084-million-ethereum-eth-in-24-hours-what-are-bulls-up-to">
# <div class="news__item-title">10.84 Million Ethereum (ETH) in 24 Hours, What Are Bulls up To?</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/godfrey-benjamin"><img alt="Godfrey Benjamin" class="humble__img" height="24" src="https://u.today/sites/default/files/2022-12/29302.jpg" width="24"/>Godfrey Benjamin
#             </a></div>
# </div>
# <div class="something something--content">
# <div class="something__content-long">
# <ins class="adsbygoogle" data-ad-client="ca-pub-4834169448759613" data-ad-slot="1698558466" style="display:inline-block;width:728px;height:90px"></ins>
# </div>
# <div class="something__content-square">
# <ins class="adsbygoogle" data-ad-client="ca-pub-4834169448759613" data-ad-slot="4003311693" style="display:inline-block;width:336px;height:280px"></ins>
# </div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 27, 2025 - 0:01</div>
# </div>
# <a class="news__item-body" href="https://u.today/is-xrp-price-ready-for-3-ethereum-eth-seeing-2000-test-shiba-inu-shib-15-trillion-whale-pump">
# <div class="news__item-title">Is XRP Price Ready for $3? Ethereum (ETH) Seeing $2,000 Test, Shiba Inu (SHIB) 1.5 Trillion Whale Pump Recorded</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/arman-shirinyan"><img alt="Arman Shirinyan" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8993.jpg" width="24"/>Arman Shirinyan
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 25, 2025 - 22:14</div>
# </div>
# <a class="news__item-body" href="https://u.today/ethereum-adoption-grows-with-launch-of-bank-issued-stablecoin">
# <div class="news__item-title">Ethereum Adoption Grows With Launch of Bank-Issued Stablecoin</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/caroline-amosun"><img alt="Caroline Amosun" class="humble__img" height="24" src="https://u.today/sites/default/files/2025-03/56827.jpg" width="24"/>Caroline Amosun
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 24, 2025 - 15:20</div>
# </div>
# <a class="news__item-body" href="https://u.today/ethereum-eth-price-prediction-for-march-24">
# <div class="news__item-title">Ethereum (ETH) Price Prediction for March 24</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/denys-serhiichuk"><img alt="Denys Serhiichuk" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8942.jpg" width="24"/>Denys Serhiichuk
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 24, 2025 - 0:01</div>
# </div>
# <a class="news__item-body" href="https://u.today/bitcoin-btc-invalidates-crucial-price-setup-xrp-faces-50-and-100-day-squeeze-ethereum-eth-finally">
# <div class="news__item-title">Bitcoin (BTC) Invalidates Crucial Price Setup, XRP Faces 50 and 100 Day Squeeze, Ethereum (ETH) Finally Bounces Back?</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/arman-shirinyan"><img alt="Arman Shirinyan" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8993.jpg" width="24"/>Arman Shirinyan
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 22, 2025 - 14:02</div>
# </div>
# <a class="news__item-body" href="https://u.today/ethereum-eth-price-prediction-for-march-22">
# <div class="news__item-title">Ethereum (ETH) Price Prediction for March 22</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/denys-serhiichuk"><img alt="Denys Serhiichuk" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8942.jpg" width="24"/>Denys Serhiichuk
#             </a></div>
# </div>
# <div class="something something--content">
# <div class="something__content-long">
# <ins class="adsbygoogle" data-ad-client="ca-pub-4834169448759613" data-ad-slot="1698558466" style="display:inline-block;width:728px;height:90px"></ins>
# </div>
# <div class="something__content-square">
# <ins class="adsbygoogle" data-ad-client="ca-pub-4834169448759613" data-ad-slot="4003311693" style="display:inline-block;width:336px;height:280px"></ins>
# </div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 21, 2025 - 21:05</div>
# </div>
# <a class="news__item-body" href="https://u.today/ethereum-eth-fees-plummet-50-as-network-activity-slowdown-sparks-concerns">
# <div class="news__item-title">Ethereum (ETH) Fees Plummet 50% as Network Activity Slowdown Sparks Concerns</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/andy-sawa"><img alt="Andy Sawa" class="humble__img" height="24" src="https://u.today/sites/default/files/2025-03/56809.jpg" width="24"/>Andy Sawa
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 21, 2025 - 15:58</div>
# </div>
# <a class="news__item-body" href="https://u.today/new-key-date-for-xrp-holders-just-emerged-major-exchange-lists-ada-and-coinbase-ethereum-for">
# <div class="news__item-title">New Key Date for XRP Holders Just Emerged, Major Exchange Lists ADA and Coinbase Ethereum for Futures Collateral, Billions of SHIB Purchased by Major Dormant ETH Whale: Crypto News Digest by U.Today</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/valeria-blokhina"><img alt="Valeria Blokhina" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-10/9844.jpg" width="24"/>Valeria Blokhina
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 21, 2025 - 0:01</div>
# </div>
# <a class="news__item-body" href="https://u.today/is-3-xrp-possible-bitcoin-btc-makes-biggest-breakout-in-2025-ethereum-eth-finally-above-2000">
# <div class="news__item-title">Is $3 XRP Possible? Bitcoin (BTC) Makes Biggest Breakout in 2025, Ethereum (ETH) Finally Above $2,000</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/arman-shirinyan"><img alt="Arman Shirinyan" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8993.jpg" width="24"/>Arman Shirinyan
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 20, 2025 - 18:53</div>
# </div>
# <a class="news__item-body" href="https://u.today/new-ethereum-etf-staking-proposal-filed-by-nyse">
# <div class="news__item-title">New Ethereum ETF Staking Proposal Filed by NYSE </div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/alex-dovbnya"><img alt="Alex Dovbnya" class="humble__img" height="24" src="https://u.today/sites/default/files/2019-11/alex-m-ava.jpg" width="24"/>Alex Dovbnya
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 20, 2025 - 15:13</div>
# </div>
# <a class="news__item-body" href="https://u.today/billions-of-shiba-inu-shib-acquired-by-major-dormant-ethereum-whale">
# <div class="news__item-title">Billions of Shiba Inu (SHIB) Acquired by Major Dormant Ethereum Whale</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/gamza-khanzadaev"><img alt="Gamza Khanzadaev" class="humble__img" height="24" src="https://u.today/sites/default/files/2022-05/14694.jpg" width="24"/>Gamza Khanzadaev
#             </a></div>
# </div>
# <div class="something something--content">
# <div class="something__content-long">
# <ins class="adsbygoogle" data-ad-client="ca-pub-4834169448759613" data-ad-slot="1698558466" style="display:inline-block;width:728px;height:90px"></ins>
# </div>
# <div class="something__content-square">
# <ins class="adsbygoogle" data-ad-client="ca-pub-4834169448759613" data-ad-slot="4003311693" style="display:inline-block;width:336px;height:280px"></ins>
# </div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 20, 2025 - 10:49</div>
# </div>
# <a class="news__item-body" href="https://u.today/major-exchange-lists-cardano-ada-and-coinbase-ethereum-for-futures-collateral">
# <div class="news__item-title">Major Exchange Lists Cardano (ADA) and Coinbase Ethereum for Futures Collateral</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/gamza-khanzadaev"><img alt="Gamza Khanzadaev" class="humble__img" height="24" src="https://u.today/sites/default/files/2022-05/14694.jpg" width="24"/>Gamza Khanzadaev
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 19, 2025 - 17:00</div>
# </div>
# <a class="news__item-body" href="https://u.today/blockdag-bdag-enters-new-roadmap-phase-as-shiba-inu-shib-ethereum-eth-price-metrics-consolidate">
# <div class="news__item-title">BlockDAG (BDAG) Enters New Roadmap Phase as Shiba Inu (SHIB), Ethereum (ETH) Price Metrics Consolidate</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/guest-author"><img alt="Guest Author" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-11/10896.jpg" width="24"/>Guest Author
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 19, 2025 - 15:05</div>
# </div>
# <a class="news__item-body" href="https://u.today/ethereum-eth-price-prediction-for-march-19">
# <div class="news__item-title">Ethereum (ETH) Price Prediction for March 19</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/denys-serhiichuk"><img alt="Denys Serhiichuk" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8942.jpg" width="24"/>Denys Serhiichuk
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/events">Event</a></div>
# <a class="news__item-body" href="https://u.today/events/consensus-2025">
# <div class="news__item-title">Consensus 2025</div>
# </a>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 19, 2025 - 5:54</div>
# </div>
# <a class="news__item-body" href="https://u.today/ethereum-etfs-hemorrhage-50-million">
# <div class="news__item-title">Ethereum ETFs Hemorrhage $50 Million </div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/alex-dovbnya"><img alt="Alex Dovbnya" class="humble__img" height="24" src="https://u.today/sites/default/files/2019-11/alex-m-ava.jpg" width="24"/>Alex Dovbnya
#             </a></div>
# </div>
# <div class="something something--content">
# <div class="something__content-long">
# <ins class="adsbygoogle" data-ad-client="ca-pub-4834169448759613" data-ad-slot="1698558466" style="display:inline-block;width:728px;height:90px"></ins>
# </div>
# <div class="something__content-square">
# <ins class="adsbygoogle" data-ad-client="ca-pub-4834169448759613" data-ad-slot="4003311693" style="display:inline-block;width:336px;height:280px"></ins>
# </div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 18, 2025 - 14:17</div>
# </div>
# <a class="news__item-body" href="https://u.today/ethereum-eth-developers-launch-hoodi-testnet-and-prepare-pectra-for-mainnet-launch-in-may">
# <div class="news__item-title">Ethereum (ETH) Developers Launch Hoodi Testnet and Prepare Pectra for Mainnet Launch in May</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/vladislav-sopov"><img alt="Vladislav Sopov" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-07/8893.jpg" width="24"/>Vladislav Sopov
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 18, 2025 - 0:01</div>
# </div>
# <a class="news__item-body" href="https://u.today/shiba-inu-shib-reaches-crucial-price-test-ethereum-eth-eyeing-2000-again-can-xrp-avoid-this-grim">
# <div class="news__item-title">Shiba Inu (SHIB) Reaches Crucial Price Test, Ethereum (ETH) Eyeing $2,000 Again, Can XRP Avoid This Grim Movement?</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/arman-shirinyan"><img alt="Arman Shirinyan" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8993.jpg" width="24"/>Arman Shirinyan
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 17, 2025 - 15:43</div>
# </div>
# <a class="news__item-body" href="https://u.today/standard-chartered-dramatically-reduces-ethereum-eth-price-target">
# <div class="news__item-title">Standard Chartered Dramatically Reduces Ethereum (ETH) Price Target </div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/alex-dovbnya"><img alt="Alex Dovbnya" class="humble__img" height="24" src="https://u.today/sites/default/files/2019-11/alex-m-ava.jpg" width="24"/>Alex Dovbnya
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 17, 2025 - 15:14</div>
# </div>
# <a class="news__item-body" href="https://u.today/ethereum-eth-price-prediction-for-march-17">
# <div class="news__item-title">Ethereum (ETH) Price Prediction for March 17</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/denys-serhiichuk"><img alt="Denys Serhiichuk" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8942.jpg" width="24"/>Denys Serhiichuk
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 15, 2025 - 13:34</div>
# </div>
# <a class="news__item-body" href="https://u.today/solana-vs-ethereum-eight-parameters-compared-by-crypto-expert">
# <div class="news__item-title">Solana vs. Ethereum: Eight Parameters Compared by Crypto Expert</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/vladislav-sopov"><img alt="Vladislav Sopov" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-07/8893.jpg" width="24"/>Vladislav Sopov
#             </a></div>
# </div>
# <div class="something something--content">
# <div class="something__content-long">
# <ins class="adsbygoogle" data-ad-client="ca-pub-4834169448759613" data-ad-slot="1698558466" style="display:inline-block;width:728px;height:90px"></ins>
# </div>
# <div class="something__content-square">
# <ins class="adsbygoogle" data-ad-client="ca-pub-4834169448759613" data-ad-slot="4003311693" style="display:inline-block;width:336px;height:280px"></ins>
# </div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 15, 2025 - 0:01</div>
# </div>
# <a class="news__item-body" href="https://u.today/xrp-already-recovered-20-enormous-ethereum-eth-selling-volume-before-2000-sixth-shiba-inu-shib">
# <div class="news__item-title">XRP Already Recovered 20%, Enormous Ethereum (ETH) Selling Volume Before $2,000, Sixth Shiba Inu (SHIB) Recovery Attempt: Another Crash?</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/arman-shirinyan"><img alt="Arman Shirinyan" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8993.jpg" width="24"/>Arman Shirinyan
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 14, 2025 - 15:31</div>
# </div>
# <a class="news__item-body" href="https://u.today/xrp-flips-ethereum-in-fully-diluted-valuation-heres-implication">
# <div class="news__item-title">XRP Flips Ethereum in Fully Diluted Valuation, Here's Implication</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/godfrey-benjamin"><img alt="Godfrey Benjamin" class="humble__img" height="24" src="https://u.today/sites/default/files/2022-12/29302.jpg" width="24"/>Godfrey Benjamin
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 14, 2025 - 10:05</div>
# </div>
# <a class="news__item-body" href="https://u.today/xrp-v-ethereum-eth-ripple-cto-clears-up-major-sale-misconception">
# <div class="news__item-title">XRP vs. Ethereum (ETH): Ripple CTO Clears up Major Sale Misconception</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/gamza-khanzadaev"><img alt="Gamza Khanzadaev" class="humble__img" height="24" src="https://u.today/sites/default/files/2022-05/14694.jpg" width="24"/>Gamza Khanzadaev
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 13, 2025 - 15:09</div>
# </div>
# <a class="news__item-body" href="https://u.today/no-ethereum-eth-is-not-dead-says-top-analyst">
# <div class="news__item-title">No, Ethereum (ETH) Is Not Dead, Says Top Analyst</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/arman-shirinyan"><img alt="Arman Shirinyan" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8993.jpg" width="24"/>Arman Shirinyan
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 12, 2025 - 22:49</div>
# </div>
# <a class="news__item-body" href="https://u.today/ethereum-risks-drop-to-1400-mirroring-2020-crash-crypto-trader-warns">
# <div class="news__item-title">Ethereum Risks Drop to $1,400, Mirroring 2020 Crash, Crypto Trader Warns</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/andy-sawa"><img alt="Andy Sawa" class="humble__img" height="24" src="https://u.today/sites/default/files/2025-03/56809.jpg" width="24"/>Andy Sawa
#             </a></div>
# </div>
# <div class="something something--content">
# <div class="something__content-long">
# <ins class="adsbygoogle" data-ad-client="ca-pub-4834169448759613" data-ad-slot="1698558466" style="display:inline-block;width:728px;height:90px"></ins>
# </div>
# <div class="something__content-square">
# <ins class="adsbygoogle" data-ad-client="ca-pub-4834169448759613" data-ad-slot="4003311693" style="display:inline-block;width:336px;height:280px"></ins>
# </div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 12, 2025 - 5:40</div>
# </div>
# <a class="news__item-body" href="https://u.today/ethereum-etfs-log-nearly-22-million-worth-of-outflows">
# <div class="news__item-title">Ethereum ETFs Log Nearly $22 Million Worth of Outflows</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/alex-dovbnya"><img alt="Alex Dovbnya" class="humble__img" height="24" src="https://u.today/sites/default/files/2019-11/alex-m-ava.jpg" width="24"/>Alex Dovbnya
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 12, 2025 - 0:01</div>
# </div>
# <a class="news__item-body" href="https://u.today/solana-sol-death-cross-incoming-dogecoin-doge-hits-last-possible-support-ethereum-eth-says-goodbye">
# <div class="news__item-title">Solana (SOL) Death Cross Incoming, Dogecoin (DOGE) Hits Last Possible Support, Ethereum (ETH) Says Goodbye to $2,000 </div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/arman-shirinyan"><img alt="Arman Shirinyan" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8993.jpg" width="24"/>Arman Shirinyan
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 11, 2025 - 16:30</div>
# </div>
# <a class="news__item-body" href="https://u.today/fidelity-files-for-staking-on-ethereum-etf-product">
# <div class="news__item-title">Fidelity Files for Staking on Ethereum ETF Product</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/godfrey-benjamin"><img alt="Godfrey Benjamin" class="humble__img" height="24" src="https://u.today/sites/default/files/2022-12/29302.jpg" width="24"/>Godfrey Benjamin
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 11, 2025 - 15:59</div>
# </div>
# <a class="news__item-body" href="https://u.today/ethereum-foundation-makes-30098-eth-liquidation-play-on-maker-details">
# <div class="news__item-title">Ethereum Foundation Makes 30,098 ETH Liquidation Play on Maker: Details</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/godfrey-benjamin"><img alt="Godfrey Benjamin" class="humble__img" height="24" src="https://u.today/sites/default/files/2022-12/29302.jpg" width="24"/>Godfrey Benjamin
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 11, 2025 - 15:22</div>
# </div>
# <a class="news__item-body" href="https://u.today/ethereum-eth-price-prediction-for-march-11">
# <div class="news__item-title">Ethereum (ETH) Price Prediction for March 11</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/denys-serhiichuk"><img alt="Denys Serhiichuk" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8942.jpg" width="24"/>Denys Serhiichuk
#             </a></div>
# </div>
# <div class="something something--content">
# <div class="something__content-long">
# <ins class="adsbygoogle" data-ad-client="ca-pub-4834169448759613" data-ad-slot="1698558466" style="display:inline-block;width:728px;height:90px"></ins>
# </div>
# <div class="something__content-square">
# <ins class="adsbygoogle" data-ad-client="ca-pub-4834169448759613" data-ad-slot="4003311693" style="display:inline-block;width:336px;height:280px"></ins>
# </div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 11, 2025 - 11:53</div>
# </div>
# <a class="news__item-body" href="https://u.today/tron-founder-justin-sun-issues-crucial-ethereum-warning-details">
# <div class="news__item-title">Tron Founder Justin Sun Issues Crucial Ethereum Warning: Details</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/yuri-molchan"><img alt="Yuri Molchan" class="humble__img" height="24" src="https://u.today/sites/default/files/2019-11/yuri-ava.jpg" width="24"/>Yuri Molchan
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 10, 2025 - 15:16</div>
# </div>
# <a class="news__item-body" href="https://u.today/ethereum-eth-price-prediction-for-march-10-0">
# <div class="news__item-title">Ethereum (ETH) Price Prediction for March 10</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/denys-serhiichuk"><img alt="Denys Serhiichuk" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8942.jpg" width="24"/>Denys Serhiichuk
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 10, 2025 - 8:42</div>
# </div>
# <a class="news__item-body" href="https://u.today/consensys-ceo-says-ethereum-must-remain-neutral">
# <div class="news__item-title">Consensys CEO Says Ethereum Must Remain Neutral </div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/alex-dovbnya"><img alt="Alex Dovbnya" class="humble__img" height="24" src="https://u.today/sites/default/files/2019-11/alex-m-ava.jpg" width="24"/>Alex Dovbnya
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 10, 2025 - 8:16</div>
# </div>
# <a class="news__item-body" href="https://u.today/ethereum-eth-2000-might-be-lost-today">
# <div class="news__item-title">Ethereum (ETH): $2,000 Might Be Lost Today</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/arman-shirinyan"><img alt="Arman Shirinyan" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8993.jpg" width="24"/>Arman Shirinyan
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 7, 2025 - 13:35</div>
# </div>
# <a class="news__item-body" href="https://u.today/ethereum-eth-price-prediction-for-march-7-0">
# <div class="news__item-title">Ethereum (ETH) Price Prediction for March 7</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/denys-serhiichuk"><img alt="Denys Serhiichuk" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8942.jpg" width="24"/>Denys Serhiichuk
#             </a></div>
# </div>
# <div class="something something--content">
# <div class="something__content-long">
# <ins class="adsbygoogle" data-ad-client="ca-pub-4834169448759613" data-ad-slot="1698558466" style="display:inline-block;width:728px;height:90px"></ins>
# </div>
# <div class="something__content-square">
# <ins class="adsbygoogle" data-ad-client="ca-pub-4834169448759613" data-ad-slot="4003311693" style="display:inline-block;width:336px;height:280px"></ins>
# </div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 7, 2025 - 0:01</div>
# </div>
# <a class="news__item-body" href="https://u.today/xrps-250-price-breakout-still-questionable-dogecoin-doge-hits-major-support-again-ethereum-eth-not">
# <div class="news__item-title">XRP's $2.50 Price Breakout Still Questionable, Dogecoin (DOGE) Hits Major Support Again, Ethereum (ETH) Not Okay</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/arman-shirinyan"><img alt="Arman Shirinyan" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8993.jpg" width="24"/>Arman Shirinyan
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 5, 2025 - 13:57</div>
# </div>
# <a class="news__item-body" href="https://u.today/ethereum-eth-price-prediction-for-march-5">
# <div class="news__item-title">Ethereum (ETH) Price Prediction for March 5</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/denys-serhiichuk"><img alt="Denys Serhiichuk" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8942.jpg" width="24"/>Denys Serhiichuk
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 5, 2025 - 0:01</div>
# </div>
# <a class="news__item-body" href="https://u.today/xrp-24-retrace-is-mind-blowing-ethereum-eth-looks-even-worse-than-before-cardano-ada-biggest">
# <div class="news__item-title">XRP: 24% Retrace is Mind-Blowing, Ethereum (ETH) Looks Even Worse Than Before, Cardano (ADA): Biggest Volatility Surge in Years </div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/arman-shirinyan"><img alt="Arman Shirinyan" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8993.jpg" width="24"/>Arman Shirinyan
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 3, 2025 - 14:51</div>
# </div>
# <a class="news__item-body" href="https://u.today/solana-flips-ethereum-again-as-dex-volume-hits-399-billion">
# <div class="news__item-title">Solana Flips Ethereum Again as DEX Volume Hits $3.99 Billion</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/godfrey-benjamin"><img alt="Godfrey Benjamin" class="humble__img" height="24" src="https://u.today/sites/default/files/2022-12/29302.jpg" width="24"/>Godfrey Benjamin
#             </a></div>
# </div>
# <script>
#             document.getElementById("search_text").focus();
#         </script>
# </div>
# <div class="something something--content">
# <div class="something__content-long">
# <div>
# <!-- TAGS Title Banner Desktop 336x280 -->
# <ins class="adsbygoogle" data-ad-client="ca-pub-9245916885225528" data-ad-slot="6672099997" style="display:inline-block;width:336px;height:280px"></ins>
# </div>
# </div>
# <div class="something__content-square">
# <div>
# <!-- Tags Title Mobile 336x280 -->
# <ins class="adsbygoogle" data-ad-client="ca-pub-9245916885225528" data-ad-slot="2099638702" style="display:inline-block;width:336px;height:280px"></ins>
# </div>
# </div>
# </div>
# <div class="pag-nav">
# <ul class="pag-nav__list">
# <li class="pag-nav__item">
# <a aria-current="Current page" class="btn--light pag-nav__btn pag-nav__btn-active" href="https://u.today/search/node?keys=Ethereum&amp;_wrapper_format=html&amp;page=0" title="Current page">
# <span class="visually-hidden">
#               Current page
#             </span>1</a>
# </li>
# <li class="pag-nav__item">
# <a class="btn--light pag-nav__btn" href="https://u.today/search/node?keys=Ethereum&amp;_wrapper_format=html&amp;page=1" title="Go to page 2">
# <span class="visually-hidden">
#               Page
#             </span>2</a>
# </li>
# <li class="pag-nav__item">
# <a class="btn--light pag-nav__btn" href="https://u.today/search/node?keys=Ethereum&amp;_wrapper_format=html&amp;page=2" title="Go to page 3">
# <span class="visually-hidden">
#               Page
#             </span>3</a>
# </li>
# <li class="pag-nav__item">
# <a class="btn--light pag-nav__btn" href="https://u.today/search/node?keys=Ethereum&amp;_wrapper_format=html&amp;page=3" title="Go to page 4">
# <span class="visually-hidden">
#               Page
#             </span>4</a>
# </li>
# <li class="pag-nav__item">
# <a class="btn--light pag-nav__btn" href="https://u.today/search/node?keys=Ethereum&amp;_wrapper_format=html&amp;page=4" title="Go to page 5">
# <span class="visually-hidden">
#               Page
#             </span>5</a>
# </li>
# <li class="pag-nav__item">
# ...
#                         });
#                     }
#                     jQuery.each(this, function (i, val) {
#                         var input = jQuery(val);
#                         if (input.attr('name') != 'file') data.append(input.attr('name'), input.val());
#                     });
#
#
#                     jQuery.ajax({
#                         url: jQuery(this).attr('action'),
#                         type: 'POST',
#                         dataType: 'json',
#                         cache: false,
#                         processData: false,
#                         contentType: false,
#                         data: data,
#                         success: function (data) {
#                             jQuery('.sevent').html('<h2>Thanks for submit. We will contact you soon.</h2>');
#                             return false;
#                         },
#                         error: function (xhr, err) {
#
#                             alert('Error');
#                         }
#                     });
#                     return false;
#                 });
#
#                 //submit event end
#             </script>
# <script type="text/javascript">
#                 const initBanners = function () {
#                     let elements =
#                         document.getElementsByClassName('imageBannersContainer');
#                     for (let i = 0; i < elements.length; i++) {
#                         let bannerElements = elements[i].getElementsByClassName("imageBanner");
#                         let bannerIndex = Math.random() * bannerElements.length;
#                         let firstDigitStr = String(bannerIndex)[0];
#                         bannerElements[firstDigitStr].style.display = 'block';
#                     }
#                 };
#
#                 jQuery(document).ready(function () {
#
#                     (function ($) {
#                         if (jQuery(window).width() > '850') {
#                             jQuery('.press-releases__slider, .upcoming__slider').slick({
#                                 infinite: false,
#                                 slidesToShow: 3,
#                                 slidesToScroll: 1,
#                                 arrows: true,
#                                 dots: false
#                             });
#                         }
#                     })(jQuery);
#
#
#                     initBanners();
#
#                     var OneSignal = window.OneSignal || [];
#                     OneSignal.push(function () {
#                         OneSignal.init({
#                             appId: "8fd8204c-a529-4b35-98be-27f71d473d9a",
#                         });
#                     });
#
#                     let menus = document.querySelectorAll('.main_page a');
#                     menus.forEach(el => el.addEventListener('click', event => {
#                         gtag('event', 'header_menu_click', {
#                             'header_menu_click': 'click',
#                         });
#                     }));
#
#                     menus = document.querySelectorAll('.article a[target="_blank"]');
#                     menus.forEach(el => el.addEventListener('click', event => {
#                         gtag('event', 'article_link_click', {
#                             'article_link_click': 'click',
#                         });
#                     }));
#                     menus = document.querySelectorAll('.article__related a');
#                     menus.forEach(el => el.addEventListener('click', event => {
#                         gtag('event', 'card_click', {
#                             'card_click': 'click',
#                         });
#                     }));
#                     menus = document.querySelectorAll('.views-infinite-scroll-content-wrapper .category-item a');
#                     menus.forEach(el => el.addEventListener('click', event => {
#                         gtag('event', 'related_click', {
#                             'related_click': 'click',
#                         });
#                     }));
#                     menus = document.querySelectorAll('.article__listen-audio');
#                     menus.forEach(el => el.addEventListener('click', event => {
#                         gtag('event', 'tts_click', {
#                             'tts_click': 'click',
#                         });
#                     }));
#                     menus = document.querySelectorAll('.header__nav-link');
#                     menus.forEach(el => el.addEventListener('click', event => {
#                         gtag('event', 'header_menu_click', {
#                             'header_menu': 'click',
#                         });
#                     }));
#                     menus = document.querySelectorAll('.footer__nav-child-link');
#                     menus.forEach(el => el.addEventListener('click', event => {
#                         gtag('event', 'footer_menu_click', {
#                             'footer_menu': 'click',
#                         });
#                     }));
#                     menus = document.querySelectorAll('.card__subscribe-item');
#                     menus.forEach(el => el.addEventListener('click', event => {
#                         gtag('event', 'subscribe', {
#                             'subscribe': 'click',
#                         });
#                     }));
#
#
#
#
#
#                                         [].forEach.call(document.querySelectorAll('.adsbygoogle'), function () {
#                         try {
#                             (adsbygoogle = window.adsbygoogle || []).push({});
#                         } catch (e) {
#                             return null;
#                         }
#                     });
#                     jQuery('.ad-feedback__form, .press-releases_form, .event_form, .airdrop_form').submit(function (e) {
#                         e.preventDefault();
#                         //data = 'subject=' + e.target.querySelector('input[name=subject]').value + '&name=' + e.target.querySelector('input[name=submit-name]').value + '&mail=' + e.target.querySelector('input[name=submit-email]').value + '&desc=' + e.target.querySelector('textarea[name=submit-massage]').value;
#                         let fd = new FormData();
#                         let other_data = jQuery(e.target).serializeArray();
#                         jQuery.each(other_data, function (key, input) {
#                             fd.append(input.name, input.value);
#                         });
#                         if(e.target.querySelector('input[name=submit-file]') != null) {
#                             fd.append('file', jQuery(e.target.querySelector('input[name=submit-file]'))[0].files[0]);
#                         }
#                         jQuery.ajax({
#                             url: '/umail',
#                             type: 'post',
#                             contentType: false,
#                             processData: false,
#                             data: fd,
#                             success: function () {
#
#                             }
#                         });
#                     });
#                     jQuery('.subscribe-page__form, .footer__subscribe-form,.aside-sub,.subscribe-form,.sub-slot__form').submit(function (e) {
#                         e.preventDefault();
#                         const form = e.target;
#                         const inputs = form.elements;
#                         let data = '';
#                         for (const input of inputs) {
#                             data = data + input.name + '=' + input.value + '&';
#                         }
#
#                         jQuery.ajax({
#                             url: '/getresponse.php',
#                             type: 'post',
#                             data: data,
#                             success: function () {
#                                 e.target.querySelector('.subscribe-result').innerHTML = '<div class="success">Subscribed</div>';
#                                 jQuery('.card__subscribe-em .input__status').text('Subscribed');
#                                 e.target.querySelector('.success').style.display = 'block';
#                             }
#                         });
#                     });
#                     jQuery('.modal__form').submit(function (e) {
#
#                         const form = e.target;
#                         const inputs = form.elements;
#                         let data = '';
#                         for (const input of inputs) {
#                             data = data + input.name + '=' + input.value + '&';
#                         }
#
#                         jQuery.ajax({
#                             url: '/getresponse.php',
#                             type: 'post',
#                             data: data,
#                             success: function () {
#                                 // e.target.querySelector('.subscribe-result').innerHTML = '<div class="success">Subscribed</div>';
#                                 // jQuery('.card__subscribe-em .input__status').text('Subscribed');
#                                 // e.target.querySelector('.success').style.display = 'block';
#                             }
#                         });
#                     });
#
#
#
#
#
#
#
#                 });
#
#                 function addLink() {
#                     let body = document.getElementsByTagName('body')[0],
#                         selection = window.getSelection(),
#                         copyright = "<p><br>Read more on U.Today <a href='" + document.location.href + "'>" + document.location.href + "</a></p>",
#                         copyrightText = selection + copyright,
#                         newdiv = document.createElement('div');
#
#                     newdiv.style.position = 'absolute';
#                     body.appendChild(newdiv);
#                     newdiv.innerHTML = copyrightText;
#                     selection.selectAllChildren(newdiv);
#
#                     window.onclick = function () {
#                         body.removeChild(newdiv);
#                     };
#                 }
#             </script>
# <script type="text/javascript">
#
#
#                 document.addEventListener("scroll", (event) => {
#
#                     [].forEach.call(document.querySelectorAll('.adsbygoogle'), function () {
#                         try {
#                             (adsbygoogle = window.adsbygoogle || []).push({});
#                         } catch (e) {
#                             //return null;
#                         }
#
#                     });
#                 });
#                 document.addEventListener('DOMContentLoaded', function () {
#                     document.querySelectorAll('audio').forEach(function (audio) {
#                         let loaded = false;
#
#                         audio.addEventListener('loadedmetadata', function () {
#                             loaded = true;
#                             checkLoad();
#                         });
#
#                         audio.addEventListener('canplaythrough', function () {
#                             loaded = true;
#                             checkLoad();
#                         });
#
#                         function checkLoad() {
#                             if (loaded) {
#                                 const article = audio.closest('.article__listen');
#                                 const duration = Math.floor(audio.duration);
#                                 const minutes = Math.floor(duration / 60);
#                                 const seconds = Math.floor(duration % 60);
#                                 minutesDisplay.textContent = `${minutes}:${(seconds < 10 ? '0' : '')}${seconds}`;
#
#                                 console.log(duration);
#                             }
#                         }
#                     });
#
#                     let currentAudio = null;
#
#                     document.body.addEventListener('click', function (e) {
#                         const article = e.target.closest('.article__listen');
#
#                         if (!article) return;
#
#                         const audio = article.querySelector('audio');
#                         const playPauseButton = article.querySelector('.article__listen-btn');
#
#                         if (audio && playPauseButton) {
#                             if (audio !== currentAudio) {
#                                 if (currentAudio) {
#                                     currentAudio.pause();
#                                     const currentPlayPauseButton = currentAudio.parentElement.querySelector('.article__listen-btn');
#                                     if (currentPlayPauseButton) {
#                                         currentPlayPauseButton.classList.remove('is-play');
#                                     }
#                                 }
#
#                                 currentAudio = audio;
#
#                                 audio.addEventListener('timeupdate', updateTimer);
#                             }
#
#                             if (audio.paused) {
#                                 audio.play();
#                                 playPauseButton.classList.add('is-play');
#                             } else {
#                                 audio.pause();
#                                 playPauseButton.classList.remove('is-play');
#                             }
#
#                             function updateTimer() {
#                                 if (!audio.duration) {
#                                     audio.removeEventListener('timeupdate', updateTimer);
#                                     audio.addEventListener('timeupdate', updateTimer);
#                                     return;
#                                 }
#
#                                 const currentTime = audio.duration - audio.currentTime;
#                                 const minutes = Math.floor(currentTime / 60);
#                                 const seconds = Math.floor(currentTime % 60);
#
#                                 minutesDisplay.textContent = `${minutes}:${(seconds < 10 ? '0' : '')}${seconds}`;
#                             }
#                         }
#                     });
#                 });
#             </script>
# <script>
#
#                 var emailInput = document.getElementsByClassName('input__elem');
#                 var submitButton = document.getElementsByClassName('submit-button');
#                 for (let i = 0; i < emailInput.length; i++) {
#                     emailInput[i].addEventListener('input', () => {
#                         let form = emailInput[i].closest('form');
#                         let captchaContainer = form.querySelector('.captcha-container');
#                         if (emailInput[i].validity.valid) {
#                             console.log('OK', captchaContainer);
#                             captchaContainer.style.display = 'block';
#                         } else {
#                             captchaContainer.style.display = 'none';
#                         }
#                     });
#                 }
#
#
#                 let isCaptchaCompleted = false;
#
#
#                 function captchaSuccess() {
#                     //console.log('captchaSuccess', submitButton.length);
#                     submitButton = document.getElementsByClassName('submit-button');
#                     isCaptchaCompleted = true;
#                     for (let i = 0; i < submitButton.length; i++) {
#                         submitButton[i].disabled = false;
#                     }
#                 }
#
#
#                 function captchaExpired() {
#                     isCaptchaCompleted = false;
#                     submitButton = document.getElementsByClassName('submit-button');
#                     for (let i = 0; i < submitButton.length; i++) {
#                         submitButton[i].disabled = true;
#                     }
#                 }
#
#
#                 function validateCaptcha() {
#                     if (!isCaptchaCompleted) {
#                         return false;
#                     }
#                     return true;
#                 }
#
#             </script>
# </body>
# </html>

# %%
# Option 1: Using CSS selectors (similar to your book_cards example)
ethereum_date = doc.select("body.not_logged_in div.main-aside-container main.main-block div.search-result div.news__item div.news__item-head div.humble")
ethereum_date
# Out:
# [<div class="humble">Mar 30, 2025 - 14:43</div>,
#  <div class="humble">Mar 30, 2025 - 12:00</div>,
#  <div class="humble">Mar 30, 2025 - 11:00</div>,
#  <div class="humble">Mar 29, 2025 - 14:54</div>,
#  <div class="humble">Mar 29, 2025 - 14:36</div>,
#  <div class="humble">Mar 29, 2025 - 11:16</div>,
#  <div class="humble">Mar 28, 2025 - 15:00</div>,
#  <div class="humble">Mar 28, 2025 - 14:54</div>,
#  <div class="humble">Mar 28, 2025 - 0:01</div>,
#  <div class="humble">Mar 27, 2025 - 17:11</div>,
#  <div class="humble">Mar 27, 2025 - 12:52</div>,
#  <div class="humble">Mar 27, 2025 - 0:01</div>,
#  <div class="humble">Mar 25, 2025 - 22:14</div>,
#  <div class="humble">Mar 24, 2025 - 15:20</div>,
#  <div class="humble">Mar 24, 2025 - 0:01</div>,
#  <div class="humble">Mar 22, 2025 - 14:02</div>,
#  <div class="humble">Mar 21, 2025 - 21:05</div>,
#  <div class="humble">Mar 21, 2025 - 15:58</div>,
#  <div class="humble">Mar 21, 2025 - 0:01</div>,
#  <div class="humble">Mar 20, 2025 - 18:53</div>,
#  <div class="humble">Mar 20, 2025 - 15:13</div>,
#  <div class="humble">Mar 20, 2025 - 10:49</div>,
#  <div class="humble">Mar 19, 2025 - 17:00</div>,
#  <div class="humble">Mar 19, 2025 - 15:05</div>,
#  <div class="humble">Mar 19, 2025 - 5:54</div>,
#  <div class="humble">Mar 18, 2025 - 14:17</div>,
#  <div class="humble">Mar 18, 2025 - 0:01</div>,
#  <div class="humble">Mar 17, 2025 - 15:43</div>,
#  <div class="humble">Mar 17, 2025 - 15:14</div>,
#  <div class="humble">Mar 15, 2025 - 13:34</div>,
#  <div class="humble">Mar 15, 2025 - 0:01</div>,
#  <div class="humble">Mar 14, 2025 - 15:31</div>,
#  <div class="humble">Mar 14, 2025 - 10:05</div>,
#  <div class="humble">Mar 13, 2025 - 15:09</div>,
#  <div class="humble">Mar 12, 2025 - 22:49</div>,
#  <div class="humble">Mar 12, 2025 - 5:40</div>,
#  <div class="humble">Mar 12, 2025 - 0:01</div>,
#  <div class="humble">Mar 11, 2025 - 16:30</div>,
#  <div class="humble">Mar 11, 2025 - 15:59</div>,
#  <div class="humble">Mar 11, 2025 - 15:22</div>,
#  <div class="humble">Mar 11, 2025 - 11:53</div>,
#  <div class="humble">Mar 10, 2025 - 15:16</div>,
#  <div class="humble">Mar 10, 2025 - 8:42</div>,
#  <div class="humble">Mar 10, 2025 - 8:16</div>,
#  <div class="humble">Mar 7, 2025 - 13:35</div>,
#  <div class="humble">Mar 7, 2025 - 0:01</div>,
#  <div class="humble">Mar 5, 2025 - 13:57</div>,
#  <div class="humble">Mar 5, 2025 - 0:01</div>,
#  <div class="humble">Mar 3, 2025 - 14:51</div>]

# %%
ethereum_dt = []
for ethereum in ethereum_date:
    
  ethereum_dt.append(ethereum.get_text())
  #print(Bitcoin.get_text())
ethereum_dt
# Out:
# ['Mar 30, 2025 - 14:43',
#  'Mar 30, 2025 - 12:00',
#  'Mar 30, 2025 - 11:00',
#  'Mar 29, 2025 - 14:54',
#  'Mar 29, 2025 - 14:36',
#  'Mar 29, 2025 - 11:16',
#  'Mar 28, 2025 - 15:00',
#  'Mar 28, 2025 - 14:54',
#  'Mar 28, 2025 - 0:01',
#  'Mar 27, 2025 - 17:11',
#  'Mar 27, 2025 - 12:52',
#  'Mar 27, 2025 - 0:01',
#  'Mar 25, 2025 - 22:14',
#  'Mar 24, 2025 - 15:20',
#  'Mar 24, 2025 - 0:01',
#  'Mar 22, 2025 - 14:02',
#  'Mar 21, 2025 - 21:05',
#  'Mar 21, 2025 - 15:58',
#  'Mar 21, 2025 - 0:01',
#  'Mar 20, 2025 - 18:53',
#  'Mar 20, 2025 - 15:13',
#  'Mar 20, 2025 - 10:49',
#  'Mar 19, 2025 - 17:00',
#  'Mar 19, 2025 - 15:05',
#  'Mar 19, 2025 - 5:54',
#  'Mar 18, 2025 - 14:17',
#  'Mar 18, 2025 - 0:01',
#  'Mar 17, 2025 - 15:43',
#  'Mar 17, 2025 - 15:14',
#  'Mar 15, 2025 - 13:34',
#  'Mar 15, 2025 - 0:01',
#  'Mar 14, 2025 - 15:31',
#  'Mar 14, 2025 - 10:05',
#  'Mar 13, 2025 - 15:09',
#  'Mar 12, 2025 - 22:49',
#  'Mar 12, 2025 - 5:40',
#  'Mar 12, 2025 - 0:01',
#  'Mar 11, 2025 - 16:30',
#  'Mar 11, 2025 - 15:59',
#  'Mar 11, 2025 - 15:22',
#  'Mar 11, 2025 - 11:53',
#  'Mar 10, 2025 - 15:16',
#  'Mar 10, 2025 - 8:42',
#  'Mar 10, 2025 - 8:16',
#  'Mar 7, 2025 - 13:35',
#  'Mar 7, 2025 - 0:01',
#  'Mar 5, 2025 - 13:57',
#  'Mar 5, 2025 - 0:01',
#  'Mar 3, 2025 - 14:51']

# %%
News_card = doc.select('div.news__item')
News_card
# Out:
# [<div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 30, 2025 - 14:43</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/ethereum-eth-price-prediction-for-march-30">
#  <div class="news__item-title">Ethereum (ETH) Price Prediction for March 30</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/denys-serhiichuk"><img alt="Denys Serhiichuk" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8942.jpg" width="24"/>Denys Serhiichuk
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 30, 2025 - 12:00</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/pre-mine-ethereum-address-suddenly-activated">
#  <div class="news__item-title">Pre-Mine Ethereum Address Suddenly Activated</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/alex-dovbnya"><img alt="Alex Dovbnya" class="humble__img" height="24" src="https://u.today/sites/default/files/2019-11/alex-m-ava.jpg" width="24"/>Alex Dovbnya
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 30, 2025 - 11:00</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/ethereum-eth-awaiting-crucial-crossover-details">
#  <div class="news__item-title">Ethereum (ETH) Awaiting Crucial Crossover: Details</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/tomiwabold-olajide"><img alt="Tomiwabold Olajide" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-11/8944.jpg" width="24"/>Tomiwabold Olajide
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 29, 2025 - 14:54</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/ethereum-eth-price-prediction-for-march-29">
#  <div class="news__item-title">Ethereum (ETH) Price Prediction for March 29</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/denys-serhiichuk"><img alt="Denys Serhiichuk" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8942.jpg" width="24"/>Denys Serhiichuk
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 29, 2025 - 14:36</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/ethereum-eth-founder-vitalik-buterin-bets-on-open-source-funding-not-public-goods">
#  <div class="news__item-title">Ethereum (ETH) Founder Vitalik Buterin Bets on Open Source Funding, Not Public Goods</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/vladislav-sopov"><img alt="Vladislav Sopov" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-07/8893.jpg" width="24"/>Vladislav Sopov
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 29, 2025 - 11:16</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/ethereum-eth-whales-close-to-liquidation-238-million-to-be-erased">
#  <div class="news__item-title">Ethereum (ETH) Whales Close to Liquidation, $238 Million to Be Erased</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/vladislav-sopov"><img alt="Vladislav Sopov" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-07/8893.jpg" width="24"/>Vladislav Sopov
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 28, 2025 - 15:00</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/is-1000-next-bloombergs-mcglone-queries-latest-ethereum-sell-off">
#  <div class="news__item-title">'Is $1,000 Next?': Bloomberg's McGlone Queries Latest Ethereum Sell-Off</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/godfrey-benjamin"><img alt="Godfrey Benjamin" class="humble__img" height="24" src="https://u.today/sites/default/files/2022-12/29302.jpg" width="24"/>Godfrey Benjamin
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 28, 2025 - 14:54</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/ethereum-crashes-74-against-bitcoin-is-reversal-imminent">
#  <div class="news__item-title">Ethereum Crashes 74% Against Bitcoin; Is Reversal Imminent?</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/tomiwabold-olajide"><img alt="Tomiwabold Olajide" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-11/8944.jpg" width="24"/>Tomiwabold Olajide
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 28, 2025 - 0:01</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/shiba-inu-shib-bulls-in-control-now-bitcoin-btc-in-great-spot-ethereum-eth-major-bearish-signal-but">
#  <div class="news__item-title">Shiba Inu (SHIB): Bulls in Control Now? Bitcoin (BTC) in Great Spot, Ethereum (ETH): Major Bearish Signal, But There's Silver Lining </div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/arman-shirinyan"><img alt="Arman Shirinyan" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8993.jpg" width="24"/>Arman Shirinyan
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 27, 2025 - 17:11</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/blockdag-bdag-pre-sale-hits-beta-testnet-launch-as-ethereum-eth-shiba-inu-shib-struggling-with">
#  <div class="news__item-title">BlockDAG (BDAG) Pre-Sale Hits Beta Testnet Launch as Ethereum (ETH), Shiba Inu (SHIB) Struggling with Pressure</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/guest-author"><img alt="Guest Author" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-11/10896.jpg" width="24"/>Guest Author
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 27, 2025 - 12:52</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/1084-million-ethereum-eth-in-24-hours-what-are-bulls-up-to">
#  <div class="news__item-title">10.84 Million Ethereum (ETH) in 24 Hours, What Are Bulls up To?</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/godfrey-benjamin"><img alt="Godfrey Benjamin" class="humble__img" height="24" src="https://u.today/sites/default/files/2022-12/29302.jpg" width="24"/>Godfrey Benjamin
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 27, 2025 - 0:01</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/is-xrp-price-ready-for-3-ethereum-eth-seeing-2000-test-shiba-inu-shib-15-trillion-whale-pump">
#  <div class="news__item-title">Is XRP Price Ready for $3? Ethereum (ETH) Seeing $2,000 Test, Shiba Inu (SHIB) 1.5 Trillion Whale Pump Recorded</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/arman-shirinyan"><img alt="Arman Shirinyan" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8993.jpg" width="24"/>Arman Shirinyan
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 25, 2025 - 22:14</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/ethereum-adoption-grows-with-launch-of-bank-issued-stablecoin">
#  <div class="news__item-title">Ethereum Adoption Grows With Launch of Bank-Issued Stablecoin</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/caroline-amosun"><img alt="Caroline Amosun" class="humble__img" height="24" src="https://u.today/sites/default/files/2025-03/56827.jpg" width="24"/>Caroline Amosun
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 24, 2025 - 15:20</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/ethereum-eth-price-prediction-for-march-24">
#  <div class="news__item-title">Ethereum (ETH) Price Prediction for March 24</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/denys-serhiichuk"><img alt="Denys Serhiichuk" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8942.jpg" width="24"/>Denys Serhiichuk
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 24, 2025 - 0:01</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/bitcoin-btc-invalidates-crucial-price-setup-xrp-faces-50-and-100-day-squeeze-ethereum-eth-finally">
#  <div class="news__item-title">Bitcoin (BTC) Invalidates Crucial Price Setup, XRP Faces 50 and 100 Day Squeeze, Ethereum (ETH) Finally Bounces Back?</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/arman-shirinyan"><img alt="Arman Shirinyan" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8993.jpg" width="24"/>Arman Shirinyan
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 22, 2025 - 14:02</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/ethereum-eth-price-prediction-for-march-22">
#  <div class="news__item-title">Ethereum (ETH) Price Prediction for March 22</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/denys-serhiichuk"><img alt="Denys Serhiichuk" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8942.jpg" width="24"/>Denys Serhiichuk
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 21, 2025 - 21:05</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/ethereum-eth-fees-plummet-50-as-network-activity-slowdown-sparks-concerns">
#  <div class="news__item-title">Ethereum (ETH) Fees Plummet 50% as Network Activity Slowdown Sparks Concerns</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/andy-sawa"><img alt="Andy Sawa" class="humble__img" height="24" src="https://u.today/sites/default/files/2025-03/56809.jpg" width="24"/>Andy Sawa
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 21, 2025 - 15:58</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/new-key-date-for-xrp-holders-just-emerged-major-exchange-lists-ada-and-coinbase-ethereum-for">
#  <div class="news__item-title">New Key Date for XRP Holders Just Emerged, Major Exchange Lists ADA and Coinbase Ethereum for Futures Collateral, Billions of SHIB Purchased by Major Dormant ETH Whale: Crypto News Digest by U.Today</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/valeria-blokhina"><img alt="Valeria Blokhina" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-10/9844.jpg" width="24"/>Valeria Blokhina
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 21, 2025 - 0:01</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/is-3-xrp-possible-bitcoin-btc-makes-biggest-breakout-in-2025-ethereum-eth-finally-above-2000">
#  <div class="news__item-title">Is $3 XRP Possible? Bitcoin (BTC) Makes Biggest Breakout in 2025, Ethereum (ETH) Finally Above $2,000</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/arman-shirinyan"><img alt="Arman Shirinyan" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8993.jpg" width="24"/>Arman Shirinyan
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 20, 2025 - 18:53</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/new-ethereum-etf-staking-proposal-filed-by-nyse">
#  <div class="news__item-title">New Ethereum ETF Staking Proposal Filed by NYSE </div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/alex-dovbnya"><img alt="Alex Dovbnya" class="humble__img" height="24" src="https://u.today/sites/default/files/2019-11/alex-m-ava.jpg" width="24"/>Alex Dovbnya
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 20, 2025 - 15:13</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/billions-of-shiba-inu-shib-acquired-by-major-dormant-ethereum-whale">
#  <div class="news__item-title">Billions of Shiba Inu (SHIB) Acquired by Major Dormant Ethereum Whale</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/gamza-khanzadaev"><img alt="Gamza Khanzadaev" class="humble__img" height="24" src="https://u.today/sites/default/files/2022-05/14694.jpg" width="24"/>Gamza Khanzadaev
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 20, 2025 - 10:49</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/major-exchange-lists-cardano-ada-and-coinbase-ethereum-for-futures-collateral">
#  <div class="news__item-title">Major Exchange Lists Cardano (ADA) and Coinbase Ethereum for Futures Collateral</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/gamza-khanzadaev"><img alt="Gamza Khanzadaev" class="humble__img" height="24" src="https://u.today/sites/default/files/2022-05/14694.jpg" width="24"/>Gamza Khanzadaev
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 19, 2025 - 17:00</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/blockdag-bdag-enters-new-roadmap-phase-as-shiba-inu-shib-ethereum-eth-price-metrics-consolidate">
#  <div class="news__item-title">BlockDAG (BDAG) Enters New Roadmap Phase as Shiba Inu (SHIB), Ethereum (ETH) Price Metrics Consolidate</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/guest-author"><img alt="Guest Author" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-11/10896.jpg" width="24"/>Guest Author
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 19, 2025 - 15:05</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/ethereum-eth-price-prediction-for-march-19">
#  <div class="news__item-title">Ethereum (ETH) Price Prediction for March 19</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/denys-serhiichuk"><img alt="Denys Serhiichuk" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8942.jpg" width="24"/>Denys Serhiichuk
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/events">Event</a></div>
#  <a class="news__item-body" href="https://u.today/events/consensus-2025">
#  <div class="news__item-title">Consensus 2025</div>
#  </a>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 19, 2025 - 5:54</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/ethereum-etfs-hemorrhage-50-million">
#  <div class="news__item-title">Ethereum ETFs Hemorrhage $50 Million </div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/alex-dovbnya"><img alt="Alex Dovbnya" class="humble__img" height="24" src="https://u.today/sites/default/files/2019-11/alex-m-ava.jpg" width="24"/>Alex Dovbnya
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 18, 2025 - 14:17</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/ethereum-eth-developers-launch-hoodi-testnet-and-prepare-pectra-for-mainnet-launch-in-may">
#  <div class="news__item-title">Ethereum (ETH) Developers Launch Hoodi Testnet and Prepare Pectra for Mainnet Launch in May</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/vladislav-sopov"><img alt="Vladislav Sopov" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-07/8893.jpg" width="24"/>Vladislav Sopov
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 18, 2025 - 0:01</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/shiba-inu-shib-reaches-crucial-price-test-ethereum-eth-eyeing-2000-again-can-xrp-avoid-this-grim">
#  <div class="news__item-title">Shiba Inu (SHIB) Reaches Crucial Price Test, Ethereum (ETH) Eyeing $2,000 Again, Can XRP Avoid This Grim Movement?</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/arman-shirinyan"><img alt="Arman Shirinyan" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8993.jpg" width="24"/>Arman Shirinyan
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 17, 2025 - 15:43</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/standard-chartered-dramatically-reduces-ethereum-eth-price-target">
#  <div class="news__item-title">Standard Chartered Dramatically Reduces Ethereum (ETH) Price Target </div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/alex-dovbnya"><img alt="Alex Dovbnya" class="humble__img" height="24" src="https://u.today/sites/default/files/2019-11/alex-m-ava.jpg" width="24"/>Alex Dovbnya
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 17, 2025 - 15:14</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/ethereum-eth-price-prediction-for-march-17">
#  <div class="news__item-title">Ethereum (ETH) Price Prediction for March 17</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/denys-serhiichuk"><img alt="Denys Serhiichuk" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8942.jpg" width="24"/>Denys Serhiichuk
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 15, 2025 - 13:34</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/solana-vs-ethereum-eight-parameters-compared-by-crypto-expert">
#  <div class="news__item-title">Solana vs. Ethereum: Eight Parameters Compared by Crypto Expert</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/vladislav-sopov"><img alt="Vladislav Sopov" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-07/8893.jpg" width="24"/>Vladislav Sopov
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 15, 2025 - 0:01</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/xrp-already-recovered-20-enormous-ethereum-eth-selling-volume-before-2000-sixth-shiba-inu-shib">
#  <div class="news__item-title">XRP Already Recovered 20%, Enormous Ethereum (ETH) Selling Volume Before $2,000, Sixth Shiba Inu (SHIB) Recovery Attempt: Another Crash?</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/arman-shirinyan"><img alt="Arman Shirinyan" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8993.jpg" width="24"/>Arman Shirinyan
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 14, 2025 - 15:31</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/xrp-flips-ethereum-in-fully-diluted-valuation-heres-implication">
#  <div class="news__item-title">XRP Flips Ethereum in Fully Diluted Valuation, Here's Implication</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/godfrey-benjamin"><img alt="Godfrey Benjamin" class="humble__img" height="24" src="https://u.today/sites/default/files/2022-12/29302.jpg" width="24"/>Godfrey Benjamin
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 14, 2025 - 10:05</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/xrp-v-ethereum-eth-ripple-cto-clears-up-major-sale-misconception">
#  <div class="news__item-title">XRP vs. Ethereum (ETH): Ripple CTO Clears up Major Sale Misconception</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/gamza-khanzadaev"><img alt="Gamza Khanzadaev" class="humble__img" height="24" src="https://u.today/sites/default/files/2022-05/14694.jpg" width="24"/>Gamza Khanzadaev
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 13, 2025 - 15:09</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/no-ethereum-eth-is-not-dead-says-top-analyst">
#  <div class="news__item-title">No, Ethereum (ETH) Is Not Dead, Says Top Analyst</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/arman-shirinyan"><img alt="Arman Shirinyan" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8993.jpg" width="24"/>Arman Shirinyan
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 12, 2025 - 22:49</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/ethereum-risks-drop-to-1400-mirroring-2020-crash-crypto-trader-warns">
#  <div class="news__item-title">Ethereum Risks Drop to $1,400, Mirroring 2020 Crash, Crypto Trader Warns</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/andy-sawa"><img alt="Andy Sawa" class="humble__img" height="24" src="https://u.today/sites/default/files/2025-03/56809.jpg" width="24"/>Andy Sawa
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 12, 2025 - 5:40</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/ethereum-etfs-log-nearly-22-million-worth-of-outflows">
#  <div class="news__item-title">Ethereum ETFs Log Nearly $22 Million Worth of Outflows</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/alex-dovbnya"><img alt="Alex Dovbnya" class="humble__img" height="24" src="https://u.today/sites/default/files/2019-11/alex-m-ava.jpg" width="24"/>Alex Dovbnya
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 12, 2025 - 0:01</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/solana-sol-death-cross-incoming-dogecoin-doge-hits-last-possible-support-ethereum-eth-says-goodbye">
#  <div class="news__item-title">Solana (SOL) Death Cross Incoming, Dogecoin (DOGE) Hits Last Possible Support, Ethereum (ETH) Says Goodbye to $2,000 </div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/arman-shirinyan"><img alt="Arman Shirinyan" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8993.jpg" width="24"/>Arman Shirinyan
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 11, 2025 - 16:30</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/fidelity-files-for-staking-on-ethereum-etf-product">
#  <div class="news__item-title">Fidelity Files for Staking on Ethereum ETF Product</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/godfrey-benjamin"><img alt="Godfrey Benjamin" class="humble__img" height="24" src="https://u.today/sites/default/files/2022-12/29302.jpg" width="24"/>Godfrey Benjamin
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 11, 2025 - 15:59</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/ethereum-foundation-makes-30098-eth-liquidation-play-on-maker-details">
#  <div class="news__item-title">Ethereum Foundation Makes 30,098 ETH Liquidation Play on Maker: Details</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/godfrey-benjamin"><img alt="Godfrey Benjamin" class="humble__img" height="24" src="https://u.today/sites/default/files/2022-12/29302.jpg" width="24"/>Godfrey Benjamin
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 11, 2025 - 15:22</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/ethereum-eth-price-prediction-for-march-11">
#  <div class="news__item-title">Ethereum (ETH) Price Prediction for March 11</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/denys-serhiichuk"><img alt="Denys Serhiichuk" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8942.jpg" width="24"/>Denys Serhiichuk
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 11, 2025 - 11:53</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/tron-founder-justin-sun-issues-crucial-ethereum-warning-details">
#  <div class="news__item-title">Tron Founder Justin Sun Issues Crucial Ethereum Warning: Details</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/yuri-molchan"><img alt="Yuri Molchan" class="humble__img" height="24" src="https://u.today/sites/default/files/2019-11/yuri-ava.jpg" width="24"/>Yuri Molchan
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 10, 2025 - 15:16</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/ethereum-eth-price-prediction-for-march-10-0">
#  <div class="news__item-title">Ethereum (ETH) Price Prediction for March 10</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/denys-serhiichuk"><img alt="Denys Serhiichuk" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8942.jpg" width="24"/>Denys Serhiichuk
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 10, 2025 - 8:42</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/consensys-ceo-says-ethereum-must-remain-neutral">
#  <div class="news__item-title">Consensys CEO Says Ethereum Must Remain Neutral </div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/alex-dovbnya"><img alt="Alex Dovbnya" class="humble__img" height="24" src="https://u.today/sites/default/files/2019-11/alex-m-ava.jpg" width="24"/>Alex Dovbnya
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 10, 2025 - 8:16</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/ethereum-eth-2000-might-be-lost-today">
#  <div class="news__item-title">Ethereum (ETH): $2,000 Might Be Lost Today</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/arman-shirinyan"><img alt="Arman Shirinyan" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8993.jpg" width="24"/>Arman Shirinyan
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 7, 2025 - 13:35</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/ethereum-eth-price-prediction-for-march-7-0">
#  <div class="news__item-title">Ethereum (ETH) Price Prediction for March 7</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/denys-serhiichuk"><img alt="Denys Serhiichuk" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8942.jpg" width="24"/>Denys Serhiichuk
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 7, 2025 - 0:01</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/xrps-250-price-breakout-still-questionable-dogecoin-doge-hits-major-support-again-ethereum-eth-not">
#  <div class="news__item-title">XRP's $2.50 Price Breakout Still Questionable, Dogecoin (DOGE) Hits Major Support Again, Ethereum (ETH) Not Okay</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/arman-shirinyan"><img alt="Arman Shirinyan" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8993.jpg" width="24"/>Arman Shirinyan
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 5, 2025 - 13:57</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/ethereum-eth-price-prediction-for-march-5">
#  <div class="news__item-title">Ethereum (ETH) Price Prediction for March 5</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/denys-serhiichuk"><img alt="Denys Serhiichuk" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8942.jpg" width="24"/>Denys Serhiichuk
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 5, 2025 - 0:01</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/xrp-24-retrace-is-mind-blowing-ethereum-eth-looks-even-worse-than-before-cardano-ada-biggest">
#  <div class="news__item-title">XRP: 24% Retrace is Mind-Blowing, Ethereum (ETH) Looks Even Worse Than Before, Cardano (ADA): Biggest Volatility Surge in Years </div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/arman-shirinyan"><img alt="Arman Shirinyan" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8993.jpg" width="24"/>Arman Shirinyan
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 3, 2025 - 14:51</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/solana-flips-ethereum-again-as-dex-volume-hits-399-billion">
#  <div class="news__item-title">Solana Flips Ethereum Again as DEX Volume Hits $3.99 Billion</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/godfrey-benjamin"><img alt="Godfrey Benjamin" class="humble__img" height="24" src="https://u.today/sites/default/files/2022-12/29302.jpg" width="24"/>Godfrey Benjamin
#              </a></div>
#  </div>,
#  <div class="news__item"><a class="news__item-body" href="https://u.today/press-releases/arciums-encrypted-ecosystem-established-to-accelerate-private-computation">
#  <div class="news__item-title">Arcium’s ‘Encrypted Ecosystem’ Established To Accelerate Private Computation</div>
#  </a></div>,
#  <div class="news__item"><a class="news__item-body" href="https://u.today/press-releases/blofin-becomes-title-sponsor-of-token2049-dubai-and-hosts-the-inaugural-whales-rave">
#  <div class="news__item-title">BloFin Becomes Title Sponsor of TOKEN2049 Dubai and Hosts the Inaugural Whale’s Rave: Arcadia Afterparty</div>
#  </a></div>,
#  <div class="news__item"><a class="news__item-body" href="https://u.today/press-releases/aster-emerges-astherus-rebrands-to-lead-decentralized-perpetual-trading">
#  <div class="news__item-title">Aster Emerges: Astherus Rebrands to Lead Decentralized Perpetual Trading</div>
#  </a></div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/companies" hreflang="en">Companies</a>
#  <div class="humble">Mar 14, 2025 - 16:04</div>
#  </div><a class="news__item-body" href="https://u.today/nebula-stride-announces-major-developments-as-nst-presale-gains-traction">
#  <div class="news__item-title">Nebula Stride Announces Major Developments as NST Presale Gains Traction</div></a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/vladislav-sopov">
#  <img alt="article image" class="humble__img" height="140" src="https://u.today/sites/default/files/2021-07/8893.jpg" width="224">
#              Vladislav Sopov</img></a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/opinions" hreflang="en">Opinions</a>
#  <div class="humble">Feb 2, 2025 - 18:00</div>
#  </div><a class="news__item-body" href="https://u.today/opinions/ripple-vs-sec-how-will-new-developments-affect-xrp-price">
#  <div class="news__item-title">Ripple v. SEC: How Will New Developments Affect XRP Price?</div></a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/dan-burgin">
#  <img alt="article image" class="humble__img" height="140" src="https://u.today/sites/default/files/2024-02/45425.jpg" width="224">
#              Dan Burgin</img></a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/opinions" hreflang="en">Opinions</a>
#  <div class="humble">Jan 18, 2025 - 18:00</div>
#  </div><a class="news__item-body" href="https://u.today/opinions/stellar-lumen-xlm-price-prediction-2025">
#  <div class="news__item-title">Stellar Lumen (XLM) Price Prediction 2025</div></a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/dan-burgin">
#  <img alt="article image" class="humble__img" height="140" src="https://u.today/sites/default/files/2024-02/45425.jpg" width="224">
#              Dan Burgin</img></a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/guides" hreflang="en">Guides</a>
#  <div class="humble">Jan 16, 2025 - 1:30</div>
#  </div><a class="news__item-body" href="https://u.today/guides/what-is-desci-guide-on-decentralized-science-in-crypto">
#  <div class="news__item-title">What is DeSci: Guide on Decentralized Science in Crypto</div></a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/vladislav-sopov">
#  <img alt="article image" class="humble__img" height="140" src="https://u.today/sites/default/files/2021-07/8893.jpg" width="224">
#              Vladislav Sopov</img></a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/latest-cryptocurrency-news" hreflang="en">News</a>
#  <div class="humble">Jan 15, 2025 - 10:56</div>
#  </div><a class="news__item-body" href="https://u.today/top-10-crypto-media-outlets-enter-2025-latest-similarweb-data-update">
#  <div class="news__item-title">Top 10 Crypto Media Outlets Enter 2025: Latest Similarweb Data Update</div></a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/vladislav-sopov">
#  <img alt="article image" class="humble__img" height="140" src="https://u.today/sites/default/files/2021-07/8893.jpg" width="224">
#              Vladislav Sopov</img></a></div>
#  </div>]

# %%
ethereum_data = []
for cards in News_card:
    data = []
    date_eth = card.select_one('div.news__item-head div.humble')
    if date_eth != None:
        datestr = date_eth.get_text()
        data.append(datetime.strptime(datestr.split(" - ")[0], "%b %d, %Y").date())
    title_eth = cards.select_one('div.news__item-title')
    if title_eth != None:
        data.append(title_eth.get_text())
    if len(data) == 2:
        ethereum_data.append(tuple(data))
    
ethereum_data
# Out:
# [(datetime.date(2025, 1, 15), 'Ethereum (ETH) Price Prediction for March 30'),
#  (datetime.date(2025, 1, 15), 'Pre-Mine Ethereum Address Suddenly Activated'),
#  (datetime.date(2025, 1, 15),
#   'Ethereum (ETH) Awaiting Crucial Crossover: Details'),
#  (datetime.date(2025, 1, 15), 'Ethereum (ETH) Price Prediction for March 29'),
#  (datetime.date(2025, 1, 15),
#   'Ethereum (ETH) Founder Vitalik Buterin Bets on Open Source Funding, Not Public Goods'),
#  (datetime.date(2025, 1, 15),
#   'Ethereum (ETH) Whales Close to Liquidation, $238 Million to Be Erased'),
#  (datetime.date(2025, 1, 15),
#   "'Is $1,000 Next?': Bloomberg's McGlone Queries Latest Ethereum Sell-Off"),
#  (datetime.date(2025, 1, 15),
#   'Ethereum Crashes 74% Against Bitcoin; Is Reversal Imminent?'),
#  (datetime.date(2025, 1, 15),
#   "Shiba Inu (SHIB): Bulls in Control Now? Bitcoin (BTC) in Great Spot, Ethereum (ETH): Major Bearish Signal, But There's Silver Lining "),
#  (datetime.date(2025, 1, 15),
#   'BlockDAG (BDAG) Pre-Sale Hits Beta Testnet Launch as Ethereum (ETH), Shiba Inu (SHIB) Struggling with Pressure'),
#  (datetime.date(2025, 1, 15),
#   '10.84 Million Ethereum (ETH) in 24 Hours, What Are Bulls up To?'),
#  (datetime.date(2025, 1, 15),
#   'Is XRP Price Ready for $3? Ethereum (ETH) Seeing $2,000 Test, Shiba Inu (SHIB) 1.5 Trillion Whale Pump Recorded'),
#  (datetime.date(2025, 1, 15),
#   'Ethereum Adoption Grows With Launch of Bank-Issued Stablecoin'),
#  (datetime.date(2025, 1, 15), 'Ethereum (ETH) Price Prediction for March 24'),
#  (datetime.date(2025, 1, 15),
#   'Bitcoin (BTC) Invalidates Crucial Price Setup, XRP Faces 50 and 100 Day Squeeze, Ethereum (ETH) Finally Bounces Back?'),
#  (datetime.date(2025, 1, 15), 'Ethereum (ETH) Price Prediction for March 22'),
#  (datetime.date(2025, 1, 15),
#   'Ethereum (ETH) Fees Plummet 50% as Network Activity Slowdown Sparks Concerns'),
#  (datetime.date(2025, 1, 15),
#   'New Key Date for XRP Holders Just Emerged, Major Exchange Lists ADA and Coinbase Ethereum for Futures Collateral, Billions of SHIB Purchased by Major Dormant ETH Whale: Crypto News Digest by U.Today'),
#  (datetime.date(2025, 1, 15),
#   'Is $3 XRP Possible? Bitcoin (BTC) Makes Biggest Breakout in 2025, Ethereum (ETH) Finally Above $2,000'),
#  (datetime.date(2025, 1, 15),
#   'New Ethereum ETF Staking Proposal Filed by NYSE '),
#  (datetime.date(2025, 1, 15),
#   'Billions of Shiba Inu (SHIB) Acquired by Major Dormant Ethereum Whale'),
#  (datetime.date(2025, 1, 15),
#   'Major Exchange Lists Cardano (ADA) and Coinbase Ethereum for Futures Collateral'),
#  (datetime.date(2025, 1, 15),
#   'BlockDAG (BDAG) Enters New Roadmap Phase as Shiba Inu (SHIB), Ethereum (ETH) Price Metrics Consolidate'),
#  (datetime.date(2025, 1, 15), 'Ethereum (ETH) Price Prediction for March 19'),
#  (datetime.date(2025, 1, 15), 'Consensus 2025'),
#  (datetime.date(2025, 1, 15), 'Ethereum ETFs Hemorrhage $50 Million '),
#  (datetime.date(2025, 1, 15),
#   'Ethereum (ETH) Developers Launch Hoodi Testnet and Prepare Pectra for Mainnet Launch in May'),
#  (datetime.date(2025, 1, 15),
#   'Shiba Inu (SHIB) Reaches Crucial Price Test, Ethereum (ETH) Eyeing $2,000 Again, Can XRP Avoid This Grim Movement?'),
#  (datetime.date(2025, 1, 15),
#   'Standard Chartered Dramatically Reduces Ethereum (ETH) Price Target '),
#  (datetime.date(2025, 1, 15), 'Ethereum (ETH) Price Prediction for March 17'),
#  (datetime.date(2025, 1, 15),
#   'Solana vs. Ethereum: Eight Parameters Compared by Crypto Expert'),
#  (datetime.date(2025, 1, 15),
#   'XRP Already Recovered 20%, Enormous Ethereum (ETH) Selling Volume Before $2,000, Sixth Shiba Inu (SHIB) Recovery Attempt: Another Crash?'),
#  (datetime.date(2025, 1, 15),
#   "XRP Flips Ethereum in Fully Diluted Valuation, Here's Implication"),
#  (datetime.date(2025, 1, 15),
#   'XRP vs. Ethereum (ETH): Ripple CTO Clears up Major Sale Misconception'),
#  (datetime.date(2025, 1, 15),
#   'No, Ethereum (ETH) Is Not Dead, Says Top Analyst'),
#  (datetime.date(2025, 1, 15),
#   'Ethereum Risks Drop to $1,400, Mirroring 2020 Crash, Crypto Trader Warns'),
#  (datetime.date(2025, 1, 15),
#   'Ethereum ETFs Log Nearly $22 Million Worth of Outflows'),
#  (datetime.date(2025, 1, 15),
#   'Solana (SOL) Death Cross Incoming, Dogecoin (DOGE) Hits Last Possible Support, Ethereum (ETH) Says Goodbye to $2,000 '),
#  (datetime.date(2025, 1, 15),
#   'Fidelity Files for Staking on Ethereum ETF Product'),
#  (datetime.date(2025, 1, 15),
#   'Ethereum Foundation Makes 30,098 ETH Liquidation Play on Maker: Details'),
#  (datetime.date(2025, 1, 15), 'Ethereum (ETH) Price Prediction for March 11'),
#  (datetime.date(2025, 1, 15),
#   'Tron Founder Justin Sun Issues Crucial Ethereum Warning: Details'),
#  (datetime.date(2025, 1, 15), 'Ethereum (ETH) Price Prediction for March 10'),
#  (datetime.date(2025, 1, 15),
#   'Consensys CEO Says Ethereum Must Remain Neutral '),
#  (datetime.date(2025, 1, 15), 'Ethereum (ETH): $2,000 Might Be Lost Today'),
#  (datetime.date(2025, 1, 15), 'Ethereum (ETH) Price Prediction for March 7'),
#  (datetime.date(2025, 1, 15),
#   "XRP's $2.50 Price Breakout Still Questionable, Dogecoin (DOGE) Hits Major Support Again, Ethereum (ETH) Not Okay"),
#  (datetime.date(2025, 1, 15), 'Ethereum (ETH) Price Prediction for March 5'),
#  (datetime.date(2025, 1, 15),
#   'XRP: 24% Retrace is Mind-Blowing, Ethereum (ETH) Looks Even Worse Than Before, Cardano (ADA): Biggest Volatility Surge in Years '),
#  (datetime.date(2025, 1, 15),
#   'Solana Flips Ethereum Again as DEX Volume Hits $3.99 Billion'),
#  (datetime.date(2025, 1, 15),
#   'Arcium’s ‘Encrypted Ecosystem’ Established To Accelerate Private Computation'),
#  (datetime.date(2025, 1, 15),
#   'BloFin Becomes Title Sponsor of TOKEN2049 Dubai and Hosts the Inaugural Whale’s Rave: Arcadia Afterparty'),
#  (datetime.date(2025, 1, 15),
#   'Aster Emerges: Astherus Rebrands to Lead Decentralized Perpetual Trading'),
#  (datetime.date(2025, 1, 15),
#   'Nebula Stride Announces Major Developments as NST Presale Gains Traction'),
#  (datetime.date(2025, 1, 15),
#   'Ripple v. SEC: How Will New Developments Affect XRP Price?'),
#  (datetime.date(2025, 1, 15), 'Stellar Lumen (XLM) Price Prediction 2025'),
#  (datetime.date(2025, 1, 15),
#   'What is DeSci: Guide on Decentralized Science in Crypto'),
#  (datetime.date(2025, 1, 15),
#   'Top 10 Crypto Media Outlets Enter 2025: Latest Similarweb Data Update')]

# %%
ethereum_DFM = pd.DataFrame(ethereum_data, columns = ['date', 'title'])
ethereum_DFM
# Out:
#           date                                              title
# 0   2025-01-15       Ethereum (ETH) Price Prediction for March 30
# 1   2025-01-15       Pre-Mine Ethereum Address Suddenly Activated
# 2   2025-01-15  Ethereum (ETH) Awaiting Crucial Crossover: Det...
# 3   2025-01-15       Ethereum (ETH) Price Prediction for March 29
# 4   2025-01-15  Ethereum (ETH) Founder Vitalik Buterin Bets on...
# 5   2025-01-15  Ethereum (ETH) Whales Close to Liquidation, $2...
# 6   2025-01-15  'Is $1,000 Next?': Bloomberg's McGlone Queries...
# 7   2025-01-15  Ethereum Crashes 74% Against Bitcoin; Is Rever...
# 8   2025-01-15  Shiba Inu (SHIB): Bulls in Control Now? Bitcoi...
# 9   2025-01-15  BlockDAG (BDAG) Pre-Sale Hits Beta Testnet Lau...
# 10  2025-01-15  10.84 Million Ethereum (ETH) in 24 Hours, What...
# 11  2025-01-15  Is XRP Price Ready for $3? Ethereum (ETH) Seei...
# 12  2025-01-15  Ethereum Adoption Grows With Launch of Bank-Is...
# 13  2025-01-15       Ethereum (ETH) Price Prediction for March 24
# 14  2025-01-15  Bitcoin (BTC) Invalidates Crucial Price Setup,...
# 15  2025-01-15       Ethereum (ETH) Price Prediction for March 22
# 16  2025-01-15  Ethereum (ETH) Fees Plummet 50% as Network Act...
# 17  2025-01-15  New Key Date for XRP Holders Just Emerged, Maj...
# 18  2025-01-15  Is $3 XRP Possible? Bitcoin (BTC) Makes Bigges...
# 19  2025-01-15   New Ethereum ETF Staking Proposal Filed by NYSE
# 20  2025-01-15  Billions of Shiba Inu (SHIB) Acquired by Major...
# 21  2025-01-15  Major Exchange Lists Cardano (ADA) and Coinbas...
# 22  2025-01-15  BlockDAG (BDAG) Enters New Roadmap Phase as Sh...
# 23  2025-01-15       Ethereum (ETH) Price Prediction for March 19
# 24  2025-01-15                                     Consensus 2025
# 25  2025-01-15              Ethereum ETFs Hemorrhage $50 Million
# 26  2025-01-15  Ethereum (ETH) Developers Launch Hoodi Testnet...
# 27  2025-01-15  Shiba Inu (SHIB) Reaches Crucial Price Test, E...
# 28  2025-01-15  Standard Chartered Dramatically Reduces Ethere...
# 29  2025-01-15       Ethereum (ETH) Price Prediction for March 17
# 30  2025-01-15  Solana vs. Ethereum: Eight Parameters Compared...
# 31  2025-01-15  XRP Already Recovered 20%, Enormous Ethereum (...
# 32  2025-01-15  XRP Flips Ethereum in Fully Diluted Valuation,...
# 33  2025-01-15  XRP vs. Ethereum (ETH): Ripple CTO Clears up M...
# 34  2025-01-15   No, Ethereum (ETH) Is Not Dead, Says Top Analyst
# 35  2025-01-15  Ethereum Risks Drop to $1,400, Mirroring 2020 ...
# 36  2025-01-15  Ethereum ETFs Log Nearly $22 Million Worth of ...
# 37  2025-01-15  Solana (SOL) Death Cross Incoming, Dogecoin (D...
# 38  2025-01-15  Fidelity Files for Staking on Ethereum ETF Pro...
# 39  2025-01-15  Ethereum Foundation Makes 30,098 ETH Liquidati...
# 40  2025-01-15       Ethereum (ETH) Price Prediction for March 11
# 41  2025-01-15  Tron Founder Justin Sun Issues Crucial Ethereu...
# 42  2025-01-15       Ethereum (ETH) Price Prediction for March 10
# 43  2025-01-15   Consensys CEO Says Ethereum Must Remain Neutral
# 44  2025-01-15         Ethereum (ETH): $2,000 Might Be Lost Today
# 45  2025-01-15        Ethereum (ETH) Price Prediction for March 7
# 46  2025-01-15  XRP's $2.50 Price Breakout Still Questionable,...
# 47  2025-01-15        Ethereum (ETH) Price Prediction for March 5
# 48  2025-01-15  XRP: 24% Retrace is Mind-Blowing, Ethereum (ET...
# 49  2025-01-15  Solana Flips Ethereum Again as DEX Volume Hits...
# 50  2025-01-15  Arcium’s ‘Encrypted Ecosystem’ Established To ...
# 51  2025-01-15  BloFin Becomes Title Sponsor of TOKEN2049 Duba...
# 52  2025-01-15  Aster Emerges: Astherus Rebrands to Lead Decen...
# 53  2025-01-15  Nebula Stride Announces Major Developments as ...
# 54  2025-01-15  Ripple v. SEC: How Will New Developments Affec...
# 55  2025-01-15          Stellar Lumen (XLM) Price Prediction 2025
# 56  2025-01-15  What is DeSci: Guide on Decentralized Science ...
# 57  2025-01-15  Top 10 Crypto Media Outlets Enter 2025: Latest...

# %%
ethereum_DFM['currency'] = "Ethereum"

# %%
#save to csv
ethereum_DFM.to_csv('ethereum_Daily_News.csv', index=False)

# %% [markdown]
# ## Solana Sraping

# %%
import requests

url = 'import requests'

url = 'https://u.today/search/node?keys=Solana'
response_s = requests.get(url)
response_s
# Out:
# <Response [200]>

# %%
import requests
import bs4

response = requests.get("https://u.today/search/node?keys=Solana")
# soup = bs4.BeautifulSoup(response.text, 'lxml') # with lxml package
docu = bs4.BeautifulSoup(response.text, 'html.parser') 
docu
# Out:
#  <!DOCTYPE html>
#
# <html class="theme-light" dir="ltr" lang="en" prefix="og: ogp.me/ns#">
# <head>
# <script async="" crossorigin="anonymous" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js?client=ca-pub-9245916885225528"></script>
# <link href="https://www.google-analytics.com" rel="preconnect"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=5" name="viewport"/>
# <script src="/core/assets/vendor/jquery/jquery.min.js"></script>
# <meta charset="utf-8">
# <link href="https://u.today/search/node" rel="canonical">
# <meta content="article" property="og:type"/>
# <meta content="https://u.today/search/node" property="og:url"/>
# <meta content="Search" property="og:title"/>
# <meta content="Search" property="og:description"/>
# <meta content="https://u.today/img/logo-utoday.png" property="og:image"/>
# <meta content="https://u.today/img/logo-utoday.png" property="og:image:url"/>
# <meta content="https://u.today/img/logo-utoday.png" property="og:image:secure_url"/>
# <meta content="2560796210663191" property="fb:app_id"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="@Utoday_en" name="twitter:site"/>
# <meta content="https://u.today/img/logo-utoday.png" name="twitter:image"/>
# <meta content="Drupal 10 (https://www.drupal.org)" name="Generator"/>
# <meta content="width" name="MobileOptimized"/>
# <meta content="true" name="HandheldFriendly"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <script type="application/ld+json">{
#     "@context": "https://schema.org",
#     "@graph": [
#         {
#             "@type": "Organization",
#             "name": "U.Today",
#             "url": "https://u.today/search/node",
#             "image": {
#                 "@type": "ImageObject",
#                 "url": "https://U.today/img/logo-utoday.png"
#             }
#         }
#     ]
# }</script>
# <!-- end: separate google analytics code -->
# <!-- Google Tag Manager -->
# <!-- End Google Tag Manager -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-2PE2QV2V0X"></script>
# <script>
#         window.dataLayer = window.dataLayer || [];
#         function gtag(){dataLayer.push(arguments);}
#         gtag('js', new Date());
#
#         gtag('config', 'G-2PE2QV2V0X');
#     </script>
# <link color="#263238" href="/img/favicon/safari-pinned-tab.svg" rel="mask-icon"/>
# <link href="/img/favicon/apple-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
# <link href="/img/favicon/apple-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
# <link href="/img/favicon/apple-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
# <link href="/img/favicon/apple-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
# <link href="/img/favicon/apple-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
# <link href="/img/favicon/apple-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
# <link href="/img/favicon/apple-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
# <link href="/img/favicon/apple-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
# <link href="/img/favicon/apple-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/img/favicon/android-icon-192x192.png" rel="icon" sizes="192x192" type="image/png"/>
# <link href="/img/favicon/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/img/favicon/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
# <link href="/img/favicon/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/site.webmanifest" rel="manifest"/>
# <link color="#263238" href="/img/favicon/safari-pinned-tab.svg" rel="mask-icon"/>
# <link href="/img/favicon/favicon.ico" rel="shortcut icon"/>
# <meta content="#263238" name="msapplication-TileColor"/>
# <meta content="/img/favicon/browserconfig.xml" name="msapplication-config"/>
# <meta content="#263238" name="theme-color"/>
# <meta content="2E6EDC1D9A57E69FC6232E905A08CBFA" name="msvalidate.01">
# <link href="/manifest.json" rel="manifest">
# <meta content="266789420636465" property="fb:pages">
# <link href="/modules/contrib/paragraphs/css/paragraphs.unpublished.css?stzpi2" media="all" rel="stylesheet">
# <link href="/themes/cryptod/libs/air-datepicker/air-datepicker.css?stzpi2" media="all" rel="stylesheet">
# <link href="/themes/cryptod/styles/slick-theme.css?stzpi2" media="all" rel="stylesheet">
# <link href="/themes/cryptod/styles/common.css?stzpi2" media="all" rel="stylesheet">
# <link href="/themes/cryptod/styles/app.css?stzpi2" media="all" rel="stylesheet">
# <link href="/themes/cryptod/styles/push.css?stzpi2" media="all" rel="stylesheet">
# <style>.ccc-widget.ccc-list .header-div a img {
#                             width: 26px;
#                             height: 26px;
#                         }
#                     </style>
# <title>Search | U.Today</title>
# <script src="https://cdn.onesignal.com/sdks/OneSignalSDK.js"></script>
# <script>
#                         function copyToClipboard(e) {
#                             let input = document.body.appendChild(document.createElement("input"));
#                             input.value = window.location.href;
#                             input.select();
#                             document.execCommand('copy');
#                             input.parentNode.removeChild(input);
#
#                             let tooltip = document.createElement('div');
#                             tooltip.className = 'copy-tooltip';
#                             tooltip.innerHTML = 'Copied!';
#
#                             if (!e.querySelector('.copy-tooltip')) {
#                                 e.append(tooltip);
#
#                                 setTimeout(() => {
#                                     e.querySelector('.copy-tooltip').remove();
#                                 }, 2000);
#                             }
#                         }
#                     </script>
# <style>
#                         @media (max-width: 849px) {
#                             body #onesignal-slidedown-container.slide-up {
#                                 bottom: 60px
#                             }
#                         }
#                     </style>
# <script async="" defer="" src="https://www.google.com/recaptcha/api.js"></script>
# <style>
#                         .captcha-container {
#                             display: none; /* CAPTCHA скрыта по умолчанию */
#                         }
#                     </style>
# </link></link></link></link></link></link></meta></link></meta></link></meta></head>
# <body class="not_logged_in">
# <!-- Google Tag Manager (noscript) -->
# <!-- End Google Tag Manager (noscript) -->
# <div class="something--upper">
# <div class="something">
# <div class="something__title">Advertisement</div>
# <div class="something__nav">
# <div class="something__label">AD</div>
# <button aria-label="Close ad" class="btn btn--light something__close"></button>
# </div>
# <div class="something__content">
# <div class="something__content--long">
# <div>
# <!-- Wideheader Fixed Desktop 1150x60 [async] -->
# <script type="text/javascript">
#
# if (!window.AdButler){(function(){var s = document.createElement("script"); s.async = true; s.type = "text/javascript"; s.src = 'https://servedbyadbutler.com/app.js'; var n = document.getElementsByTagName("script")[0]; n.parentNode.insertBefore(s, n);}());}
#
# </script>
# <script type="text/javascript">
# var AdButler = AdButler || {};
# AdButler.ads = AdButler.ads || [];
# var abkw = window.abkw || '';
# var plc602403 = window.plc602403 || 0;
# document.write('<'+'div id="placement_602403_'+plc602403+'"></'+'div>');
# AdButler.ads.push({handler: function(opt){ AdButler.register(183269, 602403, [1150,60], 'placement_602403_'+opt.place, opt); }, opt: { place: plc602403++, keywords: abkw, domain: 'servedbyadbutler.com', click: 'CLICK_MACRO_PLACEHOLDER' }});
#
# </script>
# </div>
# </div>
# <div class="something__content--square">
# <div>
# <!-- Wideheader Fixed Mobile 336x60 [async] -->
# <script type="text/javascript">
# if (document.documentElement.clientWidth < 768) {
# if (!window.AdButler){(function(){var s = document.createElement("script"); s.async = true; s.type = "text/javascript"; s.src = 'https://servedbyadbutler.com/app.js'; var n = document.getElementsByTagName("script")[0]; n.parentNode.insertBefore(s, n);}());}
# }
# </script>
# <script type="text/javascript">
# if (document.documentElement.clientWidth < 768) {
# var AdButler = AdButler || {};
# AdButler.ads = AdButler.ads || [];
# var abkw = window.abkw || '';
# var plc551690 = window.plc551690 || 0;
# document.write('<'+'div id="placement_551690_'+plc551690+'"></'+'div>');
# AdButler.ads.push({handler: function(opt){ AdButler.register(183269, 551690, [336,60], 'placement_551690_'+opt.place, opt); }, opt: { place: plc551690++, keywords: abkw, domain: 'servedbyadbutler.com', click: 'CLICK_MACRO_PLACEHOLDER' }});
# }
# </script>
# </div>
# </div>
# </div>
# </div>
# </div>
# <header class="header">
# <div class="header__container"><a class="header__logo" href="https://u.today/" title="U.Today logo"></a>
# <div class="header__search" style="display: block">
# <form action="/search/node" class="header__search-form" method="get">
# <button class="header__search-submit btn btn--light btn--search" style="display: none;" type="submit"></button>
# <input class="header__search-input" id="search_text" name="keys" type="text"/>
# <button class="header__search-close btn btn--light btn--cross"></button>
# </form>
# </div>
# </div>
# </header>
# <div class="mobile-menu-cover"></div>
# <div class="page-container container">
# <div class="main-aside-container">
# <main class="main-block">
# <div class="search-result">
# <h1 class="page-bg-title">Search results for “Solana”</h1>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 26, 2025 - 14:16</div>
# </div>
# <a class="news__item-body" href="https://u.today/solana-sol-price-prediction-for-march-26">
# <div class="news__item-title">Solana (SOL) Price Prediction for March 26</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/denys-serhiichuk"><img alt="Denys Serhiichuk" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8942.jpg" width="24"/>Denys Serhiichuk
#             </a></div>
# </div>
# <div class="something something--content">
# <div class="something__content-long">
# <ins class="adsbygoogle" data-ad-client="ca-pub-4834169448759613" data-ad-slot="1698558466" style="display:inline-block;width:728px;height:90px"></ins>
# </div>
# <div class="something__content-square">
# <ins class="adsbygoogle" data-ad-client="ca-pub-4834169448759613" data-ad-slot="4003311693" style="display:inline-block;width:336px;height:280px"></ins>
# </div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/press-releases">Press release</a>
# <div class="humble">Mar 26, 2025 - 7:16</div>
# </div>
# <a class="news__item-body" href="https://u.today/press-releases/solpot-emerges-as-solanas-premier-on-chain-platform-distributes-over-400k-in-free">
# <div class="news__item-title">Solpot Emerges as Solana's Premier On-Chain Platform, Distributes Over $400K in Free Rewards</div>
# </a>
# <div class="news__item-desc"></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 25, 2025 - 16:29</div>
# </div>
# <a class="news__item-body" href="https://u.today/breaking-fidelity-officially-joins-solana-etf-race">
# <div class="news__item-title">Breaking: Fidelity Officially Joins Solana ETF Race</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/alex-dovbnya"><img alt="Alex Dovbnya" class="humble__img" height="24" src="https://u.today/sites/default/files/2019-11/alex-m-ava.jpg" width="24"/>Alex Dovbnya
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 25, 2025 - 16:01</div>
# </div>
# <a class="news__item-body" href="https://u.today/blackrock-expands-blockchain-footprint-to-solana">
# <div class="news__item-title">BlackRock Expands Blockchain Footprint to Solana</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/godfrey-benjamin"><img alt="Godfrey Benjamin" class="humble__img" height="24" src="https://u.today/sites/default/files/2022-12/29302.jpg" width="24"/>Godfrey Benjamin
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 25, 2025 - 15:42</div>
# </div>
# <a class="news__item-body" href="https://u.today/solana-dog-coin-bonk-rallies-35-unnoticed-whats-behind-it">
# <div class="news__item-title">Solana Dog-Coin BONK Rallies 35% Unnoticed – What's Behind It?</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/tomiwabold-olajide"><img alt="Tomiwabold Olajide" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-11/8944.jpg" width="24"/>Tomiwabold Olajide
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/press-releases">Press release</a>
# <div class="humble">Mar 25, 2025 - 11:13</div>
# </div>
# <a class="news__item-body" href="https://u.today/press-releases/whaleio-to-bridge-nft-collection-from-ton-blockchain-to-solana">
# <div class="news__item-title">Whale.io to Bridge NFT Collection from TON Blockchain to Solana</div>
# </a>
# <div class="news__item-desc"></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 23, 2025 - 18:12</div>
# </div>
# <a class="news__item-body" href="https://u.today/solana-co-founder-trashes-l2s-says-l1s-are-faster-and-more-secure">
# <div class="news__item-title"> Solana Co-Founder Trashes L2s, Says L1s Are Faster and More Secure</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/alex-dovbnya"><img alt="Alex Dovbnya" class="humble__img" height="24" src="https://u.today/sites/default/files/2019-11/alex-m-ava.jpg" width="24"/>Alex Dovbnya
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 23, 2025 - 14:41</div>
# </div>
# <a class="news__item-body" href="https://u.today/solana-sol-price-prediction-for-march-23">
# <div class="news__item-title">Solana (SOL) Price Prediction for March 23</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/denys-serhiichuk"><img alt="Denys Serhiichuk" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8942.jpg" width="24"/>Denys Serhiichuk
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 20, 2025 - 21:58</div>
# </div>
# <a class="news__item-body" href="https://u.today/justin-sun-sparks-tron-etf-rumors-as-trx-expands-to-solana">
# <div class="news__item-title">Justin Sun Sparks Tron ETF Rumors as TRX Expands to Solana</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/andy-sawa"><img alt="Andy Sawa" class="humble__img" height="24" src="https://u.today/sites/default/files/2025-03/56809.jpg" width="24"/>Andy Sawa
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 19, 2025 - 0:01</div>
# </div>
# <a class="news__item-body" href="https://u.today/bitcoin-btc-make-or-break-support-reached-dogecoin-doge-price-at-breaking-point-secret-bullish">
# <div class="news__item-title">Bitcoin (BTC): Make or Break Support Reached, Dogecoin (DOGE) Price at Breaking Point, Secret Bullish Solana (SOL) Pattern Formed?</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/arman-shirinyan"><img alt="Arman Shirinyan" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8993.jpg" width="24"/>Arman Shirinyan
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 18, 2025 - 16:03</div>
# </div>
# <a class="news__item-body" href="https://u.today/did-cmes-solana-futures-flop-not-really">
# <div class="news__item-title">Did CME's Solana Futures Flop? Not Really</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/alex-dovbnya"><img alt="Alex Dovbnya" class="humble__img" height="24" src="https://u.today/sites/default/files/2019-11/alex-m-ava.jpg" width="24"/>Alex Dovbnya
#             </a></div>
# </div>
# <div class="something something--content">
# <div class="something__content-long">
# <ins class="adsbygoogle" data-ad-client="ca-pub-4834169448759613" data-ad-slot="1698558466" style="display:inline-block;width:728px;height:90px"></ins>
# </div>
# <div class="something__content-square">
# <ins class="adsbygoogle" data-ad-client="ca-pub-4834169448759613" data-ad-slot="4003311693" style="display:inline-block;width:336px;height:280px"></ins>
# </div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 17, 2025 - 15:02</div>
# </div>
# <a class="news__item-body" href="https://u.today/solana-at-127-what-to-expect-from-sol-price-this-week">
# <div class="news__item-title">Solana at $127: What to Expect From SOL Price This Week</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/godfrey-benjamin"><img alt="Godfrey Benjamin" class="humble__img" height="24" src="https://u.today/sites/default/files/2022-12/29302.jpg" width="24"/>Godfrey Benjamin
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 17, 2025 - 10:02</div>
# </div>
# <a class="news__item-body" href="https://u.today/59-million-solana-sol-in-7-days-whats-going-to-happen">
# <div class="news__item-title">$59 Million Solana (SOL) in 7 Days: What's Going to Happen?</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/arman-shirinyan"><img alt="Arman Shirinyan" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8993.jpg" width="24"/>Arman Shirinyan
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 17, 2025 - 0:01</div>
# </div>
# <a class="news__item-body" href="https://u.today/bitcoin-btc-must-break-this-to-reach-100000-dogecoin-doge-coming-closer-to-bull-market-solana-sol">
# <div class="news__item-title">Bitcoin (BTC) Must Break This to Reach $100,000, Dogecoin (DOGE) Coming Closer to Bull Market, Solana (SOL) Death Cross Complications</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/arman-shirinyan"><img alt="Arman Shirinyan" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8993.jpg" width="24"/>Arman Shirinyan
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 16, 2025 - 15:09</div>
# </div>
# <a class="news__item-body" href="https://u.today/solana-sol-celebrates-5th-birthday-details">
# <div class="news__item-title">Solana (SOL) Celebrates 5th Birthday: Details</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/gamza-khanzadaev"><img alt="Gamza Khanzadaev" class="humble__img" height="24" src="https://u.today/sites/default/files/2022-05/14694.jpg" width="24"/>Gamza Khanzadaev
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 15, 2025 - 13:34</div>
# </div>
# <a class="news__item-body" href="https://u.today/solana-vs-ethereum-eight-parameters-compared-by-crypto-expert">
# <div class="news__item-title">Solana vs. Ethereum: Eight Parameters Compared by Crypto Expert</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/vladislav-sopov"><img alt="Vladislav Sopov" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-07/8893.jpg" width="24"/>Vladislav Sopov
#             </a></div>
# </div>
# <div class="something something--content">
# <div class="something__content-long">
# <ins class="adsbygoogle" data-ad-client="ca-pub-4834169448759613" data-ad-slot="1698558466" style="display:inline-block;width:728px;height:90px"></ins>
# </div>
# <div class="something__content-square">
# <ins class="adsbygoogle" data-ad-client="ca-pub-4834169448759613" data-ad-slot="4003311693" style="display:inline-block;width:336px;height:280px"></ins>
# </div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 14, 2025 - 15:17</div>
# </div>
# <a class="news__item-body" href="https://u.today/solana-sol-price-prediction-for-march-14">
# <div class="news__item-title">Solana (SOL) Price Prediction for March 14</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/denys-serhiichuk"><img alt="Denys Serhiichuk" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8942.jpg" width="24"/>Denys Serhiichuk
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 14, 2025 - 11:22</div>
# </div>
# <a class="news__item-body" href="https://u.today/solanas-sol-legendary-cup-and-handle-pattern-shaping-up-heres-target">
# <div class="news__item-title">Solana's (SOL) Legendary Cup and Handle Pattern Shaping Up, Here's Target</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/tomiwabold-olajide"><img alt="Tomiwabold Olajide" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-11/8944.jpg" width="24"/>Tomiwabold Olajide
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 14, 2025 - 0:01</div>
# </div>
# <a class="news__item-body" href="https://u.today/dogecoin-death-cross-confirmed-solana-sol-joins-doge-with-its-own-death-cross-xrp-recovery">
# <div class="news__item-title">Dogecoin Death Cross Confirmed, Solana (SOL): Joins DOGE With Its Own Death Cross, XRP Recovery Continues: Next Level to Watch</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/arman-shirinyan"><img alt="Arman Shirinyan" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8993.jpg" width="24"/>Arman Shirinyan
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 13, 2025 - 11:43</div>
# </div>
# <a class="news__item-body" href="https://u.today/201755-solana-sol-stun-worlds-largest-crypto-exchange">
# <div class="news__item-title">201,755 Solana (SOL) Stun World's Largest Crypto Exchange</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/godfrey-benjamin"><img alt="Godfrey Benjamin" class="humble__img" height="24" src="https://u.today/sites/default/files/2022-12/29302.jpg" width="24"/>Godfrey Benjamin
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 12, 2025 - 18:55</div>
# </div>
# <a class="news__item-body" href="https://u.today/solana-etf-proposed-by-15-trillion-investment-titan">
# <div class="news__item-title">Solana ETF Proposed by $1.5 Trillion Investment Titan </div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/alex-dovbnya"><img alt="Alex Dovbnya" class="humble__img" height="24" src="https://u.today/sites/default/files/2019-11/alex-m-ava.jpg" width="24"/>Alex Dovbnya
#             </a></div>
# </div>
# <div class="something something--content">
# <div class="something__content-long">
# <ins class="adsbygoogle" data-ad-client="ca-pub-4834169448759613" data-ad-slot="1698558466" style="display:inline-block;width:728px;height:90px"></ins>
# </div>
# <div class="something__content-square">
# <ins class="adsbygoogle" data-ad-client="ca-pub-4834169448759613" data-ad-slot="4003311693" style="display:inline-block;width:336px;height:280px"></ins>
# </div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 12, 2025 - 15:05</div>
# </div>
# <a class="news__item-body" href="https://u.today/solana-sol-revenue-falls-93-from-january-high">
# <div class="news__item-title">Solana (SOL) Revenue Falls 93% From January High</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/godfrey-benjamin"><img alt="Godfrey Benjamin" class="humble__img" height="24" src="https://u.today/sites/default/files/2022-12/29302.jpg" width="24"/>Godfrey Benjamin
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 12, 2025 - 12:24</div>
# </div>
# <a class="news__item-body" href="https://u.today/solana-sol-price-prediction-for-march-12-0">
# <div class="news__item-title">Solana (SOL) Price Prediction for March 12</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/denys-serhiichuk"><img alt="Denys Serhiichuk" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8942.jpg" width="24"/>Denys Serhiichuk
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 12, 2025 - 0:01</div>
# </div>
# <a class="news__item-body" href="https://u.today/solana-sol-death-cross-incoming-dogecoin-doge-hits-last-possible-support-ethereum-eth-says-goodbye">
# <div class="news__item-title">Solana (SOL) Death Cross Incoming, Dogecoin (DOGE) Hits Last Possible Support, Ethereum (ETH) Says Goodbye to $2,000 </div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/arman-shirinyan"><img alt="Arman Shirinyan" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8993.jpg" width="24"/>Arman Shirinyan
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 11, 2025 - 11:18</div>
# </div>
# <a class="news__item-body" href="https://u.today/solana-sol-reclaims-123-is-sell-off-over">
# <div class="news__item-title">Solana (SOL) Reclaims $123, Is Sell-off Over?</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/godfrey-benjamin"><img alt="Godfrey Benjamin" class="humble__img" height="24" src="https://u.today/sites/default/files/2022-12/29302.jpg" width="24"/>Godfrey Benjamin
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 10, 2025 - 16:22</div>
# </div>
# <a class="news__item-body" href="https://u.today/solana-sol-on-verge-of-death-cross-amid-market-sell-off-potential-scenarios">
# <div class="news__item-title">Solana (SOL) on Verge of Death Cross Amid Market Sell-off: Potential Scenarios</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/tomiwabold-olajide"><img alt="Tomiwabold Olajide" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-11/8944.jpg" width="24"/>Tomiwabold Olajide
#             </a></div>
# </div>
# <div class="something something--content">
# <div class="something__content-long">
# <ins class="adsbygoogle" data-ad-client="ca-pub-4834169448759613" data-ad-slot="1698558466" style="display:inline-block;width:728px;height:90px"></ins>
# </div>
# <div class="something__content-square">
# <ins class="adsbygoogle" data-ad-client="ca-pub-4834169448759613" data-ad-slot="4003311693" style="display:inline-block;width:336px;height:280px"></ins>
# </div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 10, 2025 - 0:01</div>
# </div>
# <a class="news__item-body" href="https://u.today/xrp-movement-to-death-cross-begins-shiba-inu-shib-bulls-gave-up-solana-sol-bullish-reversal-might">
# <div class="news__item-title">XRP: Movement to Death Cross Begins, Shiba Inu (SHIB) Bulls Gave Up? Solana (SOL) Bullish Reversal Might Be Around Corner</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/arman-shirinyan"><img alt="Arman Shirinyan" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8993.jpg" width="24"/>Arman Shirinyan
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 8, 2025 - 15:16</div>
# </div>
# <a class="news__item-body" href="https://u.today/solana-sol-price-prediction-for-march-8">
# <div class="news__item-title">Solana (SOL) Price Prediction for March 8</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/denys-serhiichuk"><img alt="Denys Serhiichuk" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8942.jpg" width="24"/>Denys Serhiichuk
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 8, 2025 - 14:29</div>
# </div>
# <a class="news__item-body" href="https://u.today/518-billion-solana-sol-stun-market-bulls-heres-why">
# <div class="news__item-title">$5.18 Billion Solana (SOL) Stun Market Bulls, Here's Why</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/godfrey-benjamin"><img alt="Godfrey Benjamin" class="humble__img" height="24" src="https://u.today/sites/default/files/2022-12/29302.jpg" width="24"/>Godfrey Benjamin
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 8, 2025 - 10:43</div>
# </div>
# <a class="news__item-body" href="https://u.today/peter-schiff-creates-his-own-btc-reserve-receives-solana-instead">
# <div class="news__item-title">Peter Schiff Creates His Own BTC Reserve, Receives Solana Instead</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/dan-burgin"><img alt="Dan Burgin" class="humble__img" height="24" src="https://u.today/sites/default/files/2024-02/45425.jpg" width="24"/>Dan Burgin
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 8, 2025 - 0:01</div>
# </div>
# <a class="news__item-body" href="https://u.today/bitcoin-btc-100000-momentum-gone-solana-sol-surprising-move-incoming-shiba-inu-shib-heating-up-for">
# <div class="news__item-title">Bitcoin (BTC) $100,000 Momentum Gone, Solana (SOL): Surprising Move Incoming? Shiba Inu (SHIB) Heating up for Skyrocketing?</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/arman-shirinyan"><img alt="Arman Shirinyan" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8993.jpg" width="24"/>Arman Shirinyan
#             </a></div>
# </div>
# <div class="something something--content">
# <div class="something__content-long">
# <ins class="adsbygoogle" data-ad-client="ca-pub-4834169448759613" data-ad-slot="1698558466" style="display:inline-block;width:728px;height:90px"></ins>
# </div>
# <div class="something__content-square">
# <ins class="adsbygoogle" data-ad-client="ca-pub-4834169448759613" data-ad-slot="4003311693" style="display:inline-block;width:336px;height:280px"></ins>
# </div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 7, 2025 - 15:56</div>
# </div>
# <a class="news__item-body" href="https://u.today/blackrocks-ibit-makes-first-btc-purchase-in-7-days-solana-founder-presents-3-major-scenarios-for-us">
# <div class="news__item-title">BlackRock's IBIT Makes First BTC Purchase in 7 Days, Solana Founder Presents 3 Major Scenarios for US Strategic Reserve, Texas Senate Passes Bitcoin Reserve Bill: Crypto News Digest by U.Today</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/valeria-blokhina"><img alt="Valeria Blokhina" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-10/9844.jpg" width="24"/>Valeria Blokhina
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 6, 2025 - 9:41</div>
# </div>
# <a class="news__item-body" href="https://u.today/solana-sol-founder-presents-3-major-scenarios-for-us-strategic-reserve">
# <div class="news__item-title">Solana (SOL) Founder Presents 3 Major Scenarios for US Strategic Reserve</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/gamza-khanzadaev"><img alt="Gamza Khanzadaev" class="humble__img" height="24" src="https://u.today/sites/default/files/2022-05/14694.jpg" width="24"/>Gamza Khanzadaev
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 6, 2025 - 0:01</div>
# </div>
# <a class="news__item-body" href="https://u.today/shiba-inu-shib-delivers-grim-volume-signal-bitcoin-btc-is-it-trying-to-break-90000-solana-sol-days">
# <div class="news__item-title">Shiba Inu (SHIB) Delivers Grim Volume Signal, Bitcoin (BTC): Is it Trying to Break $90,000? Solana (SOL): Days Before Recovery?</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/arman-shirinyan"><img alt="Arman Shirinyan" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8993.jpg" width="24"/>Arman Shirinyan
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 5, 2025 - 18:51</div>
# </div>
# <a class="news__item-body" href="https://u.today/solanas-growth-falls-88">
# <div class="news__item-title">Solana's Growth Falls by 88% </div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/alex-dovbnya"><img alt="Alex Dovbnya" class="humble__img" height="24" src="https://u.today/sites/default/files/2019-11/alex-m-ava.jpg" width="24"/>Alex Dovbnya
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 5, 2025 - 9:30</div>
# </div>
# <a class="news__item-body" href="https://u.today/solana-sol-whales-capitulate-heres-how-much-will-be-sold">
# <div class="news__item-title">Solana (SOL) Whales Capitulate? Here's How Much Will Be Sold</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/arman-shirinyan"><img alt="Arman Shirinyan" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8993.jpg" width="24"/>Arman Shirinyan
#             </a></div>
# </div>
# <div class="something something--content">
# <div class="something__content-long">
# <ins class="adsbygoogle" data-ad-client="ca-pub-4834169448759613" data-ad-slot="1698558466" style="display:inline-block;width:728px;height:90px"></ins>
# </div>
# <div class="something__content-square">
# <ins class="adsbygoogle" data-ad-client="ca-pub-4834169448759613" data-ad-slot="4003311693" style="display:inline-block;width:336px;height:280px"></ins>
# </div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 5, 2025 - 6:07</div>
# </div>
# <a class="news__item-body" href="https://u.today/top-satoshi-candidate-says-xrp-and-solana-parts-of-reserve-are-obvious-scams">
# <div class="news__item-title">Top Satoshi Candidate Says XRP and Solana Parts of Reserve Are ‘Obvious Scams’</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/alex-dovbnya"><img alt="Alex Dovbnya" class="humble__img" height="24" src="https://u.today/sites/default/files/2019-11/alex-m-ava.jpg" width="24"/>Alex Dovbnya
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 4, 2025 - 12:24</div>
# </div>
# <a class="news__item-body" href="https://u.today/dogecoin-solana-xrp-up-to-20-tumbling-whats-happening">
# <div class="news__item-title">Dogecoin, Solana, XRP: Up to 20% Tumbling, What's Happening?</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/arman-shirinyan"><img alt="Arman Shirinyan" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8993.jpg" width="24"/>Arman Shirinyan
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 4, 2025 - 0:01</div>
# </div>
# <a class="news__item-body" href="https://u.today/is-bitcoin-btc-ready-for-100000-solana-sol-skyrockets-but-in-wrong-way-shiba-inu-shib-is-there-any">
# <div class="news__item-title">Is Bitcoin (BTC) Ready for $100,000? Solana (SOL) Skyrockets, But in Wrong Way, Shiba Inu (SHIB): Is There Any Hope? </div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/arman-shirinyan"><img alt="Arman Shirinyan" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8993.jpg" width="24"/>Arman Shirinyan
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 3, 2025 - 14:51</div>
# </div>
# <a class="news__item-body" href="https://u.today/solana-flips-ethereum-again-as-dex-volume-hits-399-billion">
# <div class="news__item-title">Solana Flips Ethereum Again as DEX Volume Hits $3.99 Billion</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/godfrey-benjamin"><img alt="Godfrey Benjamin" class="humble__img" height="24" src="https://u.today/sites/default/files/2022-12/29302.jpg" width="24"/>Godfrey Benjamin
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 3, 2025 - 14:39</div>
# </div>
# <a class="news__item-body" href="https://u.today/solana-sol-price-prediction-for-march-3">
# <div class="news__item-title">Solana (SOL) Price Prediction for March 3</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/denys-serhiichuk"><img alt="Denys Serhiichuk" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8942.jpg" width="24"/>Denys Serhiichuk
#             </a></div>
# </div>
# <div class="something something--content">
# <div class="something__content-long">
# <ins class="adsbygoogle" data-ad-client="ca-pub-4834169448759613" data-ad-slot="1698558466" style="display:inline-block;width:728px;height:90px"></ins>
# </div>
# <div class="something__content-square">
# <ins class="adsbygoogle" data-ad-client="ca-pub-4834169448759613" data-ad-slot="4003311693" style="display:inline-block;width:336px;height:280px"></ins>
# </div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Mar 1, 2025 - 12:56</div>
# </div>
# <a class="news__item-body" href="https://u.today/solana-price-rebounds-10-heres-impact-on-sol-liquidations">
# <div class="news__item-title">Solana Price Rebounds 10%, Here's Impact on SOL Liquidations</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/godfrey-benjamin"><img alt="Godfrey Benjamin" class="humble__img" height="24" src="https://u.today/sites/default/files/2022-12/29302.jpg" width="24"/>Godfrey Benjamin
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Feb 28, 2025 - 15:42</div>
# </div>
# <a class="news__item-body" href="https://u.today/solana-sol-futures-launch-date-confirmed-by-cme-group-details">
# <div class="news__item-title">Solana (SOL) Futures Launch Date Confirmed by CME Group: Details</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/alex-dovbnya"><img alt="Alex Dovbnya" class="humble__img" height="24" src="https://u.today/sites/default/files/2019-11/alex-m-ava.jpg" width="24"/>Alex Dovbnya
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Feb 28, 2025 - 12:51</div>
# </div>
# <a class="news__item-body" href="https://u.today/96180-solana-sol-exit-binance-staked-by-whale">
# <div class="news__item-title">96,180 Solana (SOL) Exit Binance, Staked by Whale</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/godfrey-benjamin"><img alt="Godfrey Benjamin" class="humble__img" height="24" src="https://u.today/sites/default/files/2022-12/29302.jpg" width="24"/>Godfrey Benjamin
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Feb 28, 2025 - 0:01</div>
# </div>
# <a class="news__item-body" href="https://u.today/3-major-dogecoin-doge-support-levels-shiba-inu-shib-attempts-solid-recovery-solana-sol-sees-secret">
# <div class="news__item-title">3 Major Dogecoin (DOGE) Support Levels, Shiba Inu (SHIB) Attempts Solid Recovery, Solana (SOL) Sees Secret Whale Accumulation</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/arman-shirinyan"><img alt="Arman Shirinyan" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8993.jpg" width="24"/>Arman Shirinyan
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Feb 26, 2025 - 0:01</div>
# </div>
# <a class="news__item-body" href="https://u.today/bitcoin-btc-on-yearly-low-shiba-inu-shib-plummeting-aggravated-solana-sol-far-too-close-to-100">
# <div class="news__item-title">Bitcoin (BTC) on Yearly Low, Shiba Inu (SHIB) Plummeting Aggravated, Solana (SOL) Far Too Close to $100</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/arman-shirinyan"><img alt="Arman Shirinyan" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8993.jpg" width="24"/>Arman Shirinyan
#             </a></div>
# </div>
# <div class="something something--content">
# <div class="something__content-long">
# <ins class="adsbygoogle" data-ad-client="ca-pub-4834169448759613" data-ad-slot="1698558466" style="display:inline-block;width:728px;height:90px"></ins>
# </div>
# <div class="something__content-square">
# <ins class="adsbygoogle" data-ad-client="ca-pub-4834169448759613" data-ad-slot="4003311693" style="display:inline-block;width:336px;height:280px"></ins>
# </div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Feb 24, 2025 - 12:01</div>
# </div>
# <a class="news__item-body" href="https://u.today/solana-sol-lost-45-bitcoin-domination-isnt-stopping">
# <div class="news__item-title">Solana (SOL) Lost 45%: Bitcoin Domination Isn't Stopping?</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/arman-shirinyan"><img alt="Arman Shirinyan" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8993.jpg" width="24"/>Arman Shirinyan
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Feb 24, 2025 - 0:01</div>
# </div>
# <a class="news__item-body" href="https://u.today/shiba-inu-shib-breaks-crucial-resistance-solana-sol-plummeting-finally-stops-ethereum-eth-price">
# <div class="news__item-title">Shiba Inu (SHIB) Breaks Crucial Resistance, Solana (SOL) Plummeting Finally Stops, Ethereum (ETH) Price Grows, Damage Negated?</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/arman-shirinyan"><img alt="Arman Shirinyan" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8993.jpg" width="24"/>Arman Shirinyan
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Feb 22, 2025 - 12:56</div>
# </div>
# <a class="news__item-body" href="https://u.today/solana-sol-price-prediction-for-february-22">
# <div class="news__item-title">Solana (SOL) Price Prediction for February 22</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/denys-serhiichuk"><img alt="Denys Serhiichuk" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8942.jpg" width="24"/>Denys Serhiichuk
#             </a></div>
# </div>
# <div class="news__item">
# <div class="news__item-head humble__row"><a href="/stories">Stories</a>
# <div class="humble">Feb 22, 2025 - 7:23</div>
# </div>
# <a class="news__item-body" href="https://u.today/franklin-templeton-files-for-solana-etf-details">
# <div class="news__item-title">Franklin Templeton Files for Solana ETF: Details</div>
# </a>
# <div class="news__item-footer"><a class="humble humble--author" href="/dan-burgin"><img alt="Dan Burgin" class="humble__img" height="24" src="https://u.today/sites/default/files/2024-02/45425.jpg" width="24"/>Dan Burgin
#             </a></div>
# </div>
# <script>
#             document.getElementById("search_text").focus();
#         </script>
# </div>
# <div class="something something--content">
# <div class="something__content-long">
# <div>
# <!-- TAGS Title Banner Desktop 336x280 -->
# <ins class="adsbygoogle" data-ad-client="ca-pub-9245916885225528" data-ad-slot="6672099997" style="display:inline-block;width:336px;height:280px"></ins>
# </div>
# </div>
# <div class="something__content-square">
# <div>
# <!-- Tags Title Mobile 336x280 -->
# <ins class="adsbygoogle" data-ad-client="ca-pub-9245916885225528" data-ad-slot="2099638702" style="display:inline-block;width:336px;height:280px"></ins>
# </div>
# </div>
# </div>
# <div class="pag-nav">
# <ul class="pag-nav__list">
# <li class="pag-nav__item">
# <a aria-current="Current page" class="btn--light pag-nav__btn pag-nav__btn-active" href="https://u.today/search/node?keys=Solana&amp;_wrapper_format=html&amp;page=0" title="Current page">
# <span class="visually-hidden">
#               Current page
#             </span>1</a>
# </li>
# <li class="pag-nav__item">
# <a class="btn--light pag-nav__btn" href="https://u.today/search/node?keys=Solana&amp;_wrapper_format=html&amp;page=1" title="Go to page 2">
# <span class="visually-hidden">
#               Page
#             </span>2</a>
# </li>
# <li class="pag-nav__item">
# <a class="btn--light pag-nav__btn" href="https://u.today/search/node?keys=Solana&amp;_wrapper_format=html&amp;page=2" title="Go to page 3">
# <span class="visually-hidden">
#               Page
#             </span>3</a>
# </li>
# <li class="pag-nav__item">
# <a class="btn--light pag-nav__btn" href="https://u.today/search/node?keys=Solana&amp;_wrapper_format=html&amp;page=3" title="Go to page 4">
# <span class="visually-hidden">
#               Page
#             </span>4</a>
# </li>
# <li class="pag-nav__item">
# <a class="btn--light pag-nav__btn" href="https://u.today/search/node?keys=Solana&amp;_wrapper_format=html&amp;page=4" title="Go to page 5">
# <span class="visually-hidden">
#               Page
#             </span>5</a>
# </li>
# <li class="pag-nav__item">
# <a class="btn--light pag-nav__btn" href="https://u.today/search/node?keys=Solana&amp;_wrapper_format=html&amp;page=5" title="Go to page 6">
# <span class="visually-hidden">
#               Page
#             </span>6</a>
# </li>
# <li class="pag-nav__item">
# <a class="btn--light pag-nav__btn" href="https://u.today/search/node?keys=Solana&amp;_wrapper_format=html&amp;page=6" title="Go to page 7">
# <span class="visually-hidden">
#               Page
#             </span>7</a>
# </li>
# <li class="pag-nav__item">
# ...
#                         });
#                     }
#                     jQuery.each(this, function (i, val) {
#                         var input = jQuery(val);
#                         if (input.attr('name') != 'file') data.append(input.attr('name'), input.val());
#                     });
#
#
#                     jQuery.ajax({
#                         url: jQuery(this).attr('action'),
#                         type: 'POST',
#                         dataType: 'json',
#                         cache: false,
#                         processData: false,
#                         contentType: false,
#                         data: data,
#                         success: function (data) {
#                             jQuery('.sevent').html('<h2>Thanks for submit. We will contact you soon.</h2>');
#                             return false;
#                         },
#                         error: function (xhr, err) {
#
#                             alert('Error');
#                         }
#                     });
#                     return false;
#                 });
#
#                 //submit event end
#             </script>
# <script type="text/javascript">
#                 const initBanners = function () {
#                     let elements =
#                         document.getElementsByClassName('imageBannersContainer');
#                     for (let i = 0; i < elements.length; i++) {
#                         let bannerElements = elements[i].getElementsByClassName("imageBanner");
#                         let bannerIndex = Math.random() * bannerElements.length;
#                         let firstDigitStr = String(bannerIndex)[0];
#                         bannerElements[firstDigitStr].style.display = 'block';
#                     }
#                 };
#
#                 jQuery(document).ready(function () {
#
#                     (function ($) {
#                         if (jQuery(window).width() > '850') {
#                             jQuery('.press-releases__slider, .upcoming__slider').slick({
#                                 infinite: false,
#                                 slidesToShow: 3,
#                                 slidesToScroll: 1,
#                                 arrows: true,
#                                 dots: false
#                             });
#                         }
#                     })(jQuery);
#
#
#                     initBanners();
#
#                     var OneSignal = window.OneSignal || [];
#                     OneSignal.push(function () {
#                         OneSignal.init({
#                             appId: "8fd8204c-a529-4b35-98be-27f71d473d9a",
#                         });
#                     });
#
#                     let menus = document.querySelectorAll('.main_page a');
#                     menus.forEach(el => el.addEventListener('click', event => {
#                         gtag('event', 'header_menu_click', {
#                             'header_menu_click': 'click',
#                         });
#                     }));
#
#                     menus = document.querySelectorAll('.article a[target="_blank"]');
#                     menus.forEach(el => el.addEventListener('click', event => {
#                         gtag('event', 'article_link_click', {
#                             'article_link_click': 'click',
#                         });
#                     }));
#                     menus = document.querySelectorAll('.article__related a');
#                     menus.forEach(el => el.addEventListener('click', event => {
#                         gtag('event', 'card_click', {
#                             'card_click': 'click',
#                         });
#                     }));
#                     menus = document.querySelectorAll('.views-infinite-scroll-content-wrapper .category-item a');
#                     menus.forEach(el => el.addEventListener('click', event => {
#                         gtag('event', 'related_click', {
#                             'related_click': 'click',
#                         });
#                     }));
#                     menus = document.querySelectorAll('.article__listen-audio');
#                     menus.forEach(el => el.addEventListener('click', event => {
#                         gtag('event', 'tts_click', {
#                             'tts_click': 'click',
#                         });
#                     }));
#                     menus = document.querySelectorAll('.header__nav-link');
#                     menus.forEach(el => el.addEventListener('click', event => {
#                         gtag('event', 'header_menu_click', {
#                             'header_menu': 'click',
#                         });
#                     }));
#                     menus = document.querySelectorAll('.footer__nav-child-link');
#                     menus.forEach(el => el.addEventListener('click', event => {
#                         gtag('event', 'footer_menu_click', {
#                             'footer_menu': 'click',
#                         });
#                     }));
#                     menus = document.querySelectorAll('.card__subscribe-item');
#                     menus.forEach(el => el.addEventListener('click', event => {
#                         gtag('event', 'subscribe', {
#                             'subscribe': 'click',
#                         });
#                     }));
#
#
#
#
#
#                                         [].forEach.call(document.querySelectorAll('.adsbygoogle'), function () {
#                         try {
#                             (adsbygoogle = window.adsbygoogle || []).push({});
#                         } catch (e) {
#                             return null;
#                         }
#                     });
#                     jQuery('.ad-feedback__form, .press-releases_form, .event_form, .airdrop_form').submit(function (e) {
#                         e.preventDefault();
#                         //data = 'subject=' + e.target.querySelector('input[name=subject]').value + '&name=' + e.target.querySelector('input[name=submit-name]').value + '&mail=' + e.target.querySelector('input[name=submit-email]').value + '&desc=' + e.target.querySelector('textarea[name=submit-massage]').value;
#                         let fd = new FormData();
#                         let other_data = jQuery(e.target).serializeArray();
#                         jQuery.each(other_data, function (key, input) {
#                             fd.append(input.name, input.value);
#                         });
#                         if(e.target.querySelector('input[name=submit-file]') != null) {
#                             fd.append('file', jQuery(e.target.querySelector('input[name=submit-file]'))[0].files[0]);
#                         }
#                         jQuery.ajax({
#                             url: '/umail',
#                             type: 'post',
#                             contentType: false,
#                             processData: false,
#                             data: fd,
#                             success: function () {
#
#                             }
#                         });
#                     });
#                     jQuery('.subscribe-page__form, .footer__subscribe-form,.aside-sub,.subscribe-form,.sub-slot__form').submit(function (e) {
#                         e.preventDefault();
#                         const form = e.target;
#                         const inputs = form.elements;
#                         let data = '';
#                         for (const input of inputs) {
#                             data = data + input.name + '=' + input.value + '&';
#                         }
#
#                         jQuery.ajax({
#                             url: '/getresponse.php',
#                             type: 'post',
#                             data: data,
#                             success: function () {
#                                 e.target.querySelector('.subscribe-result').innerHTML = '<div class="success">Subscribed</div>';
#                                 jQuery('.card__subscribe-em .input__status').text('Subscribed');
#                                 e.target.querySelector('.success').style.display = 'block';
#                             }
#                         });
#                     });
#                     jQuery('.modal__form').submit(function (e) {
#
#                         const form = e.target;
#                         const inputs = form.elements;
#                         let data = '';
#                         for (const input of inputs) {
#                             data = data + input.name + '=' + input.value + '&';
#                         }
#
#                         jQuery.ajax({
#                             url: '/getresponse.php',
#                             type: 'post',
#                             data: data,
#                             success: function () {
#                                 // e.target.querySelector('.subscribe-result').innerHTML = '<div class="success">Subscribed</div>';
#                                 // jQuery('.card__subscribe-em .input__status').text('Subscribed');
#                                 // e.target.querySelector('.success').style.display = 'block';
#                             }
#                         });
#                     });
#
#
#
#
#
#
#
#                 });
#
#                 function addLink() {
#                     let body = document.getElementsByTagName('body')[0],
#                         selection = window.getSelection(),
#                         copyright = "<p><br>Read more on U.Today <a href='" + document.location.href + "'>" + document.location.href + "</a></p>",
#                         copyrightText = selection + copyright,
#                         newdiv = document.createElement('div');
#
#                     newdiv.style.position = 'absolute';
#                     body.appendChild(newdiv);
#                     newdiv.innerHTML = copyrightText;
#                     selection.selectAllChildren(newdiv);
#
#                     window.onclick = function () {
#                         body.removeChild(newdiv);
#                     };
#                 }
#             </script>
# <script type="text/javascript">
#
#
#                 document.addEventListener("scroll", (event) => {
#
#                     [].forEach.call(document.querySelectorAll('.adsbygoogle'), function () {
#                         try {
#                             (adsbygoogle = window.adsbygoogle || []).push({});
#                         } catch (e) {
#                             //return null;
#                         }
#
#                     });
#                 });
#                 document.addEventListener('DOMContentLoaded', function () {
#                     document.querySelectorAll('audio').forEach(function (audio) {
#                         let loaded = false;
#
#                         audio.addEventListener('loadedmetadata', function () {
#                             loaded = true;
#                             checkLoad();
#                         });
#
#                         audio.addEventListener('canplaythrough', function () {
#                             loaded = true;
#                             checkLoad();
#                         });
#
#                         function checkLoad() {
#                             if (loaded) {
#                                 const article = audio.closest('.article__listen');
#                                 const duration = Math.floor(audio.duration);
#                                 const minutes = Math.floor(duration / 60);
#                                 const seconds = Math.floor(duration % 60);
#                                 minutesDisplay.textContent = `${minutes}:${(seconds < 10 ? '0' : '')}${seconds}`;
#
#                                 console.log(duration);
#                             }
#                         }
#                     });
#
#                     let currentAudio = null;
#
#                     document.body.addEventListener('click', function (e) {
#                         const article = e.target.closest('.article__listen');
#
#                         if (!article) return;
#
#                         const audio = article.querySelector('audio');
#                         const playPauseButton = article.querySelector('.article__listen-btn');
#
#                         if (audio && playPauseButton) {
#                             if (audio !== currentAudio) {
#                                 if (currentAudio) {
#                                     currentAudio.pause();
#                                     const currentPlayPauseButton = currentAudio.parentElement.querySelector('.article__listen-btn');
#                                     if (currentPlayPauseButton) {
#                                         currentPlayPauseButton.classList.remove('is-play');
#                                     }
#                                 }
#
#                                 currentAudio = audio;
#
#                                 audio.addEventListener('timeupdate', updateTimer);
#                             }
#
#                             if (audio.paused) {
#                                 audio.play();
#                                 playPauseButton.classList.add('is-play');
#                             } else {
#                                 audio.pause();
#                                 playPauseButton.classList.remove('is-play');
#                             }
#
#                             function updateTimer() {
#                                 if (!audio.duration) {
#                                     audio.removeEventListener('timeupdate', updateTimer);
#                                     audio.addEventListener('timeupdate', updateTimer);
#                                     return;
#                                 }
#
#                                 const currentTime = audio.duration - audio.currentTime;
#                                 const minutes = Math.floor(currentTime / 60);
#                                 const seconds = Math.floor(currentTime % 60);
#
#                                 minutesDisplay.textContent = `${minutes}:${(seconds < 10 ? '0' : '')}${seconds}`;
#                             }
#                         }
#                     });
#                 });
#             </script>
# <script>
#
#                 var emailInput = document.getElementsByClassName('input__elem');
#                 var submitButton = document.getElementsByClassName('submit-button');
#                 for (let i = 0; i < emailInput.length; i++) {
#                     emailInput[i].addEventListener('input', () => {
#                         let form = emailInput[i].closest('form');
#                         let captchaContainer = form.querySelector('.captcha-container');
#                         if (emailInput[i].validity.valid) {
#                             console.log('OK', captchaContainer);
#                             captchaContainer.style.display = 'block';
#                         } else {
#                             captchaContainer.style.display = 'none';
#                         }
#                     });
#                 }
#
#
#                 let isCaptchaCompleted = false;
#
#
#                 function captchaSuccess() {
#                     //console.log('captchaSuccess', submitButton.length);
#                     submitButton = document.getElementsByClassName('submit-button');
#                     isCaptchaCompleted = true;
#                     for (let i = 0; i < submitButton.length; i++) {
#                         submitButton[i].disabled = false;
#                     }
#                 }
#
#
#                 function captchaExpired() {
#                     isCaptchaCompleted = false;
#                     submitButton = document.getElementsByClassName('submit-button');
#                     for (let i = 0; i < submitButton.length; i++) {
#                         submitButton[i].disabled = true;
#                     }
#                 }
#
#
#                 function validateCaptcha() {
#                     if (!isCaptchaCompleted) {
#                         return false;
#                     }
#                     return true;
#                 }
#
#             </script>
# </body>
# </html>

# %%
# Option 1: Using CSS selectors (similar to your book_cards example)
Sol_date = docu.select("body.not_logged_in div.main-aside-container main.main-block div.search-result div.news__item div.news__item-head div.humble")
Sol_date
# Out:
# [<div class="humble">Mar 26, 2025 - 14:16</div>,
#  <div class="humble">Mar 26, 2025 - 7:16</div>,
#  <div class="humble">Mar 25, 2025 - 16:29</div>,
#  <div class="humble">Mar 25, 2025 - 16:01</div>,
#  <div class="humble">Mar 25, 2025 - 15:42</div>,
#  <div class="humble">Mar 25, 2025 - 11:13</div>,
#  <div class="humble">Mar 23, 2025 - 18:12</div>,
#  <div class="humble">Mar 23, 2025 - 14:41</div>,
#  <div class="humble">Mar 20, 2025 - 21:58</div>,
#  <div class="humble">Mar 19, 2025 - 0:01</div>,
#  <div class="humble">Mar 18, 2025 - 16:03</div>,
#  <div class="humble">Mar 17, 2025 - 15:02</div>,
#  <div class="humble">Mar 17, 2025 - 10:02</div>,
#  <div class="humble">Mar 17, 2025 - 0:01</div>,
#  <div class="humble">Mar 16, 2025 - 15:09</div>,
#  <div class="humble">Mar 15, 2025 - 13:34</div>,
#  <div class="humble">Mar 14, 2025 - 15:17</div>,
#  <div class="humble">Mar 14, 2025 - 11:22</div>,
#  <div class="humble">Mar 14, 2025 - 0:01</div>,
#  <div class="humble">Mar 13, 2025 - 11:43</div>,
#  <div class="humble">Mar 12, 2025 - 18:55</div>,
#  <div class="humble">Mar 12, 2025 - 15:05</div>,
#  <div class="humble">Mar 12, 2025 - 12:24</div>,
#  <div class="humble">Mar 12, 2025 - 0:01</div>,
#  <div class="humble">Mar 11, 2025 - 11:18</div>,
#  <div class="humble">Mar 10, 2025 - 16:22</div>,
#  <div class="humble">Mar 10, 2025 - 0:01</div>,
#  <div class="humble">Mar 8, 2025 - 15:16</div>,
#  <div class="humble">Mar 8, 2025 - 14:29</div>,
#  <div class="humble">Mar 8, 2025 - 10:43</div>,
#  <div class="humble">Mar 8, 2025 - 0:01</div>,
#  <div class="humble">Mar 7, 2025 - 15:56</div>,
#  <div class="humble">Mar 6, 2025 - 9:41</div>,
#  <div class="humble">Mar 6, 2025 - 0:01</div>,
#  <div class="humble">Mar 5, 2025 - 18:51</div>,
#  <div class="humble">Mar 5, 2025 - 9:30</div>,
#  <div class="humble">Mar 5, 2025 - 6:07</div>,
#  <div class="humble">Mar 4, 2025 - 12:24</div>,
#  <div class="humble">Mar 4, 2025 - 0:01</div>,
#  <div class="humble">Mar 3, 2025 - 14:51</div>,
#  <div class="humble">Mar 3, 2025 - 14:39</div>,
#  <div class="humble">Mar 1, 2025 - 12:56</div>,
#  <div class="humble">Feb 28, 2025 - 15:42</div>,
#  <div class="humble">Feb 28, 2025 - 12:51</div>,
#  <div class="humble">Feb 28, 2025 - 0:01</div>,
#  <div class="humble">Feb 26, 2025 - 0:01</div>,
#  <div class="humble">Feb 24, 2025 - 12:01</div>,
#  <div class="humble">Feb 24, 2025 - 0:01</div>,
#  <div class="humble">Feb 22, 2025 - 12:56</div>,
#  <div class="humble">Feb 22, 2025 - 7:23</div>]

# %%
New_cards = docu.select('div.news__item')
New_cards
# Out:
# [<div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 26, 2025 - 14:16</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/solana-sol-price-prediction-for-march-26">
#  <div class="news__item-title">Solana (SOL) Price Prediction for March 26</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/denys-serhiichuk"><img alt="Denys Serhiichuk" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8942.jpg" width="24"/>Denys Serhiichuk
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/press-releases">Press release</a>
#  <div class="humble">Mar 26, 2025 - 7:16</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/press-releases/solpot-emerges-as-solanas-premier-on-chain-platform-distributes-over-400k-in-free">
#  <div class="news__item-title">Solpot Emerges as Solana's Premier On-Chain Platform, Distributes Over $400K in Free Rewards</div>
#  </a>
#  <div class="news__item-desc"></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 25, 2025 - 16:29</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/breaking-fidelity-officially-joins-solana-etf-race">
#  <div class="news__item-title">Breaking: Fidelity Officially Joins Solana ETF Race</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/alex-dovbnya"><img alt="Alex Dovbnya" class="humble__img" height="24" src="https://u.today/sites/default/files/2019-11/alex-m-ava.jpg" width="24"/>Alex Dovbnya
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 25, 2025 - 16:01</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/blackrock-expands-blockchain-footprint-to-solana">
#  <div class="news__item-title">BlackRock Expands Blockchain Footprint to Solana</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/godfrey-benjamin"><img alt="Godfrey Benjamin" class="humble__img" height="24" src="https://u.today/sites/default/files/2022-12/29302.jpg" width="24"/>Godfrey Benjamin
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 25, 2025 - 15:42</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/solana-dog-coin-bonk-rallies-35-unnoticed-whats-behind-it">
#  <div class="news__item-title">Solana Dog-Coin BONK Rallies 35% Unnoticed – What's Behind It?</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/tomiwabold-olajide"><img alt="Tomiwabold Olajide" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-11/8944.jpg" width="24"/>Tomiwabold Olajide
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/press-releases">Press release</a>
#  <div class="humble">Mar 25, 2025 - 11:13</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/press-releases/whaleio-to-bridge-nft-collection-from-ton-blockchain-to-solana">
#  <div class="news__item-title">Whale.io to Bridge NFT Collection from TON Blockchain to Solana</div>
#  </a>
#  <div class="news__item-desc"></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 23, 2025 - 18:12</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/solana-co-founder-trashes-l2s-says-l1s-are-faster-and-more-secure">
#  <div class="news__item-title"> Solana Co-Founder Trashes L2s, Says L1s Are Faster and More Secure</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/alex-dovbnya"><img alt="Alex Dovbnya" class="humble__img" height="24" src="https://u.today/sites/default/files/2019-11/alex-m-ava.jpg" width="24"/>Alex Dovbnya
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 23, 2025 - 14:41</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/solana-sol-price-prediction-for-march-23">
#  <div class="news__item-title">Solana (SOL) Price Prediction for March 23</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/denys-serhiichuk"><img alt="Denys Serhiichuk" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8942.jpg" width="24"/>Denys Serhiichuk
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 20, 2025 - 21:58</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/justin-sun-sparks-tron-etf-rumors-as-trx-expands-to-solana">
#  <div class="news__item-title">Justin Sun Sparks Tron ETF Rumors as TRX Expands to Solana</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/andy-sawa"><img alt="Andy Sawa" class="humble__img" height="24" src="https://u.today/sites/default/files/2025-03/56809.jpg" width="24"/>Andy Sawa
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 19, 2025 - 0:01</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/bitcoin-btc-make-or-break-support-reached-dogecoin-doge-price-at-breaking-point-secret-bullish">
#  <div class="news__item-title">Bitcoin (BTC): Make or Break Support Reached, Dogecoin (DOGE) Price at Breaking Point, Secret Bullish Solana (SOL) Pattern Formed?</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/arman-shirinyan"><img alt="Arman Shirinyan" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8993.jpg" width="24"/>Arman Shirinyan
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 18, 2025 - 16:03</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/did-cmes-solana-futures-flop-not-really">
#  <div class="news__item-title">Did CME's Solana Futures Flop? Not Really</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/alex-dovbnya"><img alt="Alex Dovbnya" class="humble__img" height="24" src="https://u.today/sites/default/files/2019-11/alex-m-ava.jpg" width="24"/>Alex Dovbnya
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 17, 2025 - 15:02</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/solana-at-127-what-to-expect-from-sol-price-this-week">
#  <div class="news__item-title">Solana at $127: What to Expect From SOL Price This Week</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/godfrey-benjamin"><img alt="Godfrey Benjamin" class="humble__img" height="24" src="https://u.today/sites/default/files/2022-12/29302.jpg" width="24"/>Godfrey Benjamin
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 17, 2025 - 10:02</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/59-million-solana-sol-in-7-days-whats-going-to-happen">
#  <div class="news__item-title">$59 Million Solana (SOL) in 7 Days: What's Going to Happen?</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/arman-shirinyan"><img alt="Arman Shirinyan" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8993.jpg" width="24"/>Arman Shirinyan
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 17, 2025 - 0:01</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/bitcoin-btc-must-break-this-to-reach-100000-dogecoin-doge-coming-closer-to-bull-market-solana-sol">
#  <div class="news__item-title">Bitcoin (BTC) Must Break This to Reach $100,000, Dogecoin (DOGE) Coming Closer to Bull Market, Solana (SOL) Death Cross Complications</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/arman-shirinyan"><img alt="Arman Shirinyan" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8993.jpg" width="24"/>Arman Shirinyan
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 16, 2025 - 15:09</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/solana-sol-celebrates-5th-birthday-details">
#  <div class="news__item-title">Solana (SOL) Celebrates 5th Birthday: Details</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/gamza-khanzadaev"><img alt="Gamza Khanzadaev" class="humble__img" height="24" src="https://u.today/sites/default/files/2022-05/14694.jpg" width="24"/>Gamza Khanzadaev
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 15, 2025 - 13:34</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/solana-vs-ethereum-eight-parameters-compared-by-crypto-expert">
#  <div class="news__item-title">Solana vs. Ethereum: Eight Parameters Compared by Crypto Expert</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/vladislav-sopov"><img alt="Vladislav Sopov" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-07/8893.jpg" width="24"/>Vladislav Sopov
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 14, 2025 - 15:17</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/solana-sol-price-prediction-for-march-14">
#  <div class="news__item-title">Solana (SOL) Price Prediction for March 14</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/denys-serhiichuk"><img alt="Denys Serhiichuk" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8942.jpg" width="24"/>Denys Serhiichuk
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 14, 2025 - 11:22</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/solanas-sol-legendary-cup-and-handle-pattern-shaping-up-heres-target">
#  <div class="news__item-title">Solana's (SOL) Legendary Cup and Handle Pattern Shaping Up, Here's Target</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/tomiwabold-olajide"><img alt="Tomiwabold Olajide" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-11/8944.jpg" width="24"/>Tomiwabold Olajide
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 14, 2025 - 0:01</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/dogecoin-death-cross-confirmed-solana-sol-joins-doge-with-its-own-death-cross-xrp-recovery">
#  <div class="news__item-title">Dogecoin Death Cross Confirmed, Solana (SOL): Joins DOGE With Its Own Death Cross, XRP Recovery Continues: Next Level to Watch</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/arman-shirinyan"><img alt="Arman Shirinyan" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8993.jpg" width="24"/>Arman Shirinyan
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 13, 2025 - 11:43</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/201755-solana-sol-stun-worlds-largest-crypto-exchange">
#  <div class="news__item-title">201,755 Solana (SOL) Stun World's Largest Crypto Exchange</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/godfrey-benjamin"><img alt="Godfrey Benjamin" class="humble__img" height="24" src="https://u.today/sites/default/files/2022-12/29302.jpg" width="24"/>Godfrey Benjamin
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 12, 2025 - 18:55</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/solana-etf-proposed-by-15-trillion-investment-titan">
#  <div class="news__item-title">Solana ETF Proposed by $1.5 Trillion Investment Titan </div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/alex-dovbnya"><img alt="Alex Dovbnya" class="humble__img" height="24" src="https://u.today/sites/default/files/2019-11/alex-m-ava.jpg" width="24"/>Alex Dovbnya
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 12, 2025 - 15:05</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/solana-sol-revenue-falls-93-from-january-high">
#  <div class="news__item-title">Solana (SOL) Revenue Falls 93% From January High</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/godfrey-benjamin"><img alt="Godfrey Benjamin" class="humble__img" height="24" src="https://u.today/sites/default/files/2022-12/29302.jpg" width="24"/>Godfrey Benjamin
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 12, 2025 - 12:24</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/solana-sol-price-prediction-for-march-12-0">
#  <div class="news__item-title">Solana (SOL) Price Prediction for March 12</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/denys-serhiichuk"><img alt="Denys Serhiichuk" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8942.jpg" width="24"/>Denys Serhiichuk
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 12, 2025 - 0:01</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/solana-sol-death-cross-incoming-dogecoin-doge-hits-last-possible-support-ethereum-eth-says-goodbye">
#  <div class="news__item-title">Solana (SOL) Death Cross Incoming, Dogecoin (DOGE) Hits Last Possible Support, Ethereum (ETH) Says Goodbye to $2,000 </div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/arman-shirinyan"><img alt="Arman Shirinyan" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8993.jpg" width="24"/>Arman Shirinyan
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 11, 2025 - 11:18</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/solana-sol-reclaims-123-is-sell-off-over">
#  <div class="news__item-title">Solana (SOL) Reclaims $123, Is Sell-off Over?</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/godfrey-benjamin"><img alt="Godfrey Benjamin" class="humble__img" height="24" src="https://u.today/sites/default/files/2022-12/29302.jpg" width="24"/>Godfrey Benjamin
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 10, 2025 - 16:22</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/solana-sol-on-verge-of-death-cross-amid-market-sell-off-potential-scenarios">
#  <div class="news__item-title">Solana (SOL) on Verge of Death Cross Amid Market Sell-off: Potential Scenarios</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/tomiwabold-olajide"><img alt="Tomiwabold Olajide" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-11/8944.jpg" width="24"/>Tomiwabold Olajide
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 10, 2025 - 0:01</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/xrp-movement-to-death-cross-begins-shiba-inu-shib-bulls-gave-up-solana-sol-bullish-reversal-might">
#  <div class="news__item-title">XRP: Movement to Death Cross Begins, Shiba Inu (SHIB) Bulls Gave Up? Solana (SOL) Bullish Reversal Might Be Around Corner</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/arman-shirinyan"><img alt="Arman Shirinyan" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8993.jpg" width="24"/>Arman Shirinyan
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 8, 2025 - 15:16</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/solana-sol-price-prediction-for-march-8">
#  <div class="news__item-title">Solana (SOL) Price Prediction for March 8</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/denys-serhiichuk"><img alt="Denys Serhiichuk" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8942.jpg" width="24"/>Denys Serhiichuk
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 8, 2025 - 14:29</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/518-billion-solana-sol-stun-market-bulls-heres-why">
#  <div class="news__item-title">$5.18 Billion Solana (SOL) Stun Market Bulls, Here's Why</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/godfrey-benjamin"><img alt="Godfrey Benjamin" class="humble__img" height="24" src="https://u.today/sites/default/files/2022-12/29302.jpg" width="24"/>Godfrey Benjamin
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 8, 2025 - 10:43</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/peter-schiff-creates-his-own-btc-reserve-receives-solana-instead">
#  <div class="news__item-title">Peter Schiff Creates His Own BTC Reserve, Receives Solana Instead</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/dan-burgin"><img alt="Dan Burgin" class="humble__img" height="24" src="https://u.today/sites/default/files/2024-02/45425.jpg" width="24"/>Dan Burgin
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 8, 2025 - 0:01</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/bitcoin-btc-100000-momentum-gone-solana-sol-surprising-move-incoming-shiba-inu-shib-heating-up-for">
#  <div class="news__item-title">Bitcoin (BTC) $100,000 Momentum Gone, Solana (SOL): Surprising Move Incoming? Shiba Inu (SHIB) Heating up for Skyrocketing?</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/arman-shirinyan"><img alt="Arman Shirinyan" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8993.jpg" width="24"/>Arman Shirinyan
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 7, 2025 - 15:56</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/blackrocks-ibit-makes-first-btc-purchase-in-7-days-solana-founder-presents-3-major-scenarios-for-us">
#  <div class="news__item-title">BlackRock's IBIT Makes First BTC Purchase in 7 Days, Solana Founder Presents 3 Major Scenarios for US Strategic Reserve, Texas Senate Passes Bitcoin Reserve Bill: Crypto News Digest by U.Today</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/valeria-blokhina"><img alt="Valeria Blokhina" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-10/9844.jpg" width="24"/>Valeria Blokhina
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 6, 2025 - 9:41</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/solana-sol-founder-presents-3-major-scenarios-for-us-strategic-reserve">
#  <div class="news__item-title">Solana (SOL) Founder Presents 3 Major Scenarios for US Strategic Reserve</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/gamza-khanzadaev"><img alt="Gamza Khanzadaev" class="humble__img" height="24" src="https://u.today/sites/default/files/2022-05/14694.jpg" width="24"/>Gamza Khanzadaev
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 6, 2025 - 0:01</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/shiba-inu-shib-delivers-grim-volume-signal-bitcoin-btc-is-it-trying-to-break-90000-solana-sol-days">
#  <div class="news__item-title">Shiba Inu (SHIB) Delivers Grim Volume Signal, Bitcoin (BTC): Is it Trying to Break $90,000? Solana (SOL): Days Before Recovery?</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/arman-shirinyan"><img alt="Arman Shirinyan" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8993.jpg" width="24"/>Arman Shirinyan
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 5, 2025 - 18:51</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/solanas-growth-falls-88">
#  <div class="news__item-title">Solana's Growth Falls by 88% </div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/alex-dovbnya"><img alt="Alex Dovbnya" class="humble__img" height="24" src="https://u.today/sites/default/files/2019-11/alex-m-ava.jpg" width="24"/>Alex Dovbnya
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 5, 2025 - 9:30</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/solana-sol-whales-capitulate-heres-how-much-will-be-sold">
#  <div class="news__item-title">Solana (SOL) Whales Capitulate? Here's How Much Will Be Sold</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/arman-shirinyan"><img alt="Arman Shirinyan" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8993.jpg" width="24"/>Arman Shirinyan
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 5, 2025 - 6:07</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/top-satoshi-candidate-says-xrp-and-solana-parts-of-reserve-are-obvious-scams">
#  <div class="news__item-title">Top Satoshi Candidate Says XRP and Solana Parts of Reserve Are ‘Obvious Scams’</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/alex-dovbnya"><img alt="Alex Dovbnya" class="humble__img" height="24" src="https://u.today/sites/default/files/2019-11/alex-m-ava.jpg" width="24"/>Alex Dovbnya
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 4, 2025 - 12:24</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/dogecoin-solana-xrp-up-to-20-tumbling-whats-happening">
#  <div class="news__item-title">Dogecoin, Solana, XRP: Up to 20% Tumbling, What's Happening?</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/arman-shirinyan"><img alt="Arman Shirinyan" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8993.jpg" width="24"/>Arman Shirinyan
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 4, 2025 - 0:01</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/is-bitcoin-btc-ready-for-100000-solana-sol-skyrockets-but-in-wrong-way-shiba-inu-shib-is-there-any">
#  <div class="news__item-title">Is Bitcoin (BTC) Ready for $100,000? Solana (SOL) Skyrockets, But in Wrong Way, Shiba Inu (SHIB): Is There Any Hope? </div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/arman-shirinyan"><img alt="Arman Shirinyan" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8993.jpg" width="24"/>Arman Shirinyan
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 3, 2025 - 14:51</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/solana-flips-ethereum-again-as-dex-volume-hits-399-billion">
#  <div class="news__item-title">Solana Flips Ethereum Again as DEX Volume Hits $3.99 Billion</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/godfrey-benjamin"><img alt="Godfrey Benjamin" class="humble__img" height="24" src="https://u.today/sites/default/files/2022-12/29302.jpg" width="24"/>Godfrey Benjamin
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 3, 2025 - 14:39</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/solana-sol-price-prediction-for-march-3">
#  <div class="news__item-title">Solana (SOL) Price Prediction for March 3</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/denys-serhiichuk"><img alt="Denys Serhiichuk" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8942.jpg" width="24"/>Denys Serhiichuk
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Mar 1, 2025 - 12:56</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/solana-price-rebounds-10-heres-impact-on-sol-liquidations">
#  <div class="news__item-title">Solana Price Rebounds 10%, Here's Impact on SOL Liquidations</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/godfrey-benjamin"><img alt="Godfrey Benjamin" class="humble__img" height="24" src="https://u.today/sites/default/files/2022-12/29302.jpg" width="24"/>Godfrey Benjamin
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Feb 28, 2025 - 15:42</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/solana-sol-futures-launch-date-confirmed-by-cme-group-details">
#  <div class="news__item-title">Solana (SOL) Futures Launch Date Confirmed by CME Group: Details</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/alex-dovbnya"><img alt="Alex Dovbnya" class="humble__img" height="24" src="https://u.today/sites/default/files/2019-11/alex-m-ava.jpg" width="24"/>Alex Dovbnya
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Feb 28, 2025 - 12:51</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/96180-solana-sol-exit-binance-staked-by-whale">
#  <div class="news__item-title">96,180 Solana (SOL) Exit Binance, Staked by Whale</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/godfrey-benjamin"><img alt="Godfrey Benjamin" class="humble__img" height="24" src="https://u.today/sites/default/files/2022-12/29302.jpg" width="24"/>Godfrey Benjamin
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Feb 28, 2025 - 0:01</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/3-major-dogecoin-doge-support-levels-shiba-inu-shib-attempts-solid-recovery-solana-sol-sees-secret">
#  <div class="news__item-title">3 Major Dogecoin (DOGE) Support Levels, Shiba Inu (SHIB) Attempts Solid Recovery, Solana (SOL) Sees Secret Whale Accumulation</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/arman-shirinyan"><img alt="Arman Shirinyan" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8993.jpg" width="24"/>Arman Shirinyan
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Feb 26, 2025 - 0:01</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/bitcoin-btc-on-yearly-low-shiba-inu-shib-plummeting-aggravated-solana-sol-far-too-close-to-100">
#  <div class="news__item-title">Bitcoin (BTC) on Yearly Low, Shiba Inu (SHIB) Plummeting Aggravated, Solana (SOL) Far Too Close to $100</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/arman-shirinyan"><img alt="Arman Shirinyan" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8993.jpg" width="24"/>Arman Shirinyan
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Feb 24, 2025 - 12:01</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/solana-sol-lost-45-bitcoin-domination-isnt-stopping">
#  <div class="news__item-title">Solana (SOL) Lost 45%: Bitcoin Domination Isn't Stopping?</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/arman-shirinyan"><img alt="Arman Shirinyan" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8993.jpg" width="24"/>Arman Shirinyan
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Feb 24, 2025 - 0:01</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/shiba-inu-shib-breaks-crucial-resistance-solana-sol-plummeting-finally-stops-ethereum-eth-price">
#  <div class="news__item-title">Shiba Inu (SHIB) Breaks Crucial Resistance, Solana (SOL) Plummeting Finally Stops, Ethereum (ETH) Price Grows, Damage Negated?</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/arman-shirinyan"><img alt="Arman Shirinyan" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8993.jpg" width="24"/>Arman Shirinyan
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Feb 22, 2025 - 12:56</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/solana-sol-price-prediction-for-february-22">
#  <div class="news__item-title">Solana (SOL) Price Prediction for February 22</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/denys-serhiichuk"><img alt="Denys Serhiichuk" class="humble__img" height="24" src="https://u.today/sites/default/files/2021-08/8942.jpg" width="24"/>Denys Serhiichuk
#              </a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/stories">Stories</a>
#  <div class="humble">Feb 22, 2025 - 7:23</div>
#  </div>
#  <a class="news__item-body" href="https://u.today/franklin-templeton-files-for-solana-etf-details">
#  <div class="news__item-title">Franklin Templeton Files for Solana ETF: Details</div>
#  </a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/dan-burgin"><img alt="Dan Burgin" class="humble__img" height="24" src="https://u.today/sites/default/files/2024-02/45425.jpg" width="24"/>Dan Burgin
#              </a></div>
#  </div>,
#  <div class="news__item"><a class="news__item-body" href="https://u.today/press-releases/arciums-encrypted-ecosystem-established-to-accelerate-private-computation">
#  <div class="news__item-title">Arcium’s ‘Encrypted Ecosystem’ Established To Accelerate Private Computation</div>
#  </a></div>,
#  <div class="news__item"><a class="news__item-body" href="https://u.today/press-releases/blofin-becomes-title-sponsor-of-token2049-dubai-and-hosts-the-inaugural-whales-rave">
#  <div class="news__item-title">BloFin Becomes Title Sponsor of TOKEN2049 Dubai and Hosts the Inaugural Whale’s Rave: Arcadia Afterparty</div>
#  </a></div>,
#  <div class="news__item"><a class="news__item-body" href="https://u.today/press-releases/aster-emerges-astherus-rebrands-to-lead-decentralized-perpetual-trading">
#  <div class="news__item-title">Aster Emerges: Astherus Rebrands to Lead Decentralized Perpetual Trading</div>
#  </a></div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/companies" hreflang="en">Companies</a>
#  <div class="humble">Mar 14, 2025 - 16:04</div>
#  </div><a class="news__item-body" href="https://u.today/nebula-stride-announces-major-developments-as-nst-presale-gains-traction">
#  <div class="news__item-title">Nebula Stride Announces Major Developments as NST Presale Gains Traction</div></a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/vladislav-sopov">
#  <img alt="article image" class="humble__img" height="140" src="https://u.today/sites/default/files/2021-07/8893.jpg" width="224">
#              Vladislav Sopov</img></a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/opinions" hreflang="en">Opinions</a>
#  <div class="humble">Feb 2, 2025 - 18:00</div>
#  </div><a class="news__item-body" href="https://u.today/opinions/ripple-vs-sec-how-will-new-developments-affect-xrp-price">
#  <div class="news__item-title">Ripple v. SEC: How Will New Developments Affect XRP Price?</div></a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/dan-burgin">
#  <img alt="article image" class="humble__img" height="140" src="https://u.today/sites/default/files/2024-02/45425.jpg" width="224">
#              Dan Burgin</img></a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/opinions" hreflang="en">Opinions</a>
#  <div class="humble">Jan 18, 2025 - 18:00</div>
#  </div><a class="news__item-body" href="https://u.today/opinions/stellar-lumen-xlm-price-prediction-2025">
#  <div class="news__item-title">Stellar Lumen (XLM) Price Prediction 2025</div></a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/dan-burgin">
#  <img alt="article image" class="humble__img" height="140" src="https://u.today/sites/default/files/2024-02/45425.jpg" width="224">
#              Dan Burgin</img></a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/guides" hreflang="en">Guides</a>
#  <div class="humble">Jan 16, 2025 - 1:30</div>
#  </div><a class="news__item-body" href="https://u.today/guides/what-is-desci-guide-on-decentralized-science-in-crypto">
#  <div class="news__item-title">What is DeSci: Guide on Decentralized Science in Crypto</div></a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/vladislav-sopov">
#  <img alt="article image" class="humble__img" height="140" src="https://u.today/sites/default/files/2021-07/8893.jpg" width="224">
#              Vladislav Sopov</img></a></div>
#  </div>,
#  <div class="news__item">
#  <div class="news__item-head humble__row"><a href="/latest-cryptocurrency-news" hreflang="en">News</a>
#  <div class="humble">Jan 15, 2025 - 10:56</div>
#  </div><a class="news__item-body" href="https://u.today/top-10-crypto-media-outlets-enter-2025-latest-similarweb-data-update">
#  <div class="news__item-title">Top 10 Crypto Media Outlets Enter 2025: Latest Similarweb Data Update</div></a>
#  <div class="news__item-footer"><a class="humble humble--author" href="/vladislav-sopov">
#  <img alt="article image" class="humble__img" height="140" src="https://u.today/sites/default/files/2021-07/8893.jpg" width="224">
#              Vladislav Sopov</img></a></div>
#  </div>]

# %%
Sol_data = []
for card in New_cards:
    data = []
    date_sol = card.select_one('div.news__item-head div.humble')
    if date_sol != None:
        datestr = date_eth.get_text()
        data.append(datetime.strptime(datestr.split(" - ")[0], "%b %d, %Y").date())
    title_sol = card.select_one('div.news__item-title')
    if title_sol != None:
        data.append(title_sol.get_text())
    if len(data) == 2:
        Sol_data.append(tuple(data))
    
Sol_data
# Out:
# [(datetime.date(2025, 1, 15), 'Solana (SOL) Price Prediction for March 26'),
#  (datetime.date(2025, 1, 15),
#   "Solpot Emerges as Solana's Premier On-Chain Platform, Distributes Over $400K in Free Rewards"),
#  (datetime.date(2025, 1, 15),
#   'Breaking: Fidelity Officially Joins Solana ETF Race'),
#  (datetime.date(2025, 1, 15),
#   'BlackRock Expands Blockchain Footprint to Solana'),
#  (datetime.date(2025, 1, 15),
#   "Solana Dog-Coin BONK Rallies 35% Unnoticed – What's Behind It?"),
#  (datetime.date(2025, 1, 15),
#   'Whale.io to Bridge NFT Collection from TON Blockchain to Solana'),
#  (datetime.date(2025, 1, 15),
#   ' Solana Co-Founder Trashes L2s, Says L1s Are Faster and More Secure'),
#  (datetime.date(2025, 1, 15), 'Solana (SOL) Price Prediction for March 23'),
#  (datetime.date(2025, 1, 15),
#   'Justin Sun Sparks Tron ETF Rumors as TRX Expands to Solana'),
#  (datetime.date(2025, 1, 15),
#   'Bitcoin (BTC): Make or Break Support Reached, Dogecoin (DOGE) Price at Breaking Point, Secret Bullish Solana (SOL) Pattern Formed?'),
#  (datetime.date(2025, 1, 15), "Did CME's Solana Futures Flop? Not Really"),
#  (datetime.date(2025, 1, 15),
#   'Solana at $127: What to Expect From SOL Price This Week'),
#  (datetime.date(2025, 1, 15),
#   "$59 Million Solana (SOL) in 7 Days: What's Going to Happen?"),
#  (datetime.date(2025, 1, 15),
#   'Bitcoin (BTC) Must Break This to Reach $100,000, Dogecoin (DOGE) Coming Closer to Bull Market, Solana (SOL) Death Cross Complications'),
#  (datetime.date(2025, 1, 15), 'Solana (SOL) Celebrates 5th Birthday: Details'),
#  (datetime.date(2025, 1, 15),
#   'Solana vs. Ethereum: Eight Parameters Compared by Crypto Expert'),
#  (datetime.date(2025, 1, 15), 'Solana (SOL) Price Prediction for March 14'),
#  (datetime.date(2025, 1, 15),
#   "Solana's (SOL) Legendary Cup and Handle Pattern Shaping Up, Here's Target"),
#  (datetime.date(2025, 1, 15),
#   'Dogecoin Death Cross Confirmed, Solana (SOL): Joins DOGE With Its Own Death Cross, XRP Recovery Continues: Next Level to Watch'),
#  (datetime.date(2025, 1, 15),
#   "201,755 Solana (SOL) Stun World's Largest Crypto Exchange"),
#  (datetime.date(2025, 1, 15),
#   'Solana ETF Proposed by $1.5 Trillion Investment Titan '),
#  (datetime.date(2025, 1, 15),
#   'Solana (SOL) Revenue Falls 93% From January High'),
#  (datetime.date(2025, 1, 15), 'Solana (SOL) Price Prediction for March 12'),
#  (datetime.date(2025, 1, 15),
#   'Solana (SOL) Death Cross Incoming, Dogecoin (DOGE) Hits Last Possible Support, Ethereum (ETH) Says Goodbye to $2,000 '),
#  (datetime.date(2025, 1, 15), 'Solana (SOL) Reclaims $123, Is Sell-off Over?'),
#  (datetime.date(2025, 1, 15),
#   'Solana (SOL) on Verge of Death Cross Amid Market Sell-off: Potential Scenarios'),
#  (datetime.date(2025, 1, 15),
#   'XRP: Movement to Death Cross Begins, Shiba Inu (SHIB) Bulls Gave Up? Solana (SOL) Bullish Reversal Might Be Around Corner'),
#  (datetime.date(2025, 1, 15), 'Solana (SOL) Price Prediction for March 8'),
#  (datetime.date(2025, 1, 15),
#   "$5.18 Billion Solana (SOL) Stun Market Bulls, Here's Why"),
#  (datetime.date(2025, 1, 15),
#   'Peter Schiff Creates His Own BTC Reserve, Receives Solana Instead'),
#  (datetime.date(2025, 1, 15),
#   'Bitcoin (BTC) $100,000 Momentum Gone, Solana (SOL): Surprising Move Incoming? Shiba Inu (SHIB) Heating up for Skyrocketing?'),
#  (datetime.date(2025, 1, 15),
#   "BlackRock's IBIT Makes First BTC Purchase in 7 Days, Solana Founder Presents 3 Major Scenarios for US Strategic Reserve, Texas Senate Passes Bitcoin Reserve Bill: Crypto News Digest by U.Today"),
#  (datetime.date(2025, 1, 15),
#   'Solana (SOL) Founder Presents 3 Major Scenarios for US Strategic Reserve'),
#  (datetime.date(2025, 1, 15),
#   'Shiba Inu (SHIB) Delivers Grim Volume Signal, Bitcoin (BTC): Is it Trying to Break $90,000? Solana (SOL): Days Before Recovery?'),
#  (datetime.date(2025, 1, 15), "Solana's Growth Falls by 88% "),
#  (datetime.date(2025, 1, 15),
#   "Solana (SOL) Whales Capitulate? Here's How Much Will Be Sold"),
#  (datetime.date(2025, 1, 15),
#   'Top Satoshi Candidate Says XRP and Solana Parts of Reserve Are ‘Obvious Scams’'),
#  (datetime.date(2025, 1, 15),
#   "Dogecoin, Solana, XRP: Up to 20% Tumbling, What's Happening?"),
#  (datetime.date(2025, 1, 15),
#   'Is Bitcoin (BTC) Ready for $100,000? Solana (SOL) Skyrockets, But in Wrong Way, Shiba Inu (SHIB): Is There Any Hope? '),
#  (datetime.date(2025, 1, 15),
#   'Solana Flips Ethereum Again as DEX Volume Hits $3.99 Billion'),
#  (datetime.date(2025, 1, 15), 'Solana (SOL) Price Prediction for March 3'),
#  (datetime.date(2025, 1, 15),
#   "Solana Price Rebounds 10%, Here's Impact on SOL Liquidations"),
#  (datetime.date(2025, 1, 15),
#   'Solana (SOL) Futures Launch Date Confirmed by CME Group: Details'),
#  (datetime.date(2025, 1, 15),
#   '96,180 Solana (SOL) Exit Binance, Staked by Whale'),
#  (datetime.date(2025, 1, 15),
#   '3 Major Dogecoin (DOGE) Support Levels, Shiba Inu (SHIB) Attempts Solid Recovery, Solana (SOL) Sees Secret Whale Accumulation'),
#  (datetime.date(2025, 1, 15),
#   'Bitcoin (BTC) on Yearly Low, Shiba Inu (SHIB) Plummeting Aggravated, Solana (SOL) Far Too Close to $100'),
#  (datetime.date(2025, 1, 15),
#   "Solana (SOL) Lost 45%: Bitcoin Domination Isn't Stopping?"),
#  (datetime.date(2025, 1, 15),
#   'Shiba Inu (SHIB) Breaks Crucial Resistance, Solana (SOL) Plummeting Finally Stops, Ethereum (ETH) Price Grows, Damage Negated?'),
#  (datetime.date(2025, 1, 15), 'Solana (SOL) Price Prediction for February 22'),
#  (datetime.date(2025, 1, 15),
#   'Franklin Templeton Files for Solana ETF: Details'),
#  (datetime.date(2025, 1, 15),
#   'Nebula Stride Announces Major Developments as NST Presale Gains Traction'),
#  (datetime.date(2025, 1, 15),
#   'Ripple v. SEC: How Will New Developments Affect XRP Price?'),
#  (datetime.date(2025, 1, 15), 'Stellar Lumen (XLM) Price Prediction 2025'),
#  (datetime.date(2025, 1, 15),
#   'What is DeSci: Guide on Decentralized Science in Crypto'),
#  (datetime.date(2025, 1, 15),
#   'Top 10 Crypto Media Outlets Enter 2025: Latest Similarweb Data Update')]

# %%
Sol_DFM = pd.DataFrame(Sol_data, columns = ['date', 'title'])
Sol_DFM
# Out:
#           date                                              title
# 0   2025-01-15         Solana (SOL) Price Prediction for March 26
# 1   2025-01-15  Solpot Emerges as Solana's Premier On-Chain Pl...
# 2   2025-01-15  Breaking: Fidelity Officially Joins Solana ETF...
# 3   2025-01-15   BlackRock Expands Blockchain Footprint to Solana
# 4   2025-01-15  Solana Dog-Coin BONK Rallies 35% Unnoticed – W...
# 5   2025-01-15  Whale.io to Bridge NFT Collection from TON Blo...
# 6   2025-01-15   Solana Co-Founder Trashes L2s, Says L1s Are F...
# 7   2025-01-15         Solana (SOL) Price Prediction for March 23
# 8   2025-01-15  Justin Sun Sparks Tron ETF Rumors as TRX Expan...
# 9   2025-01-15  Bitcoin (BTC): Make or Break Support Reached, ...
# 10  2025-01-15          Did CME's Solana Futures Flop? Not Really
# 11  2025-01-15  Solana at $127: What to Expect From SOL Price ...
# 12  2025-01-15  $59 Million Solana (SOL) in 7 Days: What's Goi...
# 13  2025-01-15  Bitcoin (BTC) Must Break This to Reach $100,00...
# 14  2025-01-15      Solana (SOL) Celebrates 5th Birthday: Details
# 15  2025-01-15  Solana vs. Ethereum: Eight Parameters Compared...
# 16  2025-01-15         Solana (SOL) Price Prediction for March 14
# 17  2025-01-15  Solana's (SOL) Legendary Cup and Handle Patter...
# 18  2025-01-15  Dogecoin Death Cross Confirmed, Solana (SOL): ...
# 19  2025-01-15  201,755 Solana (SOL) Stun World's Largest Cryp...
# 20  2025-01-15  Solana ETF Proposed by $1.5 Trillion Investmen...
# 21  2025-01-15   Solana (SOL) Revenue Falls 93% From January High
# 22  2025-01-15         Solana (SOL) Price Prediction for March 12
# 23  2025-01-15  Solana (SOL) Death Cross Incoming, Dogecoin (D...
# 24  2025-01-15      Solana (SOL) Reclaims $123, Is Sell-off Over?
# 25  2025-01-15  Solana (SOL) on Verge of Death Cross Amid Mark...
# 26  2025-01-15  XRP: Movement to Death Cross Begins, Shiba Inu...
# 27  2025-01-15          Solana (SOL) Price Prediction for March 8
# 28  2025-01-15  $5.18 Billion Solana (SOL) Stun Market Bulls, ...
# 29  2025-01-15  Peter Schiff Creates His Own BTC Reserve, Rece...
# 30  2025-01-15  Bitcoin (BTC) $100,000 Momentum Gone, Solana (...
# 31  2025-01-15  BlackRock's IBIT Makes First BTC Purchase in 7...
# 32  2025-01-15  Solana (SOL) Founder Presents 3 Major Scenario...
# 33  2025-01-15  Shiba Inu (SHIB) Delivers Grim Volume Signal, ...
# 34  2025-01-15                      Solana's Growth Falls by 88%
# 35  2025-01-15  Solana (SOL) Whales Capitulate? Here's How Muc...
# 36  2025-01-15  Top Satoshi Candidate Says XRP and Solana Part...
# 37  2025-01-15  Dogecoin, Solana, XRP: Up to 20% Tumbling, Wha...
# 38  2025-01-15  Is Bitcoin (BTC) Ready for $100,000? Solana (S...
# 39  2025-01-15  Solana Flips Ethereum Again as DEX Volume Hits...
# 40  2025-01-15          Solana (SOL) Price Prediction for March 3
# 41  2025-01-15  Solana Price Rebounds 10%, Here's Impact on SO...
# 42  2025-01-15  Solana (SOL) Futures Launch Date Confirmed by ...
# 43  2025-01-15  96,180 Solana (SOL) Exit Binance, Staked by Whale
# 44  2025-01-15  3 Major Dogecoin (DOGE) Support Levels, Shiba ...
# 45  2025-01-15  Bitcoin (BTC) on Yearly Low, Shiba Inu (SHIB) ...
# 46  2025-01-15  Solana (SOL) Lost 45%: Bitcoin Domination Isn'...
# 47  2025-01-15  Shiba Inu (SHIB) Breaks Crucial Resistance, So...
# 48  2025-01-15      Solana (SOL) Price Prediction for February 22
# 49  2025-01-15   Franklin Templeton Files for Solana ETF: Details
# 50  2025-01-15  Nebula Stride Announces Major Developments as ...
# 51  2025-01-15  Ripple v. SEC: How Will New Developments Affec...
# 52  2025-01-15          Stellar Lumen (XLM) Price Prediction 2025
# 53  2025-01-15  What is DeSci: Guide on Decentralized Science ...
# 54  2025-01-15  Top 10 Crypto Media Outlets Enter 2025: Latest...

# %%
Sol_DFM['currency'] = "Solana"
Sol_DFM
# Out:
#           date                                              title currency
# 0   2025-01-15         Solana (SOL) Price Prediction for March 26   Solana
# 1   2025-01-15  Solpot Emerges as Solana's Premier On-Chain Pl...   Solana
# 2   2025-01-15  Breaking: Fidelity Officially Joins Solana ETF...   Solana
# 3   2025-01-15   BlackRock Expands Blockchain Footprint to Solana   Solana
# 4   2025-01-15  Solana Dog-Coin BONK Rallies 35% Unnoticed – W...   Solana
# 5   2025-01-15  Whale.io to Bridge NFT Collection from TON Blo...   Solana
# 6   2025-01-15   Solana Co-Founder Trashes L2s, Says L1s Are F...   Solana
# 7   2025-01-15         Solana (SOL) Price Prediction for March 23   Solana
# 8   2025-01-15  Justin Sun Sparks Tron ETF Rumors as TRX Expan...   Solana
# 9   2025-01-15  Bitcoin (BTC): Make or Break Support Reached, ...   Solana
# 10  2025-01-15          Did CME's Solana Futures Flop? Not Really   Solana
# 11  2025-01-15  Solana at $127: What to Expect From SOL Price ...   Solana
# 12  2025-01-15  $59 Million Solana (SOL) in 7 Days: What's Goi...   Solana
# 13  2025-01-15  Bitcoin (BTC) Must Break This to Reach $100,00...   Solana
# 14  2025-01-15      Solana (SOL) Celebrates 5th Birthday: Details   Solana
# 15  2025-01-15  Solana vs. Ethereum: Eight Parameters Compared...   Solana
# 16  2025-01-15         Solana (SOL) Price Prediction for March 14   Solana
# 17  2025-01-15  Solana's (SOL) Legendary Cup and Handle Patter...   Solana
# 18  2025-01-15  Dogecoin Death Cross Confirmed, Solana (SOL): ...   Solana
# 19  2025-01-15  201,755 Solana (SOL) Stun World's Largest Cryp...   Solana
# 20  2025-01-15  Solana ETF Proposed by $1.5 Trillion Investmen...   Solana
# 21  2025-01-15   Solana (SOL) Revenue Falls 93% From January High   Solana
# 22  2025-01-15         Solana (SOL) Price Prediction for March 12   Solana
# 23  2025-01-15  Solana (SOL) Death Cross Incoming, Dogecoin (D...   Solana
# 24  2025-01-15      Solana (SOL) Reclaims $123, Is Sell-off Over?   Solana
# 25  2025-01-15  Solana (SOL) on Verge of Death Cross Amid Mark...   Solana
# 26  2025-01-15  XRP: Movement to Death Cross Begins, Shiba Inu...   Solana
# 27  2025-01-15          Solana (SOL) Price Prediction for March 8   Solana
# 28  2025-01-15  $5.18 Billion Solana (SOL) Stun Market Bulls, ...   Solana
# 29  2025-01-15  Peter Schiff Creates His Own BTC Reserve, Rece...   Solana
# 30  2025-01-15  Bitcoin (BTC) $100,000 Momentum Gone, Solana (...   Solana
# 31  2025-01-15  BlackRock's IBIT Makes First BTC Purchase in 7...   Solana
# 32  2025-01-15  Solana (SOL) Founder Presents 3 Major Scenario...   Solana
# 33  2025-01-15  Shiba Inu (SHIB) Delivers Grim Volume Signal, ...   Solana
# 34  2025-01-15                      Solana's Growth Falls by 88%    Solana
# 35  2025-01-15  Solana (SOL) Whales Capitulate? Here's How Muc...   Solana
# 36  2025-01-15  Top Satoshi Candidate Says XRP and Solana Part...   Solana
# 37  2025-01-15  Dogecoin, Solana, XRP: Up to 20% Tumbling, Wha...   Solana
# 38  2025-01-15  Is Bitcoin (BTC) Ready for $100,000? Solana (S...   Solana
# 39  2025-01-15  Solana Flips Ethereum Again as DEX Volume Hits...   Solana
# 40  2025-01-15          Solana (SOL) Price Prediction for March 3   Solana
# 41  2025-01-15  Solana Price Rebounds 10%, Here's Impact on SO...   Solana
# 42  2025-01-15  Solana (SOL) Futures Launch Date Confirmed by ...   Solana
# 43  2025-01-15  96,180 Solana (SOL) Exit Binance, Staked by Whale   Solana
# 44  2025-01-15  3 Major Dogecoin (DOGE) Support Levels, Shiba ...   Solana
# 45  2025-01-15  Bitcoin (BTC) on Yearly Low, Shiba Inu (SHIB) ...   Solana
# 46  2025-01-15  Solana (SOL) Lost 45%: Bitcoin Domination Isn'...   Solana
# 47  2025-01-15  Shiba Inu (SHIB) Breaks Crucial Resistance, So...   Solana
# 48  2025-01-15      Solana (SOL) Price Prediction for February 22   Solana
# 49  2025-01-15   Franklin Templeton Files for Solana ETF: Details   Solana
# 50  2025-01-15  Nebula Stride Announces Major Developments as ...   Solana
# 51  2025-01-15  Ripple v. SEC: How Will New Developments Affec...   Solana
# 52  2025-01-15          Stellar Lumen (XLM) Price Prediction 2025   Solana
# 53  2025-01-15  What is DeSci: Guide on Decentralized Science ...   Solana
# 54  2025-01-15  Top 10 Crypto Media Outlets Enter 2025: Latest...   Solana

# %%
#save to csv
Sol_DFM.to_csv('Solana_Daily_News.csv', index=False)

# %%
import pandas as pd

# Load datasets
bitcoin_ddf = pd.read_csv('Bitcoin_Daily_News.csv')
ethereum_ddf = pd.read_csv('Ethereum_Daily_News.csv')
Sol_ddf = pd.read_csv('Solana_Daily_News.csv')

# Add currency identifier
#bitcoin['currency'] = 'Bitcoin'
#ethereum['currency'] = 'Ethereum'

# Combine vertically
crypto_news = pd.concat([bitcoin_ddf, ethereum_ddf, Sol_ddf], ignore_index=True)

# Convert date to datetime and sort
crypto_news['date'] = pd.to_datetime(crypto_news['date'])
crypto_news = crypto_news.sort_values(['date'])

# Reset index
crypto_news = crypto_news.reset_index(drop=True)

# Save to CSV
crypto_news.to_csv('Crypto_News.csv', index=False)

# Display result
print(crypto_news.head(10))
# Out:
#         date                                              title  currency
# 0 2025-01-15  Standard Chartered Dramatically Reduces Ethere...  Ethereum
# 1 2025-01-15  Aster Emerges: Astherus Rebrands to Lead Decen...  Ethereum
# 2 2025-01-15  Nebula Stride Announces Major Developments as ...  Ethereum
# 3 2025-01-15  Ripple v. SEC: How Will New Developments Affec...  Ethereum
# 4 2025-01-15          Stellar Lumen (XLM) Price Prediction 2025  Ethereum
# 5 2025-01-15  What is DeSci: Guide on Decentralized Science ...  Ethereum
# 6 2025-01-15  Top 10 Crypto Media Outlets Enter 2025: Latest...  Ethereum
# 7 2025-01-15         Solana (SOL) Price Prediction for March 26    Solana
# 8 2025-01-15  Solpot Emerges as Solana's Premier On-Chain Pl...    Solana
# 9 2025-01-15  Breaking: Fidelity Officially Joins Solana ETF...    Solana

# %%
crypto_news.head(10)
# Out:
#         date                                              title  currency
# 0 2025-01-15  Standard Chartered Dramatically Reduces Ethere...  Ethereum
# 1 2025-01-15  Aster Emerges: Astherus Rebrands to Lead Decen...  Ethereum
# 2 2025-01-15  Nebula Stride Announces Major Developments as ...  Ethereum
# 3 2025-01-15  Ripple v. SEC: How Will New Developments Affec...  Ethereum
# 4 2025-01-15          Stellar Lumen (XLM) Price Prediction 2025  Ethereum
# 5 2025-01-15  What is DeSci: Guide on Decentralized Science ...  Ethereum
# 6 2025-01-15  Top 10 Crypto Media Outlets Enter 2025: Latest...  Ethereum
# 7 2025-01-15         Solana (SOL) Price Prediction for March 26    Solana
# 8 2025-01-15  Solpot Emerges as Solana's Premier On-Chain Pl...    Solana
# 9 2025-01-15  Breaking: Fidelity Officially Joins Solana ETF...    Solana

# %% [markdown]
# # Railway

# %%
from dotenv import load_dotenv
import os
load_dotenv()

dbconn = os.getenv("DBCONN")

# %%
import psycopg

# %%
# establish database connection using connection string from .env
conn = psycopg.connect(dbconn)

# create a cursor
cur = conn.cursor()

# %%
crypto.head()
# Out:
#         date      open      high       low     close       volume  \
# 0 2024-04-28  60985.08  63134.63  58411.49  58947.56  2398.396625
# 1 2024-04-28  60985.08  63134.63  58411.49  58947.56  2398.396625
# 2 2024-04-28  60985.08  63134.63  58411.49  58947.56  2398.396625
# 3 2024-05-05  58965.50  60365.57  52943.49  59506.98  4178.038841
# 4 2024-05-05  58965.50  60365.57  52943.49  59506.98  4178.038841
#
#   currency_name
# 0        Solana
# 1       Bitcoin
# 2      Ethereum
# 3       Bitcoin
# 4      Ethereum

# %%
cur.execute('''
    CREATE TABLE IF NOT EXISTS crypto(
        date TIMESTAMP NOT NULL,
        open DOUBLE PRECISION,
        high DOUBLE PRECISION,
        low DOUBLE PRECISION,
        close DOUBLE PRECISION,
        volume DOUBLE PRECISION,
        currency_name VARCHAR(50) NOT NULL,
        PRIMARY KEY(date, currency_name)
    );
''')
# Out:
# <psycopg.Cursor [COMMAND_OK] [INTRANS] (host=shuttle.proxy.rlwy.net port=29785 user=postgres database=railway) at 0x132b32810>

# %%
# commit to all executed queries
conn.commit()

# %%
# close the cursor and sever connection
cur.close()
conn.close()

# %%
api_key = os.getenv("API_KEY")

# %%
conn = psycopg.connect(dbconn)

# create a cursor
cur = conn.cursor()

# %%
#  Load CSV into Pandas DataFrame
crypto_df = pd.read_csv("Combined_Crypto_Data.csv")
#  Insert Data Row by Row
for _, row in crypto_df.iterrows():
    cur.execute('''
        INSERT INTO crypto (date, open, high, low, close, volume, currency_name)
        VALUES (%s, %s, %s, %s, %s, %s, %s)
        ON CONFLICT (date, currency_name) DO NOTHING;
    ''', tuple(row))  # Convert row to tuple

conn.commit()
cur.close()
conn.close()

# %% [markdown]
# ## For Crypto News

# %%
# establish database connection using connection string from .env
conn = psycopg.connect(dbconn)

# create a cursor
cur = conn.cursor()

# %%
#crypto_news.head(50)

# %%
crypto_news[crypto_news.duplicated("title")]
# Out:
#           date                                              title currency
# 46  2025-01-15  Solana Flips Ethereum Again as DEX Volume Hits...   Solana
# 57  2025-01-15  Nebula Stride Announces Major Developments as ...   Solana
# 58  2025-01-15  Ripple v. SEC: How Will New Developments Affec...   Solana
# 59  2025-01-15          Stellar Lumen (XLM) Price Prediction 2025   Solana
# 64  2025-01-15  Solana vs. Ethereum: Eight Parameters Compared...   Solana
# 72  2025-01-15  Solana (SOL) Death Cross Incoming, Dogecoin (D...   Solana
# 83  2025-01-15  Top 10 Crypto Media Outlets Enter 2025: Latest...   Solana
# 85  2025-01-15  Top 10 Crypto Media Outlets Enter 2025: Latest...  Bitcoin
# 111 2025-01-15  What is DeSci: Guide on Decentralized Science ...   Solana
# 114 2025-01-16  What is DeSci: Guide on Decentralized Science ...  Bitcoin
# 115 2025-01-18          Stellar Lumen (XLM) Price Prediction 2025  Bitcoin
# 116 2025-02-02  Ripple v. SEC: How Will New Developments Affec...  Bitcoin
# 117 2025-03-14  Nebula Stride Announces Major Developments as ...  Bitcoin
# 141 2025-03-28  Ethereum Crashes 74% Against Bitcoin; Is Rever...  Bitcoin
# 148 2025-03-28  Shiba Inu (SHIB): Bulls in Control Now? Bitcoi...  Bitcoin

# %%
cur.execute("DROP TABLE crypto_news;")
# Out:
# <psycopg.Cursor [COMMAND_OK] [INTRANS] (host=shuttle.proxy.rlwy.net port=29785 user=postgres database=railway) at 0x134acac90>

# %%
cur.execute('''
    CREATE TABLE IF NOT EXISTS crypto_news(
        date TIMESTAMP NOT NULL,
        title TEXT,
        currency VARCHAR(50) NOT NULL,
        PRIMARY KEY(date, title)
    );
''')
# Out:
# <psycopg.Cursor [COMMAND_OK] [INTRANS] (host=shuttle.proxy.rlwy.net port=29785 user=postgres database=railway) at 0x134acb7d0>

# %%
# commit to all executed queries
conn.commit()

# %%
# close the cursor and sever connection
cur.close()
conn.close()

# %%
import pandas as pd

# %%
conn = psycopg.connect(dbconn)

# create a cursor
cur = conn.cursor()

# %%
#  Load CSV into Pandas DataFrame
crypto_nw = pd.read_csv("Crypto_News.csv")
#  Insert Data Row by Row
for _, row in crypto_nw.iterrows():
    print(tuple(row))
    cur.execute('''
        INSERT INTO crypto_news (date, title, currency)
        VALUES (%s, %s, %s)
        ON CONFLICT (date, title) DO NOTHING;
    ''', tuple(row))  # Convert row to tuple

conn.commit()
cur.close()
conn.close()
# Out:
# ('2025-01-15', 'Standard Chartered Dramatically Reduces Ethereum (ETH) Price Target ', 'Ethereum')
# ('2025-01-15', 'Aster Emerges: Astherus Rebrands to Lead Decentralized Perpetual Trading', 'Ethereum')
# ('2025-01-15', 'Nebula Stride Announces Major Developments as NST Presale Gains Traction', 'Ethereum')
# ('2025-01-15', 'Ripple v. SEC: How Will New Developments Affect XRP Price?', 'Ethereum')
# ('2025-01-15', 'Stellar Lumen (XLM) Price Prediction 2025', 'Ethereum')
# ('2025-01-15', 'What is DeSci: Guide on Decentralized Science in Crypto', 'Ethereum')
# ('2025-01-15', 'Top 10 Crypto Media Outlets Enter 2025: Latest Similarweb Data Update', 'Ethereum')
# ('2025-01-15', 'Solana (SOL) Price Prediction for March 26', 'Solana')
# ('2025-01-15', "Solpot Emerges as Solana's Premier On-Chain Platform, Distributes Over $400K in Free Rewards", 'Solana')
# ('2025-01-15', 'Breaking: Fidelity Officially Joins Solana ETF Race', 'Solana')
# ('2025-01-15', 'BlackRock Expands Blockchain Footprint to Solana', 'Solana')
# ('2025-01-15', "Solana Dog-Coin BONK Rallies 35% Unnoticed – What's Behind It?", 'Solana')
# ('2025-01-15', 'Whale.io to Bridge NFT Collection from TON Blockchain to Solana', 'Solana')
# ('2025-01-15', ' Solana Co-Founder Trashes L2s, Says L1s Are Faster and More Secure', 'Solana')
# ('2025-01-15', 'Solana (SOL) Price Prediction for March 23', 'Solana')
# ('2025-01-15', 'Justin Sun Sparks Tron ETF Rumors as TRX Expands to Solana', 'Solana')
# ('2025-01-15', 'Bitcoin (BTC): Make or Break Support Reached, Dogecoin (DOGE) Price at Breaking Point, Secret Bullish Solana (SOL) Pattern Formed?', 'Solana')
# ('2025-01-15', "Did CME's Solana Futures Flop? Not Really", 'Solana')
# ('2025-01-15', 'BloFin Becomes Title Sponsor of TOKEN2049 Dubai and Hosts the Inaugural Whale’s Rave: Arcadia Afterparty', 'Ethereum')
# ('2025-01-15', 'Solana at $127: What to Expect From SOL Price This Week', 'Solana')
# ('2025-01-15', 'Arcium’s ‘Encrypted Ecosystem’ Established To Accelerate Private Computation', 'Ethereum')
# ('2025-01-15', 'XRP: 24% Retrace is Mind-Blowing, Ethereum (ETH) Looks Even Worse Than Before, Cardano (ADA): Biggest Volatility Surge in Years ', 'Ethereum')
# ('2025-01-15', 'XRP Already Recovered 20%, Enormous Ethereum (ETH) Selling Volume Before $2,000, Sixth Shiba Inu (SHIB) Recovery Attempt: Another Crash?', 'Ethereum')
# ('2025-01-15', "XRP Flips Ethereum in Fully Diluted Valuation, Here's Implication", 'Ethereum')
# ('2025-01-15', 'XRP vs. Ethereum (ETH): Ripple CTO Clears up Major Sale Misconception', 'Ethereum')
# ('2025-01-15', 'No, Ethereum (ETH) Is Not Dead, Says Top Analyst', 'Ethereum')
# ('2025-01-15', 'Ethereum Risks Drop to $1,400, Mirroring 2020 Crash, Crypto Trader Warns', 'Ethereum')
# ('2025-01-15', 'Ethereum ETFs Log Nearly $22 Million Worth of Outflows', 'Ethereum')
# ('2025-01-15', 'Solana (SOL) Death Cross Incoming, Dogecoin (DOGE) Hits Last Possible Support, Ethereum (ETH) Says Goodbye to $2,000 ', 'Ethereum')
# ('2025-01-15', 'Fidelity Files for Staking on Ethereum ETF Product', 'Ethereum')
# ('2025-01-15', 'Ethereum Foundation Makes 30,098 ETH Liquidation Play on Maker: Details', 'Ethereum')
# ('2025-01-15', 'Ethereum (ETH) Price Prediction for March 11', 'Ethereum')
# ('2025-01-15', 'Tron Founder Justin Sun Issues Crucial Ethereum Warning: Details', 'Ethereum')
# ('2025-01-15', 'Ethereum (ETH) Price Prediction for March 10', 'Ethereum')
# ('2025-01-15', 'Consensys CEO Says Ethereum Must Remain Neutral ', 'Ethereum')
# ('2025-01-15', 'Ethereum (ETH): $2,000 Might Be Lost Today', 'Ethereum')
# ('2025-01-15', 'Ethereum (ETH) Price Prediction for March 7', 'Ethereum')
# ('2025-01-15', "XRP's $2.50 Price Breakout Still Questionable, Dogecoin (DOGE) Hits Major Support Again, Ethereum (ETH) Not Okay", 'Ethereum')
# ('2025-01-15', 'Ethereum (ETH) Price Prediction for March 5', 'Ethereum')
# ('2025-01-15', 'Solana Flips Ethereum Again as DEX Volume Hits $3.99 Billion', 'Ethereum')
# ('2025-01-15', 'Solana vs. Ethereum: Eight Parameters Compared by Crypto Expert', 'Ethereum')
# ('2025-01-15', "$59 Million Solana (SOL) in 7 Days: What's Going to Happen?", 'Solana')
# ('2025-01-15', 'Solana (SOL) Celebrates 5th Birthday: Details', 'Solana')
# ('2025-01-15', 'Top Satoshi Candidate Says XRP and Solana Parts of Reserve Are ‘Obvious Scams’', 'Solana')
# ('2025-01-15', "Dogecoin, Solana, XRP: Up to 20% Tumbling, What's Happening?", 'Solana')
# ('2025-01-15', 'Is Bitcoin (BTC) Ready for $100,000? Solana (SOL) Skyrockets, But in Wrong Way, Shiba Inu (SHIB): Is There Any Hope? ', 'Solana')
# ('2025-01-15', 'Solana Flips Ethereum Again as DEX Volume Hits $3.99 Billion', 'Solana')
# ('2025-01-15', 'Solana (SOL) Price Prediction for March 3', 'Solana')
# ('2025-01-15', "Solana Price Rebounds 10%, Here's Impact on SOL Liquidations", 'Solana')
# ('2025-01-15', 'Solana (SOL) Futures Launch Date Confirmed by CME Group: Details', 'Solana')
# ('2025-01-15', '96,180 Solana (SOL) Exit Binance, Staked by Whale', 'Solana')
# ('2025-01-15', '3 Major Dogecoin (DOGE) Support Levels, Shiba Inu (SHIB) Attempts Solid Recovery, Solana (SOL) Sees Secret Whale Accumulation', 'Solana')
# ('2025-01-15', 'Bitcoin (BTC) on Yearly Low, Shiba Inu (SHIB) Plummeting Aggravated, Solana (SOL) Far Too Close to $100', 'Solana')
# ('2025-01-15', "Solana (SOL) Lost 45%: Bitcoin Domination Isn't Stopping?", 'Solana')
# ('2025-01-15', 'Shiba Inu (SHIB) Breaks Crucial Resistance, Solana (SOL) Plummeting Finally Stops, Ethereum (ETH) Price Grows, Damage Negated?', 'Solana')
# ('2025-01-15', 'Solana (SOL) Price Prediction for February 22', 'Solana')
# ('2025-01-15', 'Franklin Templeton Files for Solana ETF: Details', 'Solana')
# ('2025-01-15', 'Nebula Stride Announces Major Developments as NST Presale Gains Traction', 'Solana')
# ('2025-01-15', 'Ripple v. SEC: How Will New Developments Affect XRP Price?', 'Solana')
# ('2025-01-15', 'Stellar Lumen (XLM) Price Prediction 2025', 'Solana')
# ('2025-01-15', "Solana (SOL) Whales Capitulate? Here's How Much Will Be Sold", 'Solana')
# ('2025-01-15', 'Bitcoin (BTC) Must Break This to Reach $100,000, Dogecoin (DOGE) Coming Closer to Bull Market, Solana (SOL) Death Cross Complications', 'Solana')
# ('2025-01-15', "Solana's Growth Falls by 88% ", 'Solana')
# ('2025-01-15', 'Solana (SOL) Founder Presents 3 Major Scenarios for US Strategic Reserve', 'Solana')
# ('2025-01-15', 'Solana vs. Ethereum: Eight Parameters Compared by Crypto Expert', 'Solana')
# ('2025-01-15', 'Solana (SOL) Price Prediction for March 14', 'Solana')
# ('2025-01-15', "Solana's (SOL) Legendary Cup and Handle Pattern Shaping Up, Here's Target", 'Solana')
# ('2025-01-15', 'Dogecoin Death Cross Confirmed, Solana (SOL): Joins DOGE With Its Own Death Cross, XRP Recovery Continues: Next Level to Watch', 'Solana')
# ('2025-01-15', "201,755 Solana (SOL) Stun World's Largest Crypto Exchange", 'Solana')
# ('2025-01-15', 'Solana ETF Proposed by $1.5 Trillion Investment Titan ', 'Solana')
# ('2025-01-15', 'Solana (SOL) Revenue Falls 93% From January High', 'Solana')
# ('2025-01-15', 'Solana (SOL) Price Prediction for March 12', 'Solana')
# ('2025-01-15', 'Solana (SOL) Death Cross Incoming, Dogecoin (DOGE) Hits Last Possible Support, Ethereum (ETH) Says Goodbye to $2,000 ', 'Solana')
# ('2025-01-15', 'Solana (SOL) Reclaims $123, Is Sell-off Over?', 'Solana')
# ('2025-01-15', 'Solana (SOL) on Verge of Death Cross Amid Market Sell-off: Potential Scenarios', 'Solana')
# ('2025-01-15', 'XRP: Movement to Death Cross Begins, Shiba Inu (SHIB) Bulls Gave Up? Solana (SOL) Bullish Reversal Might Be Around Corner', 'Solana')
# ('2025-01-15', 'Solana (SOL) Price Prediction for March 8', 'Solana')
# ('2025-01-15', "$5.18 Billion Solana (SOL) Stun Market Bulls, Here's Why", 'Solana')
# ('2025-01-15', 'Peter Schiff Creates His Own BTC Reserve, Receives Solana Instead', 'Solana')
# ('2025-01-15', 'Bitcoin (BTC) $100,000 Momentum Gone, Solana (SOL): Surprising Move Incoming? Shiba Inu (SHIB) Heating up for Skyrocketing?', 'Solana')
# ('2025-01-15', "BlackRock's IBIT Makes First BTC Purchase in 7 Days, Solana Founder Presents 3 Major Scenarios for US Strategic Reserve, Texas Senate Passes Bitcoin Reserve Bill: Crypto News Digest by U.Today", 'Solana')
# ('2025-01-15', 'Shiba Inu (SHIB) Delivers Grim Volume Signal, Bitcoin (BTC): Is it Trying to Break $90,000? Solana (SOL): Days Before Recovery?', 'Solana')
# ('2025-01-15', 'Ethereum (ETH) Price Prediction for March 17', 'Ethereum')
# ('2025-01-15', 'Top 10 Crypto Media Outlets Enter 2025: Latest Similarweb Data Update', 'Solana')
# ('2025-01-15', 'Shiba Inu (SHIB) Reaches Crucial Price Test, Ethereum (ETH) Eyeing $2,000 Again, Can XRP Avoid This Grim Movement?', 'Ethereum')
# ('2025-01-15', 'Top 10 Crypto Media Outlets Enter 2025: Latest Similarweb Data Update', 'Bitcoin')
# ('2025-01-15', 'Ethereum (ETH) Price Prediction for March 30', 'Ethereum')
# ('2025-01-15', 'Pre-Mine Ethereum Address Suddenly Activated', 'Ethereum')
# ('2025-01-15', 'Ethereum (ETH) Awaiting Crucial Crossover: Details', 'Ethereum')
# ('2025-01-15', 'Ethereum (ETH) Price Prediction for March 29', 'Ethereum')
# ('2025-01-15', 'Ethereum (ETH) Founder Vitalik Buterin Bets on Open Source Funding, Not Public Goods', 'Ethereum')
# ('2025-01-15', 'Ethereum (ETH) Whales Close to Liquidation, $238 Million to Be Erased', 'Ethereum')
# ('2025-01-15', "'Is $1,000 Next?': Bloomberg's McGlone Queries Latest Ethereum Sell-Off", 'Ethereum')
# ('2025-01-15', "Shiba Inu (SHIB): Bulls in Control Now? Bitcoin (BTC) in Great Spot, Ethereum (ETH): Major Bearish Signal, But There's Silver Lining ", 'Ethereum')
# ('2025-01-15', 'BlockDAG (BDAG) Pre-Sale Hits Beta Testnet Launch as Ethereum (ETH), Shiba Inu (SHIB) Struggling with Pressure', 'Ethereum')
# ('2025-01-15', '10.84 Million Ethereum (ETH) in 24 Hours, What Are Bulls up To?', 'Ethereum')
# ('2025-01-15', 'Is XRP Price Ready for $3? Ethereum (ETH) Seeing $2,000 Test, Shiba Inu (SHIB) 1.5 Trillion Whale Pump Recorded', 'Ethereum')
# ('2025-01-15', 'Ethereum Adoption Grows With Launch of Bank-Issued Stablecoin', 'Ethereum')
# ('2025-01-15', 'Ethereum Crashes 74% Against Bitcoin; Is Reversal Imminent?', 'Ethereum')
# ('2025-01-15', 'Bitcoin (BTC) Invalidates Crucial Price Setup, XRP Faces 50 and 100 Day Squeeze, Ethereum (ETH) Finally Bounces Back?', 'Ethereum')
# ('2025-01-15', 'Ethereum (ETH) Price Prediction for March 24', 'Ethereum')
# ('2025-01-15', 'Ethereum ETFs Hemorrhage $50 Million ', 'Ethereum')
# ('2025-01-15', 'Consensus 2025', 'Ethereum')
# ('2025-01-15', 'Ethereum (ETH) Price Prediction for March 19', 'Ethereum')
# ('2025-01-15', 'BlockDAG (BDAG) Enters New Roadmap Phase as Shiba Inu (SHIB), Ethereum (ETH) Price Metrics Consolidate', 'Ethereum')
# ('2025-01-15', 'Major Exchange Lists Cardano (ADA) and Coinbase Ethereum for Futures Collateral', 'Ethereum')
# ('2025-01-15', 'Ethereum (ETH) Developers Launch Hoodi Testnet and Prepare Pectra for Mainnet Launch in May', 'Ethereum')
# ('2025-01-15', 'New Ethereum ETF Staking Proposal Filed by NYSE ', 'Ethereum')
# ('2025-01-15', 'Billions of Shiba Inu (SHIB) Acquired by Major Dormant Ethereum Whale', 'Ethereum')
# ('2025-01-15', 'Ethereum (ETH) Price Prediction for March 22', 'Ethereum')
# ('2025-01-15', 'Ethereum (ETH) Fees Plummet 50% as Network Activity Slowdown Sparks Concerns', 'Ethereum')
# ('2025-01-15', 'What is DeSci: Guide on Decentralized Science in Crypto', 'Solana')
# ('2025-01-15', 'Is $3 XRP Possible? Bitcoin (BTC) Makes Biggest Breakout in 2025, Ethereum (ETH) Finally Above $2,000', 'Ethereum')
# ('2025-01-15', 'New Key Date for XRP Holders Just Emerged, Major Exchange Lists ADA and Coinbase Ethereum for Futures Collateral, Billions of SHIB Purchased by Major Dormant ETH Whale: Crypto News Digest by U.Today', 'Ethereum')
# ('2025-01-16', 'What is DeSci: Guide on Decentralized Science in Crypto', 'Bitcoin')
# ('2025-01-18', 'Stellar Lumen (XLM) Price Prediction 2025', 'Bitcoin')
# ('2025-02-02', 'Ripple v. SEC: How Will New Developments Affect XRP Price?', 'Bitcoin')
# ('2025-03-14', 'Nebula Stride Announces Major Developments as NST Presale Gains Traction', 'Bitcoin')
# ('2025-03-25', "XRP Hits Bullish Reversal, Bitcoin Faces 'Great Reset' Risk, Mike McGlone Warns; Second Biggest SHIB Wallet Sees Mysterious Transfers: Crypto News Digest by U.Today", 'Bitcoin')
# ('2025-03-25', 'Bitcoin (BTC) Breakout? Bollinger Bands Hint at Big Upside', 'Bitcoin')
# ('2025-03-25', "Fidelity's Timmer Says Bitcoin's Wallet Count Shows Little Growth ", 'Bitcoin')
# ('2025-03-25', 'Breaking: GameStop Adopts Bitcoin as Reserve Asset', 'Bitcoin')
# ('2025-03-26', "'We Are All Satoshi': USDT Founder Reacts to News About Bitcoin Creator", 'Bitcoin')
# ('2025-03-26', 'Breaking: GameStop Raising $1.3 Billion to Buy Bitcoin', 'Bitcoin')
# ('2025-03-26', 'Bitcoin Whales With 10K BTC Holdings Increase — Supply Squeeze Incoming?', 'Bitcoin')
# ('2025-03-26', "Bitcoin Not in 'Overheated Zone' Yet: CryptoQuant", 'Bitcoin')
# ('2025-03-26', "Strategy's Saylor Challenges GameStop to Go Big on Bitcoin ", 'Bitcoin')
# ('2025-03-26', "Bitcoin (BTC) Invalidates Death Cross: What's Next?", 'Bitcoin')
# ('2025-03-26', 'Mysterious $262,759,132 Bitcoin Transfer Stuns Major US Exchange', 'Bitcoin')
# ('2025-03-26', "Legendary Angel Investor Mocks GameStop's Bitcoin Pivot", 'Bitcoin')
# ('2025-03-26', "Bitcoin (BTC) Mini-Death Cross Originates, Key XRP Breakthrough Turns to be Fakeout? Dogecoin (DOGE) Only Top Asset Didn't Do It", 'Bitcoin')
# ('2025-03-26', "Bitcoin up 700% Since Michael Saylor's Strategy's First BTC Buy", 'Bitcoin')
# ('2025-03-27', "Strategy's Saylor Joins Gihbli Trend With Bullish Bitcoin Post", 'Bitcoin')
# ('2025-03-27', 'Billionaire Cliff Asness: "I\'m Not a Bitcoin Fan\'', 'Bitcoin')
# ('2025-03-27', 'XRP vs. Bitcoin (BTC): 3 Big Scenarios From Bollinger Bands', 'Bitcoin')
# ('2025-03-27', "Peter Schiff Reacts to Bitcoin's Drop as Gold Sets Fresh Record High", 'Bitcoin')
# ('2025-03-27', 'GameStop Shares Getting Annihilated Following Bitcoin Pivot', 'Bitcoin')
# ('2025-03-27', 'US Government Moving Millions of Dollars Worth of Bitcoin', 'Bitcoin')
# ('2025-03-27', "Buying Bitcoin 'Not Viable Long-Term Business Model', Says Peter Schiff", 'Bitcoin')
# ('2025-03-28', "Fidelity Says It's 'Possible' for Bitcoin to Overtake Gold", 'Bitcoin')
# ('2025-03-28', 'Bitcoin (BTC) Loses Crucial 200-Day Moving Average Amid Inflation Report', 'Bitcoin')
# ('2025-03-28', 'Ethereum Crashes 74% Against Bitcoin; Is Reversal Imminent?', 'Bitcoin')
# ('2025-03-28', 'Schiff: Bitcoin (BTC) to Collapse to $10K', 'Bitcoin')
# ('2025-03-28', "$1.5 Billion: BlackRock Celebrates New Crypto Milestone, And It's Not Bitcoin", 'Bitcoin')
# ('2025-03-28', 'Breaking: Tether Mints 1 Billion USDT Tokens as Bitcoin Plunges Below $85K', 'Bitcoin')
# ('2025-03-28', 'Bitcoin (BTC) Major Core Update: Key Changes Revealed', 'Bitcoin')
# ('2025-03-28', 'Bitcoin (BTC) Faces Brutal Drop, Confirms Legendary Trader Peter Brandt', 'Bitcoin')
# ('2025-03-28', "'Rich Dad Poor Dad' Author Predicts New ATH for Second Best Asset to Bitcoin", 'Bitcoin')
# ('2025-03-28', "Shiba Inu (SHIB): Bulls in Control Now? Bitcoin (BTC) in Great Spot, Ethereum (ETH): Major Bearish Signal, But There's Silver Lining ", 'Bitcoin')
# ('2025-03-28', 'Bitcoin (BTC) Price Prediction for March 28', 'Bitcoin')
# ('2025-03-29', "Bitcoin Shows Bear Trap, '$1 Million BTC' Samson Mow Claims", 'Bitcoin')
# ('2025-03-29', 'Bitcoin (BTC) Bleeds, but Price History Says April Could Be Fire', 'Bitcoin')
# ('2025-03-29', "Bitcoin (BTC) Price to $72,000: Top Trader on 'Dead Cat Bounce'", 'Bitcoin')
# ('2025-03-29', '15 Years Since Huge Bitcoin Bug Satoshi Had to Fix ASAP', 'Bitcoin')
# ('2025-03-30', 'Bitcoin Magnate to Fly into Space Tomorrow', 'Bitcoin')
# ('2025-03-30', 'Bitcoin (BTC) Price Prediction for March 30', 'Bitcoin')
# ('2025-03-30', 'Bitcoin (BTC) Finds Bottom? Key Indicator Hints at Reversal', 'Bitcoin')
# ('2025-03-30', 'Mysterious $333,000,000 Bitcoin Transfer Stuns Major US Exchange', 'Bitcoin')
# ('2025-03-30', 'Bitcoin ETFs Skyrocket by $200 Million, but Worrying Catch Emerges', 'Bitcoin')
# ('2025-03-30', 'Has 20,000,000th Bitcoin Been Mined?', 'Bitcoin')
# ('2025-03-30', 'Legendary Trader Brandt Warns This Bitcoin Pattern Could Be a Trap', 'Bitcoin')
# ('2025-03-30', 'Michael Saylor Teases Another Bitcoin Mega-Buy With New Cryptic Post', 'Bitcoin')
# ('2025-03-31', 'XRP Rapidly Diving Below $2, Bitcoin (BTC) on Verge of Losing $80,000, Shiba Inu (SHIB) Loses All Breakout Gains', 'Bitcoin')
# ('2025-03-31', 'Metaplanet Issues More Debt to Buy Bitcoin', 'Bitcoin')
# ('2025-03-31', 'Spot Bitcoin ETF Inflows Down 73% in Seven Days: Details', 'Bitcoin')
# ('2025-03-31', "Bitcoin (BTC) 'Death Cross' Appears on Rare Indicator: What Happens Next?", 'Bitcoin')
# ('2025-03-31', 'Breaking: Strategy Buys Nearly $2 Billion Worth of Bitcoin', 'Bitcoin')
# ('2025-03-31', 'Litecoin (LTC) Decouples From Bitcoin in Key Metric: Details', 'Bitcoin')
