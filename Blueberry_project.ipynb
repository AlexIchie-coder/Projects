# %% [markdown]
# # MY DATA

# %%
import numpy as np
import pandas as pd
import

red_wine = pd.read_csv('winequality-red.csv', sep=';')
# Out:
#   Cell In[1081], line 3
#     import
#           ^
# SyntaxError: invalid syntax

# %%
white_wine = pd.read_csv('winequality-white.csv', sep=';')

# %%
red_wine.columns= red_wine.columns.str.replace(' ','_')
white_wine.columns = white_wine.columns.str.replace(' ','_')

# %% [markdown]
# # DATA WRANGLING

# %%
pd.concat([red_wine.describe(), white_wine.describe()], axis=1, keys=["Red Wines Stats", "White Wines Stats"])
# Out:
#       Red Wines Stats                                               \
#         fixed_acidity volatile_acidity  citric_acid residual_sugar
# count     1599.000000      1599.000000  1599.000000    1599.000000
# mean         8.319637         0.527821     0.270976       2.538806
# std          1.741096         0.179060     0.194801       1.409928
# min          4.600000         0.120000     0.000000       0.900000
# 25%          7.100000         0.390000     0.090000       1.900000
# 50%          7.900000         0.520000     0.260000       2.200000
# 75%          9.200000         0.640000     0.420000       2.600000
# max         15.900000         1.580000     1.000000      15.500000
#
#                                                                           \
#          chlorides free_sulfur_dioxide total_sulfur_dioxide      density
# count  1599.000000         1599.000000          1599.000000  1599.000000
# mean      0.087467           15.874922            46.467792     0.996747
# ...

# %%
# we are creating a new column called "quality_label", we define a range and associate that range with a label
red_wine['quality_label'] = red_wine['quality'].apply(lambda value: 'low'
if value <= 5 else 'medium'
if value <= 7 else 'high')

#here we are transforming these labels into a categorical data type (specific to pandas) instead of a simple string
red_wine['quality_label'] = pd.Categorical(red_wine['quality_label'],
categories=['low', 'medium', 'high'])

red_wine
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
print(red_wine)
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
# we are creating a new column called "quality_label", we define a range and associate that range with a label
white_wine['quality_label'] = white_wine['quality'].apply(lambda value: 'low'
if value <= 5 else 'medium'
if value <= 7 else 'high')

#here we are transforming these labels into a categorical data type (specific to pandas) instead of a simple string
white_wine['quality_label'] = pd.Categorical(white_wine['quality_label'],
categories=['low', 'medium', 'high'])

white_wine
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
print(white_wine)
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
red_wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed_acidity         1599 non-null   float64
#  1   volatile_acidity      1599 non-null   float64
#  2   citric_acid           1599 non-null   float64
#  3   residual_sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free_sulfur_dioxide   1599 non-null   float64
#  6   total_sulfur_dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
#  12  quality_label         1599 non-null   category
# dtypes: category(1), float64(11), int64(1)
# memory usage: 151.7 KB

# %%
white_wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed_acidity         4898 non-null   float64
#  1   volatile_acidity      4898 non-null   float64
#  2   citric_acid           4898 non-null   float64
#  3   residual_sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free_sulfur_dioxide   4898 non-null   float64
#  6   total_sulfur_dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
#  12  quality_label         4898 non-null   category
# dtypes: category(1), float64(11), int64(1)
# memory usage: 464.2 KB

# %%
red_wine.shape
# Out:
# (1599, 13)

# %%
white_wine.shape
# Out:
# (4898, 13)

# %%
red_wine.isna().any()
# Out:
# fixed_acidity           False
# volatile_acidity        False
# citric_acid             False
# residual_sugar          False
# chlorides               False
# free_sulfur_dioxide     False
# total_sulfur_dioxide    False
# density                 False
# pH                      False
# sulphates               False
# alcohol                 False
# quality                 False
# quality_label           False
# dtype: bool

# %%
white_wine.isna().any()
# Out:
# fixed_acidity           False
# volatile_acidity        False
# citric_acid             False
# residual_sugar          False
# chlorides               False
# free_sulfur_dioxide     False
# total_sulfur_dioxide    False
# density                 False
# pH                      False
# sulphates               False
# alcohol                 False
# quality                 False
# quality_label           False
# dtype: bool

# %%
red_wine.describe().round(2)
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# count        1599.00           1599.00      1599.00         1599.00
# mean            8.32              0.53         0.27            2.54
# std             1.74              0.18         0.19            1.41
# min             4.60              0.12         0.00            0.90
# 25%             7.10              0.39         0.09            1.90
# 50%             7.90              0.52         0.26            2.20
# 75%             9.20              0.64         0.42            2.60
# max            15.90              1.58         1.00           15.50
#
#        chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density       pH  \
# count    1599.00              1599.00               1599.00  1599.00  1599.00
# mean        0.09                15.87                 46.47     1.00     3.31
# std         0.05                10.46                 32.90     0.00     0.15
# ...

# %%
white_wine.describe().round(2)
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# count        4898.00           4898.00      4898.00         4898.00
# mean            6.85              0.28         0.33            6.39
# std             0.84              0.10         0.12            5.07
# min             3.80              0.08         0.00            0.60
# 25%             6.30              0.21         0.27            1.70
# 50%             6.80              0.26         0.32            5.20
# 75%             7.30              0.32         0.39            9.90
# max            14.20              1.10         1.66           65.80
#
#        chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density       pH  \
# count    4898.00              4898.00               4898.00  4898.00  4898.00
# mean        0.05                35.31                138.36     0.99     3.19
# std         0.02                17.01                 42.50     0.00     0.15
# ...

# %%
red_wine ['quality_label'] = red_wine['quality'].apply(lambda value: 'low' if value <= 5 
                                                        else 'medium' if value <= 7 
                                                        else 'high')

red_wine['quality_label'] = pd.Categorical(red_wine['quality_label'],
categories=['low', 'medium', 'high'])

white_wine ['quality_label'] = white_wine['quality'].apply(lambda value: 'low' if value <= 5 
                                                        else 'medium' if value <= 7 
                                                        else 'high')

white_wine["quality_label"] = pd.Categorical(white_wine["quality_label"], categories = ["low","medium","high"])

# %%
red_wine ["type"] = 'Red Wine'
red_wine['type'] = pd.Categorical(red_wine['type'],
categories=["Red Wine","White Wine"])

white_wine ["type"] = 'White Wine'
white_wine['type'] = pd.Categorical(white_wine['type'],
categories=["Red Wine","White Wine"])

# %% [markdown]
# # MERGED DATASETS

# %%
white_and_red = pd.merge(red_wine, white_wine, how = "outer")
white_and_red.head(10)
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            3.8             0.310         0.02           11.10      0.036
# 1            3.9             0.225         0.40            4.20      0.030
# 2            4.2             0.170         0.36            1.80      0.029
# 3            4.2             0.215         0.23            5.10      0.041
# 4            4.4             0.320         0.39            4.30      0.030
# 5            4.4             0.460         0.10            2.80      0.024
# 6            4.4             0.540         0.09            5.10      0.038
# 7            4.5             0.190         0.21            0.95      0.033
# 8            4.6             0.445         0.00            1.40      0.053
# 9            4.6             0.520         0.15            2.10      0.054
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# ...

# %%
white_and_red.duplicated().sum()
# Out:
# np.int64(1177)

# %% [markdown]
# # STRING COL

# %%
string_col = white_and_red.select_dtypes(include="object").columns

# %%
white_and_red[string_col].head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
for col in string_col:
    print(f"The distribution of categorical values in the {col} is : ")
    print(white_and_red[col].value_counts())

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
white_and_red['type'] = le.fit_transform(white_and_red['type'])

white_and_red['type'].head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: type, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
white_and_red['type'] = le.fit_transform(white_and_red['type'])

white_and_red['type'].tail()
# Out:
# 6492    0
# 6493    0
# 6494    0
# 6495    0
# 6496    0
# Name: type, dtype: int64

# %% [markdown]
# # INTERQUARTILE

# %%
numeric_white_and_red = white_and_red.select_dtypes(include="float64")

# %%
q1= numeric_white_and_red.quantile(0.25)
q1
# Out:
# fixed_acidity            6.40000
# volatile_acidity         0.23000
# citric_acid              0.25000
# residual_sugar           1.80000
# chlorides                0.03800
# free_sulfur_dioxide     17.00000
# total_sulfur_dioxide    77.00000
# density                  0.99234
# pH                       3.11000
# sulphates                0.43000
# alcohol                  9.50000
# Name: 0.25, dtype: float64

# %%
q3 = numeric_white_red.quantile(0.75)
q3
# Out:
# fixed_acidity             7.70000
# volatile_acidity          0.40000
# citric_acid               0.39000
# residual_sugar            8.10000
# chlorides                 0.06500
# free_sulfur_dioxide      41.00000
# total_sulfur_dioxide    156.00000
# density                   0.99699
# pH                        3.32000
# sulphates                 0.60000
# alcohol                  11.30000
# Name: 0.75, dtype: float64

# %%
Q1 = numeric_white_and_red.quantile(0.25)
Q3 = numeric_white_and_red.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# fixed_acidity            1.30000
# volatile_acidity         0.17000
# citric_acid              0.14000
# residual_sugar           6.30000
# chlorides                0.02700
# free_sulfur_dioxide     24.00000
# total_sulfur_dioxide    79.00000
# density                  0.00465
# pH                       0.21000
# sulphates                0.17000
# alcohol                  1.80000
# dtype: float64

# %%
print(numeric_white_and_red < (Q1 - 1.5 * IQR)) |(numeric_white_and_red> (Q3 + 1.5 * IQR))
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0              True             False         True           False      False
# 1              True             False        False           False      False
# 2              True             False        False           False      False
# 3              True             False        False           False      False
# 4              True             False        False           False      False
# ...             ...               ...          ...             ...        ...
# 6492          False             False        False           False      False
# 6493          False             False        False           False      False
# 6494          False             False        False           False      False
# 6495          False             False        False           False      False
# 6496          False             False        False           False      False
#
# ...

# %%
print(numeric_white_and_red.skew())
numeric_white_and_red.describe()
# Out:
# fixed_acidity           1.723290
# volatile_acidity        1.495097
# citric_acid             0.471731
# residual_sugar          1.435404
# chlorides               5.399828
# free_sulfur_dioxide     1.220066
# total_sulfur_dioxide   -0.001177
# density                 0.503602
# pH                      0.386839
# sulphates               1.797270
# alcohol                 0.565718
# dtype: float64
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# count    6497.000000       6497.000000  6497.000000     6497.000000
# mean        7.215307          0.339666     0.318633        5.443235
# std         1.296434          0.164636     0.145318        4.757804
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# ...

# %%
print(numeric_white_and_red['total_sulfur_dioxide'].quantile(0.10))
print(numeric_white_and_red['total_sulfur_dioxide'].quantile(0.90))
# Out:
# 30.0
# 188.0

# %%
index = white_and_red[(white_and_red['total_sulfur_dioxide'] >= 100)|(white_and_red['total_sulfur_dioxide'] <= 18)].index
white_and_red.drop(index, inplace=True)
white_and_red['total_sulfur_dioxide'].describe()
# Out:
# count    2050.000000
# mean       61.457073
# std        25.752115
# min        19.000000
# 25%        37.000000
# 50%        64.000000
# 75%        86.000000
# max        99.000000
# Name: total_sulfur_dioxide, dtype: float64

# %%
numeric_white_and_red_out = numeric_white_and_red[~((numeric_white_and_red < (Q1 - 1.5 * IQR)) |(numeric_white_and_red > (Q3 + 1.5 * IQR))).any(axis=1)]
print(numeric_white_and_red_out.shape)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1135], line 1
# ----> 1 numeric_white_and_red_out = numeric_white_and_red[~((numeric_white_and_red < (Q1 - 1.5 * IQR)) |(numeric_white_and_red > (Q3 + 1.5 * IQR))).any(axis=1)]
#       2 print(numeric_white_and_red_out.shape)
#
# File ~/anaconda3/envs/Experience/lib/python3.12/site-packages/pandas/core/generic.py:2171, in NDFrame.__array_ufunc__(self, ufunc, method, *inputs, **kwargs)
#    2167 @final
#    2168 def __array_ufunc__(
#    2169     self, ufunc: np.ufunc, method: str, *inputs: Any, **kwargs: Any
#    2170 ):
# -> 2171     return arraylike.array_ufunc(self, ufunc, method, *inputs, **kwargs)
#
# File ~/anaconda3/envs/Experience/lib/python3.12/site-packages/pandas/core/arraylike.py:276, in array_ufunc(self, ufunc, method, *inputs, **kwargs)
#     273 kwargs = _standardize_out_kwarg(**kwargs)
# ...

# %% [markdown]
# # LABEL ENCODER

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
white_and_red['type'] = le.fit_transform(white_and_red['type'])

white_and_red['type'].head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: type, dtype: int64

# %%
white_and_red['type'].tail()
# Out:
# 6492    0
# 6493    0
# 6494    0
# 6495    0
# 6496    0
# Name: type, dtype: int64

# %% [markdown]
# # HEATMAP

# %%
import matplotlib.pyplot as plt

import seaborn as sns

# %%
plt.figure(figsize=(8,8))
numeric_colums =white_and_red.select_dtypes(include=['float64', 'int64'])
corr= numeric_colums.corr()
#matrix = np.triu(corr)

# creating mask 
mask = np.triu(np.ones_like(corr))

# plotting a triangle correlation heatmap 
dataplot = sns.heatmap(corr, cmap="coolwarm", annot=True, mask=mask, fmt='.2f')

# %% [markdown]
# # split data

# %%
from sklearn.model_selection import train_test_split

X = white_and_red.drop(['type','quality_label', 'quality'], axis=1)
y = white_and_redl['type']


print("original:", white_and_red.shape, "\nX:", X.shape, "\ny:", y.shape)
# Out:
# original: (6497, 14)
# X: (6497, 11)
# y: (6497,)

# %%
X
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               3.8             0.310         0.02            11.1      0.036
# 1               3.9             0.225         0.40             4.2      0.030
# 2               4.2             0.170         0.36             1.8      0.029
# 3               4.2             0.215         0.23             5.1      0.041
# 4               4.4             0.320         0.39             4.3      0.030
# ...             ...               ...          ...             ...        ...
# 6492           15.5             0.645         0.49             4.2      0.095
# 6493           15.5             0.645         0.49             4.2      0.095
# 6494           15.6             0.645         0.49             4.2      0.095
# 6495           15.6             0.685         0.76             3.7      0.100
# 6496           15.9             0.360         0.65             7.5      0.096
#
# ...

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

LR_model = LogisticRegression(max_iter=700)

# %%
LR_model.fit(x_train, y_train)
# Out:
# LogisticRegression(max_iter=700)

# %%
preds = LR_model.predict(x_test)
preds
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
y_test
# Out:
# 3103    1
# 1419    1
# 4761    1
# 4690    1
# 4032    1
#        ..
# 889     1
# 2850    1
# 4917    1
# 5198    1
# 5643    1
# Name: type, Length: 1300, dtype: int64

# %%
from sklearn.metrics import accuracy_score 

acc = accuracy_score(y_test, preds)
acc
# Out:
# 0.9861538461538462

# %% [markdown]
# RandomForest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
RF_clf = RandomForestClassifier()

# %%
RF_clf.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
preds = RF_clf.predict(x_test)
preds
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
acc = accuracy_score(y_test, preds)
acc
# Out:
# 0.9976923076923077
