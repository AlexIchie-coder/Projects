# %%
import numpy as np
import pandas as pd

red_wine = pd.read_csv('winequality-red.csv', sep=';')

# %%
#import numpy as np
#import pandas as pd

white_wine = pd.read_csv('winequality-white.csv', sep=';')

# %% [markdown]
# # DATA WRANGLING

# %%
pd.concat([red_wine.describe(), white_wine.describe()], axis=1, keys=["Red Wines Stats", "White Wines Stats"])
# Out:
#       Red Wines Stats                                               \
#         fixed acidity volatile acidity  citric acid residual sugar
# count     1599.000000      1599.000000  1599.000000    1599.000000
# mean         8.319637         0.527821     0.270976       2.538806
# std          1.741096         0.179060     0.194801       1.409928
# min          4.600000         0.120000     0.000000       0.900000
# 25%          7.100000         0.390000     0.090000       1.900000
# 50%          7.900000         0.520000     0.260000       2.200000
# 75%          9.200000         0.640000     0.420000       2.600000
# max         15.900000         1.580000     1.000000      15.500000
#
#                                                                           \
#          chlorides free sulfur dioxide total sulfur dioxide      density
# count  1599.000000         1599.000000          1599.000000  1599.000000
# mean      0.087467           15.874922            46.467792     0.996747
# ...

# %%
# we are creating a new column called "quality_label", we define a range and associate that range with a label
red_wine['quality_label'] = red_wine['quality'].apply(lambda value: 'low'
if value <= 5 else 'medium'
if value <= 7 else 'high')

#here we are transforming these labels into a categorical data type (specific to pandas) instead of a simple string
red_wine['quality_label'] = pd.Categorical(red_wine['quality_label'],
categories=['low', 'medium', 'high'])

red_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
print(red_wine)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
# we are creating a new column called "quality_label", we define a range and associate that range with a label
white_wine['quality_label'] = white_wine['quality'].apply(lambda value: 'low'
if value <= 5 else 'medium'
if value <= 7 else 'high')

#here we are transforming these labels into a categorical data type (specific to pandas) instead of a simple string
white_wine['quality_label'] = pd.Categorical(white_wine['quality_label'],
categories=['low', 'medium', 'high'])

white_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
red_wine ['quality_label'] = red_wine['quality'].apply(lambda value: 'low' if value <= 5 
                                                        else 'medium' if value <= 7 
                                                        else 'high')

red_wine['quality_label'] = pd.Categorical(red_wine['quality_label'],
categories=['low', 'medium', 'high'])

# %%
red_wine ["type"] = 'Red Wine'
red_wine['type'] = pd.Categorical(red_wine['type'],
categories=["Red Wine","White Wine"])

white_wine ["type"] = 'White Wine'
white_wine['type'] = pd.Categorical(white_wine['type'],
categories=["Red Wine","White Wine"])

# %%
print(white_wine)
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
red_wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed_acidity         1599 non-null   float64
#  1   volatile_acidity      1599 non-null   float64
#  2   citric_acid           1599 non-null   float64
#  3   residual_sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free_sulfur_dioxide   1599 non-null   float64
#  6   total_sulfur_dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
#  12  quality_label         1599 non-null   category
#  13  type                  1599 non-null   category
# ...

# %%
white_wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed_acidity         4898 non-null   float64
#  1   volatile_acidity      4898 non-null   float64
#  2   citric_acid           4898 non-null   float64
#  3   residual_sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free_sulfur_dioxide   4898 non-null   float64
#  6   total_sulfur_dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
#  12  quality_label         4898 non-null   category
#  13  type                  4898 non-null   category
# ...

# %%
red_wine.shape
# Out:
# (1599, 14)

# %%
white_wine.shape
# Out:
# (4898, 14)

# %% [markdown]
# ## Formatting

# %%
red_wine.columns= red_wine.columns.str.replace(' ','_')
white_wine.columns = white_wine.columns.str.replace(' ','_')

# %% [markdown]
# ## NULL VALUES

# %%
white_wine.isna().any()
# Out:
# fixed_acidity           False
# volatile_acidity        False
# citric_acid             False
# residual_sugar          False
# chlorides               False
# free_sulfur_dioxide     False
# total_sulfur_dioxide    False
# density                 False
# pH                      False
# sulphates               False
# alcohol                 False
# quality                 False
# quality_label           False
# type                    False
# dtype: bool

# %%
red_wine.isna().any()
# Out:
# fixed_acidity           False
# volatile_acidity        False
# citric_acid             False
# residual_sugar          False
# chlorides               False
# free_sulfur_dioxide     False
# total_sulfur_dioxide    False
# density                 False
# pH                      False
# sulphates               False
# alcohol                 False
# quality                 False
# quality_label           False
# type                    False
# dtype: bool

# %% [markdown]
# ## DESCRIPTIVE STADISTICS

# %%
red_wine.describe().round(2)
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# count        1599.00           1599.00      1599.00         1599.00
# mean            8.32              0.53         0.27            2.54
# std             1.74              0.18         0.19            1.41
# min             4.60              0.12         0.00            0.90
# 25%             7.10              0.39         0.09            1.90
# 50%             7.90              0.52         0.26            2.20
# 75%             9.20              0.64         0.42            2.60
# max            15.90              1.58         1.00           15.50
#
#        chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density       pH  \
# count    1599.00              1599.00               1599.00  1599.00  1599.00
# mean        0.09                15.87                 46.47     1.00     3.31
# std         0.05                10.46                 32.90     0.00     0.15
# ...

# %%
white_wine.describe().round(2)
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# count        4898.00           4898.00      4898.00         4898.00
# mean            6.85              0.28         0.33            6.39
# std             0.84              0.10         0.12            5.07
# min             3.80              0.08         0.00            0.60
# 25%             6.30              0.21         0.27            1.70
# 50%             6.80              0.26         0.32            5.20
# 75%             7.30              0.32         0.39            9.90
# max            14.20              1.10         1.66           65.80
#
#        chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density       pH  \
# count    4898.00              4898.00               4898.00  4898.00  4898.00
# mean        0.05                35.31                138.36     0.99     3.19
# std         0.02                17.01                 42.50     0.00     0.15
# ...

# %% [markdown]
# # MERGE DATA

# %%
white_and_red = pd.merge(red_wine, white_wine, how = "outer")
white_and_red.head(10)
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            3.8             0.310         0.02           11.10      0.036
# 1            3.9             0.225         0.40            4.20      0.030
# 2            4.2             0.170         0.36            1.80      0.029
# 3            4.2             0.215         0.23            5.10      0.041
# 4            4.4             0.320         0.39            4.30      0.030
# 5            4.4             0.460         0.10            2.80      0.024
# 6            4.4             0.540         0.09            5.10      0.038
# 7            4.5             0.190         0.21            0.95      0.033
# 8            4.6             0.445         0.00            1.40      0.053
# 9            4.6             0.520         0.15            2.10      0.054
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# ...

# %% [markdown]
# # Exploratory Analysis

# %% [markdown]
# ## CONCAT

# %%
white_and_red_concat = pd.concat([red_wine[["residual_sugar","total_sulfur_dioxide", "sulphates", "alcohol","volatile_acidity","quality"]].describe(), 
            white_wine[["residual_sugar","total_sulfur_dioxide", "sulphates", "alcohol","volatile_acidity","quality"]].describe()], 
            axis=1, 
            keys=["Red Wines Stats", "White Wines Stats"])

white_and_red_concat.round(2)
# Out:
#       Red Wines Stats                                          \
#        residual_sugar total_sulfur_dioxide sulphates  alcohol
# count         1599.00              1599.00   1599.00  1599.00
# mean             2.54                46.47      0.66    10.42
# std              1.41                32.90      0.17     1.07
# min              0.90                 6.00      0.33     8.40
# 25%              1.90                22.00      0.55     9.50
# 50%              2.20                38.00      0.62    10.20
# 75%              2.60                62.00      0.73    11.10
# max             15.50               289.00      2.00    14.90
#
#                                 White Wines Stats                       \
#       volatile_acidity  quality    residual_sugar total_sulfur_dioxide
# count          1599.00  1599.00           4898.00              4898.00
# mean              0.53     5.64              6.39               138.36
# ...

# %%
import matplotlib.pyplot as plt

import seaborn as sns

# %%
fig, pie_lst = plt.subplots(1)
fig.tight_layout()

labels = 'Red Wine', 'White Wine'
quality_count = [1599, 4898]

pie_lst.pie(quality_count, labels=labels, autopct='%1.0f%%')
pie_lst.set_title('Wine Quality')
# Out:
# Text(0.5, 1.0, 'Wine Quality')

# %%
fig, ax = plt.subplots(1,2, sharey=True)
#fig.tight_layout()
fig.suptitle('Distribution of Quality Score')


sns.histplot(red_wine['quality_label'],  ax=ax[0], color='red', shrink=0.7)
ax[0].set_title( 'Red Wine')
ax[1].set_title( 'White Wine')
sns.histplot(white_wine['quality_label'],  ax=ax[1], color='grey' , shrink=0.7)

# plt.xlabel('Quality Score')
# plt.ylabel('Frequency')
# plt.title('Distribution of Quality Scores') 
#äplt.xlabel('Quality Score')
# plt.ylabel('Frequency')
# plt.title('Distribution of Quality Scores
# Out:
# <Axes: title={'center': 'White Wine'}, xlabel='quality_label', ylabel='Count'>

# %% [markdown]
# # quality scores with seaborn

# %%
grid3 = sns.FacetGrid (white_and_red, col= "type")
grid3.map(sns.histplot, "quality_label")

# %%
fig, ax = plt.subplots(1,2)
fig.set_figwidth(12)
#fig.tight_layout()
fig.suptitle('White Wine Quality - Ahcohol Content/PH')

#ax[0].set_title( 'Red Wine')
sns.boxplot(white_wine,  ax=ax[0], x='quality_label', y="pH", hue='quality_label')
#ax[1].set_title( 'White Wine')
sns.boxplot(white_wine, ax=ax[1],x='quality_label' ,y='alcohol', hue='quality_label')
# Out:
# <Axes: xlabel='quality_label', ylabel='alcohol'>

# %%
fig, ax = plt.subplots(1,2)
fig.set_figwidth(12)
#fig.tight_layout()
fig.suptitle('Red Wine Quality - Ahcohol Content/PH')

#ax[0].set_title( 'Red Wine')
sns.boxplot(red_wine,  ax=ax[0], x='quality_label', y="pH", hue='quality_label')
#ax[1].set_title( 'Red Wine')
sns.boxplot(red_wine, ax=ax[1],x='quality_label' ,y='alcohol', hue='quality_label')
# Out:
# <Axes: xlabel='quality_label', ylabel='alcohol'>

# %% [markdown]
# ## sulphates/residual sugar/alcohol/fixed acidity/ type of wine

# %%
variables = ["sulphates", "residual_sugar","alcohol", "fixed_acidity"]
g = sns.PairGrid(white_and_red, hue="type", vars=variables)
g.map_diag(sns.histplot, hue=None, color=".3")
g.map_offdiag(sns.scatterplot)
g.add_legend()

# %% [markdown]
# ## ph/alcohol - type/quality Lmplot (regression model)

# %%
sns.lmplot(x= 'pH', y= 'alcohol', data = white_and_red, col = 'type', row = "quality_label")

# %% [markdown]
# ## Residual sugar content / type of wine histogram

# %%
fig, ax =plt.subplots(1,2, sharey=True, constrained_layout=True)
plt.margins(x=0,y=0)
# fig.tight_layout()
fig.suptitle("Residual Sugar Content in Wine")
ax[1].set_title("White Wine")
ax[0].set_title("Red Wine")
ax[0].set_xlim([0, 15.0])
ax[1].set_xlim([0, 60])
ax[0].autoscale(tight = True)




white_wines_hist = sns.histplot(white_wine["residual_sugar"], ax=ax[1], color= "g", bins = 12)
red_wines_hist = sns.histplot(red_wine['residual_sugar'], ax=ax[0], color = "r", bins = 12)

# %% [markdown]
# ## Alcohol content / type of wine histogram

# %%
fig, ax = plt.subplots(1,2, sharey = True)  
fig.suptitle("Alcohol Content in Wine")
ax[1].set_title("White Wine")
ax[0].set_title("Red Wine")
sns.histplot(red_wine["alcohol"], ax = ax[0], color = "r" )
sns.histplot(white_wine["alcohol"], ax = ax[1], color = "g" )
# Out:
# <Axes: title={'center': 'White Wine'}, xlabel='alcohol', ylabel='Count'>

# %% [markdown]
# ## Value counts for wine quality score

# %%
white_and_red['quality'].value_counts().sort_index().plot.bar()
# Out:
# <Axes: xlabel='quality'>

# %%
white_and_red['quality'].value_counts().sort_index().plot.line()
# Out:
# <Axes: xlabel='quality'>

# %% [markdown]
# ## Comparisons between types of wine

# %% [markdown]
# ## fixed acidity

# %%
plt.rcParams["figure.figsize"] = [7.50, 3.50]
plt.rcParams["figure.autolayout"] = True

x_red_median = np.median(red_wine["fixed_acidity"])
x_red_mean =np.mean(red_wine["fixed_acidity"])
# k = sns.kdeplot(x=white_and_red["volatile_acidity"], shade=True)
x_white_median = np.median(white_wine["fixed_acidity"])
x_white_mean =np.mean(white_wine["fixed_acidity"])

grid9 = sns.FacetGrid(white_and_red, col= "type", height = 5, aspect =1)
grid9.map(sns.kdeplot, "fixed_acidity", fill= True)
grid9.add_legend()
grid9.figure.suptitle ("Fixed Acidity ")
grid9.axes[0,0].set_xlabel('Fixed Acidity g/dm3')
grid9.axes[0,1].set_xlabel('Fixed Acidity g/dm3')
grid9.axes[0,0].set_ylabel('Count')
axes = grid9.axes.flatten() 
axes[0].set_title("Red Wine")
axes[1].set_title("White Wine")
axes[0].axvline(x_red_mean, c='green')
axes[0].axvline(x_red_median, c='k', ls = "--", lw=2)
axes[1].axvline(x_white_mean, c='green')
axes[1].axvline(x_white_median, c='k', ls = "--", lw=2)

# %% [markdown]
# ## HeatMap

# %%
white_and_red_drop = white_and_red.drop(["quality_label", "type"], axis = 1)

# %%
corr = white_and_red_drop.corr()
matrix = np.triu(corr)
heatmap_wines = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(220, 20, n=256),
    square=True,
    annot = True,
    mask =  matrix
)
heatmap_wines.set_xticklabels(
    heatmap_wines.get_xticklabels(),
    rotation=45,
    horizontalalignment='right')

sns.set_theme(rc = {'figure.figsize':(15,8)})

# %% [markdown]
# Overall, the relationship between chlorides and density in red wine from the Vinho Verde region is complex and influenced by various factors, including terroir, grape variety, and alcohol content.
#
# Chlorides: Influence the quality and taste of red wine, with high levels leading to an undesirable salty taste
# Density: Inversely related to alcohol content, with lower density wines having higher alcohol content
# Vinho Verde Region: Known for its red wines, with varying levels of chlorides and density depending on terroir and grape variety
# Terroir: Influences the concentration of chlorides in red wines, with different regions having distinct levels of chlorides
# Grape Variety: Also influences the concentration of chlorides in red wines, with some varieties having higher levels than others

# %%
sns.lmplot( x= 'alcohol',y='density', data = red_wine, col = 'quality_label')

# %% [markdown]
# The correlation between chloride levels and quality is more pronounced for white wines, where chloride levels have a correlation larger than 0.2 with quality, indicating a more significant impact on white wine quality compared to red wines.
#
# In the Vinho Verde region’s white wine, chlorides and density are two important physicochemical properties that influence wine quality.
#
# The data shows that as the amount of chlorides increases, the perceived quality of the wine tends to decline.

# %%
sns.lmplot(x='alcohol', y='density', data = white_wine, col = 'quality_label')

# %% [markdown]
# Density and residual sugar are two crucial parameters in wine production and quality assessment.
#
# Residual Sugar:
# Measured in units of grams per liter (g/L) or grams per 100 milliliters (g/100mL)
# Refers to the amount of unfermented sugars remaining in the wine after fermentation
# Influenced by factors like grape variety, ripeness, fermentation conditions, and yeast strain
# Higher residual sugar levels typically indicate a sweeter wine, while lower levels indicate a drier wine
# Residual sugar can also affect the wine’s overall balance, with high levels potentially masking acidity and tannins
#
#
# Density:
#
# -Influenced by factors like grape variety, ripeness, fermentation conditions, and aging
#
# -Higher density typically indicates a wine with more solids and potentially more tannins and acidity
#
# -Lower density may indicate a wine with more water and potentially less tannins and acidity

# %% [markdown]
# Red Wine (Residual Sugar)
#
# -Residual sugar levels in red wine are not always directly correlated with perceived sweetness, as other factors like acidity, tannins, and fruit flavors influence the overall taste experience.
#
# -Dry red wines can still have some residual sugar, while sweet red wines may have very little.
#
# Red Wine (Density)
#
# -It’s worth noting that the density of wine can range from 980 to 1020 kg/m³, with red wines typically having a higher density due to their higher alcohol and tannin content.

# %%
# Create a figure with two subplots
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(8, 6))

sns.kdeplot(red_wine["residual sugar"], fill=True, ax=ax1)
ax1.set_xlabel("Residual Sugar")
ax1.set_ylabel("Density")
ax1.set_title("Red Wine - Density of Residual Sugar")

# Bottom subplot: Residual plot
sns.residplot(x="density", y="residual sugar", data=red_wine, ax=ax2)
ax2.set_xlabel("density")
ax2.set_ylabel("Residual")
ax2.set_title("Residual Plot")

plt.tight_layout()
plt.show()

# %% [markdown]
# White Wine (Residual Sugar)
#
# -Residual sugar levels in white wine vary significantly across styles and regions.(In Portugal)
#
# -Dry white wines typically have RS levels below 2 g/L, while off-dry and sweet wines have higher levels.
#
#
# White Wine (Density)
#
# -Density has a moderate impact on white wine quality. Higher density wines tend to have a richer mouthfeel and more full-bodied character, while lower density wines may appear lighter and more crisp.

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(8, 6))

sns.kdeplot(white_wine["residual sugar"], fill=True, ax=ax1)
ax1.set_xlabel("Residual Sugar")
ax1.set_ylabel("Density")
ax1.set_title("White Wine - Density of Residual Sugar")

# Bottom subplot: Residual plot
sns.residplot( x="density", y="residual sugar", data=white_wine, ax=ax2)
ax2.set_xlabel("density")
ax2.set_ylabel("Residual")
ax2.set_title("Residual Plot")

plt.tight_layout()
plt.show()

# %%
#sns.histplot(x=red_wine['density'], y=red_wine['alcohol'])
#plt.title('Density vs. Alcohol Content')
#plt.xlabel('Density (g/mL)')
#plt.ylabel('Alcohol Content (%)')
#plt.show()

sns.set()

plt.figure(figsize=(10, 8))
plt.title()
sns.pairplot(red_wine[["free sulfur dioxide", "total sulfur dioxide"]], diag_kind="hist")
#plt.title('Correlation between Density and Alcohol Content in Red Wine')
plt.show()

# %%
#sns.histplot(x=white_wine['density'], y=white_wine['alcohol'])
#plt.title('Density vs. Alcohol Content')
#plt.xlabel('Density (g/mL)')
#plt.ylabel('Alcohol Content (%)')
#plt.show()

sns.set()

plt.figure(figsize=(10, 8))
sns.pairplot(white_wine[["free sulfur dioxide", "total sulfur dioxide"]], diag_kind="hist")
#plt.title('Correlation between Density and Alcohol Content in Red Wine')
plt.show()

# %% [markdown]
# Soil and climate factors can also impact residual sugar and sulfur levels in Portuguese wine. For instance:
#
# Wines from limestone-rich soils, like those found in the Douro Valley, may have higher mineral content and potentially lower residual sugar levels.
# Wines from warmer and sunnier regions, like the Alentejo, may have higher sugar levels due to more intense ripening.
# Cooler and more humid regions, like Vinho Verde, may produce wines with lower sugar levels and higher acidity.

# %% [markdown]
# In the Vinho Verde region, fixed acidity and citric acid are important components in red wine that contribute to its overall quality and taste.
#
# Fixed acidity, primarily composed of tartaric acid, is a non-volatile acid that does not evaporate readily. It is crucial for the wine’s structure and balance. In the dataset related to Vinho Verde red wines,the fixed acidity ranges from a minimum of 4.60 g/dm³ to a maximum of 15.90 g/dm³, with a mean of 8.32 g/dm³.
#
# citric acid, found in small quantities, adds freshness and flavor to wines. It is one of the acids that can be present in wine naturally or added during the winemaking process. In the dataset, citric acid levels range from 0.00 g/dm³ to 0.56 g/dm³
#
# Both fixed acidity and citric acid have a positive correlation with the quality of red wines. Higher levels of these acids are generally associated with better quality ratings. The correlation between citric acid and fixed acidity is particularly strong, with a correlation coefficient of 0.672, indicating that wines with higher citric acid content tend to also have higher fixed acidity levels.
#
# fixed acidity and citric acid play significant roles in determining the quality and taste of Vinho Verde red wines

# %%
sns.jointplot(x='fixed acidity', y='citric acid', data=red_wine, kind='scatter', marginal_kws=dict(bins=15, fill=True))
plt.show()

# %%
sns.jointplot(x='fixed acidity', y='citric acid', data=white_wine, kind='scatter', marginal_kws=dict(bins=15, fill=True))
plt.show()

# %%
sns.set()
sns.jointplot(x='fixed acidity', y='density', data=red_wine, kind='hex')
plt.show()

# %%
sns.set()
sns.jointplot(x='fixed acidity', y='density', data=white_wine, kind='hex')
plt.show()

# %%
g = sns.FacetGrid(white_wine, col="quality_label", hue="quality_label")
g.map_dataframe(sns.scatterplot, x="density", y="alcohol")
g.add_legend()

# %%
sns.relplot(data=red_wine,y="Density",x="total_sulfur_dioxide_g/dm3", hue="quality_label", col="quality_label")

# %%
g = sns.FacetGrid(red_wine,  col="quality_label")
g.map_dataframe(sns.histplot, x="alcohol")

# %%
g = sns.FacetGrid(white_wine,  col="quality_label")
g.map_dataframe(sns.histplot, x="alcohol")
